# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (0.14.5)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from statsmodels) (2.2.5)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from statsmodels) (1.15.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from statsmodels) (2.2.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)

# %%
! pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from seaborn) (2.2.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import os
from pathlib import Path

# %% [markdown]
# ## Setting the path to input files

# %%
import os
from singscore.singscore import *

BASE_DIR = os.getcwd()   # current working directory
print(BASE_DIR)

entrez_sample_path = os.path.normpath('{}/{}'.format(BASE_DIR,
                                'singscore_new_code/UK65_clean_gene_log_tpm.txt'))

sig_path = os.path.normpath('{}/{}'.format(BASE_DIR,
                                'singscore/test/test_sigs/tgfb_upDown.txt'))
# Out:
# d:\GS\PySingscore_replicate

# %% [markdown]
# ## Reading the data

# %%
data = pandas.read_csv(open(entrez_sample_path, 'r'), header=
'infer', sep='\t')
data = data.set_index(keys='GeneName')
data
# Out:
#                log2_TPM
# GeneName
# 7SK           17.004583
# A1BG           5.457517
# A1BG-AS1       7.251618
# A1CF           1.187320
# A2M            8.725599
# ...                 ...
# ZYG11B         4.011921
# ZYX            7.907273
# ZZEF1          6.529184
# ZZZ3           8.051912
# hsa-mir-1253   4.325359
#
# [24510 rows x 1 columns]

# %% [markdown]
# # prepare signatures

# %% [markdown]
# ### seperating the aanotated up and downregulated genes

# %%
#  up= pandas.read_csv("singscore_new_code/FOROUTAN_PRODRANK_TGFB_EMT_UP.txt", sep="\t",header=None)
#  up= up[0].to_list()
#  up
# Out:
# ['ABCA1',
#  'ACKR3',
#  'ACTN1',
#  'ADAM12',
#  'ADAM19',
#  'ADAMTS6',
#  'AKT3',
#  'ALOX5AP',
#  'AMIGO2',
#  'ANGPTL4',
#  'ANKLE2',
#  'AP1S2',
#  'APBB2',
#  'ARFGAP1',
#  'ARHGEF40',
#  'BHLHE40',
#  'BMAL1',
#  'BMP1',
#  'BMP2',
#  'BMPR2',
#  'BPGM',
#  'C3orf52',
#  'CALD1',
#  'CCN2',
#  'CD59',
#  'CDH11',
#  'CDH2',
#  'CDK14',
#  'CHRNA9',
#  'CHST11',
#  'COL1A1',
#  'COL4A1',
#  'COL4A2',
#  'COL5A1',
#  'COL7A1',
#  'CRLF1',
#  'CYTH1',
#  'DAAM1',
#  'DACT1',
#  'DHRS2',
#  'DIXDC1',
#  'DLC1',
#  'DOCK4',
#  'DSE',
#  'DUSP10',
#  'ELK3',
#  'EML1',
#  'EPHB2',
#  'ETS2',
#  'FAM114A1',
#  'FBN1',
#  'FERMT2',
#  'FHOD3',
#  'FN1',
#  'FOXD1',
#  'FSTL3',
#  'GADD45B',
#  'GAL',
#  'GALNT10',
#  'GASK1B',
#  'GFPT2',
#  'GLIPR1',
#  'GNG11',
#  'GRB10',
#  'GREM1',
#  'HMGA2',
#  'HMOX1',
#  'HRH1',
#  'HS3ST3A1',
#  'HSF2BP',
#  'HTRA1',
#  'IGFBP5',
#  'IGFBP7',
#  'IL11',
#  'INHBA',
#  'INPP4B',
#  'ITGA5',
#  'ITGB3',
#  'JAG1',
#  'JARID2',
#  'JUN',
#  'JUNB',
#  'KCNJ15',
#  'KCNMA1',
#  'KDELR3',
#  'KLF7',
#  'LAMC2',
#  'LARP6',
#  'LBH',
#  'LMCD1',
#  'LOX',
#  'MAF',
#  'MAGED2',
#  'MAP1LC3B',
#  'MATN3',
#  'MBOAT2',
#  'MFAP2',
#  'MICAL2',
#  'MMP1',
#  'MMP10',
#  'MMP2',
#  'MMP9',
#  'MN1',
#  'MRC2',
#  'MYL9',
#  'MYO10',
#  'NCF2',
#  'NEDD9',
#  'NKX3-1',
#  'NREP',
#  'NRIP3',
#  'NT5E',
#  'NUAK1',
#  'PALLD',
#  'PDGFA',
#  'PDGFC',
#  'PDLIM7',
#  'PEA15',
#  'PID1',
#  'PIK3CD',
#  'PLAUR',
#  'PLEK2',
#  'PMEPA1',
#  'PODXL',
#  'POSTN',
#  'PRR5L',
#  'PSMD2',
#  'PTHLH',
#  'PTPN21',
#  'PTPRK',
#  'PXDC1',
#  'RALA',
#  'RFTN1',
#  'RGS4',
#  'RUNX2',
#  'SACS',
#  'SCG5',
#  'SEMA3C',
#  'SERPINE1',
#  'SERPINE2',
#  'SIK1',
#  'SKIL',
#  'SLC22A4',
#  'SLC26A2',
#  'SLCO2A1',
#  'SLN',
#  'SMAD7',
#  'SMURF2',
#  'SNAI2',
#  'SPARC',
#  'SPDL1',
#  'SPHK1',
#  'SPOCK1',
#  'SRPX',
#  'SRRD',
#  'STC1',
#  'TAGLN',
#  'TAGLN2',
#  'TBX3',
#  'TCF4',
#  'TFPI2',
#  'TGFB1',
#  'TGFB1I1',
#  'TGFBI',
#  'TGM2',
#  'THBS1',
#  'TIMP2',
#  'TMCC1',
#  'TNFAIP6',
#  'TNS1',
#  'TP53I3',
#  'TPM1',
#  'TPM4',
#  'TPST1',
#  'TPST2',
#  'TUBA1A',
#  'TUBA4A',
#  'TUFT1',
#  'VCAN',
#  'VEGFC',
#  'VIM',
#  'WNT5A',
#  'WNT5B',
#  'XYLT1',
#  'ZNF365']

# %%
# down= pandas.read_csv("singscore_new_code/FOROUTAN_PRODRANK_TGFB_EMT_DN.txt", sep="\t",header=None)
# down= down[0].to_list()
# down
# Out:
# ['ABLIM1',
#  'ADORA2B',
#  'AGR2',
#  'ALDH3A2',
#  'ALDH5A1',
#  'ANK3',
#  'AREG',
#  'ARHGAP29',
#  'BIRC3',
#  'C1orf115',
#  'C1orf116',
#  'CAVIN2',
#  'CD9',
#  'CDH1',
#  'CEBPD',
#  'CITED2',
#  'CXADR',
#  'CYB5A',
#  'CYP1B1',
#  'DEPTOR',
#  'DST',
#  'EHF',
#  'ELF3',
#  'EPAS1',
#  'EPB41L4B',
#  'EPCAM',
#  'ERBB3',
#  'EREG',
#  'ERMP1',
#  'ESRP1',
#  'FOXA2',
#  'GDF15',
#  'GLDC',
#  'GPRC5C',
#  'GSE1',
#  'GULP1',
#  'HOOK1',
#  'HPGD',
#  'IMPA2',
#  'JAG2',
#  'KITLG',
#  'KRT19',
#  'LAMA5',
#  'LY6E',
#  'MAP7',
#  'MBP',
#  'MITF',
#  'MMP7',
#  'MTUS1',
#  'MUC1',
#  'MYO5C',
#  'NR2F2',
#  'NUP210',
#  'PDK4',
#  'PEG10',
#  'PKP2',
#  'PLAAT3',
#  'PLAAT4',
#  'PLS1',
#  'PPL',
#  'PPP1R9A',
#  'RAB26',
#  'RAB38',
#  'RBM47',
#  'S100P',
#  'SCNN1A',
#  'SERPINB1',
#  'SLC16A7',
#  'SLC27A2',
#  'SLCO4A1',
#  'SMPDL3B',
#  'SORD',
#  'SPRY1',
#  'SQOR',
#  'SULT1A1',
#  'SYBU',
#  'TBC1D8',
#  'TFAP2A',
#  'TJP2',
#  'TMT1A',
#  'TNFAIP2',
#  'TPD52L1']

# %%
# sigs = pandas.read_csv(open(sig_path, 'r'), header=
# 'infer', sep='\t')
# sigs
# Out:
#      EntrezID    Symbol upDown_integrative_signature  \
# 0          19     ABCA1                            0
# 1          87     ACTN1                            0
# 2         136   ADORA2B                            0
# 3         182      JAG1                           up
# 4         220   ALDH1A3                         down
# ..        ...       ...                          ...
# 296    161291   TMEM30B                         down
# 297    221749  C6orf145                            0
# 298    347902    AMIGO2                            0
# 299    389136     VGLL3                           up
# 300    402055      SRRD                            0
#
#     upDown_comparative_signature upDown
# 0                             up     up
# 1                             up     up
# 2                           down   down
# 3                             up     up
# 4                              0   down
# ..                           ...    ...
# 296                            0   down
# 297                           up     up
# 298                           up     up
# 299                            0     up
# 300                           up     up
#
# [301 rows x 5 columns]

# %%
# # subset the data for up and down
# up = sigs[sigs['upDown'] == 'up']
# down = sigs[sigs['upDown'] == 'down']
# up
# Out:
#      EntrezID    Symbol upDown_integrative_signature  \
# 0          19     ABCA1                            0
# 1          87     ACTN1                            0
# 3         182      JAG1                           up
# 6         241   ALOX5AP                           up
# 8         323     APBB2                            0
# ..        ...       ...                          ...
# 295    150094      SIK1                            0
# 297    221749  C6orf145                            0
# 298    347902    AMIGO2                            0
# 299    389136     VGLL3                           up
# 300    402055      SRRD                            0
#
#     upDown_comparative_signature upDown
# 0                             up     up
# 1                             up     up
# 3                             up     up
# 6                             up     up
# 8                             up     up
# ..                           ...    ...
# 295                           up     up
# 297                           up     up
# 298                           up     up
# 299                            0     up
# 300                           up     up
#
# [193 rows x 5 columns]

# %%
# get a list of ids
# up = list(up['Symbol'])
# down = list(down['Symbol'])
# up
# Out:
# ['ABCA1',
#  'ACTN1',
#  'JAG1',
#  'ALOX5AP',
#  'APBB2',
#  'ARNTL',
#  'BMP1',
#  'BMP2',
#  'BMPR2',
#  'BPGM',
#  'CALD1',
#  'RUNX2',
#  'CD59',
#  'CDH2',
#  'CDH11',
#  'COL1A1',
#  'COL3A1',
#  'COL4A1',
#  'COL4A2',
#  'COL5A1',
#  'COL5A2',
#  'COL6A3',
#  'COL7A1',
#  'VCAN',
#  'CTGF',
#  'SLC26A2',
#  'ELK3',
#  'EML1',
#  'EPHB2',
#  'ETS2',
#  'FBN1',
#  'FOXD1',
#  'FN1',
#  'GNG11',
#  'GRB10',
#  'HMOX1',
#  'HRH1',
#  'IGFBP5',
#  'IGFBP7',
#  'IL11',
#  'INHBA',
#  'ITGA5',
#  'ITGB3',
#  'JARID2',
#  'JUN',
#  'JUNB',
#  'KCNJ15',
#  'KCNMA1',
#  'LAMC2',
#  'LOX',
#  'LUM',
#  'SMAD7',
#  'MAF',
#  'MATN3',
#  'MFAP2',
#  'MMP1',
#  'MMP2',
#  'MMP9',
#  'MMP10',
#  'MN1',
#  'GADD45B',
#  'MYO10',
#  'NCF2',
#  'NEDD9',
#  'NKX3-1',
#  'NT5E',
#  'SERPINE1',
#  'PDGFA',
#  'PFTK1',
#  'SERPINE2',
#  'PIK3CD',
#  'PLAUR',
#  'PODXL',
#  'HTRA1',
#  'PSMD2',
#  'PTHLH',
#  'PTPRK',
#  'RALA',
#  'RGS4',
#  'SCG5',
#  'SKIL',
#  'SLCO2A1',
#  'SLC22A4',
#  'SLN',
#  'SNAI2',
#  'SPARC',
#  'SPOCK1',
#  'STC1',
#  'TAGLN',
#  'TCF4',
#  'TBX3',
#  'TGFB1',
#  'TGFB1I1',
#  'TGFBI',
#  'TGM2',
#  'THBS1',
#  'TIMP2',
#  'TNFAIP6',
#  'TNS1',
#  'TPM1',
#  'TPM4',
#  'TUBA4A',
#  'TUFT1',
#  'VEGFC',
#  'VIM',
#  'WNT5A',
#  'TUBA1A',
#  'SCG2',
#  'TFPI2',
#  'ADAM12',
#  'HMGA2',
#  'SRPX',
#  'TAGLN2',
#  'TPST2',
#  'TPST1',
#  'BHLHB2',
#  'KLF7',
#  'PEA15',
#  'ADAM19',
#  'INPP4B',
#  'SPHK1',
#  'AP1S2',
#  'CRLF1',
#  'PDLIM7',
#  'PSCD1',
#  'C5orf13',
#  'TP53I3',
#  'MICAL2',
#  'DOCK4',
#  'NUAK1',
#  'MRC2',
#  'GFPT2',
#  'HS3ST3B1',
#  'HS3ST3A1',
#  'AKT3',
#  'DHRS2',
#  'FSTL3',
#  'DLC1',
#  'MYL9',
#  'SEMA3C',
#  'POSTN',
#  'MAGED2',
#  'FERMT2',
#  'GLIPR1',
#  'KDELR3',
#  'HSF2BP',
#  'PTPN21',
#  'ADAMTS6',
#  'DUSP10',
#  'ZNF365',
#  'DAAM1',
#  'PALLD',
#  'TMCC1',
#  'KIAA0692',
#  'RFTN1',
#  'SACS',
#  'PLEK2',
#  'GREM1',
#  'LOH3CR2A',
#  'DSE',
#  'LMCD1',
#  'CHST11',
#  'GAL',
#  'ANGPTL4',
#  'C4orf18',
#  'DACT1',
#  'CCDC99',
#  'PID1',
#  'LARP6',
#  'GALNT10',
#  'CHRNA9',
#  'FLJ10357',
#  'ARFGAP1',
#  'PDGFC',
#  'NRIP3',
#  'PMEPA1',
#  'CXCR7',
#  'XYLT1',
#  'SMURF2',
#  'C3orf52',
#  'FLJ14213',
#  'FHOD3',
#  'WNT5B',
#  'LBH',
#  'MAP1LC3B',
#  'DIXDC1',
#  'FAM114A1',
#  'MBOAT2',
#  'SIK1',
#  'C6orf145',
#  'AMIGO2',
#  'VGLL3',
#  'SRRD']

# %% [markdown]
# ## Palbocilib resistance check

# %%
# down= pandas.read_csv("singscore_new_code/Palbocilib_resistance_down_genes.txt", sep="\t",header=None)
# down= down[0].to_list()
# down
# Out:
# ['P3H3',
#  'CPNE7',
#  'ITGBL1',
#  'AFAP1L1',
#  'PLEKHH2',
#  'NUDT13',
#  'HELB',
#  'SEL1L3',
#  'DMC1',
#  'NRP2',
#  'AK7',
#  'MACROD1',
#  'DOCK10',
#  'TMEM71',
#  'LUCAT1',
#  'RAB38',
#  'CCDC110',
#  'FAM160A1',
#  'C2orf88',
#  'GABBR2',
#  'DUSP5',
#  'MIR17HG',
#  'CHEK1',
#  'KRBOX1',
#  'SLAIN1',
#  'NAGS',
#  'FABP3',
#  'VSIG2',
#  'TMC8',
#  'ALDH8A1',
#  'ZNF287',
#  'KDELC2',
#  'FXYD3',
#  'LURAP1L-AS1',
#  'C1orf115',
#  'ACSM3',
#  'PDE3B',
#  'CLMN',
#  'NPAT',
#  'RN7SL73P',
#  'CPNE9',
#  'HNRNPA1P67',
#  'TRPC3',
#  'SULT1A1',
#  'STRIP2',
#  'IL1RL2',
#  'OSMR-AS1',
#  'FAM184A',
#  'C3orf67',
#  'ARNTL2',
#  'CA9',
#  'KBTBD3',
#  'BUD13',
#  'SFTA1P',
#  'BCL2L11',
#  'E2F8',
#  'DAW1',
#  'RNA5SP236',
#  'PARD6A',
#  'RFX3',
#  'C6orf141',
#  'HTR1D',
#  'ARHGAP9',
#  'ALMS1-IT1',
#  'PYY',
#  'TAF1D',
#  'RPL7AP30',
#  'NSUN7',
#  'CRHBP',
#  'SLC37A4',
#  'TNIP3',
#  'EFEMP2',
#  'FDXACB1',
#  'MIR4500HG',
#  'ARHGAP32',
#  'ERI1',
#  'NQO1',
#  'STEAP1',
#  'CEP57',
#  'ADGRV1',
#  'DGKH',
#  'PDE4D',
#  'C5',
#  'RPL22L1',
#  'NCAM2',
#  'PDLIM3',
#  'GPR17',
#  'HMGB2',
#  'NYNRIN',
#  'CNTRL',
#  'IL24',
#  'GRB14',
#  'PPP1R3C',
#  'ARHGAP30',
#  'KISS1',
#  'MYO7B',
#  'FIGF',
#  'NEMP2',
#  'ZNF660',
#  'RN7SKP11',
#  'APBB1IP',
#  'MIR100HG',
#  'USP2-AS1',
#  'C2orf48',
#  'ZNF747',
#  'HPSE',
#  'FAM109B',
#  'CRNDE',
#  'KIAA1211',
#  'SLC7A11',
#  'ALDH1L1',
#  'SLC7A2',
#  'PCSK9',
#  'MT1JP',
#  'CHST4',
#  'ECSCR',
#  'LINC01322',
#  'PPP1R3B',
#  'IRX5',
#  'COBLL1',
#  'TMEM45B',
#  'EPCAM',
#  'APOC1',
#  'RGN',
#  'RAP1GAP2',
#  'STOM',
#  'CKMT1B',
#  'TEX14',
#  'MTMR8',
#  'GMFG',
#  'CCNA1',
#  'IL18',
#  'FAM24B',
#  'ESAM',
#  'MBOAT1',
#  'ACOT4',
#  'OCLN',
#  'CACNB4',
#  'ST6GALNAC3',
#  'SMCO2',
#  'PIK3CG',
#  'CA2',
#  'FAM83B',
#  'HENMT1',
#  'GPM6B',
#  'CIART',
#  'MAGI2-AS3',
#  'EXPH5',
#  'HTRA3',
#  'SLC15A1',
#  'ESR1',
#  'CKMT1A',
#  'NPR3',
#  'SPTSSB',
#  'MEI4',
#  'BMP6',
#  'KCTD19',
#  'ESRP2',
#  'PHGDH',
#  'LINC00942',
#  'SOBP',
#  'ATF7IP2',
#  'KIF5C',
#  'LRRC36',
#  'NRIP3',
#  'GSX2',
#  'TMEM163',
#  'GALNT14',
#  'NUP210',
#  'KDR',
#  'ARL10',
#  'MYB',
#  'LINC00707',
#  'CNKSR2',
#  'SNCAIP',
#  'TSTD1',
#  'ZNF662',
#  'CST6',
#  'GAL',
#  'CD2',
#  'RAMP2',
#  'PQLC2L',
#  'ANKRD20A7P',
#  'IGHV3OR16-7',
#  'TPTE']

# %%
#  up= pandas.read_csv("singscore_new_code/Palbocilib_resistance_up_genes.txt", sep="\t",header=None)
#  up= up[0].to_list()
#  up
# Out:
# ['DGKG',
#  'DUSP13',
#  'PALMD',
#  'CLEC11A',
#  'CCL2',
#  'GCG',
#  'TREM1',
#  'DEFB126',
#  'IDO1',
#  'FCRLA',
#  'LINC00470',
#  'JCHAIN',
#  'DYDC2',
#  'SLCO2B1',
#  'SLC2A5',
#  'ZNF300',
#  'KCNK13',
#  'ART3',
#  'LYZL4',
#  'PAGE5',
#  'S100B',
#  'SLAMF9',
#  'SPINK1',
#  'DRGX',
#  'BTNL9',
#  'TMEM100',
#  'SPRY3',
#  'VGLL2',
#  'SLN',
#  'CST5',
#  'C8orf74',
#  'ANO5',
#  'RIIAD1',
#  'PDE6G',
#  'MORN5',
#  'NAP1L3',
#  'CYP4X1',
#  'SNTN',
#  'DCAF8L2',
#  'CSAG1',
#  'LRRC37A5P',
#  'TRAV18',
#  'SPINK13',
#  'LINC01133',
#  'ZNF503-AS1',
#  'SLC8A1-AS1',
#  'LINC01515',
#  'KRT16P4',
#  'LINC00892',
#  'ZDHHC20P1',
#  'CBX1P3',
#  'HLA-DQA2',
#  'RNU2-11P',
#  'SYNPR-AS1',
#  'LINC00871',
#  'LINC00639',
#  'LINC00648',
#  'RN7SL811P',
#  'TOP1P1',
#  'SIGLEC22P',
#  'ERVV-2',
#  'CCL3',
#  'GRAMD1B',
#  'RYR2',
#  'CPA3',
#  'SLC9C2',
#  'FLRT3',
#  'CHRDL1',
#  'LBH',
#  'LRRC15',
#  'INHBA',
#  'FAM134B',
#  'SLCO1A2',
#  'CLIC2',
#  'TNFSF15',
#  'TSPAN7',
#  'IGFBP5',
#  'VIPR1',
#  'CYP17A1',
#  'FAM133A',
#  'SPN',
#  'BCHE',
#  'LGALS9',
#  'SH2D1B',
#  'ANGPTL4',
#  'KCNN3',
#  'SPOCK1',
#  'CPEB1',
#  'SLITRK6',
#  'SCN8A',
#  'VIPR1-AS1',
#  'DNAH10',
#  'CD33',
#  'LCN2',
#  'SPANXB1',
#  'TTC3P1',
#  'PLEKHS1',
#  'SPANXC',
#  'LINC01268',
#  'GPR158',
#  'SEPP1',
#  'DAAM2',
#  'ANXA8L1',
#  'LDLRAD4',
#  'TCN1',
#  'RNF43',
#  'LINC01615',
#  'NGFR',
#  'OVCH2',
#  'MOB3B',
#  'HSPB8',
#  'TMEM63C',
#  'MEIS1',
#  'FAM26E',
#  'PITX2',
#  'PLCZ1',
#  'FOLR1',
#  'MRGPRX3',
#  'TMEM98',
#  'MYL1',
#  'FAM83A',
#  'ANO2',
#  'MMP8',
#  'SEMA6D',
#  'CDH11',
#  'ADGRF4',
#  'SERPINA5',
#  'DNER',
#  'C4orf19',
#  'TFCP2L1',
#  'AFAP1-AS1',
#  'SCARA5',
#  'C4orf26',
#  'UCA1',
#  'FRMD3',
#  'ADCY5',
#  'CCL5',
#  'SCG2',
#  'SLAMF7',
#  'PCDHB2',
#  'GPRC5C',
#  'DIO2',
#  'DUSP15',
#  'PLCH2',
#  'KRT81',
#  'UNC13A',
#  'QPRT',
#  'AP3B2',
#  'PMEPA1',
#  'FLI1',
#  'VSTM2L',
#  'COL21A1',
#  'C15orf48',
#  'LINC01085',
#  'OAS1',
#  'RARRES2',
#  'INHBB',
#  'VASH1',
#  'PDE1C',
#  'APOL1',
#  'CHST9',
#  'VSTM4',
#  'PBX1',
#  'ADAM28',
#  'DNAH10OS',
#  'SDR16C5',
#  'TLR4',
#  'LONRF2',
#  'ANKRD30B',
#  'RAB6B',
#  'ALPK2',
#  'ZNF542P',
#  'ARHGAP28',
#  'TGM2',
#  'TMEM169',
#  'AADACP1',
#  'HSD17B3',
#  'EDARADD',
#  'SLC16A2',
#  'COL6A2',
#  'CST4',
#  'KATNAL2',
#  'SPX',
#  'COL6A1',
#  'CPA4',
#  'CIB2',
#  'FIRRE',
#  'FBXO39',
#  'CES3',
#  'ENPP2',
#  'NLRP2',
#  'APOE',
#  'COL6A3',
#  'THSD7B',
#  'ADORA1',
#  'LYPD8',
#  'NDP',
#  'PROM2',
#  'CNTN1',
#  'ROBO1',
#  'ACKR3',
#  'HOXB-AS1',
#  'CXCL11',
#  'CCL26',
#  'RHOJ',
#  'NXF3',
#  'HSPA6',
#  'FPR1',
#  'MAOB',
#  'ADGRG2',
#  'FBXO2',
#  'TRIM61',
#  'CST2',
#  'CFI',
#  'LYZ',
#  'ICOSLG',
#  'COL15A1',
#  'OR2T4',
#  'ADAMTS14',
#  'CST7',
#  'F13A1',
#  'CEMIP',
#  'PARK2',
#  'KCNJ15',
#  'CYGB',
#  'ST6GALNAC5',
#  'SH2D2A',
#  'FGF13',
#  'CSF2',
#  'HIST1H4H',
#  'CEACAM1',
#  'TRPV4',
#  'FPR2',
#  'ANXA10',
#  'BPI',
#  'PLP1',
#  'TSPEAR-AS2',
#  'GPR35',
#  'SAMD9L',
#  'LINC01341',
#  'PCDH1',
#  'SELENBP1',
#  'GPR55',
#  'TUBB4A',
#  'ARL14',
#  'ABCA1',
#  'EHD3',
#  'CRYAB',
#  'PTPRB',
#  'MGAM',
#  'ALOX5AP',
#  'RCAN2',
#  'ZC3H12B',
#  'RTP4',
#  'LEMD1',
#  'TFAP2C',
#  'SAA2',
#  'NHSL2',
#  'PCBP3',
#  'ALPP',
#  'TP53I11',
#  'DTNA',
#  'RASD2',
#  'CASC10',
#  'WNK2',
#  'MCF2L',
#  'MLLT11',
#  'LINC00473',
#  'C10orf11',
#  'TMEM221',
#  'PLA2G4C',
#  'ATOH8',
#  'ZDHHC11',
#  'MFNG',
#  'VAV1',
#  'TFF2',
#  'EHF',
#  'SCG5',
#  'SAA1',
#  'HLA-DQB2',
#  'DGCR5',
#  'ABCA7',
#  'LINC01139',
#  'ABCA13',
#  'KIAA1462',
#  'TMTC1',
#  'PTPN6',
#  'F2RL2',
#  'AK8',
#  'KLHL3',
#  'CXCL16',
#  'ITGB8',
#  'LINC01561',
#  'SLC2A10',
#  'GRIK2',
#  'HOXC4',
#  'PSG1',
#  'C10orf90',
#  'ANXA8',
#  'SMAD6',
#  'FGF11',
#  'SGSM1',
#  'SCEL',
#  'CDK20',
#  'A2M',
#  'SLC26A7',
#  'SLC9A7P1',
#  'DKKL1',
#  'RINL',
#  'MISP',
#  'KLRC4-KLRK1',
#  'IL1B',
#  'RYR3',
#  'NAPSA',
#  'AQP1',
#  'SYT17',
#  'TNS1',
#  'SERPINF1',
#  'MAP1A',
#  'BLACAT1',
#  'STXBP6',
#  'CAMSAP3',
#  'P2RX6',
#  'PAPPA-AS1',
#  'KCNAB3',
#  'GAS7',
#  'TRHDE',
#  'FABP6',
#  'FAM222A',
#  'TNFSF10',
#  'SCN2A',
#  'RORA',
#  'HLF',
#  'IGF2',
#  'COL5A1',
#  'CXCL14',
#  'CAMK1G',
#  'BSCL2',
#  'NKAPP1',
#  'LANCL3',
#  'ABCA8',
#  'CYP2E1',
#  'PSG6',
#  'VNN1',
#  'TMEM229B',
#  'CACNG7',
#  'DDO',
#  'PAPPA',
#  'PPP5D1',
#  'NPL',
#  'ZNF575',
#  'POU2F3',
#  'PLAT',
#  'FOSB',
#  'SPON1',
#  'DHRS3',
#  'GBP5',
#  'TIMP3',
#  'NTNG2',
#  'LRP1',
#  'GNAZ',
#  'MIR22HG',
#  'PSG9',
#  'WNT9A',
#  'ALS2CR11',
#  'CD177',
#  'FAM20C',
#  'PROM1',
#  'PIGZ',
#  'POPDC2',
#  'SLC7A9',
#  'GCNT3',
#  'MDFI',
#  'SLC30A10',
#  'BRSK2',
#  'NTM',
#  'SPP1',
#  'PLD5',
#  'GABRE',
#  'DNAH12',
#  'NWD1',
#  'NLRP10',
#  'S100A1',
#  'TSPAN9',
#  'MAP2K6',
#  'LYPD6B',
#  'ZNF521',
#  'LINC01589',
#  'CST1',
#  'TESC',
#  'IPO5P1',
#  'ASB2',
#  'DOCK8',
#  'MIR3142HG',
#  'PTGS2',
#  'PAX9',
#  'GPER1',
#  'PRKRIRP8',
#  'KLRC2',
#  'NDST3',
#  'MUC1',
#  'FAM179A',
#  'C1S',
#  'DPF3',
#  'MIA',
#  'SERPING1',
#  'RPL23AP49',
#  'HLA-DRB6',
#  'LINC00887',
#  'EML1',
#  'PDGFB',
#  'MAP1LC3C',
#  'ITGA7',
#  'FAM198B',
#  'PSG5',
#  'ADGRF1',
#  'AARD',
#  'SULT1C2',
#  'RAB3A',
#  'C1orf145',
#  'DBH',
#  'KLRC3',
#  'TDO2',
#  'DYNLRB2',
#  'TMIE',
#  'BMPER',
#  'MYO15B',
#  'ZNF117',
#  'RSAD2',
#  'HDX',
#  'LTBP3',
#  'CD34',
#  'TTLL9',
#  'INPP5J',
#  'NOTCH3',
#  'TSACC',
#  'ZFP3',
#  'RIMS1',
#  'COPZ2',
#  'C1orf106',
#  'SEMA6A',
#  'COL4A6',
#  'SDC2',
#  'SHROOM2',
#  'TNFAIP8L3',
#  'SERPINF2',
#  'LPAR2',
#  'CT62',
#  'EFNB1',
#  'RASSF9',
#  'ANKLE1',
#  'C5AR1',
#  'LINC01296',
#  'FAM155A',
#  'SCNN1A',
#  'ZNF594',
#  'LST1',
#  'ADGRF5',
#  'MB',
#  'PADI1',
#  'ATP6V0D2',
#  'GPR85',
#  'DPYSL3',
#  'C15orf54',
#  'LFNG',
#  'LAMA5',
#  'ZNF467',
#  'TNFSF13B',
#  'RGS7',
#  'MPZL2',
#  'CALCR',
#  'LINC00973',
#  'ALDH1A2',
#  'SOST',
#  'CHI3L2',
#  'RASA4CP',
#  'SHISA4',
#  'TSNAXIP1',
#  'OLFML3',
#  'SYT7',
#  'HIST2H2BE',
#  'FER1L4',
#  'LPAR5',
#  'ROGDI',
#  'HLA-DQB1',
#  'CCR1',
#  'CXCL1',
#  'KRT7',
#  'C17orf97',
#  'WNT7B',
#  'SEMA3A',
#  'MSX2',
#  'C3',
#  'OPRL1',
#  'PRSS22',
#  'CFH',
#  'L1CAM',
#  'ABCD1',
#  'MIR99AHG',
#  'CSF1R',
#  'CDK18',
#  'VCAN',
#  'APOBEC3G',
#  'SYT1',
#  'ZC3H12D',
#  'PALM',
#  'CCDC190',
#  'CDK5R2',
#  'MX2',
#  'DACT3',
#  'ZSWIM5',
#  'FAM172BP',
#  'ADCK1',
#  'ISG15',
#  'TMCC2',
#  'CDNF',
#  'C21orf2',
#  'CMKLR1',
#  'ESM1',
#  'TNFSF4',
#  'AFP',
#  'SLCO3A1',
#  'NCF2',
#  'LINC01411',
#  'F3',
#  'ATP8A1',
#  'S1PR3',
#  'LCMT1-AS1',
#  'ZNF66',
#  'ARHGEF37',
#  'FAM189A2',
#  'ITGA2B',
#  'BTC',
#  'PRR29',
#  'IDUA',
#  'SELPLG',
#  'CSGALNACT1',
#  'MICALL2',
#  'XDH',
#  'NEBL',
#  'GPR1',
#  'GBP4',
#  'LINC01234',
#  'AFF3',
#  'CYP19A1',
#  'DENND6B',
#  'S100A5',
#  'TAGLN2',
#  'OAS2',
#  'OR2M4',
#  'CFAP44',
#  'WT1',
#  'PPP1R1B',
#  'APLP1',
#  'WFDC2',
#  'ADAMTS9-AS1',
#  'SLC22A4',
#  'MROH6',
#  'OLFM2',
#  'BZRAP1',
#  'VNN2',
#  'SOX4',
#  'HLA-DRB5',
#  'ONECUT2',
#  'KIAA1755',
#  'SRGAP3',
#  'XAF1',
#  'ADAMTS9',
#  'LCP1',
#  'MXRA8',
#  'RGAG4',
#  'HIST1H2AC',
#  'DBH-AS1',
#  'IFI6',
#  'TNFRSF9',
#  'NRG2',
#  'NRG4',
#  'QRICH2',
#  'TNFRSF19',
#  'ID3',
#  'LINC01012',
#  'PTGFRN',
#  'PLAU',
#  'SERINC2',
#  'SPNS2',
#  'ARHGEF6',
#  'ASIC3',
#  'OASL',
#  'ARSA',
#  'SHC2',
#  'RNASEL',
#  'HIST2H2BA',
#  'LAPTM5',
#  'PTPRR',
#  'KLHDC9',
#  'LY6E',
#  'KIFC2',
#  'LMNTD2',
#  'DMPK',
#  'PLXDC2',
#  'C2',
#  'GBP1',
#  'GPRC5B',
#  'FBN1',
#  'FGFBP1',
#  'GIMAP2',
#  'GNG2',
#  'RRAD',
#  'TNFRSF11B',
#  'COL5A2',
#  'TDRD12',
#  'ABLIM2',
#  'FLG',
#  'LPAR4',
#  'CCDC40',
#  'FBXO32',
#  'ATF5',
#  'LOXL4',
#  'MID2',
#  'LINC00632',
#  'CSF3',
#  'MNX1-AS1',
#  'MPZL3',
#  'MSLN',
#  'RGS4',
#  'RCSD1',
#  'FHDC1',
#  'TMEM86A',
#  'BMP5',
#  'IFNLR1',
#  'NOV',
#  'SWSAP1',
#  'ENTPD3',
#  'SLC52A3',
#  'VSIG1',
#  'ADGRF5P2',
#  'EGF',
#  'TRIM9',
#  'ONECUT1',
#  'MEI1',
#  'LINC01224',
#  'LINC00313',
#  'P4HA2',
#  'TJP3',
#  'PAQR6',
#  'IFI30',
#  'SORBS2',
#  'DZIP1',
#  'PLXNA1',
#  'CYB5R2',
#  'SEMA6C',
#  'MBL1P',
#  'TPRG1',
#  'RPS6KA2',
#  'MAL2',
#  'MFAP5',
#  'GRPR',
#  'PLEKHB1',
#  'PCDH18',
#  'GPR65',
#  'FILIP1',
#  'SNAI2',
#  'TBXA2R',
#  'C5orf56',
#  'MPP4',
#  'CCDC64',
#  'JUP',
#  'PLXNB3',
#  'PLXNA3',
#  'ATP2A1',
#  'SLC12A7',
#  'APOL3',
#  'FN1',
#  'GPR153',
#  'PCDH7',
#  'GBGT1',
#  'NBEAP3',
#  'SLC25A21',
#  'CMAHP',
#  'B3GALT5',
#  'SIRT2',
#  'GALNT16',
#  'LINC00342',
#  'HCAR1',
#  'TCEA2',
#  'PRUNE2',
#  'ZNF324B',
#  'DCDC1',
#  'SLC16A4',
#  'SORBS1',
#  'VDR',
#  'ZNF703',
#  'HIST2H2BF',
#  'PCDHB8',
#  'MYL9',
#  'LINC01443',
#  'FMO5',
#  'CMYA5',
#  'IL7R',
#  'HAND1',
#  'PTPRU',
#  'APOL2',
#  'PRSS54',
#  'FAM174B',
#  'GPX7',
#  'SERPINC1',
#  'SLC6A8',
#  'PSG4',
#  'SORCS2',
#  'FHOD3',
#  'ZBTB7B',
#  'NES',
#  'PIK3C2B',
#  'SLC7A5',
#  'ANO8',
#  'OVGP1',
#  'SDSL',
#  'LINC00205',
#  'EEF1A2',
#  'P2RY6',
#  'MYO15A',
#  'C10orf91',
#  'LINC00460',
#  'ABCC6P1',
#  'LOXL1',
#  'HES2',
#  'HES1',
#  'IFIT2',
#  'PADI3',
#  'FKBP9P1',
#  'KCNIP3',
#  'NIM1K',
#  'SEMA7A',
#  'SYPL2',
#  'GNG7',
#  'PLOD1',
#  'FAM58A',
#  'MUSK',
#  'CD96',
#  'YJEFN3',
#  'CD37',
#  'PEX5L',
#  'COL18A1',
#  'CES4A',
#  'SLC38A4',
#  'Mar-10',
#  'LINC01134',
#  'GPRASP1',
#  'DHRS2',
#  'TRIML2',
#  'FOS',
#  'S100A4',
#  'DOK3',
#  'CCDC69',
#  'USP18',
#  'KYNU',
#  'TMEM102',
#  'RABAC1',
#  'AIM2',
#  'H2BFM',
#  'FAXDC2',
#  'LINC00520',
#  'SAMD9',
#  'TPM1',
#  'C19orf57',
#  'CNIH3',
#  'TGFB2-OT1',
#  'CCDC24',
#  'HHIPL2',
#  'CD99L2',
#  'PLPPR2',
#  'SERPINB9P1',
#  'SLC9A2',
#  'C19orf18',
#  'CD226',
#  'FAM43A',
#  'LINC00337',
#  'C1orf101',
#  'LYPD1',
#  'ATG9B',
#  'TP53TG3D',
#  'ECM1']

# %% [markdown]
# ## gene set reactome cyclinD associated events in G1

# %%
down= pandas.read_csv("singscore_new_code/cyclind_down_genes.txt", sep="\t",header=None)
down= down[0].to_list()
down
# Out:
# ['CCND1',
#  'CCND2',
#  'CCND3',
#  'CDK2',
#  'CDK4',
#  'CDK6',
#  'CDK7',
#  'CUL1',
#  'E2F1',
#  'E2F2',
#  'E2F3',
#  'E2F4',
#  'E2F5',
#  'SKP1',
#  'SKP2']

# %%
up= pandas.read_csv("singscore_new_code/cyclind_up_genes.txt", sep="\t",header=None)
up= up[0].to_list()
up
# Out:
# ['CCNE1',
#  'CCNE2',
#  'CDKN1A',
#  'CDKN1B',
#  'CDKN1C',
#  'CDKN2A',
#  'CDKN2B',
#  'CDKN2C',
#  'CDKN2D',
#  'RB1',
#  'RBL1',
#  'RBL2',
#  'UBA52',
#  'UBB',
#  'UBC']

# %%
print(f'{len(up), len(down)}')
# Out:
# (15, 15)

# %%
up_present = [gene for gene in up if gene in data.index]
down_present = [gene for gene in down if gene in data.index]

# Print counts and summary
print(f"Total up genes in signature: {len(up)}")
print(f"Up genes found in expression data: {len(up_present)}")

print(f"Total down genes in signature: {len(down)}")
print(f"Down genes found in expression data: {len(down_present)}")

# Optionally, print the missing ones
missing_up = set(up) - set(data.index)
missing_down = set(down) - set(data.index)

print(f"Missing up genes: {len(missing_up)}")
print(f"Missing down genes: {len(missing_down)}")
# Out:
# Total up genes in signature: 15
# Up genes found in expression data: 15
# Total down genes in signature: 15
# Down genes found in expression data: 15
# Missing up genes: 0
# Missing down genes: 0

# %% [markdown]
# # Scoring the genes

# %%
scored_data = score(up_gene=up, down_gene=False, sample=data,
                    norm_method='theoretical', full_data=True)
print(scored_data)
# Out:
#           total_score    total_mad
# log2_TPM     0.168305  4919.274161

# %%
# plot dispersion of scores
output_path = os.path.normpath('{}/{}'.format(BASE_DIR,
                                    'singscore/test/output_JN/dispersion_UK65_cyclind.png'))

plotdispersion(scored_data, ctrlstring='Ctrl', teststring='TGFb',
               testlabel='TGFb', colour_1='g', colour_2='b',
               outpath=output_path, show=False)

# %% [markdown]
# ### for permutations/pvalue to be correctly calculated the genes rtandomly selected shiould be equal to the genes present in the rna-seq data of up and down gene list

# %%
output_path = os.path.normpath('{}/{}'.format(BASE_DIR,
                                        'singscore/test/output_JN/nulldist_UK65_cyclind.png'))
permd = permutate(data, n_up=len(up_present), n_down=False)
pvals = empiricalpval(permutations=permd, score=scored_data)
print(pvals)
# Out:
#           empirical p value
# log2_TPM           0.011299

# %%
nulldistribution(permutations=permd, score=scored_data, nrows=2, ncols=5,
                 threshold=0.05, outpath=output_path, show=False)
# Out:
# d:\GS\PySingscore_replicate\singscore\singscore.py:857: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   seaborn.distplot(permutations[p],hist=True, kde_kws={'color':color},

# %%
import os
import json
import pandas as pd
from pathlib import Path
from datetime import datetime
import shutil
import tempfile
from typing import Dict

# import singscore functions (adjust import if your package layout differs)
from singscore.singscore import *

def singscore_pathway_report(entrez_sample_path: str,
                             up_path: str,
                             down_path: str,
                             pathway_name: str,
                             norm_method: str = 'theoretical',
                             perms: int = 10000,
                             full_data: bool = True):
    """
    Run singscore for a pathway and return results in dict (JSON-able) format.

    Parameters
    ----------
    entrez_sample_path : str
        Path to expression matrix (tab-delimited). First column = gene id column name (e.g. "GeneName").
    up_path : str
        Path to file with up-regulated gene symbols (one per line).
    down_path : str
        Path to file with down-regulated gene symbols (one per line).
    pathway_name : str
        Display name for the pathway.
    norm_method : str
        Normalisation used by score(); default 'theoretical'.
    perms : int
        Number of permutations for empirical p-value (default 10000).
    full_data : bool
        Whether to request full_data=True from score().

    Returns
    -------
    dict
        JSON-serializable dictionary with pathway, gene_set_info, scores, statistics.
    """
    # --- Read expression data ---
    if not os.path.exists(entrez_sample_path):
        raise FileNotFoundError(f"Expression file not found: {entrez_sample_path}")
    # autodetect separator: assume tab-delimited like your example
    df = pd.read_csv(entrez_sample_path, sep="\t", header=0, index_col=0)
    # df index are gene identifiers (matching the signature)
    
    # --- Read gene lists ---
    def read_list(path):
        if not os.path.exists(path):
            raise FileNotFoundError(f"Gene list file not found: {path}")
        s = pd.read_csv(path, header=None, sep="\t", comment='#', engine='python')
        # first column contains gene symbols/ids
        return [str(x).strip() for x in s.iloc[:,0].tolist() if pd.notna(x)]
    
    up = read_list(up_path)
    down = read_list(down_path)
    
    # --- Check coverage in dataset (genes present) ---
    up_present = [g for g in up if g in df.index]
    down_present = [g for g in down if g in df.index]
    
    # --- Optional: warn about missing genes ---
    missing_up = set(up) - set(up_present)
    missing_down = set(down) - set(down_present)
    
    # --- Compute singscore ---
    # Use the original lists as inputs to score(); singscore internally ignores missing genes.
    scored = score(up_gene=up, down_gene=down, sample=df,
                   norm_method=norm_method, full_data=full_data)
    # scored is typically a DataFrame (rows = sample(s), columns include up_score, down_score, total_score)
    
    # Attempt to extract the numeric scores for the first sample (or the only sample)
    if isinstance(scored, pd.DataFrame):
        # If there are multiple rows (samples), pick the first row
        sample_row = scored.iloc[0]
        # Common column names in singscore outputs:
        # try several possibilities for column names
        col_names = {c.lower(): c for c in scored.columns}
        def pick_col(key_options):
            for k in key_options:
                if k in col_names:
                    return col_names[k]
            return None
        up_col = pick_col(['up_score', 's_up', 'sdir', 's_up_score', 's_up'])
        down_col = pick_col(['down_score', 's_down', 'sdir_down', 's_down_score', 's_down'])
        total_col = pick_col(['total_score', 's_total', 'stotal', 'score', 'total'])
        # fallback: if we can't find names, try to detect numeric columns by content
        if up_col is None or down_col is None or total_col is None:
            # find numeric columns and attempt to match by position or names containing 'up'/'down'
            numeric_cols = [c for c in scored.columns if pd.api.types.is_numeric_dtype(scored[c])]
            # name matching heuristic
            for c in scored.columns:
                cl = c.lower()
                if 'up' in cl and up_col is None:
                    up_col = c
                if 'down' in cl and down_col is None:
                    down_col = c
                if ('total' in cl or 'score' in cl) and total_col is None:
                    total_col = c
            # final fallback: first three numeric columns
            if (up_col is None or down_col is None or total_col is None) and len(numeric_cols) >= 3:
                up_col, down_col, total_col = numeric_cols[:3]
        # extract values (if still None, set to None)
        up_score = float(sample_row[up_col]) if up_col is not None else None
        down_score = float(sample_row[down_col]) if down_col is not None else None
        total_score = float(sample_row[total_col]) if total_col is not None else None
    else:
        # If scored is a scalar or other structure, attempt to convert
        # most robust approach is to convert to DataFrame first, but if not possible:
        raise ValueError("Unexpected return type from score(): expected DataFrame-like output.")
    
    # --- Permutation and empirical p-value ---
    # Use number of up/down genes actually present in data (so permutations are matched to effective sizes)
    n_up_used = len(up_present)
    n_down_used = len(down_present)
    permd = permutate(df, n_up=n_up_used, n_down=n_down_used, reps=perms, norm_method=norm_method)
    pvals_df = empiricalpval(permutations=permd, score=scored)
    # pvals_df often contains a column 'empirical p value' or similar; extract numeric value for first sample
    if isinstance(pvals_df, pd.DataFrame):
        # pick first numeric column
        numeric_cols = [c for c in pvals_df.columns if pd.api.types.is_numeric_dtype(pvals_df[c])]
        if len(numeric_cols) == 0:
            # try to find a column name containing 'p' or 'empir'
            numeric_cols = [c for c in pvals_df.columns if 'p' in c.lower() or 'empir' in c.lower()]
        if len(numeric_cols) == 0:
            empirical_p = None
        else:
            empirical_p = float(pvals_df.iloc[0][numeric_cols[0]])
    else:
        empirical_p = None
    
    # --- Build result dict ---
    result = {
        pathway_name: {
            "pathway_display_name": pathway_name,
            "gene_set_info": {
                "up_geneset_size": len(up),
                "down_geneset_size": len(down),
                "geneset_covered_in_sample": n_up_used + n_down_used
            },
            "scores": {
                "up_geneset_score": up_score,
                "down_geneset_score": down_score,
                "total_singscore": total_score
            },
            "statistics": {
                "p_value": empirical_p,
                "method": "permutation (empirical)",
                "permutations": perms
            }
        }
    }
    
    return result


def append_report_to_json(report: Dict, out_json_path: str,
                          overwrite: bool = True,
                          backup: bool = True):
    """
    Append or merge a `report` dict into a JSON file at out_json_path.

    Parameters
    ----------
    report : dict
        JSON-serializable dictionary containing one or more pathway entries
        (same format as your 'report' returned by singscore_pathway_report).
    out_json_path : str
        Path to the JSON file to update (will be created if missing).
    overwrite : bool
        If True, replace an existing pathway entry with the same key. If False,
        and the key exists, the function will create a new key by appending a suffix.
    backup : bool
        If True and the output file already exists, create a timestamped backup copy.
    """
    out_path = Path(out_json_path)
    # Load existing content if present
    if out_path.exists():
        try:
            with out_path.open("r", encoding="utf-8") as fh:
                existing = json.load(fh)
                if not isinstance(existing, dict):
                    raise ValueError("Existing JSON root is not a dict. Aborting.")
        except Exception as e:
            raise RuntimeError(f"Failed to read existing JSON file: {e}")

        # Optionally backup original file
        if backup:
            ts = datetime.now().strftime("%Y%m%d_%H%M%S")
            backup_path = out_path.with_name(out_path.stem + f"_backup_{ts}" + out_path.suffix)
            shutil.copy2(out_path, backup_path)
            print(f"Backup of existing JSON saved to: {backup_path}")
    else:
        existing = {}

    # Merge report into existing dictionary
    for pathway_key, pathway_val in report.items():
        if pathway_key in existing:
            if overwrite:
                existing[pathway_key] = pathway_val
                print(f"Overwrote existing entry for pathway: {pathway_key}")
            else:
                # Create unique key by appending timestamp (or a counter)
                ts = datetime.now().strftime("%Y%m%d_%H%M%S")
                new_key = f"{pathway_key}__dup__{ts}"
                existing[new_key] = pathway_val
                print(f"Pathway key exists. Added as new key: {new_key}")
        else:
            existing[pathway_key] = pathway_val
            print(f"Appended new pathway: {pathway_key}")

    # Write atomically to avoid partial writes (write to temp then move)
    tmp_fd, tmp_path = tempfile.mkstemp(dir=str(out_path.parent), prefix=".tmp_", suffix=".json")
    try:
        with open(tmp_fd, "w", encoding="utf-8") as tmpf:
            json.dump(existing, tmpf, indent=2, ensure_ascii=False)
            tmpf.flush()
        # Atomically replace
        Path(tmp_path).replace(out_path)
        print(f"Updated JSON written to: {out_path}")
    except Exception as e:
        # cleanup temp file on failure
        try:
            Path(tmp_path).unlink(missing_ok=True)
        except Exception:
            pass
        raise RuntimeError(f"Failed to write updated JSON file: {e}")

# %% [markdown]
# ## Tamoxifen resistance

# %%
# -------------------------
# Example usage:
# -------------------------
report = singscore_pathway_report(
    "singscore_new_code/UK65_clean_gene_log_tpm.txt",
    "singscore_new_code/tamoxcifen/BECKER_TAMOXIFEN_RESISTANCE_UP.txt",
    "singscore_new_code/tamoxcifen/BECKER_TAMOXIFEN_RESISTANCE_DN.txt",
    "Tamoxifen_resistance",
    norm_method='theoretical',
    perms=10000
)
append_report_to_json(report, "singscore_new_code/results/pathway_enrichment_analysis_output_modified.json", overwrite=True, backup=True)
# Out:
# Backup of existing JSON saved to: singscore_new_code\results\pathway_enrichment_analysis_output_modified_backup_20251110_155535.json
# Appended new pathway: Tamoxifen_resistance
# Updated JSON written to: singscore_new_code\results\pathway_enrichment_analysis_output_modified.json

# %%
! pip install gseapy
# Out:
# Collecting gseapy
#   Downloading gseapy-1.1.10-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.13.0 in c:\users\jeet\.conda\envs\ctrextension\lib\site-packages (from gseapy) (1.26.4)
# Requirement already satisfied: scipy in c:\users\jeet\.conda\envs\ctrextension\lib\site-packages (from gseapy) (1.16.3)
# Requirement already satisfied: pandas in c:\users\jeet\.conda\envs\ctrextension\lib\site-packages (from gseapy) (2.2.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\jeet\.conda\envs\ctrextension\lib\site-packages (from gseapy) (3.9.2)
# Requirement already satisfied: requests in c:\users\jeet\.conda\envs\ctrextension\lib\site-packages (from gseapy) (2.32.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jeet\.conda\envs\ctrextension\lib\site-packages (from matplotlib>=2.2->gseapy) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jeet\.conda\envs\ctrextension\lib\site-packages (from matplotlib>=2.2->gseapy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jeet\.conda\envs\ctrextension\lib\site-packages (from matplotlib>=2.2->gseapy) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jeet\.conda\envs\ctrextension\lib\site-packages (from matplotlib>=2.2->gseapy) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\jeet\.conda\envs\ctrextension\lib\site-packages (from matplotlib>=2.2->gseapy) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\jeet\.conda\envs\ctrextension\lib\site-packages (from matplotlib>=2.2->gseapy) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jeet\.conda\envs\ctrextension\lib\site-packages (from matplotlib>=2.2->gseapy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jeet\.conda\envs\ctrextension\lib\site-packages (from matplotlib>=2.2->gseapy) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jeet\.conda\envs\ctrextension\lib\site-packages (from pandas->gseapy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jeet\.conda\envs\ctrextension\lib\site-packages (from pandas->gseapy) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jeet\.conda\envs\ctrextension\lib\site-packages (from requests->gseapy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jeet\.conda\envs\ctrextension\lib\site-packages (from requests->gseapy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jeet\.conda\envs\ctrextension\lib\site-packages (from requests->gseapy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jeet\.conda\envs\ctrextension\lib\site-packages (from requests->gseapy) (2024.7.4)
# Requirement already satisfied: six>=1.5 in c:\users\jeet\.conda\envs\ctrextension\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->gseapy) (1.16.0)
# Downloading gseapy-1.1.10-cp312-cp312-win_amd64.whl (421 kB)
# Installing collected packages: gseapy
# Successfully installed gseapy-1.1.10

# %%
import gseapy as gp

# %%
hallmark  = gp.get_library_name(organism='Human')
hallmark
# Out:
# ['ARCHS4_Cell-lines',
#  'ARCHS4_IDG_Coexp',
#  'ARCHS4_Kinases_Coexp',
#  'ARCHS4_TFs_Coexp',
#  'ARCHS4_Tissues',
#  'Achilles_fitness_decrease',
#  'Achilles_fitness_increase',
#  'Aging_Perturbations_from_GEO_down',
#  'Aging_Perturbations_from_GEO_up',
#  'Allen_Brain_Atlas_10x_scRNA_2021',
#  'Allen_Brain_Atlas_down',
#  'Allen_Brain_Atlas_up',
#  'Azimuth_2023',
#  'Azimuth_Cell_Types_2021',
#  'BioCarta_2013',
#  'BioCarta_2015',
#  'BioCarta_2016',
#  'BioPlanet_2019',
#  'BioPlex_2017',
#  'CCLE_Proteomics_2020',
#  'CM4AI_U2OS_Protein_Localization_Assemblies',
#  'COMPARTMENTS_Curated_2025',
#  'COMPARTMENTS_Experimental_2025',
#  'CORUM',
#  'COVID-19_Related_Gene_Sets',
#  'COVID-19_Related_Gene_Sets_2021',
#  'Cancer_Cell_Line_Encyclopedia',
#  'CellMarker_2024',
#  'CellMarker_Augmented_2021',
#  'ChEA_2013',
#  'ChEA_2015',
#  'ChEA_2016',
#  'ChEA_2022',
#  'Chromosome_Location',
#  'Chromosome_Location_hg19',
#  'ClinVar_2019',
#  'ClinVar_2025',
#  'DGIdb_Drug_Targets_2024',
#  'DSigDB',
#  'Data_Acquisition_Method_Most_Popular_Genes',
#  'DepMap_CRISPR_GeneDependency_CellLines_2023',
#  'DepMap_WG_CRISPR_Screens_Broad_CellLines_2019',
#  'DepMap_WG_CRISPR_Screens_Sanger_CellLines_2019',
#  'Descartes_Cell_Types_and_Tissue_2021',
#  'Diabetes_Perturbations_GEO_2022',
#  'DisGeNET',
#  'Disease_Perturbations_from_GEO_down',
#  'Disease_Perturbations_from_GEO_up',
#  'Disease_Signatures_from_GEO_down_2014',
#  'Disease_Signatures_from_GEO_up_2014',
#  'DrugMatrix',
#  'Drug_Perturbations_from_GEO_2014',
#  'Drug_Perturbations_from_GEO_down',
#  'Drug_Perturbations_from_GEO_up',
#  'ENCODE_Histone_Modifications_2013',
#  'ENCODE_Histone_Modifications_2015',
#  'ENCODE_TF_ChIP-seq_2014',
#  'ENCODE_TF_ChIP-seq_2015',
#  'ENCODE_and_ChEA_Consensus_TFs_from_ChIP-X',
#  'ESCAPE',
#  'Elsevier_Pathway_Collection',
#  'Enrichr_Libraries_Most_Popular_Genes',
#  'Enrichr_Submissions_TF-Gene_Coocurrence',
#  'Enrichr_Users_Contributed_Lists_2020',
#  'Epigenomics_Roadmap_HM_ChIP-seq',
#  'FANTOM6_lncRNA_KD_DEGs',
#  'GO_Biological_Process_2021',
#  'GO_Biological_Process_2023',
#  'GO_Biological_Process_2025',
#  'GO_Cellular_Component_2021',
#  'GO_Cellular_Component_2023',
#  'GO_Cellular_Component_2025',
#  'GO_Molecular_Function_2021',
#  'GO_Molecular_Function_2023',
#  'GO_Molecular_Function_2025',
#  'GTEx_Aging_Signatures_2021',
#  'GTEx_Tissue_Expression_Down',
#  'GTEx_Tissue_Expression_Up',
#  'GTEx_Tissues_V8_2023',
#  'GWAS_Catalog_2019',
#  'GWAS_Catalog_2023',
#  'GWAS_Catalog_2025',
#  'GeDiPNet_2023',
#  'GeneSigDB',
#  'Gene_Perturbations_from_GEO_down',
#  'Gene_Perturbations_from_GEO_up',
#  'Genes_Associated_with_NIH_Grants',
#  'Genome_Browser_PWMs',
#  'GlyGen_Glycosylated_Proteins_2022',
#  'HDSigDB_Human_2021',
#  'HDSigDB_Mouse_2021',
#  'HMDB_Metabolites',
#  'HMS_LINCS_KinomeScan',
#  'HomoloGene',
#  'HuBMAP_ASCT_plus_B_augmented_w_RNAseq_Coexpression',
#  'HuBMAP_ASCTplusB_augmented_2022',
#  'HumanCyc_2015',
#  'HumanCyc_2016',
#  'Human_Gene_Atlas',
#  'Human_Phenotype_Ontology',
#  'IDG_Drug_Targets_2022',
#  'InterPro_Domains_2019',
#  'JASPAR_PWM_Human_2025',
#  'JASPAR_PWM_Mouse_2025',
#  'Jensen_COMPARTMENTS',
#  'Jensen_DISEASES',
#  'Jensen_DISEASES_Curated_2025',
#  'Jensen_DISEASES_Experimental_2025',
#  'Jensen_TISSUES',
#  'KEA_2013',
#  'KEA_2015',
#  'KEGG_2013',
#  'KEGG_2015',
#  'KEGG_2016',
#  'KEGG_2019_Human',
#  'KEGG_2019_Mouse',
#  'KEGG_2021_Human',
#  'KOMP2_Mouse_Phenotypes_2022',
#  'Kinase_Perturbations_from_GEO_down',
#  'Kinase_Perturbations_from_GEO_up',
#  'L1000_Kinase_and_GPCR_Perturbations_down',
#  'L1000_Kinase_and_GPCR_Perturbations_up',
#  'LINCS_L1000_CRISPR_KO_Consensus_Sigs',
#  'LINCS_L1000_Chem_Pert_Consensus_Sigs',
#  'LINCS_L1000_Chem_Pert_down',
#  'LINCS_L1000_Chem_Pert_up',
#  'LINCS_L1000_Ligand_Perturbations_down',
#  'LINCS_L1000_Ligand_Perturbations_up',
#  'Ligand_Perturbations_from_GEO_down',
#  'Ligand_Perturbations_from_GEO_up',
#  'MAGMA_Drugs_and_Diseases',
#  'MAGNET_2023',
#  'MCF7_Perturbations_from_GEO_down',
#  'MCF7_Perturbations_from_GEO_up',
#  'MGI_Mammalian_Phenotype_Level_4_2021',
#  'MGI_Mammalian_Phenotype_Level_4_2024',
#  'MSigDB_Computational',
#  'MSigDB_Hallmark_2020',
#  'MSigDB_Oncogenic_Signatures',
#  'Metabolomics_Workbench_Metabolites_2022',
#  'Microbe_Perturbations_from_GEO_down',
#  'Microbe_Perturbations_from_GEO_up',
#  'MoTrPAC_2023',
#  'Mouse_Gene_Atlas',
#  'NCI-60_Cancer_Cell_Lines',
#  'NCI-Nature_2016',
#  'NIBR_DRUGseq_2025_down',
#  'NIBR_DRUGseq_2025_up',
#  'NURSA_Human_Endogenous_Complexome',
#  'OMIM_Disease',
#  'OMIM_Expanded',
#  'Old_CMAP_down',
#  'Old_CMAP_up',
#  'Orphanet_Augmented_2021',
#  'PFOCR_Pathways_2023',
#  'PPI_Hub_Proteins',
#  'PanglaoDB_Augmented_2021',
#  'Panther_2015',
#  'Panther_2016',
#  'PerturbAtlas',
#  'PerturbAtlas_MouseGenePerturbationSigs',
#  'PerturbSeq_ReplogleK562',
#  'PerturbSeq_ReplogleRPE1',
#  'Pfam_Domains_2019',
#  'Pfam_InterPro_Domains',
#  'PheWeb_2019',
#  'PhenGenI_Association_2021',
#  'Phosphatase_Substrates_from_DEPOD',
#  'ProteomicsDB_2020',
#  'Proteomics_Drug_Atlas_2023',
#  'RNA-Seq_Disease_Gene_and_Drug_Signatures_from_GEO',
#  'Rare_Diseases_AutoRIF_ARCHS4_Predictions',
#  'Rare_Diseases_AutoRIF_Gene_Lists',
#  'Rare_Diseases_GeneRIF_ARCHS4_Predictions',
#  'Rare_Diseases_GeneRIF_Gene_Lists',
#  'Reactome_2022',
#  'Reactome_Pathways_2024',
#  'RummaGEO_DrugPerturbations_2025',
#  'RummaGEO_GenePerturbations_2025',
#  'Rummagene_kinases',
#  'Rummagene_signatures',
#  'Rummagene_transcription_factors',
#  'SILAC_Phosphoproteomics',
#  'SubCell_BarCode',
#  'SynGO_2022',
#  'SynGO_2024',
#  'SysMyo_Muscle_Gene_Sets',
#  'TF-LOF_Expression_from_GEO',
#  'TF_Perturbations_Followed_by_Expression',
#  'TG_GATES_2020',
#  'TISSUES_Curated_2025',
#  'TISSUES_Experimental_2025',
#  'TRANSFAC_and_JASPAR_PWMs',
#  'TRRUST_Transcription_Factors_2019',
#  'Table_Mining_of_CRISPR_Studies',
#  'Tabula_Muris',
#  'Tabula_Sapiens',
#  'TargetScan_microRNA',
#  'TargetScan_microRNA_2017',
#  'The_Kinase_Library_2023',
#  'The_Kinase_Library_2024',
#  'Tissue_Protein_Expression_from_Human_Proteome_Map',
#  'Tissue_Protein_Expression_from_ProteomicsDB',
#  'Transcription_Factor_PPIs',
#  'UK_Biobank_GWAS_v1',
#  'Virus-Host_PPI_P-HIPSTer_2020',
#  'VirusMINT',
#  'Virus_Perturbations_from_GEO_down',
#  'Virus_Perturbations_from_GEO_up',
#  'WikiPathway_2021_Human',
#  'WikiPathway_2023_Human',
#  'WikiPathways_2013',
#  'WikiPathways_2015',
#  'WikiPathways_2016',
#  'WikiPathways_2019_Human',
#  'WikiPathways_2019_Mouse',
#  'WikiPathways_2024_Human',
#  'WikiPathways_2024_Mouse',
#  'dbGaP',
#  'huMAP',
#  'lncHUB_lncRNA_Co-Expression',
#  'miRTarBase_2017']

# %%
hallmark  = gp.get_library(organism='Human', name ='MSigDB_Hallmark_2020')
hallmark
# Out:
# {'TNF-alpha Signaling via NF-kB': ['MARCKS',
#   'IL23A',
#   'NINJ1',
#   'TNFSF9',
#   'SIK1',
#   'ATF3',
#   'SERPINE1',
#   'MYC',
#   'HES1',
#   'CCN1',
#   'CCNL1',
#   'EGR1',
#   'EGR2',
#   'EGR3',
#   'JAG1',
#   'ABCA1',
#   'GADD45B',
#   'GADD45A',
#   'KLF10',
#   'PLK2',
#   'EIF1',
#   'EHD1',
#   'FOSL2',
#   'FOSL1',
#   'GPR183',
#   'PLPP3',
#   'IFIT2',
#   'ICAM1',
#   'ZC3H12A',
#   'IER2',
#   'IL12B',
#   'IER5',
#   'JUNB',
#   'IER3',
#   'STAT5A',
#   'DUSP5',
#   'EDN1',
#   'DUSP4',
#   'JUN',
#   'DUSP1',
#   'DUSP2',
#   'TSC22D1',
#   'CCL20',
#   'SPHK1',
#   'LIF',
#   'IL18',
#   'TUBB2A',
#   'RHOB',
#   'VEGFA',
#   'IL1A',
#   'PTPRE',
#   'TLR2',
#   'IL1B',
#   'BHLHE40',
#   'CLCF1',
#   'ID2',
#   'REL',
#   'FJX1',
#   'SGK1',
#   'BTG3',
#   'BTG2',
#   'BTG1',
#   'SDC4',
#   'LITAF',
#   'AREG',
#   'SOCS3',
#   'PANX1',
#   'RIPK2',
#   'NFIL3',
#   'SERPINB2',
#   'GCH1',
#   'IFNGR2',
#   'G0S2',
#   'FOS',
#   'F3',
#   'SERPINB8',
#   'SPSB1',
#   'FOSB',
#   'PER1',
#   'F2RL1',
#   'HBEGF',
#   'CD44',
#   'TRIP10',
#   'CDKN1A',
#   'PTGER4',
#   'PTGS2',
#   'IFIH1',
#   'NAMPT',
#   'OLR1',
#   'ICOSLG',
#   'PHLDA1',
#   'ZBTB10',
#   'TAP1',
#   'PNRC1',
#   'CXCL10',
#   'CXCL11',
#   'IL6ST',
#   'CD69',
#   'SQSTM1',
#   'RELA',
#   'CD83',
#   'CSF2',
#   'CSF1',
#   'CD80',
#   'PPP1R15A',
#   'TNC',
#   'TNF',
#   'RELB',
#   'TANK',
#   'ZFP36',
#   'CCND1',
#   'RNF19B',
#   'CCRL2',
#   'DENND5A',
#   'MAP3K8',
#   'PHLDA2',
#   'LDLR',
#   'SLC16A6',
#   'SMAD3',
#   'TGIF1',
#   'MAP2K3',
#   'DDX58',
#   'INHBA',
#   'TRAF1',
#   'NFKB1',
#   'NFKB2',
#   'GEM',
#   'MAFF',
#   'NR4A3',
#   'RCAN1',
#   'EFNA1',
#   'NR4A2',
#   'MXD1',
#   'BIRC2',
#   'BIRC3',
#   'YRDC',
#   'IL7R',
#   'PFKFB3',
#   'IRS2',
#   'SLC2A3',
#   'PLAU',
#   'SAT1',
#   'SLC2A6',
#   'ETS2',
#   'NR4A1',
#   'SNN',
#   'PMEPA1',
#   'TNFRSF9',
#   'MSC',
#   'TIPARP',
#   'LAMB3',
#   'GFPT2',
#   'CFLAR',
#   'TNIP1',
#   'IRF1',
#   'NFKBIA',
#   'BMP2',
#   'IL6',
#   'TNIP2',
#   'BCL6',
#   'BCL3',
#   'NFKBIE',
#   'NFE2L2',
#   'B4GALT1',
#   'NFAT5',
#   'BCL2A1',
#   'TNFAIP8',
#   'TNFAIP6',
#   'TNFAIP3',
#   'CXCL2',
#   'CXCL1',
#   'TNFAIP2',
#   'CXCL3',
#   'CXCL6',
#   'FUT4',
#   'DRAM1',
#   'DNAJB4',
#   'PDE4B',
#   'PDLIM5',
#   'MCL1',
#   'KDM6B',
#   'IL15RA',
#   'PLAUR',
#   'ATP2B1',
#   'KLF4',
#   'KLF2',
#   'SOD2',
#   'KLF9',
#   'KLF6',
#   'ACKR3',
#   'PTX3',
#   'B4GALT5',
#   'TRIB1',
#   'CEBPB',
#   'CEBPD',
#   'PLEK',
#   'CCL5',
#   'KYNU',
#   'CCL4',
#   'CCL2'],
#  'Hypoxia': ['WSB1',
#   'JMJD6',
#   'XPNPEP1',
#   'RRAGD',
#   'PPP1R3C',
#   'MT1E',
#   'TES',
#   'ATF3',
#   'SERPINE1',
#   'GLRX',
#   'UGP2',
#   'NOCT',
#   'MXI1',
#   'DPYSL4',
#   'CCN5',
#   'CCN2',
#   'PPARGC1A',
#   'CCN1',
#   'DTNA',
#   'SIAH2',
#   'MIF',
#   'PRKCA',
#   'EXT1',
#   'FOSL2',
#   'SLC6A6',
#   'SULT2B1',
#   'BCAN',
#   'LALBA',
#   'CHST2',
#   'SDC2',
#   'HOXB9',
#   'CHST3',
#   'LXN',
#   'NEDD4L',
#   'PDGFB',
#   'ENO1',
#   'ENO2',
#   'ENO3',
#   'RBPJ',
#   'MT2A',
#   'PLAC8',
#   'PRDX5',
#   'HMOX1',
#   'PDK1',
#   'IER3',
#   'PDK3',
#   'EDN2',
#   'ANXA2',
#   'JUN',
#   'DUSP1',
#   'TPI1',
#   'AMPD3',
#   'CP',
#   'VEGFA',
#   'P4HA1',
#   'P4HA2',
#   'BHLHE40',
#   'CCNG2',
#   'PAM',
#   'ALDOC',
#   'ALDOB',
#   'ALDOA',
#   'GPI',
#   'BTG1',
#   'CITED2',
#   'SDC3',
#   'SDC4',
#   'STC1',
#   'ADM',
#   'STC2',
#   'VLDLR',
#   'BRS3',
#   'LDHC',
#   'LDHA',
#   'CSRP2',
#   'IDS',
#   'NFIL3',
#   'PCK1',
#   'TPD52',
#   'PKLR',
#   'PGAM2',
#   'GAA',
#   'FOS',
#   'BGN',
#   'F3',
#   'TPST2',
#   'ANGPTL4',
#   'PLIN2',
#   'INHA',
#   'ERRFI1',
#   'SRPX',
#   'CDKN1B',
#   'CDKN1C',
#   'ERO1A',
#   'HEXA',
#   'CDKN1A',
#   'NCAN',
#   'GBE1',
#   'GCNT2',
#   'PYGM',
#   'GYS1',
#   'NDST2',
#   'NDST1',
#   'AKAP12',
#   'STBD1',
#   'CXCR4',
#   'CA12',
#   'HS3ST1',
#   'MAP3K1',
#   'TGFB3',
#   'CAVIN1',
#   'CAVIN3',
#   'KLHL24',
#   'PNRC1',
#   'SAP30',
#   'GCK',
#   'ILVBL',
#   'COL5A1',
#   'TGFBI',
#   'GAPDHS',
#   'S100A4',
#   'PKP1',
#   'PPP1R15A',
#   'HDLBP',
#   'EGFR',
#   'FOXO3',
#   'NDRG1',
#   'KIF5A',
#   'ZFP36',
#   'GPC1',
#   'HAS1',
#   'GPC4',
#   'GPC3',
#   'PPFIA4',
#   'IGFBP1',
#   'BNIP3L',
#   'IGFBP3',
#   'B3GALT6',
#   'PGF',
#   'MAFF',
#   'EFNA1',
#   'ISG20',
#   'EFNA3',
#   'LOX',
#   'PFKFB3',
#   'IRS2',
#   'SLC2A1',
#   'AK4',
#   'SLC2A3',
#   'SLC2A5',
#   'ETS1',
#   'RORA',
#   'TGM2',
#   'FAM162A',
#   'PIM1',
#   'ANKZF1',
#   'TIPARP',
#   'HSPA5',
#   'CAV1',
#   'GALK1',
#   'GRHPR',
#   'IL6',
#   'ADORA2B',
#   'MYH9',
#   'BCL2',
#   'FBP1',
#   'TMEM45A',
#   'SLC25A1',
#   'TNFAIP3',
#   'HK1',
#   'HK2',
#   'CASP6',
#   'PGK1',
#   'B4GALNT2',
#   'SLC37A4',
#   'TKTL1',
#   'TPBG',
#   'PLAUR',
#   'DCN',
#   'SELENBP1',
#   'KLF7',
#   'NAGK',
#   'KLF6',
#   'PFKL',
#   'DDIT4',
#   'DDIT3',
#   'ACKR3',
#   'KDELR3',
#   'GAPDH',
#   'PFKP',
#   'KDM3A',
#   'ZNF292',
#   'NR3C1',
#   'PHKG1',
#   'VHL',
#   'ATP7A',
#   'PGM2',
#   'SCARB1',
#   'LARGE1',
#   'PGM1'],
#  'Cholesterol Homeostasis': ['STARD4',
#   'GSTM2',
#   'CHKA',
#   'HMGCS1',
#   'TNFRSF12A',
#   'ANXA5',
#   'ECH1',
#   'GPX8',
#   'PNRC1',
#   'CPEB2',
#   'SCD',
#   'CD9',
#   'ETHE1',
#   'ALDOC',
#   'DHCR7',
#   'IDI1',
#   'ATF3',
#   'CLU',
#   'HSD17B7',
#   'ANTXR2',
#   'CXCL16',
#   'ACAT2',
#   'ATXN2',
#   'PMVK',
#   'SC5D',
#   'MAL2',
#   'STX5',
#   'NFIL3',
#   'ACSS2',
#   'FDFT1',
#   'LDLR',
#   'S100A11',
#   'ABCA2',
#   'FDPS',
#   'NIBAN1',
#   'SREBF2',
#   'JAG1',
#   'CYP51A1',
#   'PCYT2',
#   'ANXA13',
#   'TP53INP1',
#   'AVPR1A',
#   'LSS',
#   'PLAUR',
#   'SQLE',
#   'FABP5',
#   'PLSCR1',
#   'FASN',
#   'LGMN',
#   'PPARG',
#   'MVD',
#   'TRIB3',
#   'ATF5',
#   'ERRFI1',
#   'MVK',
#   'GLDC',
#   'CTNNB1',
#   'LPL',
#   'SEMA3B',
#   'ACTG1',
#   'HMGCR',
#   'TMEM97',
#   'GNAI1',
#   'TM7SF2',
#   'ADH4',
#   'CBS',
#   'LGALS3',
#   'EBP',
#   'NSDHL',
#   'ALCAM',
#   'FBXO6',
#   'GUSB',
#   'FADS2',
#   'PDK3'],
#  'Mitotic Spindle': ['ACTN4',
#   'PCGF5',
#   'APC',
#   'MARCKS',
#   'NIN',
#   'KIF20B',
#   'EPB41',
#   'STAU1',
#   'CD2AP',
#   'UXT',
#   'PPP4R2',
#   'CSNK1D',
#   'RACGAP1',
#   'CDC27',
#   'PREX1',
#   'STK38L',
#   'ARFIP2',
#   'PLK1',
#   'BCR',
#   'LATS1',
#   'CCDC88A',
#   'TPX2',
#   'BIN1',
#   'NET1',
#   'SASS6',
#   'EZR',
#   'TRIO',
#   'ITSN1',
#   'NUMA1',
#   'SMC4',
#   'SMC3',
#   'ABR',
#   'EPB41L2',
#   'CDK5RAP2',
#   'CEP72',
#   'KIFAP3',
#   'CEP192',
#   'SYNPO',
#   'RHOF',
#   'LRPPRC',
#   'ANLN',
#   'CENPE',
#   'CENPF',
#   'INCENP',
#   'CENPJ',
#   'PAFAH1B1',
#   'ARHGEF2',
#   'ARHGEF3',
#   'RAPGEF6',
#   'KPTN',
#   'ARHGEF7',
#   'RAPGEF5',
#   'RABGAP1',
#   'KIF11',
#   'PIF1',
#   'TOP2A',
#   'KIF15',
#   'NEDD9',
#   'RASAL2',
#   'BRCA2',
#   'CNTRL',
#   'KIF1B',
#   'SPTBN1',
#   'CEP57',
#   'DLGAP5',
#   'MAP1S',
#   'SORBS2',
#   'DYNLL2',
#   'MYO9B',
#   'FARP1',
#   'RANBP9',
#   'SEPTIN9',
#   'CLIP2',
#   'CLIP1',
#   'CTTN',
#   'TAOK2',
#   'LLGL1',
#   'ARF6',
#   'DYNC1H1',
#   'MAPRE1',
#   'RAB3GAP1',
#   'ALMS1',
#   'TUBD1',
#   'WASL',
#   'AKAP13',
#   'PCM1',
#   'OPHN1',
#   'NUSAP1',
#   'RICTOR',
#   'SPTAN1',
#   'GSN',
#   'RALBP1',
#   'ARHGAP29',
#   'TSC1',
#   'ARHGAP27',
#   'MID1',
#   'TUBA4A',
#   'ABI1',
#   'KIF4A',
#   'TUBGCP6',
#   'ARL8A',
#   'TUBGCP5',
#   'CNTROB',
#   'ROCK1',
#   'GEMIN4',
#   'AURKA',
#   'KATNB1',
#   'FGD4',
#   'BCL2L11',
#   'FGD6',
#   'KIF5B',
#   'CEP250',
#   'FLNA',
#   'CLASP1',
#   'FLNB',
#   'KNTC1',
#   'MYH10',
#   'PCNT',
#   'ARHGEF12',
#   'ARHGEF11',
#   'KIF22',
#   'TBCD',
#   'KIF23',
#   'CKAP5',
#   'NDC80',
#   'SSH2',
#   'DLG1',
#   'ARHGAP10',
#   'CDC42EP4',
#   'BIRC5',
#   'CDC42EP2',
#   'FSCN1',
#   'MAP3K11',
#   'CDC42EP1',
#   'KIF2C',
#   'VCL',
#   'DOCK4',
#   'NOTCH2',
#   'PXN',
#   'TUBGCP2',
#   'TUBGCP3',
#   'ARHGAP4',
#   'ARHGAP5',
#   'CCNB2',
#   'KIF3C',
#   'KIF3B',
#   'NEK2',
#   'ABL1',
#   'MARK4',
#   'SAC3D1',
#   'SUN2',
#   'ARFGEF1',
#   'RFC1',
#   'ARAP3',
#   'SHROOM1',
#   'SHROOM2',
#   'CDC42BPA',
#   'SMC1A',
#   'RASA1',
#   'HOOK3',
#   'ESPL1',
#   'RASA2',
#   'MYH9',
#   'CDK1',
#   'NF1',
#   'ATG4B',
#   'DOCK2',
#   'BCAR1',
#   'SOS1',
#   'YWHAE',
#   'LMNB1',
#   'KLC1',
#   'RHOT2',
#   'CAPZB',
#   'ECT2',
#   'WASF1',
#   'WASF2',
#   'PDLIM5',
#   'PLEKHG2',
#   'DST',
#   'CEP131',
#   'MID1IP1',
#   'KATNA1',
#   'PRC1',
#   'TIAM1',
#   'CDC42',
#   'MYO1E',
#   'PALLD',
#   'ALS2',
#   'HDAC6',
#   'TTK',
#   'PKD2',
#   'ARHGDIA',
#   'FBXO5',
#   'TLK1',
#   'BUB1',
#   'CYTH2',
#   'NCK1',
#   'NCK2'],
#  'Wnt-beta Catenin Signaling': ['FZD1',
#   'JAG1',
#   'JAG2',
#   'FZD8',
#   'WNT5B',
#   'AXIN2',
#   'AXIN1',
#   'PTCH1',
#   'CSNK1E',
#   'DKK1',
#   'DKK4',
#   'ADAM17',
#   'KAT2A',
#   'NCOR2',
#   'TCF7',
#   'PPARD',
#   'TP53',
#   'NUMB',
#   'HDAC5',
#   'LEF1',
#   'NOTCH4',
#   'NOTCH1',
#   'HDAC11',
#   'HDAC2',
#   'CTNNB1',
#   'MAML1',
#   'CUL1',
#   'PSEN2',
#   'DLL1',
#   'GNAI1',
#   'NKD1',
#   'RBPJ',
#   'WNT6',
#   'FRAT1',
#   'CCND2',
#   'HEY2',
#   'HEY1',
#   'DVL2',
#   'MYC',
#   'WNT1',
#   'NCSTN',
#   'SKP2'],
#  'TGF-beta Signaling': ['TGFB1',
#   'ACVR1',
#   'RHOA',
#   'SMURF2',
#   'SMURF1',
#   'HIPK2',
#   'TGFBR1',
#   'PPP1CA',
#   'CDK9',
#   'SKI',
#   'RAB31',
#   'APC',
#   'BMP2',
#   'NCOR2',
#   'ID1',
#   'ID3',
#   'ID2',
#   'BMPR1A',
#   'BCAR3',
#   'BMPR2',
#   'SERPINE1',
#   'UBE2D3',
#   'PPP1R15A',
#   'ARID4B',
#   'CDH1',
#   'MAP3K7',
#   'SKIL',
#   'SPTBN1',
#   'SMAD3',
#   'WWTR1',
#   'TGIF1',
#   'LEFTY2',
#   'NOG',
#   'IFNGR2',
#   'SMAD1',
#   'KLF10',
#   'SMAD7',
#   'SMAD6',
#   'PPM1A',
#   'FKBP1A',
#   'TJP1',
#   'XIAP',
#   'ENG',
#   'TRIM33',
#   'CDKN1C',
#   'HDAC1',
#   'FURIN',
#   'CTNNB1',
#   'SLC20A1',
#   'THBS1',
#   'LTBP2',
#   'FNTA',
#   'PMEPA1',
#   'JUNB'],
#  'IL-6/JAK/STAT3 Signaling': ['PTPN1',
#   'TGFB1',
#   'CCR1',
#   'PTPN2',
#   'IL4R',
#   'JUN',
#   'IL1R1',
#   'IL1R2',
#   'ITGA4',
#   'TNFRSF12A',
#   'IL10RB',
#   'PLA2G2A',
#   'DNTT',
#   'PTPN11',
#   'TYK2',
#   'OSMR',
#   'TNFRSF1A',
#   'TNFRSF1B',
#   'CXCL10',
#   'HAX1',
#   'TLR2',
#   'CXCL11',
#   'IL1B',
#   'IRF1',
#   'TNFRSF21',
#   'IL7',
#   'CXCL13',
#   'IL6',
#   'CD9',
#   'FAS',
#   'IL3RA',
#   'IL9R',
#   'IRF9',
#   'IL6ST',
#   'PF4',
#   'STAM2',
#   'CRLF2',
#   'IL18R1',
#   'CNTFR',
#   'ACVRL1',
#   'CSF3R',
#   'CXCL9',
#   'CSF2',
#   'CSF1',
#   'EBI3',
#   'PIK3R5',
#   'TNF',
#   'CXCL1',
#   'IL2RG',
#   'CXCL3',
#   'SOCS3',
#   'SOCS1',
#   'CD38',
#   'CD36',
#   'IL12RB1',
#   'MAP3K8',
#   'IL17RA',
#   'IL15RA',
#   'IFNGR1',
#   'STAT1',
#   'IFNGR2',
#   'STAT2',
#   'STAT3',
#   'INHBE',
#   'IL17RB',
#   'MYD88',
#   'LTBR',
#   'IL2RA',
#   'LTB',
#   'GRB2',
#   'IFNAR1',
#   'CD44',
#   'REG1A',
#   'ITGB3',
#   'PDGFC',
#   'CSF2RA',
#   'ACVR1B',
#   'CBL',
#   'CSF2RB',
#   'CCL7',
#   'HMOX1',
#   'LEPR',
#   'PIM1',
#   'BAK1',
#   'A2M',
#   'CD14',
#   'IL13RA1'],
#  'DNA Repair': ['DUT',
#   'BRF2',
#   'LIG1',
#   'PDE6G',
#   'ALYREF',
#   'UPF3B',
#   'GTF2F1',
#   'RBX1',
#   'TARBP2',
#   'POLR3C',
#   'POLE4',
#   'SRSF6',
#   'EIF1B',
#   'CDA',
#   'TP53',
#   'VPS28',
#   'PCNA',
#   'MPG',
#   'RNMT',
#   'RALA',
#   'GTF2B',
#   'TYMS',
#   'ADCY6',
#   'PNP',
#   'TAF1C',
#   'ZNF707',
#   'CLP1',
#   'NT5C',
#   'RAE1',
#   'STX3',
#   'SMAD5',
#   'SURF1',
#   'VPS37D',
#   'VPS37B',
#   'SUPT5H',
#   'SDCBP',
#   'BCAM',
#   'NT5C3A',
#   'ITPA',
#   'HPRT1',
#   'CCNO',
#   'TSG101',
#   'POM121',
#   'COX17',
#   'ARL6IP1',
#   'AK1',
#   'CSTF3',
#   'AK3',
#   'XPC',
#   'AAAS',
#   'DGUOK',
#   'MPC2',
#   'NELFE',
#   'NELFB',
#   'SAC3D1',
#   'GSDME',
#   'RFC4',
#   'RFC5',
#   'NCBP2',
#   'POLR3GL',
#   'RFC2',
#   'GPX4',
#   'RFC3',
#   'NME3',
#   'EDF1',
#   'NME4',
#   'ZWINT',
#   'NME1',
#   'POLA1',
#   'POLA2',
#   'AGO4',
#   'NFX1',
#   'RRM2B',
#   'ADA',
#   'UMPS',
#   'GTF2A2',
#   'GTF3C5',
#   'CETN2',
#   'ELL',
#   'NPR2',
#   'SUPT4H1',
#   'MRPL40',
#   'ZNRD1',
#   'SNAPC4',
#   'SNAPC5',
#   'NELFCD',
#   'PDE4B',
#   'DGCR8',
#   'TMED2',
#   'TK2',
#   'BCAP31',
#   'SF3A3',
#   'TAF13',
#   'ADRM1',
#   'TAF12',
#   'BOLA2',
#   'RPA2',
#   'GTF2H1',
#   'RPA3',
#   'TAF10',
#   'SSRP1',
#   'GTF2H3',
#   'GTF2H5',
#   'APRT',
#   'DDB2',
#   'DDB1',
#   'ERCC1',
#   'NUDT21',
#   'RAD51',
#   'NUDT9',
#   'RAD52',
#   'ERCC4',
#   'ERCC5',
#   'IMPDH2',
#   'DAD1',
#   'ERCC2',
#   'POLR1C',
#   'ERCC3',
#   'POLR1D',
#   'CMPK2',
#   'ERCC8',
#   'HCLS1',
#   'TAF9',
#   'TAF6',
#   'FEN1',
#   'CANT1',
#   'GMPR2',
#   'USP11',
#   'DCTN4',
#   'PRIM1',
#   'POLD4',
#   'POLB',
#   'GUK1',
#   'POLR2A',
#   'POLD1',
#   'POLR2C',
#   'POLR2D',
#   'SEC61A1',
#   'POLD3',
#   'POLR2E',
#   'ELOA',
#   'POLR2F',
#   'POLR2G',
#   'POLR2H',
#   'POLL',
#   'POLR2I',
#   'POLR2J',
#   'POLR2K',
#   'POLH',
#   'REV3L'],
#  'G2-M Checkpoint': ['H2AZ2',
#   'CASP8AP2',
#   'EGF',
#   'H2AZ1',
#   'KNL1',
#   'SLC12A2',
#   'HUS1',
#   'CDC20',
#   'MAPK14',
#   'PML',
#   'DDX39A',
#   'MARCKS',
#   'NUP98',
#   'HNRNPD',
#   'KIF20B',
#   'CCNF',
#   'HNRNPU',
#   'NOLC1',
#   'EWSR1',
#   'CHEK1',
#   'RACGAP1',
#   'CDC27',
#   'RAD54L',
#   'SNRPD1',
#   'E2F1',
#   'MYC',
#   'E2F2',
#   'E2F3',
#   'E2F4',
#   'PLK4',
#   'PLK1',
#   'SQLE',
#   'STAG1',
#   'TPX2',
#   'UCK2',
#   'EZH2',
#   'ATF5',
#   'JPT1',
#   'NUMA1',
#   'HIF1A',
#   'SMC4',
#   'SMC2',
#   'GSPT1',
#   'TMPO',
#   'MT2A',
#   'SYNCRIP',
#   'STMN1',
#   'MYBL2',
#   'BARD1',
#   'SS18',
#   'UPF1',
#   'CDC7',
#   'CDC6',
#   'CENPE',
#   'SLC7A5',
#   'CENPF',
#   'INCENP',
#   'MTF2',
#   'PAFAH1B1',
#   'CDKN3',
#   'DTYMK',
#   'KIF11',
#   'YTHDC1',
#   'SUV39H1',
#   'TOP2A',
#   'KIF15',
#   'RASAL2',
#   'BRCA2',
#   'CTCF',
#   'SLC7A1',
#   'HOXC10',
#   'PBK',
#   'MAP3K20',
#   'CDKN2C',
#   'PRMT5',
#   'RPA2',
#   'TRAIP',
#   'CKS2',
#   'TACC3',
#   'H2AX',
#   'CDKN1B',
#   'PRIM2',
#   'MKI67',
#   'CENPA',
#   'XPO1',
#   'WRN',
#   'DMD',
#   'NUSAP1',
#   'SRSF10',
#   'GINS2',
#   'TGFB1',
#   'TLE3',
#   'UBE2C',
#   'CDC25A',
#   'PRPF4B',
#   'LIG3',
#   'ILF3',
#   'CDC25B',
#   'SAP30',
#   'DKC1',
#   'UBE2S',
#   'KIF4A',
#   'PTTG3P',
#   'MAD2L1',
#   'CCNT1',
#   'ODC1',
#   'SRSF1',
#   'SRSF2',
#   'ARID4A',
#   'AURKA',
#   'EFNA5',
#   'HIRA',
#   'AURKB',
#   'CCND1',
#   'NSD2',
#   'PURA',
#   'KIF5B',
#   'PTTG1',
#   'KMT5A',
#   'HMGN2',
#   'KPNA2',
#   'SMAD3',
#   'SLC38A1',
#   'KIF22',
#   'ODF2',
#   'STIL',
#   'FANCC',
#   'KIF23',
#   'NASP',
#   'FOXN3',
#   'NDC80',
#   'CCNA2',
#   'TFDP1',
#   'NCL',
#   'BIRC5',
#   'TROAP',
#   'KIF2C',
#   'MNAT1',
#   'NOTCH2',
#   'CUL5',
#   'CUL3',
#   'CUL1',
#   'PDS5B',
#   'CHAF1A',
#   'CCNB2',
#   'G3BP1',
#   'CHMP1A',
#   'NEK2',
#   'ABL1',
#   'DR1',
#   'HSPA8',
#   'CBX1',
#   'RAD23B',
#   'HMGA1',
#   'SMC1A',
#   'CUL4A',
#   'NUP50',
#   'POLA2',
#   'MEIS2',
#   'RBL1',
#   'MEIS1',
#   'ESPL1',
#   'SFPQ',
#   'CDK4',
#   'H2BC12',
#   'BCL3',
#   'CDK1',
#   'MCM5',
#   'MCM6',
#   'TOP1',
#   'MCM2',
#   'MCM3',
#   'AMD1',
#   'CKS1B',
#   'HMGB3',
#   'HMMR',
#   'LMNB1',
#   'TENT4A',
#   'ORC6',
#   'ORC5',
#   'RAD21',
#   'LBR',
#   'TNPO2',
#   'RBM14',
#   'SMARCC1',
#   'ATRX',
#   'POLQ',
#   'KATNA1',
#   'PRC1',
#   'KPNB1',
#   'DBF4',
#   'TTK',
#   'RPS6KA5',
#   'CDC45',
#   'POLE',
#   'EXO1',
#   'TRA2B',
#   'FBXO5',
#   'BUB3',
#   'BUB1'],
#  'Apoptosis': ['GSN',
#   'PDGFRB',
#   'BIK',
#   'LUM',
#   'TGFB2',
#   'GSR',
#   'TAP1',
#   'CDC25B',
#   'EREG',
#   'MADD',
#   'CD2',
#   'FEZ1',
#   'FAS',
#   'CTH',
#   'BAX',
#   'PDCD4',
#   'CD69',
#   'SQSTM1',
#   'APP',
#   'DAP3',
#   'LEF1',
#   'ATF3',
#   'RELA',
#   'IFITM3',
#   'ROCK1',
#   'SATB1',
#   'RETSAT',
#   'CLU',
#   'TNF',
#   'LMNA',
#   'BCL2L11',
#   'PAK1',
#   'CCND2',
#   'BCL2L10',
#   'CCND1',
#   'SC5D',
#   'CREBBP',
#   'IGF2R',
#   'EGR3',
#   'F2R',
#   'IGFBP6',
#   'GADD45B',
#   'BNIP3L',
#   'GADD45A',
#   'HGF',
#   'AVPR1A',
#   'H1-0',
#   'SMAD7',
#   'PTK2',
#   'ISG20',
#   'CCNA1',
#   'BCL2L1',
#   'PPT1',
#   'BIRC3',
#   'BCL2L2',
#   'BCL10',
#   'PRF1',
#   'PSEN1',
#   'ENO2',
#   'FASLG',
#   'PLAT',
#   'PSEN2',
#   'SAT1',
#   'PPP3R1',
#   'LGALS3',
#   'EBP',
#   'ANKH',
#   'FDXR',
#   'HMOX1',
#   'PMAIP1',
#   'BMF',
#   'TNFSF10',
#   'CD14',
#   'IER3',
#   'DNM1L',
#   'GPX1',
#   'ANXA1',
#   'GPX3',
#   'JUN',
#   'GSTM1',
#   'GPX4',
#   'MMP2',
#   'TNFRSF12A',
#   'CAV1',
#   'CFLAR',
#   'EMP1',
#   'PPP2R5B',
#   'IL18',
#   'RHOB',
#   'TGFBR3',
#   'IL1A',
#   'DNAJC3',
#   'IL1B',
#   'IRF1',
#   'CYLD',
#   'BMP2',
#   'DAP',
#   'IL6',
#   'KRT18',
#   'DPYD',
#   'CDK2',
#   'ETF1',
#   'RARA',
#   'GUCY2D',
#   'BTG3',
#   'BTG2',
#   'DIABLO',
#   'TOP2A',
#   'PEA15',
#   'BRCA1',
#   'NEDD9',
#   'HMGB2',
#   'HSPB1',
#   'CASP8',
#   'CASP9',
#   'RHOT2',
#   'CASP6',
#   'CASP7',
#   'CASP4',
#   'ERBB2',
#   'ERBB3',
#   'CASP2',
#   'TIMP3',
#   'CASP3',
#   'CD38',
#   'TIMP1',
#   'CASP1',
#   'TIMP2',
#   'MCL1',
#   'BCAP31',
#   'DFFA',
#   'IFNGR1',
#   'MGMT',
#   'GCH1',
#   'BGN',
#   'F2',
#   'SOD1',
#   'DCN',
#   'SOD2',
#   'DNAJA1',
#   'WEE1',
#   'XIAP',
#   'TXNIP',
#   'DDIT3',
#   'VDAC2',
#   'PLCB2',
#   'CD44',
#   'CDKN1B',
#   'RNASEL',
#   'CDKN1A',
#   'PLPPR4',
#   'CTNNB1',
#   'SLC20A1',
#   'ADD1',
#   'GNA15',
#   'AIFM3',
#   'IFNB1',
#   'TSPO',
#   'NEFH',
#   'SPTAN1',
#   'BID'],
#  'Notch Signaling': ['FZD1',
#   'PSENEN',
#   'JAG1',
#   'TCF7L2',
#   'FBXW11',
#   'FZD5',
#   'WNT5A',
#   'FZD7',
#   'PRKCA',
#   'HEYL',
#   'RBX1',
#   'SAP30',
#   'KAT2A',
#   'PPARD',
#   'NOTCH3',
#   'NOTCH1',
#   'NOTCH2',
#   'MAML2',
#   'DTX1',
#   'CUL1',
#   'DTX2',
#   'DTX4',
#   'PSEN2',
#   'DLL1',
#   'APH1A',
#   'LFNG',
#   'ARRB1',
#   'CCND1',
#   'ST3GAL6',
#   'HES1',
#   'WNT2',
#   'SKP1'],
#  'Adipogenesis': ['ECH1',
#   'CIDEA',
#   'PEX14',
#   'LEP',
#   'UQCRC1',
#   'SPARCL1',
#   'PREB',
#   'SUCLG1',
#   'ITIH5',
#   'RETSAT',
#   'UQCR10',
#   'GHITM',
#   'RETN',
#   'ARAF',
#   'UQCR11',
#   'TOB1',
#   'ADCY6',
#   'SLC5A6',
#   'SNCG',
#   'STOM',
#   'COX8A',
#   'FZD4',
#   'ABCA1',
#   'OMD',
#   'GADD45A',
#   'TALDO1',
#   'RMDN3',
#   'CMBL',
#   'POR',
#   'UCK1',
#   'SSPN',
#   'CD302',
#   'PEMT',
#   'NMT1',
#   'ITSN1',
#   'BAZ2A',
#   'MGST3',
#   'MRPL15',
#   'MYLK',
#   'C3',
#   'PRDX3',
#   'SULT1A1',
#   'LIPE',
#   'GRPEL1',
#   'SCP2',
#   'APOE',
#   'SLC19A1',
#   'DECR1',
#   'STAT5A',
#   'CS',
#   'VEGFB',
#   'CCNG2',
#   'MRAP',
#   'ALDOA',
#   'MGLL',
#   'COX7B',
#   'MTARC2',
#   'ADIPOR2',
#   'ECHS1',
#   'NKIRAS1',
#   'CD36',
#   'ADIG',
#   'ADIPOQ',
#   'MAP4K3',
#   'CDKN2C',
#   'IFNGR1',
#   'MDH2',
#   'DGAT1',
#   'ELOVL6',
#   'ELMOD3',
#   'MCCC1',
#   'SQOR',
#   'SORBS1',
#   'DHRS7',
#   'COL4A1',
#   'FABP4',
#   'ESYT1',
#   'GPAM',
#   'NDUFAB1',
#   'LPCAT3',
#   'ANGPTL4',
#   'ATP5PO',
#   'PPARG',
#   'DLD',
#   'PLIN2',
#   'TKT',
#   'CMPK1',
#   'ORM1',
#   'SLC66A3',
#   'ATL2',
#   'PTGER3',
#   'GBE1',
#   'SAMM50',
#   'ACADM',
#   'ACADL',
#   'AIFM1',
#   'ENPP2',
#   'DLAT',
#   'GPAT4',
#   'RIOK3',
#   'ACADS',
#   'CAVIN1',
#   'PHYH',
#   'PTCD3',
#   'CAVIN2',
#   'APLP2',
#   'ATP1B3',
#   'LIFR',
#   'SDHB',
#   'FAH',
#   'SDHC',
#   'RAB34',
#   'UQCRQ',
#   'GPD2',
#   'PDCD4',
#   'DHCR7',
#   'CRAT',
#   'PPP1R15B',
#   'PHLDB1',
#   'SLC27A1',
#   'UCP2',
#   'SLC1A5',
#   'TANK',
#   'COX6A1',
#   'BCL2L13',
#   'ESRRA',
#   'IDH1',
#   'NABP1',
#   'EPHX2',
#   'CHCHD10',
#   'DNAJC15',
#   'ACLY',
#   'QDPR',
#   'REEP6',
#   'REEP5',
#   'PFKFB3',
#   'CD151',
#   'LPL',
#   'AK2',
#   'UBC',
#   'G3BP2',
#   'PIM3',
#   'ACAA2',
#   'CYC1',
#   'HADH',
#   'BCKDHA',
#   'GPX3',
#   'JAGN1',
#   'ANGPT1',
#   'GPX4',
#   'COQ9',
#   'COQ5',
#   'COQ3',
#   'BCL6',
#   'ACOX1',
#   'NDUFS3',
#   'ACO2',
#   'ITGA7',
#   'ARL4A',
#   'RTN3',
#   'SLC25A1',
#   'YWHAG',
#   'NDUFB7',
#   'ABCB8',
#   'HSPB8',
#   'DHRS7B',
#   'AGPAT3',
#   'DRAM2',
#   'DBT',
#   'CPT2',
#   'ME1',
#   'DNAJB9',
#   'RREB1',
#   'HIBCH',
#   'IDH3G',
#   'MIGA2',
#   'CHUK',
#   'NDUFA5',
#   'CYP4B1',
#   'IMMT',
#   'SOD1',
#   'PPM1B',
#   'PFKL',
#   'CAT',
#   'TST',
#   'SLC25A10',
#   'MTCH2',
#   'RNF11',
#   'SOWAHC',
#   'COL15A1',
#   'LAMA4',
#   'ETFB',
#   'GPHN',
#   'LTC4S',
#   'DDT',
#   'ALDH2',
#   'UBQLN1',
#   'IDH3A',
#   'SCARB1',
#   'PGM1'],
#  'Estrogen Response Early': ['TTC39A',
#   'AMFR',
#   'KRT8',
#   'MED13L',
#   'GLA',
#   'NBL1',
#   'RETREG1',
#   'AKAP1',
#   'ADCY1',
#   'PEX11A',
#   'ADCY9',
#   'AQP3',
#   'ABAT',
#   'TOB1',
#   'MUC1',
#   'MYB',
#   'MYC',
#   'CCN5',
#   'HES1',
#   'FDFT1',
#   'ABCA3',
#   'EGR3',
#   'XBP1',
#   'BCL11B',
#   'KLF10',
#   'SIAH2',
#   'PLAAT3',
#   'CBFA2T3',
#   'OVOL2',
#   'PDZK1',
#   'IL17RB',
#   'AR',
#   'SULT2B1',
#   'FASN',
#   'UNC119',
#   'PTGES',
#   'SLC22A5',
#   'RAPGEFL1',
#   'TSKU',
#   'SOX3',
#   'GJA1',
#   'INPP5F',
#   'SFN',
#   'MYBL1',
#   'SLC19A2',
#   'GREB1',
#   'ITPK1',
#   'MYOF',
#   'GAB2',
#   'KRT13',
#   'FAM102A',
#   'KLK10',
#   'RHOD',
#   'SLC7A5',
#   'KRT19',
#   'NCOR2',
#   'TUBB2B',
#   'KRT18',
#   'MAPT',
#   'MPPED2',
#   'BHLHE40',
#   'KRT15',
#   'TFF3',
#   'RARA',
#   'TFF1',
#   'RET',
#   'FOXC1',
#   'ABHD2',
#   'ENDOD1',
#   'STC2',
#   'TMPRSS3',
#   'AREG',
#   'SLC7A2',
#   'TMEM164',
#   'UGCG',
#   'SEC14L2',
#   'CLIC3',
#   'ELOVL2',
#   'SVIL',
#   'ELOVL5',
#   'FOS',
#   'SNX24',
#   'GFRA1',
#   'DHRS2',
#   'DHRS3',
#   'FARP1',
#   'MYBBP1A',
#   'DLC1',
#   'CD44',
#   'TJP3',
#   'LAD1',
#   'PRSS23',
#   'OLFML3',
#   'TBC1D30',
#   'ANXA9',
#   'RRP12',
#   'DEPTOR',
#   'JAK2',
#   'CA12',
#   'TFAP2C',
#   'MREG',
#   'SLC16A1',
#   'NPY1R',
#   'KAZN',
#   'OLFM1',
#   'CXCL12',
#   'RAB31',
#   'PPIF',
#   'IL6ST',
#   'DHCR7',
#   'FKBP5',
#   'FKBP4',
#   'FRK',
#   'SLC27A2',
#   'CELSR1',
#   'SLC1A1',
#   'SCNN1A',
#   'HR',
#   'SLC1A4',
#   'ASB13',
#   'CELSR2',
#   'PAPSS2',
#   'ABLIM1',
#   'CCND1',
#   'FLNB',
#   'SH3BP5',
#   'SLC39A6',
#   'RBBP8',
#   'MICB',
#   'OPN3',
#   'TGIF2',
#   'WFS1',
#   'CISH',
#   'IGFBP4',
#   'INHBB',
#   'SLC9A3R1',
#   'MED24',
#   'REEP1',
#   'PGR',
#   'BLVRB',
#   'FCMR',
#   'SLC26A2',
#   'WWC1',
#   'MINDY1',
#   'SLC2A1',
#   'ARL3',
#   'ISG20L2',
#   'IGF1R',
#   'RHOBTB3',
#   'TGM2',
#   'CALCR',
#   'RASGRP1',
#   'PODXL',
#   'BAG1',
#   'ALDH3B1',
#   'PMAIP1',
#   'SYBU',
#   'SLC37A1',
#   'KDM4B',
#   'TIPARP',
#   'NAV2',
#   'ELF1',
#   'ELF3',
#   'CHPT1',
#   'ESRP2',
#   'BCL2',
#   'KCNK5',
#   'B4GALT1',
#   'MAST4',
#   'HSPB8',
#   'AFF1',
#   'SYNGR1',
#   'CALB2',
#   'CYP26B1',
#   'PDLIM3',
#   'NRIP1',
#   'P2RY2',
#   'ZNF185',
#   'DYNLT3',
#   'TPBG',
#   'KCNK15',
#   'KLF4',
#   'TIAM1',
#   'TPD52L1',
#   'CLDN7',
#   'MLPH',
#   'SYT12',
#   'RAB17',
#   'SLC24A3',
#   'CANT1',
#   'NXT1',
#   'SEMA3B',
#   'FHL2',
#   'ADD3',
#   'NADSYN1',
#   'THSD4',
#   'RPS6KA2',
#   'LRIG1',
#   'MSMB',
#   'SCARB1'],
#  'Estrogen Response Late': ['UNC13B',
#   'HOMER2',
#   'CACNA2D2',
#   'AMFR',
#   'MAPK13',
#   'CDC20',
#   'ASS1',
#   'CD9',
#   'GLA',
#   'KIF20A',
#   'NBL1',
#   'TOB1',
#   'ASCL1',
#   'MYB',
#   'CCN5',
#   'MEST',
#   'FDFT1',
#   'ABCA3',
#   'PLK4',
#   'EGR3',
#   'CHST8',
#   'XBP1',
#   'ST14',
#   'TNNC1',
#   'XRCC3',
#   'SIAH2',
#   'PLAAT3',
#   'OVOL2',
#   'PDZK1',
#   'IL17RB',
#   'SULT2B1',
#   'GJB3',
#   'IGSF1',
#   'HPRT1',
#   'PTGES',
#   'HSPA4L',
#   'SLC22A5',
#   'TSTA3',
#   'RAPGEFL1',
#   'SOX3',
#   'PRKAR2B',
#   'PLAC1',
#   'SFN',
#   'TPSAB1',
#   'DUSP2',
#   'ITPK1',
#   'MYOF',
#   'EMP2',
#   'KRT13',
#   'CDC6',
#   'FAM102A',
#   'KLK10',
#   'COX6C',
#   'KLK11',
#   'SLC7A5',
#   'UGDH',
#   'KRT19',
#   'NCOR2',
#   'TH',
#   'MAPT',
#   'NMU',
#   'ID2',
#   'TFF3',
#   'TFF1',
#   'MOCS2',
#   'SGK1',
#   'SERPINA3',
#   'RET',
#   'BTG3',
#   'SERPINA1',
#   'FOXC1',
#   'ABHD2',
#   'TOP2A',
#   'TMPRSS3',
#   'AREG',
#   'SERPINA5',
#   'CLIC3',
#   'ELOVL5',
#   'METTL3',
#   'FOS',
#   'DHRS2',
#   'FARP1',
#   'GAL',
#   'FABP5',
#   'SLC29A1',
#   'LLGL2',
#   'CD44',
#   'TJP3',
#   'PTGER3',
#   'PRSS23',
#   'SNX10',
#   'IMPA2',
#   'CKB',
#   'ANXA9',
#   'AGR2',
#   'JAK1',
#   'JAK2',
#   'GINS2',
#   'CA12',
#   'TFAP2C',
#   'PRLR',
#   'SLC16A1',
#   'TFPI2',
#   'NPY1R',
#   'BATF',
#   'OLFM1',
#   'CXCL12',
#   'RAB31',
#   'PCP4',
#   'PKP3',
#   'PDCD4',
#   'PPIF',
#   'IL6ST',
#   'PLXNB1',
#   'DHCR7',
#   'FKBP5',
#   'FKBP4',
#   'PTPN6',
#   'S100A9',
#   'FRK',
#   'SLC27A2',
#   'SCNN1A',
#   'HR',
#   'SLC1A4',
#   'CELSR2',
#   'CXCL14',
#   'PAPSS2',
#   'SCUBE2',
#   'ZFP36',
#   'CCND1',
#   'CDH1',
#   'PERP',
#   'FLNB',
#   'RBBP8',
#   'MICB',
#   'OPN3',
#   'WFS1',
#   'CISH',
#   'STIL',
#   'IDH2',
#   'IGFBP4',
#   'DNAJC12',
#   'CYP4F11',
#   'SLC9A3R1',
#   'ALDH3A2',
#   'ISG20',
#   'CCNA1',
#   'DLG5',
#   'PGR',
#   'RNASEH2A',
#   'BLVRB',
#   'FGFR3',
#   'SLC26A2',
#   'NAB2',
#   'ARL3',
#   'SLC2A8',
#   'CALCR',
#   'BAG1',
#   'ALDH3B1',
#   'HMGCS2',
#   'CAV1',
#   'SORD',
#   'RABEP1',
#   'DNAJC1',
#   'ACOX2',
#   'CHPT1',
#   'CPE',
#   'BCL2',
#   'KCNK5',
#   'ST6GALNAC2',
#   'HSPB8',
#   'LAMC2',
#   'AFF1',
#   'CA2',
#   'MDK',
#   'CYP26B1',
#   'PDLIM3',
#   'NRIP1',
#   'GPER1',
#   'DYNLT3',
#   'DCXR',
#   'TPBG',
#   'ATP2B4',
#   'LSR',
#   'KLF4',
#   'TIAM1',
#   'TPD52L1',
#   'GALE',
#   'TST',
#   'LTF',
#   'SLC24A3',
#   'NXT1',
#   'SEMA3B',
#   'ETFB',
#   'TSPAN13',
#   'ADD3',
#   'TRIM29',
#   'RPS6KA2',
#   'SCARB1',
#   'LARGE1'],
#  'Androgen Response': ['UBE2I',
#   'GUCY1A1',
#   'ACSL3',
#   'GSR',
#   'HOMER2',
#   'ACTN1',
#   'KRT8',
#   'ZBTB10',
#   'LIFR',
#   'SELENOP',
#   'SCD',
#   'AZGP1',
#   'GPD1L',
#   'FKBP5',
#   'SEC24D',
#   'HPGD',
#   'NDRG1',
#   'SPDEF',
#   'CCND3',
#   'HERC3',
#   'ZMIZ1',
#   'CCND1',
#   'AKT1',
#   'B2M',
#   'SLC38A2',
#   'TMEM50A',
#   'XRCC5',
#   'XRCC6',
#   'ARID5B',
#   'H1-0',
#   'ELL2',
#   'PIAS1',
#   'INPP4B',
#   'MAF',
#   'MYL12A',
#   'APPBP2',
#   'MAK',
#   'SMS',
#   'PLPP1',
#   'SRP19',
#   'SLC26A2',
#   'NGLY1',
#   'INSIG1',
#   'SAT1',
#   'CDC14B',
#   'UBE2J1',
#   'ELK4',
#   'PMEPA1',
#   'ANKH',
#   'NKX3-1',
#   'RAB4A',
#   'ABCC4',
#   'HMGCS1',
#   'TSC22D1',
#   'NCOA4',
#   'PA2G4',
#   'DHCR24',
#   'SORD',
#   'MERTK',
#   'KRT19',
#   'CDK6',
#   'CENPN',
#   'BMPR1B',
#   'SGK1',
#   'IDI1',
#   'B4GALT1',
#   'KLK2',
#   'TNFAIP8',
#   'ABHD2',
#   'PTPN21',
#   'TMPRSS2',
#   'DBI',
#   'IQGAP2',
#   'KLK3',
#   'UAP1',
#   'STK39',
#   'MAP7',
#   'DNAJB9',
#   'PDLIM5',
#   'TPD52',
#   'ELOVL5',
#   'ADRM1',
#   'SPCS3',
#   'VAPA',
#   'ALDH1A3',
#   'STEAP4',
#   'SRF',
#   'HMGCR',
#   'HSD17B14',
#   'CAMKK2',
#   'GNAI3',
#   'LMAN1',
#   'AKAP12',
#   'ADAMTS1',
#   'RPS6KA3',
#   'PTK2B',
#   'PGM3',
#   'RRP12',
#   'ITGAV',
#   'FADS1'],
#  'Myogenesis': ['IFRD1',
#   'ACTN3',
#   'ACSL1',
#   'ACTN2',
#   'DES',
#   'COL1A1',
#   'MAPK12',
#   'MYL7',
#   'PC',
#   'SCD',
#   'MYL1',
#   'MYL2',
#   'PPP1R3C',
#   'MYL3',
#   'MYL4',
#   'APP',
#   'RB1',
#   'TAGLN',
#   'VIPR1',
#   'ADCY9',
#   'SPDEF',
#   'AKT2',
#   'SH3BGR',
#   'WWTR1',
#   'DTNA',
#   'GABARAPL2',
#   'DMPK',
#   'ATP6AP1',
#   'GADD45B',
#   'TNNC1',
#   'TNNC2',
#   'IGF1',
#   'OCEL1',
#   'PTP4A3',
#   'SLC6A8',
#   'MYLPF',
#   'TNNT1',
#   'SMTN',
#   'TNNT2',
#   'BIN1',
#   'TNNT3',
#   'PKIA',
#   'SSPN',
#   'CRYAB',
#   'CFD',
#   'SPARC',
#   'SCHIP1',
#   'ENO3',
#   'MYLK',
#   'GJA5',
#   'APOD',
#   'MYBPC3',
#   'MYOG',
#   'SPHK1',
#   'SIRT2',
#   'FXYD1',
#   'MRAS',
#   'COL3A1',
#   'BHLHE40',
#   'HRC',
#   'ACHE',
#   'FLII',
#   'STC2',
#   'AEBP1',
#   'CSRP3',
#   'ANKRD2',
#   'CD36',
#   'TEAD4',
#   'NQO1',
#   'MEF2A',
#   'MEF2D',
#   'SVIL',
#   'MEF2C',
#   'PGAM2',
#   'PICK1',
#   'GAA',
#   'ADAM12',
#   'SORBS1',
#   'SORBS3',
#   'MYBPH',
#   'FKBP1B',
#   'FABP3',
#   'COL4A2',
#   'RIT1',
#   'TCAP',
#   'HBEGF',
#   'MAPRE3',
#   'RYR1',
#   'CTF1',
#   'CDKN1A',
#   'PYGM',
#   'CHRNG',
#   'CKB',
#   'DMD',
#   'SPTAN1',
#   'MYOZ1',
#   'GSN',
#   'TGFB1',
#   'AGL',
#   'CKM',
#   'TPM3',
#   'TPM2',
#   'TSC2',
#   'APLNR',
#   'PLXNB2',
#   'CHRNB1',
#   'CRAT',
#   'AGRN',
#   'CHRNA1',
#   'CLU',
#   'COX6A2',
#   'FOXO4',
#   'ABLIM1',
#   'SLN',
#   'SH2B1',
#   'MYH11',
#   'KCNH1',
#   'PPFIA4',
#   'KCNH2',
#   'FDPS',
#   'PRNP',
#   'DENND2B',
#   'FST',
#   'IGFBP3',
#   'REEP1',
#   'KIFC3',
#   'COL6A3',
#   'COL6A2',
#   'CDH13',
#   'CASQ1',
#   'CASQ2',
#   'MYF6',
#   'PVALB',
#   'MYOM1',
#   'MYOM2',
#   'NOTCH1',
#   'AK1',
#   'PSEN2',
#   'COX7A1',
#   'FGF2',
#   'MYL6B',
#   'CACNA1H',
#   'CNN3',
#   'BAG1',
#   'IGFBP7',
#   'GPX3',
#   'CAV3',
#   'NAV2',
#   'MYH1',
#   'MYH2',
#   'ACTA1',
#   'MYH3',
#   'LPIN1',
#   'MYH4',
#   'GNAO1',
#   'MYH9',
#   'ITGA7',
#   'MYH7',
#   'MYH8',
#   'NCAM1',
#   'HSPB8',
#   'HSPB2',
#   'SYNGR2',
#   'MB',
#   'ERBB3',
#   'BDKRB2',
#   'PDLIM7',
#   'PTGIS',
#   'DAPK2',
#   'PDE4DIP',
#   'KLF5',
#   'SOD3',
#   'TPD52L1',
#   'MYO1C',
#   'PFKM',
#   'HDAC5',
#   'EIF4A2',
#   'ITGB1',
#   'LSP1',
#   'COL15A1',
#   'ITGB5',
#   'LAMA2',
#   'FHL1',
#   'ITGB4',
#   'CAMK2B',
#   'ATP2A1',
#   'LDB3',
#   'ACTC1',
#   'EFS',
#   'CKMT2',
#   'SGCG',
#   'SGCD',
#   'SGCA',
#   'SPEG',
#   'TNNI2',
#   'CACNG1',
#   'NOS1',
#   'EPHB3',
#   'LARGE1',
#   'TNNI1'],
#  'Protein Secretion': ['ARFGEF2',
#   'ARFGEF1',
#   'RAB2A',
#   'CAV2',
#   'YIPF6',
#   'OCRL',
#   'AP3B1',
#   'SCAMP1',
#   'SCAMP3',
#   'ZW10',
#   'KRT18',
#   'TMX1',
#   'RER1',
#   'ANP32E',
#   'GLA',
#   'PAM',
#   'ERGIC3',
#   'SEC24D',
#   'COPE',
#   'STX16',
#   'TMED10',
#   'ARF1',
#   'SGMS1',
#   'SNAP23',
#   'NAPA',
#   'VPS4B',
#   'CLTC',
#   'CLTA',
#   'ATP1A1',
#   'EGFR',
#   'NAPG',
#   'STX12',
#   'SNX2',
#   'LAMP2',
#   'STX7',
#   'AP2S1',
#   'TMED2',
#   'YKT6',
#   'ARFIP1',
#   'KIF1B',
#   'CTSC',
#   'IGF2R',
#   'MON2',
#   'TPD52',
#   'ABCA1',
#   'GBF1',
#   'DST',
#   'AP2B1',
#   'COG2',
#   'M6PR',
#   'ADAM10',
#   'STAM',
#   'ARCN1',
#   'SOD1',
#   'ARFGAP3',
#   'GALC',
#   'VAMP7',
#   'DOP1A',
#   'RAB14',
#   'TOM1L1',
#   'RAB9A',
#   'USO1',
#   'VPS45',
#   'GNAS',
#   'PPT1',
#   'SSPN',
#   'RAB5A',
#   'SEC22B',
#   'ATP6V1B1',
#   'VAMP3',
#   'VAMP4',
#   'BET1',
#   'TSG101',
#   'CD63',
#   'COPB2',
#   'COPB1',
#   'GOSR2',
#   'ICA1',
#   'CLCN3',
#   'RAB22A',
#   'CLN5',
#   'LMAN1',
#   'GOLGA4',
#   'AP1G1',
#   'SCRN1',
#   'RPS6KA3',
#   'TSPAN8',
#   'AP3S1',
#   'BNIP3',
#   'MAPK1',
#   'SEC31A',
#   'ATP7A',
#   'ATP6V1H',
#   'AP2M1',
#   'DNM1L',
#   'SH3GL2'],
#  'Interferon Alpha Response': ['CD74',
#   'IL4R',
#   'MX1',
#   'SP110',
#   'RSAD2',
#   'TAP1',
#   'PSMB9',
#   'CXCL10',
#   'CXCL11',
#   'IFI44L',
#   'LAP3',
#   'LPAR6',
#   'IFI27',
#   'TRAFD1',
#   'LY6E',
#   'TRIM14',
#   'IFITM2',
#   'IFITM3',
#   'SAMD9',
#   'CSF1',
#   'IFITM1',
#   'SAMD9L',
#   'UBE2L6',
#   'RNF31',
#   'HERC6',
#   'LAMP3',
#   'CCRL2',
#   'MVB12A',
#   'B2M',
#   'CMTR1',
#   'GBP2',
#   'EPSTI1',
#   'GBP4',
#   'BATF2',
#   'HLA-C',
#   'TENT5A',
#   'ISG15',
#   'TDRD7',
#   'IFI44',
#   'PARP14',
#   'MOV10',
#   'ISG20',
#   'PARP12',
#   'PLSCR1',
#   'PROCR',
#   'SELL',
#   'PSME2',
#   'PSME1',
#   'CNP',
#   'LGALS3BP',
#   'IFI35',
#   'IFIT2',
#   'IFI30',
#   'DDX60',
#   'IFIT3',
#   'HELZ2',
#   'NUB1',
#   'PNPT1',
#   'IL15',
#   'NCOA7',
#   'EIF2AK2',
#   'NMI',
#   'OAS1',
#   'BST2',
#   'ELF1',
#   'IRF1',
#   'IL7',
#   'IRF2',
#   'IRF9',
#   'IRF7',
#   'UBA7',
#   'GMPR',
#   'ADAR',
#   'CASP8',
#   'TRIM5',
#   'RIPK2',
#   'CASP1',
#   'STAT2',
#   'WARS1',
#   'PARP9',
#   'PSMA3',
#   'CMPK2',
#   'TXNIP',
#   'CD47',
#   'RTP4',
#   'C1S',
#   'OGFR',
#   'TMEM140',
#   'USP18',
#   'OASL',
#   'SLC25A28',
#   'IFIH1',
#   'PSMB8',
#   'DHX58',
#   'TRIM25',
#   'TRIM26',
#   'TRIM21'],
#  'Interferon Gamma Response': ['GBP6',
#   'MX1',
#   'SP110',
#   'MX2',
#   'RSAD2',
#   'PSMB9',
#   'PML',
#   'NUP93',
#   'LAP3',
#   'MTHFD2',
#   'IFI27',
#   'TRIM14',
#   'RBCK1',
#   'IDO1',
#   'IFITM2',
#   'IFITM3',
#   'FGL2',
#   'NOD1',
#   'UBE2L6',
#   'PSMB10',
#   'APOL6',
#   'HERC6',
#   'PNP',
#   'ST3GAL5',
#   'SLAMF7',
#   'B2M',
#   'EPSTI1',
#   'GBP4',
#   'BATF2',
#   'ST8SIA4',
#   'PLA2G4A',
#   'HLA-A',
#   'HLA-B',
#   'HLA-G',
#   'IFI44',
#   'PARP14',
#   'LATS2',
#   'PARP12',
#   'PLSCR1',
#   'VAMP8',
#   'BANK1',
#   'PSME2',
#   'SERPING1',
#   'PSME1',
#   'SSPN',
#   'VAMP5',
#   'CFB',
#   'HLA-DRB1',
#   'CFH',
#   'IFI35',
#   'HIF1A',
#   'IFIT2',
#   'IFI30',
#   'IFIT1',
#   'ICAM1',
#   'IFIT3',
#   'RNF213',
#   'HELZ2',
#   'MT2A',
#   'KLRK1',
#   'TNFSF10',
#   'CMKLR1',
#   'GPR18',
#   'NCOA3',
#   'PNPT1',
#   'IL15',
#   'IL10RA',
#   'NMI',
#   'BST2',
#   'RAPGEF6',
#   'IL18BP',
#   'CD40',
#   'BTG1',
#   'SECTM1',
#   'FPR1',
#   'SOCS3',
#   'SOCS1',
#   'CD38',
#   'RIPK2',
#   'RIPK1',
#   'HLA-DQA1',
#   'P2RY14',
#   'STAT1',
#   'GCH1',
#   'STAT2',
#   'STAT3',
#   'STAT4',
#   'PSMA2',
#   'PSMA3',
#   'CMPK2',
#   'PELI1',
#   'MARCHF1',
#   'CDKN1A',
#   'OGFR',
#   'PTGS2',
#   'IFIH1',
#   'PSMB8',
#   'NAMPT',
#   'PSMB2',
#   'METTL7B',
#   'HLA-DMA',
#   'JAK2',
#   'PTPN1',
#   'PTPN2',
#   'ZBP1',
#   'CD74',
#   'IL4R',
#   'TOR1B',
#   'TAP1',
#   'VCAM1',
#   'CXCL10',
#   'CXCL11',
#   'IFI44L',
#   'ZNFX1',
#   'FAS',
#   'TRAFD1',
#   'LY6E',
#   'CD69',
#   'PTPN6',
#   'CD86',
#   'SAMD9L',
#   'RNF31',
#   'CMTR1',
#   'DDX58',
#   'AUTS2',
#   'ARID5B',
#   'ISG15',
#   'TDRD7',
#   'NFKB1',
#   'ISG20',
#   'MYD88',
#   'SELP',
#   'XAF1',
#   'IFNAR2',
#   'CD274',
#   'LGALS3BP',
#   'SPPL2A',
#   'CSF2RB',
#   'DDX60',
#   'PIM1',
#   'EIF2AK2',
#   'XCL1',
#   'TAPBP',
#   'IRF1',
#   'NFKBIA',
#   'IL7',
#   'IL6',
#   'IRF4',
#   'OAS2',
#   'IRF5',
#   'OAS3',
#   'IRF2',
#   'IRF8',
#   'IRF9',
#   'IRF7',
#   'LCP2',
#   'EIF4E3',
#   'ARL4A',
#   'CXCL9',
#   'TNFAIP6',
#   'TNFAIP3',
#   'NLRC5',
#   'TNFAIP2',
#   'ADAR',
#   'CASP8',
#   'CASP7',
#   'CASP4',
#   'CASP3',
#   'ISOC1',
#   'PDE4B',
#   'CASP1',
#   'CIITA',
#   'IL15RA',
#   'GZMA',
#   'LYSMD2',
#   'BPGM',
#   'WARS1',
#   'SOD2',
#   'IL2RB',
#   'TXNIP',
#   'PFKP',
#   'C1R',
#   'RTP4',
#   'C1S',
#   'MVP',
#   'SRI',
#   'USP18',
#   'OASL',
#   'SAMHD1',
#   'SLC25A28',
#   'FCGR1A',
#   'CCL7',
#   'DHX58',
#   'CCL5',
#   'TRIM25',
#   'TRIM26',
#   'CCL2',
#   'ITGB7',
#   'TRIM21',
#   'UPP1'],
#  'Apical Junction': ['GAMT',
#   'ACTN4',
#   'CADM2',
#   'ACTN3',
#   'CADM3',
#   'ACTN2',
#   'ACTN1',
#   'MAPK13',
#   'MAPK14',
#   'MAPK11',
#   'CD209',
#   'COL9A1',
#   'MYL9',
#   'PFN1',
#   'SKAP2',
#   'MYL12B',
#   'PARD6G',
#   'ACTB',
#   'TIAL1',
#   'AKT3',
#   'AKT2',
#   'FYB1',
#   'TUBG1',
#   'ALOX15B',
#   'PBX2',
#   'PTK2',
#   'VASP',
#   'WNK4',
#   'GRB7',
#   'DMP1',
#   'ICAM4',
#   'ICAM5',
#   'ICAM1',
#   'ICAM2',
#   'EPB41L2',
#   'DHX16',
#   'PLCG1',
#   'TSPAN4',
#   'TMEM8B',
#   'CDSN',
#   'JUP',
#   'RHOF',
#   'VAV2',
#   'CLDN11',
#   'PTPRC',
#   'CLDN15',
#   'CLDN14',
#   'CLDN19',
#   'EXOC4',
#   'CLDN18',
#   'ARHGEF6',
#   'SDC3',
#   'TNFRSF11B',
#   'THY1',
#   'CX3CL1',
#   'RRAS',
#   'MPZL1',
#   'RSU1',
#   'MAP3K20',
#   'CD34',
#   'MPZL2',
#   'MAP4K2',
#   'CAP1',
#   'MPP5',
#   'SYK',
#   'SORBS3',
#   'LIMA1',
#   'TJP1',
#   'ADAM15',
#   'TAOK2',
#   'CRB3',
#   'AMIGO1',
#   'AMIGO2',
#   'ADAM23',
#   'WASL',
#   'GNAI1',
#   'GNAI2',
#   'CTNNA1',
#   'HRAS',
#   'LDLRAP1',
#   'RAC2',
#   'IKBKG',
#   'GTF2F1',
#   'TSC1',
#   'VCAM1',
#   'ITGA10',
#   'TGFBI',
#   'ZYX',
#   'ADAM9',
#   'DSC1',
#   'CRAT',
#   'DSC3',
#   'CNTN1',
#   'CD86',
#   'COL16A1',
#   'CTNND1',
#   'NEXN',
#   'ATP1A3',
#   'INPPL1',
#   'EGFR',
#   'CDH8',
#   'CDH6',
#   'CDH4',
#   'CDH3',
#   'CDH1',
#   'NRAP',
#   'SLIT2',
#   'FLNC',
#   'STX4',
#   'MYH10',
#   'JAM3',
#   'KCNH2',
#   'SLC30A3',
#   'TRAF1',
#   'LAYN',
#   'KRT31',
#   'DLG1',
#   'CDH11',
#   'ARPC2',
#   'FSCN1',
#   'CDH15',
#   'FBN1',
#   'VCL',
#   'CD276',
#   'CD274',
#   'COL17A1',
#   'IRS1',
#   'INSIG1',
#   'ACTG1',
#   'ACTG2',
#   'CNN2',
#   'PDZD3',
#   'SIRPA',
#   'NRTN',
#   'HADH',
#   'CD99',
#   'LAMB3',
#   'MMP2',
#   'ITGA3',
#   'MSN',
#   'ITGA2',
#   'SHROOM2',
#   'MMP9',
#   'BAIAP2',
#   'PARVA',
#   'RASA1',
#   'VCAN',
#   'ACTA1',
#   'CDK8',
#   'BMP1',
#   'PIK3CB',
#   'ITGA9',
#   'MYH9',
#   'NF2',
#   'NF1',
#   'PECAM1',
#   'B4GALT1',
#   'NLGN2',
#   'NLGN3',
#   'SHC1',
#   'NRXN2',
#   'PIK3R3',
#   'LAMC2',
#   'ADRA1B',
#   'TRO',
#   'MDK',
#   'CALB2',
#   'MADCAM1',
#   'SYMPK',
#   'AMH',
#   'YWHAH',
#   'NEGR1',
#   'VWF',
#   'CLDN7',
#   'CLDN6',
#   'CLDN5',
#   'CLDN4',
#   'NFASC',
#   'PPP2R2C',
#   'CLDN9',
#   'CLDN8',
#   'NECTIN1',
#   'CERCAM',
#   'EVL',
#   'MVD',
#   'NECTIN4',
#   'NECTIN3',
#   'NECTIN2',
#   'ITGB1',
#   'PKD1',
#   'SRC',
#   'LAMA3',
#   'ITGB4',
#   'PTEN',
#   'ACTC1',
#   'THBS3',
#   'ADAMTS5',
#   'SGCE',
#   'SPEG',
#   'PCDH1'],
#  'Apical Surface': ['LYN',
#   'SLC34A3',
#   'GSTM3',
#   'AFAP1L2',
#   'NTNG1',
#   'NCOA6',
#   'ATP8B1',
#   'CD160',
#   'ADAM10',
#   'PLAUR',
#   'SHROOM2',
#   'SULF2',
#   'DCBLD2',
#   'RTN4RL1',
#   'GAS1',
#   'IL2RB',
#   'MAL',
#   'GHRL',
#   'RHCG',
#   'APP',
#   'CRYBG1',
#   'SRPX',
#   'B4GALT1',
#   'MDGA1',
#   'CROCC',
#   'LYPD3',
#   'AKAP7',
#   'BRCA1',
#   'PCSK9',
#   'SLC2A4',
#   'IL2RG',
#   'ADIPOR2',
#   'GATA3',
#   'THY1',
#   'CX3CL1',
#   'EFNA5',
#   'HSPB1',
#   'SCUBE1',
#   'PKHD1',
#   'FLOT2',
#   'ATP6V0A4',
#   'TMEM8B',
#   'EPHB4',
#   'SLC22A12'],
#  'Hedgehog Signaling': ['TLE3',
#   'TLE1',
#   'UNC5C',
#   'PTCH1',
#   'VEGFA',
#   'L1CAM',
#   'PML',
#   'RASA1',
#   'CDK6',
#   'MYH9',
#   'NF1',
#   'CDK5R1',
#   'SCG2',
#   'ACHE',
#   'CNTFR',
#   'NRP1',
#   'NRP2',
#   'RTN1',
#   'CELSR1',
#   'LDB1',
#   'CRMP1',
#   'PLG',
#   'THY1',
#   'VLDLR',
#   'ETS2',
#   'GLI1',
#   'AMOT',
#   'DPYSL2',
#   'SHH',
#   'HEY2',
#   'HEY1',
#   'OPHN1',
#   'SLIT1',
#   'NRCAM',
#   'ADGRG1',
#   'NKX6-1'],
#  'Complement': ['ACTN2',
#   'HPCAL4',
#   'PSMB9',
#   'XPNPEP1',
#   'LAP3',
#   'FDX1',
#   'HSPA1A',
#   'CALM3',
#   'PFN1',
#   'CDA',
#   'CALM1',
#   'LRP1',
#   'SERPINE1',
#   'C4BPB',
#   'CBLB',
#   'PRCP',
#   'ITIH1',
#   'RNF4',
#   'GNG2',
#   'S100A13',
#   'SPOCK2',
#   'PRSS3',
#   'S100A12',
#   'APOBEC3F',
#   'APOBEC3G',
#   'PRKCD',
#   'PLA2G4A',
#   'EHD1',
#   'PLSCR1',
#   'LGMN',
#   'SERPING1',
#   'GRB2',
#   'ZFPM2',
#   'CFB',
#   'GMFB',
#   'CFH',
#   'PDGFB',
#   'PREP',
#   'GATA3',
#   'PLA2G7',
#   'C2',
#   'LIPA',
#   'C3',
#   'LGALS3',
#   'PPP4C',
#   'C9',
#   'LTA4H',
#   'CTSB',
#   'DUSP5',
#   'DUSP6',
#   'LYN',
#   'ANXA5',
#   'FN1',
#   'SIRT6',
#   'RHOG',
#   'CP',
#   'RBSN',
#   'GP9',
#   'MMP13',
#   'ZEB1',
#   'MMP12',
#   'MMP15',
#   'MMP14',
#   'KLKB1',
#   'SERPINA1',
#   'TMPRSS6',
#   'KLK1',
#   'PCSK9',
#   'CTSV',
#   'CTSS',
#   'GNGT2',
#   'CTSO',
#   'CSRP1',
#   'CASP10',
#   'CTSL',
#   'HNF4A',
#   'CTSH',
#   'RCE1',
#   'TIMP1',
#   'TIMP2',
#   'CD36',
#   'FCER1G',
#   'CTSD',
#   'CTSC',
#   'SERPINB2',
#   'PRSS36',
#   'F2',
#   'GP1BA',
#   'F3',
#   'RABIF',
#   'F5',
#   'F7',
#   'F8',
#   'PDP1',
#   'COL4A2',
#   'CD40LG',
#   'CDK5R1',
#   'CD46',
#   'MSRB1',
#   'C1QC',
#   'C1QA',
#   'SERPINC1',
#   'WAS',
#   'GNAI2',
#   'GNAI3',
#   'PHEX',
#   'PCLO',
#   'PPP2CB',
#   'CD59',
#   'AKAP10',
#   'OLR1',
#   'CD55',
#   'JAK2',
#   'USP8',
#   'BRPF3',
#   'F10',
#   'GCA',
#   'TFPI2',
#   'GPD2',
#   'ADAM9',
#   'SCG3',
#   'S100A9',
#   'FCN1',
#   'RAF1',
#   'DGKH',
#   'DGKG',
#   'PRDM4',
#   'CLU',
#   'DOCK10',
#   'LAMP2',
#   'STX4',
#   'SH2B3',
#   'ADRA2B',
#   'MAFF',
#   'KIF2A',
#   'GNB2',
#   'CDH13',
#   'GNB4',
#   'NOTCH4',
#   'DOCK4',
#   'DYRK2',
#   'DOCK9',
#   'PSEN1',
#   'PLAT',
#   'VCPIP1',
#   'RASGRP1',
#   'PIM1',
#   'MMP8',
#   'KCNIP2',
#   'HSPA5',
#   'KCNIP3',
#   'MT3',
#   'APOA4',
#   'IRF1',
#   'IL6',
#   'PIK3CA',
#   'IRF2',
#   'IRF7',
#   'LCP2',
#   'CPM',
#   'CPQ',
#   'L3MBTL4',
#   'PIK3R5',
#   'TNFAIP3',
#   'CXCL1',
#   'DPP4',
#   'CA2',
#   'CASP9',
#   'CASP7',
#   'CASP4',
#   'CASP5',
#   'CASP3',
#   'ME1',
#   'CASP1',
#   'CR1',
#   'CR2',
#   'GZMB',
#   'ERAP2',
#   'GZMA',
#   'PLAUR',
#   'ATOX1',
#   'GZMK',
#   'LCK',
#   'APOC1',
#   'ANG',
#   'LTF',
#   'USP14',
#   'CEBPB',
#   'USP15',
#   'C1R',
#   'SRC',
#   'USP16',
#   'PLEK',
#   'C1S',
#   'PLG',
#   'ITGAM',
#   'PIK3CG',
#   'CCL5',
#   'KYNU',
#   'FYN'],
#  'Unfolded Protein Response': ['IMP3',
#   'ZBTB17',
#   'YIF1A',
#   'ERN1',
#   'CNOT6',
#   'DKC1',
#   'MTHFD2',
#   'PSAT1',
#   'CNOT2',
#   'CNOT4',
#   'PREB',
#   'TARS1',
#   'DCP1A',
#   'NHP2',
#   'ATF3',
#   'ATP6V0D1',
#   'GEMIN4',
#   'NOLC1',
#   'PARN',
#   'SLC1A4',
#   'SDAD1',
#   'HSP90B1',
#   'KHSRP',
#   'EXOSC10',
#   'TATDN2',
#   'EXOSC5',
#   'IARS1',
#   'EXOSC9',
#   'KIF5B',
#   'CHAC1',
#   'BANF1',
#   'EXOSC4',
#   'EXOSC2',
#   'EXOSC1',
#   'TTC37',
#   'IGFBP1',
#   'NOP14',
#   'TSPYL2',
#   'XBP1',
#   'WFS1',
#   'EDEM1',
#   'NABP1',
#   'SLC30A5',
#   'LSM1',
#   'EEF2',
#   'EIF2S1',
#   'LSM4',
#   'PDIA6',
#   'PDIA5',
#   'ARFGAP1',
#   'EIF4G1',
#   'SRPRB',
#   'HYOU1',
#   'ATF6',
#   'ATF4',
#   'EIF4EBP1',
#   'POP4',
#   'SRPRA',
#   'IFIT1',
#   'RRP9',
#   'EDC4',
#   'BAG3',
#   'SEC31A',
#   'RPS14',
#   'HSPA9',
#   'FUS',
#   'HSPA5',
#   'ASNS',
#   'EIF2AK3',
#   'WIPI1',
#   'TUBB2A',
#   'VEGFA',
#   'SLC7A5',
#   'DNAJC3',
#   'ALDH18A1',
#   'CALR',
#   'EXOC2',
#   'SHC1',
#   'CKS1B',
#   'STC2',
#   'SSR1',
#   'DNAJB9',
#   'EIF4E',
#   'NPM1',
#   'NFYB',
#   'DDX10',
#   'YWHAZ',
#   'SPCS3',
#   'SPCS1',
#   'XPOT',
#   'DDIT4',
#   'DNAJA4',
#   'KDELR3',
#   'DCP2',
#   'NOP56',
#   'EIF4A3',
#   'CEBPB',
#   'EIF4A2',
#   'H2AX',
#   'EIF4A1',
#   'SEC11A',
#   'ERO1A',
#   'CEBPG',
#   'FKBP14',
#   'GOSR2',
#   'CXXC1',
#   'DCTN1',
#   'HERPUD1',
#   'SERP1',
#   'MTREX',
#   'CCL2',
#   'NFYA',
#   'PAIP1'],
#  'PI3K/AKT/mTOR  Signaling': ['TSC2',
#   'PPP1CA',
#   'MAPK10',
#   'SQSTM1',
#   'PFN1',
#   'RAF1',
#   'UBE2N',
#   'PRKAA2',
#   'RALB',
#   'ATF1',
#   'SLA',
#   'UBE2D3',
#   'NOD1',
#   'ADCY2',
#   'IL2RG',
#   'EGFR',
#   'HSP90B1',
#   'E2F1',
#   'AKT1',
#   'CFL1',
#   'MAP3K7',
#   'PAK4',
#   'PITX2',
#   'FGF22',
#   'SMAD2',
#   'MAP2K3',
#   'PRKCB',
#   'TRAF2',
#   'FGF17',
#   'MYD88',
#   'ARPC3',
#   'CSNK2B',
#   'GRB2',
#   'PIN1',
#   'SLC2A1',
#   'FASLG',
#   'DAPP1',
#   'FGF6',
#   'TBK1',
#   'THEM4',
#   'PRKAR2A',
#   'PLCG1',
#   'SFN',
#   'PDK1',
#   'MAP2K6',
#   'AP2M1',
#   'ACTR3',
#   'ACTR2',
#   'DUSP3',
#   'PTPN11',
#   'IRAK4',
#   'TNFRSF1A',
#   'VAV3',
#   'NFKBIB',
#   'IL4',
#   'ECSIT',
#   'PIKFYVE',
#   'AKT1S1',
#   'CDK4',
#   'CDK2',
#   'CAMK4',
#   'CDK1',
#   'CALR',
#   'GSK3B',
#   'YWHAB',
#   'ARF1',
#   'CAB39L',
#   'MAPKAP1',
#   'CLTC',
#   'ITPR2',
#   'PIK3R3',
#   'ACACA',
#   'GRK2',
#   'GNGT1',
#   'MKNK1',
#   'MKNK2',
#   'RIPK1',
#   'EIF4E',
#   'PLA2G12A',
#   'STAT2',
#   'NGF',
#   'TIAM1',
#   'LCK',
#   'RIT1',
#   'DDIT3',
#   'TRIB3',
#   'PLCB1',
#   'CDKN1B',
#   'CDKN1A',
#   'CAB39',
#   'PTEN',
#   'PRKAG1',
#   'GNA14',
#   'ARHGDIA',
#   'RPTOR',
#   'MAPK9',
#   'MAPK8',
#   'RPS6KA1',
#   'PPP2R1B',
#   'CXCR4',
#   'RPS6KA3',
#   'HRAS',
#   'MAPK1',
#   'RAC1',
#   'NCK1'],
#  'mTORC1 Signaling': ['STARD4',
#   'ACSL3',
#   'IFRD1',
#   'SYTL2',
#   'PPA1',
#   'HSPE1',
#   'CCT6A',
#   'DDX39A',
#   'PSMC6',
#   'SCD',
#   'HMBS',
#   'MTHFD2',
#   'PSMC4',
#   'CD9',
#   'MTHFD2L',
#   'PSMC2',
#   'CTH',
#   'POLR3G',
#   'GLA',
#   'SKAP2',
#   'TES',
#   'NUP205',
#   'FGL2',
#   'CCNF',
#   'ARPC5L',
#   'GLRX',
#   'PNP',
#   'XBP1',
#   'PLK1',
#   'EDEM1',
#   'TUBG1',
#   'DHFR',
#   'UCHL5',
#   'SLC6A6',
#   'SQLE',
#   'MLLT11',
#   'EPRS1',
#   'LGMN',
#   'PSME3',
#   'HPRT1',
#   'NMT1',
#   'TFRC',
#   'PITPNB',
#   'ENO1',
#   'TMEM97',
#   'CFP',
#   'IFI30',
#   'RRP9',
#   'TBK1',
#   'FDXR',
#   'PRDX1',
#   'LTA4H',
#   'PNO1',
#   'SERPINH1',
#   'PDK1',
#   'SDF2L1',
#   'TPI1',
#   'SLC7A5',
#   'P4HA1',
#   'BHLHE40',
#   'CCNG1',
#   'CALR',
#   'ALDOA',
#   'EEF1E1',
#   'GPI',
#   'BTG2',
#   'RPN1',
#   'STC1',
#   'ADIPOR2',
#   'SLC7A11',
#   'VLDLR',
#   'ACACA',
#   'STIP1',
#   'LDHA',
#   'SSR1',
#   'NFIL3',
#   'PHGDH',
#   'CTSC',
#   'EGLN3',
#   'ELOVL5',
#   'ELOVL6',
#   'NFYC',
#   'CACYBP',
#   'GTF2H1',
#   'RPA1',
#   'PSMA4',
#   'PSMA3',
#   'RIT1',
#   'CANX',
#   'USO1',
#   'TCEA1',
#   'TOMM40',
#   'ERO1A',
#   'CDKN1A',
#   'GBE1',
#   'UNG',
#   'PSMB5',
#   'SERP1',
#   'NAMPT',
#   'CXCR4',
#   'FADS2',
#   'FADS1',
#   'G6PD',
#   'GSR',
#   'CDC25A',
#   'PDAP1',
#   'TUBA4A',
#   'COPS5',
#   'PPIA',
#   'NUPR1',
#   'PSAT1',
#   'DHCR7',
#   'SQSTM1',
#   'RAB1A',
#   'FKBP2',
#   'SLA',
#   'UBE2D3',
#   'PPP1R15A',
#   'AURKA',
#   'SLC1A4',
#   'SLC1A5',
#   'PLOD2',
#   'HSP90B1',
#   'GGA2',
#   'SC5D',
#   'YKT6',
#   'LDLR',
#   'ABCF2',
#   'IDH1',
#   'NIBAN1',
#   'MAP2K3',
#   'GOT1',
#   'IGFBP5',
#   'M6PR',
#   'EIF2S2',
#   'SLC9A3R1',
#   'ACLY',
#   'QDPR',
#   'GCLC',
#   'BCAT1',
#   'ATP6V1D',
#   'INSIG1',
#   'SLC2A1',
#   'AK4',
#   'SLC2A3',
#   'CORO1A',
#   'ATP5MC1',
#   'DAPP1',
#   'TM7SF2',
#   'EBP',
#   'SRD5A1',
#   'PSPH',
#   'ACTR3',
#   'CYB5B',
#   'HSPA9',
#   'ACTR2',
#   'HMGCS1',
#   'HSPA5',
#   'TXNRD1',
#   'ASNS',
#   'HSPA4',
#   'DHCR24',
#   'SORD',
#   'NFKBIB',
#   'MCM4',
#   'ETF1',
#   'PSMG1',
#   'MCM2',
#   'IDI1',
#   'GSK3B',
#   'NUFIP1',
#   'PSMD13',
#   'PSMD12',
#   'PSMD14',
#   'SHMT2',
#   'GMPS',
#   'PIK3R3',
#   'HK2',
#   'RDH11',
#   'ME1',
#   'PGK1',
#   'SLC37A4',
#   'RRM2',
#   'CYP51A1',
#   'IMMT',
#   'WARS1',
#   'PFKL',
#   'UFM1',
#   'DDIT4',
#   'DDIT3',
#   'TRIB3',
#   'GAPDH',
#   'ITGB2',
#   'SEC11A',
#   'ATP2A2',
#   'HMGCR',
#   'HSPD1',
#   'ADD3',
#   'BUB1',
#   'PGM1'],
#  'E2F Targets': ['DUT',
#   'H2AZ1',
#   'DEK',
#   'HUS1',
#   'CDC20',
#   'PHF5A',
#   'ZW10',
#   'DDX39A',
#   'MTHFD2',
#   'CCP110',
#   'ANP32E',
#   'ASF1A',
#   'HNRNPD',
#   'ASF1B',
#   'TP53',
#   'RAN',
#   'NUP205',
#   'NOLC1',
#   'PNN',
#   'EXOSC8',
#   'CHEK1',
#   'RACGAP1',
#   'CHEK2',
#   'MYC',
#   'TIPIN',
#   'E2F8',
#   'PLK4',
#   'PLK1',
#   'XRCC6',
#   'TUBG1',
#   'STAG1',
#   'EZH2',
#   'JPT1',
#   'POP7',
#   'CDCA3',
#   'TFRC',
#   'CDCA8',
#   'PRKDC',
#   'SMC6',
#   'SMC4',
#   'GSPT1',
#   'SMC3',
#   'PRDX4',
#   'TMPO',
#   'SYNCRIP',
#   'STMN1',
#   'MYBL2',
#   'BARD1',
#   'TCF19',
#   'TUBB',
#   'NME1',
#   'CENPE',
#   'RAD51C',
#   'CENPM',
#   'DEPDC1',
#   'CDKN3',
#   'SLBP',
#   'SUV39H1',
#   'TOP2A',
#   'BRCA1',
#   'BRCA2',
#   'CTCF',
#   'PSMC3IP',
#   'RAD51AP1',
#   'TK1',
#   'LYAR',
#   'DLGAP5',
#   'ATAD2',
#   'CDKN2C',
#   'HELLS',
#   'MLH1',
#   'CDKN2A',
#   'RANBP1',
#   'RPA2',
#   'RPA3',
#   'RPA1',
#   'CIT',
#   'SPC24',
#   'NUDT21',
#   'CCNE1',
#   'CKS2',
#   'NCAPD2',
#   'TRIP13',
#   'TACC3',
#   'TIMELESS',
#   'RAD1',
#   'SPC25',
#   'H2AX',
#   'CDKN1B',
#   'CDKN1A',
#   'DSCC1',
#   'PRIM2',
#   'MKI67',
#   'UNG',
#   'XPO1',
#   'ING3',
#   'PPP1R8',
#   'GINS3',
#   'GINS1',
#   'LIG1',
#   'GINS4',
#   'CDC25A',
#   'DONSON',
#   'MSH2',
#   'ILF3',
#   'CDC25B',
#   'MELK',
#   'UBE2S',
#   'UBE2T',
#   'BUB1B',
#   'KIF4A',
#   'POLE4',
#   'CNOT9',
#   'MRE11',
#   'MAD2L1',
#   'SNRPB',
#   'PCNA',
#   'DCLRE1B',
#   'SRSF1',
#   'SRSF2',
#   'AURKA',
#   'TBRG4',
#   'AURKB',
#   'PTTG1',
#   'NBN',
#   'CSE1L',
#   'USP1',
#   'RBBP7',
#   'PMS2',
#   'KPNA2',
#   'KIF22',
#   'NUP153',
#   'CTPS1',
#   'NASP',
#   'EIF2S1',
#   'MMS22L',
#   'PAN2',
#   'DIAPH3',
#   'KIF18B',
#   'BIRC5',
#   'KIF2C',
#   'RNASEH2A',
#   'DNMT1',
#   'MXD3',
#   'AK2',
#   'IPO7',
#   'PDS5B',
#   'CCNB2',
#   'PAICS',
#   'CBX5',
#   'RFC2',
#   'RFC3',
#   'RFC1',
#   'PA2G4',
#   'HMGA1',
#   'NAP1L1',
#   'SMC1A',
#   'POLA2',
#   'ESPL1',
#   'CDK4',
#   'BRMS1L',
#   'MCM4',
#   'CDK1',
#   'MCM5',
#   'DCTPP1',
#   'MCM6',
#   'MCM7',
#   'NAA38',
#   'LUC7L3',
#   'MCM2',
#   'MCM3',
#   'SHMT1',
#   'CKS1B',
#   'HMGB3',
#   'HMMR',
#   'LMNB1',
#   'PSIP1',
#   'HMGB2',
#   'ORC6',
#   'RAD21',
#   'ORC2',
#   'UBR7',
#   'LBR',
#   'EED',
#   'RRM2',
#   'SPAG5',
#   'DCK',
#   'SSRP1',
#   'RAD50',
#   'WEE1',
#   'PPM1D',
#   'NOP56',
#   'NUP107',
#   'PRPS1',
#   'WDR90',
#   'POLE',
#   'POLD1',
#   'POLD2',
#   'POLD3',
#   'TRA2B'],
#  'Myc Targets V1': ['SSB',
#   'DUT',
#   'H2AZ1',
#   'IFRD1',
#   'RPL22',
#   'STARD7',
#   'CNBP',
#   'DEK',
#   'MRPS18B',
#   'HSPE1',
#   'CDC20',
#   'PSMC6',
#   'PSMC4',
#   'CLNS1A',
#   'SERBP1',
#   'HNRNPC',
#   'HNRNPD',
#   'RAN',
#   'SF3B3',
#   'HNRNPU',
#   'NOLC1',
#   'HNRNPR',
#   'UBE2L3',
#   'FAM120A',
#   'EXOSC7',
#   'PSMD7',
#   'PSMD8',
#   'IARS1',
#   'SNRPD3',
#   'SNRPD2',
#   'PSMD3',
#   'SNRPD1',
#   'MYC',
#   'PSMD1',
#   'RPL14',
#   'RPL18',
#   'XRCC6',
#   'TOMM70',
#   'SRPK1',
#   'AIMP2',
#   'EPRS1',
#   'RNPS1',
#   'HPRT1',
#   'SET',
#   'RPL6',
#   'PHB2',
#   'PWP1',
#   'RPL34',
#   'PCBP1',
#   'RRP9',
#   'GSPT1',
#   'PRDX4',
#   'PRDX3',
#   'SYNCRIP',
#   'MRPL9',
#   'DHX15',
#   'CSTF2',
#   'RPS10',
#   'PTGES3',
#   'TCP1',
#   'GNL3',
#   'NME1',
#   'MRPL23',
#   'PABPC4',
#   'PABPC1',
#   'LDHA',
#   'C1QBP',
#   'CCT4',
#   'CCT3',
#   'NPM1',
#   'CCT2',
#   'RANBP1',
#   'UBE2E1',
#   'PSMA6',
#   'RSL1D1',
#   'PSMA7',
#   'PSMA4',
#   'HNRNPA2B1',
#   'PSMA2',
#   'XPOT',
#   'NDUFAB1',
#   'APEX1',
#   'PSMA1',
#   'CANX',
#   'PRPF31',
#   'HDGF',
#   'SF3A1',
#   'COX5A',
#   'RPLP0',
#   'XPO1',
#   'PSMB3',
#   'PSMB2',
#   'AP3S1',
#   'RACK1',
#   'CCT7',
#   'CCT5',
#   'TUFM',
#   'EIF1AX',
#   'RPS6',
#   'ILF2',
#   'COPS5',
#   'SNRPA',
#   'PPIA',
#   'POLE3',
#   'SRSF3',
#   'SNRPG',
#   'SRSF7',
#   'TARDBP',
#   'MAD2L1',
#   'NHP2',
#   'HDDC2',
#   'PCNA',
#   'KARS1',
#   'ODC1',
#   'SRSF1',
#   'SRSF2',
#   'TYMS',
#   'FBL',
#   'RUVBL2',
#   'RPS5',
#   'USP1',
#   'RPS2',
#   'RPS3',
#   'TXNL4A',
#   'KPNA2',
#   'NOP16',
#   'GOT2',
#   'LSM2',
#   'CTPS1',
#   'EIF2S2',
#   'EIF2S1',
#   'CCNA2',
#   'TFDP1',
#   'LSM7',
#   'UBA2',
#   'ERH',
#   'EIF4G2',
#   'PHB',
#   'CUL1',
#   'EEF1B2',
#   'G3BP1',
#   'CYC1',
#   'RFC4',
#   'NCBP2',
#   'VBP1',
#   'CBX3',
#   'NCBP1',
#   'PA2G4',
#   'RAD23B',
#   'NAP1L1',
#   'CDK4',
#   'CDK2',
#   'MCM4',
#   'ETF1',
#   'MCM5',
#   'MCM6',
#   'MCM7',
#   'MCM2',
#   'SLC25A3',
#   'YWHAE',
#   'PSMD14',
#   'GLO1',
#   'ORC2',
#   'YWHAQ',
#   'PGK1',
#   'EIF4H',
#   'ACP1',
#   'EIF4E',
#   'DDX18',
#   'SMARCC1',
#   'CAD',
#   'RRM1',
#   'KPNB1',
#   'IMPDH2',
#   'EIF3J',
#   'VDAC3',
#   'SSBP1',
#   'SNRPA1',
#   'VDAC1',
#   'EIF3D',
#   'EIF3B',
#   'ABCE1',
#   'NOP56',
#   'PRPS2',
#   'EIF4A1',
#   'HSP90AB1',
#   'HDAC2',
#   'DDX21',
#   'U2AF1',
#   'HSPD1',
#   'SRM',
#   'PPM1G',
#   'CDC45',
#   'POLD2',
#   'TRA2B',
#   'SNRPB2',
#   'TRIM28',
#   'BUB3',
#   'HNRNPA3',
#   'HNRNPA1'],
#  'Myc Targets V2': ['DUSP2',
#   'IMP4',
#   'CBX3',
#   'PUS1',
#   'PA2G4',
#   'SORD',
#   'WDR74',
#   'GNL3',
#   'HSPE1',
#   'BYSL',
#   'MRTO4',
#   'LAS1L',
#   'CDK4',
#   'MCM4',
#   'MCM5',
#   'DCTPP1',
#   'NIP7',
#   'NOP2',
#   'NOLC1',
#   'NOC4L',
#   'TBRG4',
#   'HK2',
#   'EXOSC5',
#   'PPRC1',
#   'TCOF1',
#   'MYC',
#   'PES1',
#   'MAP3K6',
#   'DDX18',
#   'NPM1',
#   'PLK4',
#   'NOP16',
#   'PLK1',
#   'PRMT3',
#   'TFB2M',
#   'SUPV3L1',
#   'AIMP2',
#   'MYBBP1A',
#   'RCL1',
#   'GRWD1',
#   'NDUFAF4',
#   'SLC29A2',
#   'FARSA',
#   'NOP56',
#   'MPHOSPH10',
#   'PHB',
#   'IPO4',
#   'PPAN',
#   'WDR43',
#   'TMEM97',
#   'HSPD1',
#   'RABEPK',
#   'SRM',
#   'UNG',
#   'RRP9',
#   'RRP12',
#   'UTP20',
#   'SLC19A1'],
#  'Epithelial Mesenchymal Transition': ['LUM',
#   'CADM1',
#   'DKK1',
#   'P3H1',
#   'COL1A2',
#   'SFRP4',
#   'COL1A1',
#   'MGP',
#   'VIM',
#   'MXRA5',
#   'MYL9',
#   'PFN2',
#   'PRSS2',
#   'LRP1',
#   'TAGLN',
#   'COL12A1',
#   'SERPINE1',
#   'SERPINE2',
#   'SFRP1',
#   'DPYSL3',
#   'ABI3BP',
#   'SPOCK1',
#   'CCN2',
#   'MEST',
#   'CCN1',
#   'GADD45B',
#   'FZD8',
#   'GADD45A',
#   'FERMT2',
#   'SLC6A8',
#   'SDC1',
#   'SNAI2',
#   'SPARC',
#   'OXTR',
#   'ENO2',
#   'MYLK',
#   'GJA1',
#   'LGALS1',
#   'ANPEP',
#   'SERPINH1',
#   'FUCA1',
#   'JUN',
#   'IL15',
#   'TNFRSF12A',
#   'MAGEE1',
#   'VEGFC',
#   'FN1',
#   'EMP3',
#   'RHOB',
#   'VEGFA',
#   'CRLF1',
#   'COL3A1',
#   'MMP14',
#   'GAS1',
#   'ID2',
#   'CALU',
#   'FOXC2',
#   'ELN',
#   'SDC4',
#   'TNFRSF11B',
#   'AREG',
#   'THY1',
#   'TIMP3',
#   'QSOX1',
#   'TIMP1',
#   'CAP2',
#   'IL32',
#   'ADAM12',
#   'BGN',
#   'COL4A1',
#   'COL4A2',
#   'FMOD',
#   'CD44',
#   'LRRC15',
#   'ECM1',
#   'ECM2',
#   'FSTL1',
#   'CAPG',
#   'FSTL3',
#   'COL11A1',
#   'CD59',
#   'TGFB1',
#   'PDGFRB',
#   'APLP1',
#   'PRRX1',
#   'TPM4',
#   'TFPI2',
#   'WNT5A',
#   'TPM2',
#   'VCAM1',
#   'CXCL12',
#   'COL5A2',
#   'PLOD1',
#   'COL5A1',
#   'FAP',
#   'FAS',
#   'COL5A3',
#   'TGFBI',
#   'PMP22',
#   'SCG2',
#   'PPIB',
#   'COL16A1',
#   'TNC',
#   'FBLN2',
#   'PLOD3',
#   'PVR',
#   'FBLN1',
#   'PLOD2',
#   'LOXL1',
#   'LOXL2',
#   'FBLN5',
#   'CDH6',
#   'COMP',
#   'NT5E',
#   'BASP1',
#   'CDH2',
#   'GPC1',
#   'FLNA',
#   'SLIT2',
#   'TPM1',
#   'MSX1',
#   'SLIT3',
#   'SPP1',
#   'IGFBP2',
#   'POSTN',
#   'IGFBP4',
#   'IGFBP3',
#   'INHBA',
#   'GEM',
#   'LOX',
#   'CDH11',
#   'COL6A3',
#   'COL6A2',
#   'MATN2',
#   'FBN1',
#   'FBN2',
#   'MATN3',
#   'COPA',
#   'NOTCH2',
#   'NTM',
#   'HTRA1',
#   'FGF2',
#   'SAT1',
#   'TGM2',
#   'EFEMP2',
#   'GLIPR1',
#   'RGS4',
#   'CALD1',
#   'PMEPA1',
#   'EDIL3',
#   'ITGA5',
#   'MMP1',
#   'MMP2',
#   'BDNF',
#   'GPX7',
#   'MMP3',
#   'ITGA2',
#   'TGFBR3',
#   'ACTA2',
#   'MFAP5',
#   'VCAN',
#   'DAB2',
#   'IL6',
#   'BMP1',
#   'COL7A1',
#   'MCM7',
#   'CXCL8',
#   'NNMT',
#   'LAMC1',
#   'TNFAIP3',
#   'CXCL1',
#   'LAMC2',
#   'NID2',
#   'CXCL6',
#   'PDLIM4',
#   'DST',
#   'PCOLCE',
#   'PLAUR',
#   'DCN',
#   'PTHLH',
#   'SNTB1',
#   'GREM1',
#   'COL8A2',
#   'PCOLCE2',
#   'PTX3',
#   'ITGB1',
#   'LAMA3',
#   'WIPF1',
#   'ITGB5',
#   'LAMA2',
#   'ITGB3',
#   'LAMA1',
#   'THBS1',
#   'THBS2',
#   'SGCG',
#   'SGCD',
#   'SGCB',
#   'ITGAV',
#   'COLGALT1',
#   'CTHRC1'],
#  'Inflammatory Response': ['IL1R1',
#   'EREG',
#   'MARCO',
#   'TNFSF9',
#   'VIP',
#   'SLAMF1',
#   'SGMS2',
#   'IFITM1',
#   'AQP9',
#   'SERPINE1',
#   'C3AR1',
#   'NOD2',
#   'MYC',
#   'PROK2',
#   'MSR1',
#   'ABCA1',
#   'TNFSF15',
#   'FZD5',
#   'SLC11A2',
#   'RNF144B',
#   'GPR183',
#   'CHST2',
#   'MEP1A',
#   'NPFFR2',
#   'HPN',
#   'ICAM4',
#   'HIF1A',
#   'ICAM1',
#   'LPAR1',
#   'KCNMB2',
#   'IL12B',
#   'SCARF1',
#   'FFAR2',
#   'TNFSF10',
#   'CD14',
#   'CMKLR1',
#   'SCN1B',
#   'EDN1',
#   'LYN',
#   'CCL24',
#   'GABBR1',
#   'IL10',
#   'CCL22',
#   'IL15',
#   'CCL20',
#   'IL10RA',
#   'SPHK1',
#   'NMI',
#   'TACR3',
#   'LIF',
#   'EMP3',
#   'TACR1',
#   'IL18',
#   'RHOG',
#   'OSMR',
#   'DCBLD2',
#   'IL1A',
#   'PTPRE',
#   'TLR2',
#   'BST2',
#   'IL1B',
#   'TLR1',
#   'MMP14',
#   'IL18R1',
#   'TLR3',
#   'BTG2',
#   'CD40',
#   'MEFV',
#   'EBI3',
#   'ADM',
#   'FPR1',
#   'SLC7A1',
#   'CX3CL1',
#   'SLC7A2',
#   'RIPK2',
#   'TIMP1',
#   'CCR7',
#   'KIF1B',
#   'GCH1',
#   'IFNGR2',
#   'GP1BA',
#   'F3',
#   'CD48',
#   'HBEGF',
#   'CDKN1A',
#   'PTGER2',
#   'PTAFR',
#   'KCNA3',
# ...
#   'SEC14L1',
#   'HBQ1',
#   'HTATIP2',
#   'CLIC2',
#   'CTSE',
#   'HBZ',
#   'DMTN',
#   'MOCOS',
#   'MPP1',
#   'TCEA1',
#   'HDGF',
#   'RHAG',
#   'RNF123',
#   'MARCHF2',
#   'SLC66A2',
#   'PIGQ',
#   'RHD',
#   'TRAK2',
#   'NUDT4',
#   'XPO7',
#   'MARCHF8',
#   'RIOK3',
#   'AHSP',
#   'LMO2',
#   'RHCE',
#   'SLC25A38',
#   'XK',
#   'SIDT2',
#   'LRP10',
#   'YPEL5',
#   'ABCG2',
#   'SLC25A37',
#   'OSBP2',
#   'ALDH1L1',
#   'UCP2',
#   'CPOX',
#   'FOXO3',
#   'CCND3',
#   'LAMP2',
#   'RNF19A',
#   'CIR1',
#   'ARHGEF12',
#   'CAST',
#   'MAP2K3',
#   'BNIP3L',
#   'NEK7',
#   'UROS',
#   'VEZF1',
#   'SLC30A1',
#   'FBXO34',
#   'MFHAS1',
#   'SDCBP',
#   'MINPP1',
#   'PICALM',
#   'GCLC',
#   'RCL1',
#   'TFDP2',
#   'SYNJ1',
#   'MKRN1',
#   'BMP2K',
#   'GCLM',
#   'BLVRB',
#   'BLVRA',
#   'NARF',
#   'SLC2A1',
#   'HTRA2',
#   'UROD',
#   'MARK3',
#   'FN3K',
#   'EIF2AK1',
#   'ASNS',
#   'PPP2R5B',
#   'RAD23A',
#   'SPTB',
#   'ARL2BP',
#   'TSPO2',
#   'HAGH',
#   'TRIM58',
#   'ATG4A',
#   'LPIN2',
#   'TOP1',
#   'NFE2L1',
#   'TNRC6B',
#   'FECH',
#   'ABCB6',
#   'GMPS',
#   'RAP1GAP',
#   'AGPAT4',
#   'MOSPD1',
#   'CA2',
#   'ALAD',
#   'CA1',
#   'HEBP1',
#   'ACP5',
#   'RBM38',
#   'SMOX',
#   'GLRX5',
#   'KHNYN',
#   'KLF1',
#   'MBOAT2',
#   'FOXJ2',
#   'BPGM',
#   'EPOR',
#   'KLF3',
#   'SELENBP1',
#   'ACKR1',
#   'CAT',
#   'DAAM1',
#   'USP15',
#   'ALAS2',
#   'CCDC28A',
#   'SLC4A1',
#   'CLCN3',
#   'NR3C1',
#   'ADD2',
#   'FTCD',
#   'ADD1',
#   'RBM5',
#   'PGLS',
#   'DCAF10',
#   'FBXO7',
#   'DCAF11',
#   'FBXO9'],
#  'Coagulation': ['GSN',
#   'F11',
#   'F10',
#   'S100A1',
#   'TFPI2',
#   'F12',
#   'CD9',
#   'ISCU',
#   'ADAM9',
#   'PF4',
#   'GDA',
#   'LRP1',
#   'SERPINE1',
#   'PROS1',
#   'CLU',
#   'ITIH1',
#   'COMP',
#   'LAMP2',
#   'CAPN5',
#   'S100A13',
#   'CAPN2',
#   'SH2B2',
#   'MAFF',
#   'PROC',
#   'GNB2',
#   'LGMN',
#   'SERPING1',
#   'F13B',
#   'MEP1A',
#   'PEF1',
#   'FBN1',
#   'CFB',
#   'CFD',
#   'SPARC',
#   'CPB2',
#   'CFI',
#   'HPN',
#   'CFH',
#   'PDGFB',
#   'PREP',
#   'PLAU',
#   'HTRA1',
#   'PLAT',
#   'C2',
#   'C3',
#   'C9',
#   'LTA4H',
#   'A2M',
#   'CTSB',
#   'DUSP6',
#   'ANXA1',
#   'MMP7',
#   'MMP8',
#   'HMGCS2',
#   'MMP1',
#   'MMP2',
#   'MMP3',
#   'MST1',
#   'ITGA2',
#   'FN1',
#   'MMP9',
#   'GNG12',
#   'SIRT2',
#   'GP9',
#   'MMP11',
#   'MMP10',
#   'TF',
#   'MMP15',
#   'MMP14',
#   'BMP1',
#   'ACOX2',
#   'APOA1',
#   'PECAM1',
#   'RAPGEF3',
#   'KLKB1',
#   'HRG',
#   'ARF4',
#   'CPQ',
#   'SERPINA1',
#   'TMPRSS6',
#   'PROZ',
#   'C8A',
#   'CTSV',
#   'C8B',
#   'DUSP14',
#   'KLK8',
#   'DPP4',
#   'C8G',
#   'CASP9',
#   'CTSO',
#   'CSRP1',
#   'CTSK',
#   'HNF4A',
#   'P2RY1',
#   'TIMP3',
#   'CTSH',
#   'TIMP1',
#   'CTSE',
#   'FGA',
#   'LEFTY2',
#   'SERPINB2',
#   'FGG',
#   'VWF',
#   'F2',
#   'GP1BA',
#   'F3',
#   'RABIF',
#   'F8',
#   'F9',
#   'KLF7',
#   'APOC1',
#   'DCT',
#   'APOC3',
#   'APOC2',
#   'ANG',
#   'F2RL2',
#   'RGN',
#   'MASP2',
#   'MSRB2',
#   'C1QA',
#   'C1R',
#   'WDR1',
#   'PLEK',
#   'SERPINC1',
#   'C1S',
#   'FURIN',
#   'USP11',
#   'ITGB3',
#   'THBS1',
#   'PLG',
#   'PRSS23',
#   'CRIP2',
#   'CPN1',
#   'THBD',
#   'RAC1',
#   'FYN',
#   'MBL2',
#   'OLR1'],
#  'IL-2/STAT5 Signaling': ['IL1R2',
#   'TTC39B',
#   'RRAGD',
#   'ITIH5',
#   'CYFIP1',
#   'IFITM3',
#   'AHNAK',
#   'FGL2',
#   'PNP',
#   'MUC1',
#   'FLT3LG',
#   'MYC',
#   'WLS',
#   'GBP4',
#   'ST3GAL4',
#   'PRKCH',
#   'BATF3',
#   'RABGAP1L',
#   'GABARAPL1',
#   'XBP1',
#   'GADD45B',
#   'CDCP1',
#   'PLSCR1',
#   'UCK2',
#   'PLPP1',
#   'CDC42SE2',
#   'RNH1',
#   'IKZF2',
#   'ENO3',
#   'IKZF4',
#   'GATA1',
#   'CD79B',
#   'ALCAM',
#   'TNFSF11',
#   'TNFSF10',
#   'NCOA3',
#   'IL10',
#   'ANXA4',
#   'IL13',
#   'IL10RA',
#   'EMP1',
#   'RHOH',
#   'LIF',
#   'PTCH1',
#   'CDC6',
#   'FAM126B',
#   'RHOB',
#   'P4HA1',
#   'BHLHE40',
#   'ETFBKMT',
#   'TLR7',
#   'UMPS',
#   'IL18R1',
#   'CTSZ',
#   'PTH1R',
#   'SHE',
#   'SOCS1',
#   'SOCS2',
#   'PENK',
#   'SH3BGRL2',
#   'CTLA4',
#   'MAP6',
#   'NFIL3',
#   'SNX9',
#   'CCR4',
#   'ICOS',
#   'IFNGR1',
#   'GSTO1',
#   'DHRS3',
#   'SERPINB6',
#   'ADAM19',
#   'CCNE1',
#   'F2RL2',
#   'PTRH2',
#   'CD48',
#   'PLIN2',
#   'SLC29A2',
#   'CD44',
#   'EEF1AKMT1',
#   'NRP1',
#   'ECM1',
#   'AHCY',
#   'CDKN1C',
#   'SERPINC1',
#   'PTGER2',
#   'SNX14',
#   'CAPG',
#   'CST7',
#   'PDCD2L',
#   'ENPP1',
#   'NCS1',
#   'PLAGL1',
#   'DCPS',
#   'EOMES',
#   'IL4R',
#   'PHLDA1',
#   'APLP1',
#   'S100A1',
#   'PRAF2',
#   'PUS1',
#   'HUWE1',
#   'HIPK2',
#   'FAH',
#   'BATF',
#   'CXCL10',
#   'MAPKAPK2',
#   'CD86',
#   'CD83',
#   'CSF2',
#   'CSF1',
#   'CD81',
#   'ODC1',
#   'RGS16',
#   'GPR65',
#   'AHR',
#   'SLC1A5',
#   'LCLAT1',
#   'NDRG1',
#   'NT5E',
#   'CCND3',
#   'CCND2',
#   'CAPN3',
#   'DENND5A',
#   'SLC39A8',
#   'SPP1',
#   'MAP3K8',
#   'IGF2R',
#   'SWAP70',
#   'CISH',
#   'PRNP',
#   'TRAF1',
#   'CKAP4',
#   'HOPX',
#   'MAFF',
#   'MXD1',
#   'SELP',
#   'AMACR',
#   'COL6A1',
#   'SELL',
#   'BCL2L1',
#   'DRC1',
#   'GUCY1B1',
#   'SLC2A3',
#   'AGER',
#   'GPR83',
#   'RORA',
#   'IGF1R',
#   'TGM2',
#   'GLIPR2',
#   'SCN9A',
#   'TNFRSF8',
#   'PIM1',
#   'TNFRSF9',
#   'TNFRSF4',
#   'POU2F1',
#   'GPX4',
#   'NFKBIZ',
#   'ETV4',
#   'TNFRSF1B',
#   'TNFRSF21',
#   'BMP2',
#   'IRF4',
#   'ITGAE',
#   'IL3RA',
#   'IRF8',
#   'BCL2',
#   'IRF6',
#   'ITGA6',
#   'PLEC',
#   'ARL4A',
#   'ABCB1',
#   'BMPR2',
#   'NOP2',
#   'PHTF2',
#   'HK2',
#   'CA2',
#   'SYNGR2',
#   'CASP3',
#   'TNFRSF18',
#   'TIAM1',
#   'MYO1E',
#   'TWSG1',
#   'MYO1C',
#   'KLF6',
#   'P2RX4',
#   'IL2RA',
#   'IL2RB',
#   'SYT11',
#   'LTB',
#   'SPRY4',
#   'SMPDL3A',
#   'GALM',
#   'FURIN',
#   'COCH',
#   'IL1RL1',
#   'SPRED2',
#   'LRIG1',
#   'ITGAV',
#   'LRRC8C'],
#  'Bile Acid Metabolism': ['ABCG8',
#   'HSD3B7',
#   'PEX19',
#   'PHYH',
#   'ACSL1',
#   'DIO1',
#   'HSD3B1',
#   'DIO2',
#   'ACSL5',
#   'PEX12',
#   'PEX13',
#   'CYP39A1',
#   'PEX16',
#   'SOAT2',
#   'RBP1',
#   'PEX11G',
#   'ABCG4',
#   'ALDH8A1',
#   'OPTN',
#   'SLC27A2',
#   'AKR1D1',
#   'PEX11A',
#   'RETSAT',
#   'AQP9',
#   'SLC23A2',
#   'SLC35B2',
#   'SLC23A1',
#   'HSD17B4',
#   'HSD17B6',
#   'CH25H',
#   'PEX26',
#   'RXRA',
#   'PIPOX',
#   'LONP2',
#   'RXRG',
#   'ABCA2',
#   'ABCA3',
#   'IDH1',
#   'GSTK1',
#   'ABCA1',
#   'ABCA6',
#   'ABCA4',
#   'IDH2',
#   'ABCA5',
#   'EPHX2',
#   'ABCA8',
#   'NR0B2',
#   'ABCA9',
#   'AR',
#   'CYP27A1',
#   'SULT2B1',
#   'AMACR',
#   'GNPAT',
#   'SLCO1A2',
#   'GCLM',
#   'SLC27A5',
#   'PECR',
#   'CYP46A1',
#   'LIPE',
#   'PRDX5',
#   'FDXR',
#   'SCP2',
#   'HACL1',
#   'BBOX1',
#   'PEX1',
#   'CYP7B1',
#   'DHCR24',
#   'NPC1',
#   'BMP6',
#   'SULT1B1',
#   'APOA1',
#   'PEX7',
#   'PXMP2',
#   'PEX6',
#   'EFHC1',
#   'PAOX',
#   'IDI1',
#   'BCAR3',
#   'NR1I2',
#   'TFCP2L1',
#   'CROT',
#   'CYP7A1',
#   'SERPINA6',
#   'SLC22A18',
#   'ISOC1',
#   'HAO1',
#   'ATXN1',
#   'PNPLA8',
#   'KLF1',
#   'NR1H4',
#   'CYP8B1',
#   'GNMT',
#   'SOD1',
#   'LCK',
#   'PFKM',
#   'ALDH1A1',
#   'CAT',
#   'NEDD4',
#   'ALDH9A1',
#   'SLC29A1',
#   'AGXT',
#   'ABCD3',
#   'NR3C2',
#   'HSD17B11',
#   'NUDT12',
#   'TTR',
#   'MLYCD',
#   'GC',
#   'ABCD1',
#   'ABCD2',
#   'FADS2',
#   'FADS1'],
#  'Pperoxisome': ['HSD3B7',
#   'ACOT8',
#   'ACSL1',
#   'DIO1',
#   'ECH1',
#   'CADM1',
#   'CNBP',
#   'ACSL5',
#   'ACSL4',
#   'MSH2',
#   'PEX13',
#   'PEX14',
#   'SCGB1A1',
#   'CRAT',
#   'SLC27A2',
#   'PEX11A',
#   'RETSAT',
#   'CRABP1',
#   'PEX11B',
#   'SLC23A2',
#   'SLC35B2',
#   'CRABP2',
#   'HSD17B4',
#   'STS',
#   'LONP2',
#   'RXRG',
#   'FDPS',
#   'FIS1',
#   'SIAH1',
#   'IDH1',
#   'GSTK1',
#   'IDH2',
#   'EPHX2',
#   'CEL',
#   'CTPS1',
#   'ESR2',
#   'SULT2B1',
#   'DLG4',
#   'GNPAT',
#   'CTBP1',
#   'ECI2',
#   'BCL10',
#   'CACNA1B',
#   'PRDX5',
#   'PRDX1',
#   'SCP2',
#   'ACAA1',
#   'ABCC5',
#   'ABCC8',
#   'DHCR24',
#   'PEX2',
#   'CDK7',
#   'PEX5',
#   'ITGB1BP1',
#   'ACOX1',
#   'ALB',
#   'PEX6',
#   'PABPC1',
#   'IDI1',
#   'ABCB4',
#   'ABCB1',
#   'SLC25A4',
#   'NR1I2',
#   'TOP2A',
#   'VPS4B',
#   'IDE',
#   'EHHADH',
#   'ABCB9',
#   'SERPINA6',
#   'HSD11B2',
#   'RDH11',
#   'ISOC1',
#   'HAO2',
#   'ATXN1',
#   'YWHAH',
#   'SMARCC1',
#   'ELOVL5',
#   'UGT2B17',
#   'DHRS3',
#   'SOD1',
#   'SOD2',
#   'SLC25A17',
#   'ERCC1',
#   'SLC25A19',
#   'ALDH1A1',
#   'CAT',
#   'FABP6',
#   'ERCC3',
#   'ALDH9A1',
#   'ABCD3',
#   'MVP',
#   'SEMA3C',
#   'CLN8',
#   'HSD17B11',
#   'CLN6',
#   'HMGCL',
#   'TTR',
#   'NUDT19',
#   'HRAS',
#   'MLYCD',
#   'TSPO',
#   'ABCD1',
#   'ABCD2',
#   'FADS1'],
#  'Allograft Rejection': ['KRT1',
#   'EREG',
#   'CD2',
#   'CD4',
#   'CD7',
#   'IL2RG',
#   'IL27RA',
#   'PSMB10',
#   'AKT1',
#   'APBB1',
#   'B2M',
#   'GBP2',
#   'ELANE',
#   'FYB1',
#   'PRKCG',
#   'ST8SIA4',
#   'HLA-A',
#   'PRKCB',
#   'HLA-G',
#   'HLA-E',
#   'RPL3L',
#   'SPI1',
#   'BCL10',
#   'PRF1',
#   'CD1D',
#   'HIF1A',
#   'RPL9',
#   'CFP',
#   'C2',
#   'ICAM1',
#   'CD79A',
#   'MRPL3',
#   'RPS19',
#   'IL12B',
#   'RPL39',
#   'IL12A',
#   'CCR2',
#   'IL11',
#   'CCR1',
#   'LYN',
#   'IL10',
#   'CCL22',
#   'IL15',
#   'IL16',
#   'IL13',
#   'LIF',
#   'IL18',
#   'NME1',
#   'TLR2',
#   'IL1B',
#   'TLR1',
#   'PTPRC',
#   'NCR1',
#   'CD28',
#   'TLR6',
#   'ITK',
#   'TLR3',
#   'ACHE',
#   'IGSF6',
#   'CD40',
#   'BRCA1',
#   'CD3G',
#   'THY1',
#   'CD3E',
#   'CD3D',
#   'CTSS',
#   'SOCS1',
#   'RIPK2',
#   'TIMP1',
#   'CCR5',
#   'SOCS5',
#   'HLA-DQA1',
#   'NPM1',
#   'TPD52',
#   'MAP4K1',
#   'CDKN2A',
#   'IFNGR1',
#   'STAT1',
#   'IFNGR2',
#   'STAT4',
#   'F2',
#   'HCLS1',
#   'CD40LG',
#   'CD47',
#   'CCL13',
#   'CCL11',
#   'GCNT1',
#   'WAS',
#   'CAPG',
#   'IKBKB',
#   'HLA-DMB',
#   'STAB1',
#   'CXCR3',
#   'CCL19',
#   'HLA-DMA',
#   'ICOSLG',
#   'JAK2',
#   'TGFB1',
#   'CD74',
#   'IL4R',
#   'RARS1',
#   'TGFB2',
#   'RPS9',
#   'CRTAM',
#   'TAP2',
#   'TAP1',
#   'CXCL13',
#   'ABI1',
#   'FAS',
#   'KLRD1',
#   'PF4',
#   'DEGS1',
#   'PTPN6',
#   'UBE2N',
#   'CD86',
#   'CSF1',
#   'CD80',
#   'UBE2D1',
#   'GPR65',
#   'TNF',
#   'EGFR',
#   'CCND3',
#   'CCND2',
#   'FLNA',
#   'NLRP3',
#   'HLA-DOB',
#   'MAP3K7',
#   'IL12RB1',
#   'HLA-DOA',
#   'CD96',
#   'F2R',
#   'GLMN',
#   'INHBA',
#   'LY86',
#   'INHBB',
#   'TRAF2',
#   'CARTPT',
#   'DARS1',
#   'CD8B',
#   'CD8A',
#   'BCAT1',
#   'EIF4G3',
#   'IFNAR2',
#   'DYRK3',
#   'NCF4',
#   'LY75',
#   'FASLG',
#   'ETS1',
#   'IL18RAP',
#   'SIT1',
#   'EIF5A',
#   'SRGN',
#   'GALNT1',
#   'RPS3A',
#   'MMP9',
#   'TAPBP',
#   'ACVR2A',
#   'IL2',
#   'IL4',
#   'IL7',
#   'FCGR2B',
#   'IL6',
#   'ELF4',
#   'IL9',
#   'IRF4',
#   'IFNG',
#   'BCL3',
#   'HLA-DRA',
#   'IRF8',
#   'IRF7',
#   'LCP2',
#   'CD247',
#   'CXCL9',
#   'MTIF2',
#   'AARS1',
#   'EIF3A',
#   'GZMB',
#   'GZMA',
#   'WARS1',
#   'FGR',
#   'LCK',
#   'ZAP70',
#   'IL2RA',
#   'EIF3J',
#   'IL2RB',
#   'LTB',
#   'EIF3D',
#   'ABCE1',
#   'ITGB2',
#   'HDAC9',
#   'ITGAL',
#   'CCL7',
#   'CCL5',
#   'CCL4',
#   'CCL2',
#   'TRAT1',
#   'CSK',
#   'NOS2',
#   'MBL2',
#   'NCK1'],
#  'Spermatogenesis': ['TLE4',
#   'PRM2',
#   'HSPA1L',
#   'SLC12A2',
#   'ZPBP',
#   'CHFR',
#   'HTR5A',
#   'CCT6B',
#   'ADAM2',
#   'THEG',
#   'ZC2HC1C',
#   'CNIH2',
#   'IFT88',
#   'MTNR1A',
#   'DPEP3',
#   'GAPDHS',
#   'SCG5',
#   'STAM2',
#   'SCG3',
#   'CHRM4',
#   'HOXB1',
#   'CLPB',
#   'AURKA',
#   'NCAPH',
#   'PEBP1',
#   'TUBA3C',
#   'AKAP4',
#   'CLGN',
#   'NPHP1',
#   'TEKT2',
#   'ADAD1',
#   'IL12RB2',
#   'JAM3',
#   'TALDO1',
#   'PIAS2',
#   'RPL39L',
#   'H1-6',
#   'CCNA1',
#   'MLLT10',
#   'GPR182',
#   'MEP1B',
#   'RAD17',
#   'KIF2C',
#   'EZH2',
#   'CFTR',
#   'CRISP2',
#   'HSPA4L',
#   'DDX4',
#   'ACTL7B',
#   'GFI1',
#   'SLC2A5',
#   'GMCL1',
#   'ACRBP',
#   'ART3',
#   'CCNB2',
#   'PRKAR2A',
#   'PAPOLB',
#   'NEK2',
#   'ODF1',
#   'AGFG1',
#   'ZC3H14',
#   'PCSK1N',
#   'IL13RA2',
#   'TCP11',
#   'ACE',
#   'GSTM3',
#   'RFC4',
#   'NPY5R',
#   'PDHA2',
#   'STRBP',
#   'HSPA2',
#   'BRAF',
#   'SIRT1',
#   'MLF1',
#   'SNAP91',
#   'LPIN1',
#   'DMC1',
#   'NF2',
#   'ACRV1',
#   'CAMK4',
#   'CDK1',
#   'ARL4A',
#   'PSMG1',
#   'CDKN3',
#   'MAST2',
#   'ALOX15',
#   'IDE',
#   'SPATA6',
#   'OAZ3',
#   'SHE',
#   'PCSK4',
#   'COIL',
#   'LDHC',
#   'PGS1',
#   'PGK2',
#   'TOPBP1',
#   'MAP7',
#   'DNAJB8',
#   'IP6K1',
#   'HBZ',
#   'DCC',
#   'TKTL1',
#   'PACRG',
#   'CSNK2A2',
#   'NAA11',
#   'PARP2',
#   'ELOVL3',
#   'DMRT1',
#   'GAD1',
#   'SEPTIN4',
#   'MTOR',
#   'TSN',
#   'ADCYAP1',
#   'POMC',
#   'DBF4',
#   'VDAC3',
#   'TNP2',
#   'TSSK2',
#   'TNP1',
#   'DDX25',
#   'SYCP1',
#   'TTK',
#   'TULP2',
#   'YBX2',
#   'CST8',
#   'PHF7',
#   'ZNRF4',
#   'GRM8',
#   'GSG1',
#   'PHKG2',
#   'TNNI3',
#   'NOS1',
#   'NEFH',
#   'BUB1',
#   'CLVS1'],
#  'KRAS Signaling Up': ['ATG10',
#   'CIDEA',
#   'EREG',
#   'MALL',
#   'NIN',
#   'RBP4',
#   'SLPI',
#   'ITGBL1',
#   'SPARCL1',
#   'ZNF277',
#   'ADAMDEC1',
#   'SATB1',
#   'C3AR1',
#   'RETN',
#   'GLRX',
#   'IL2RG',
#   'TFPI',
#   'ADGRA2',
#   'AKT2',
#   'RABGAP1L',
#   'ST6GAL1',
#   'GADD45G',
#   'PPBP',
#   'AMMECR1',
#   'NR0B2',
#   'IGF2',
#   'BTC',
#   'TNNT2',
#   'CCSER2',
#   'STRN',
#   'CFB',
#   'SPON1',
#   'CFH',
#   'PLEK2',
#   'IKZF1',
#   'GNG11',
#   'EPB41L3',
#   'TSPAN7',
#   'ANKH',
#   'SOX9',
#   'KCNN4',
#   'CMKLR1',
#   'TSPAN1',
#   'APOD',
#   'SCN1B',
#   'GABRA3',
#   'DUSP6',
#   'FUCA1',
#   'ACE',
#   'JUP',
#   'CCL20',
#   'IL10RA',
#   'EMP1',
#   'LIF',
#   'PDCD1LG2',
#   'SNAP91',
#   'DCBLD2',
#   'MMP11',
#   'WDR33',
#   'MMP10',
#   'VWA5A',
#   'IL1B',
#   'LAT2',
#   'GPRC5B',
#   'CFHR2',
#   'ID2',
#   'TLR8',
#   'SDCCAG8',
#   'ADGRL4',
#   'AVL9',
#   'SERPINA3',
#   'TPH1',
#   'GYPC',
#   'PTPRR',
#   'CAB39L',
#   'CROT',
#   'TOR1AIP2',
#   'CTSS',
#   'MAP7',
#   'CD37',
#   'FCER1G',
#   'MPZL2',
#   'PRELID3B',
#   'HSD11B1',
#   'IL33',
#   'MMD',
#   'MAP4K1',
#   'ARG1',
#   'TMEM176A',
#   'G0S2',
#   'TMEM176B',
#   'WNT7A',
#   'LAPTM5',
#   'NR1H4',
#   'ANO1',
#   'TMEM158',
#   'ADAM17',
#   'ANGPTL4',
#   'F2RL1',
#   'ENG',
#   'HBEGF',
#   'NRP1',
#   'ERO1A',
#   'MTMR10',
#   'F13A1',
#   'PIGR',
#   'HOXD11',
#   'PTGS2',
#   'PSMB8',
#   'AKAP12',
#   'CXCR4',
#   'GPNMB',
#   'CBR4',
#   'MAP3K1',
#   'PTCD2',
#   'GUCY1A1',
#   'PRRX1',
#   'H2BC3',
#   'CXCL10',
#   'MYCN',
#   'PCP4',
#   'CLEC4A',
#   'ADAM8',
#   'SCG5',
#   'SCG3',
#   'PLVAP',
#   'CSF2',
#   'PPP1R15A',
#   'RGS16',
#   'PRDM1',
#   'RELN',
#   'CCND2',
#   'KIF5C',
#   'SPP1',
#   'IGFBP3',
#   'INHBA',
#   'TRAF1',
#   'MAFB',
#   'DNMBP',
#   'BIRC3',
#   'YRDC',
#   'IL7R',
#   'PLAU',
#   'PLAT',
#   'CSF2RA',
#   'ETS1',
#   'TMEM100',
#   'FGF9',
#   'BTBD3',
#   'PCSK1N',
#   'CDADC1',
#   'CBX8',
#   'GALNT3',
#   'PEG3',
#   'GFPT2',
#   'ITGA2',
#   'ETV1',
#   'NAP1L2',
#   'ETV4',
#   'MMP9',
#   'ETV5',
#   'TNFRSF1B',
#   'BMP2',
#   'LCP1',
#   'CPE',
#   'ZNF639',
#   'IRF8',
#   'PECAM1',
#   'DOCK2',
#   'SNAP25',
#   'ABCB1',
#   'TNFAIP3',
#   'LY96',
#   'PTBP2',
#   'CA2',
#   'EVI5',
#   'PRKG2',
#   'ANXA10',
#   'PLAUR',
#   'BPGM',
#   'KLF4',
#   'NGF',
#   'ALDH1A3',
#   'ALDH1A2',
#   'HKDC1',
#   'SPRY2',
#   'TRIB2',
#   'TRIB1',
#   'ITGB2',
#   'FLT4',
#   'SEMA3B',
#   'USP12',
#   'HDAC9',
#   'TSPAN13',
#   'CBL',
#   'USH1C',
#   'RBM4',
#   'IL1RL2',
#   'FBXO4',
#   'EPHB2'],
#  'KRAS Signaling Dn': ['KRT1',
#   'SLC12A3',
#   'EPHA5',
#   'GAMT',
#   'EGF',
#   'KRT5',
#   'MX1',
#   'KRT4',
#   'ENTPD7',
#   'RSAD2',
#   'SOX10',
#   'CYP39A1',
#   'ZC2HC1C',
#   'SCGB1A1',
#   'SCN10A',
#   'PCDHB1',
#   'ASB7',
#   'CD207',
#   'CPEB3',
#   'CNTFR',
#   'SPRR3',
#   'ITIH3',
#   'SMPX',
#   'ALOX12B',
#   'CALML5',
#   'SLC5A5',
#   'VPREB1',
#   'RIBC2',
#   'SNCB',
#   'DTNB',
#   'MTHFR',
#   'SLC6A14',
#   'TEX15',
#   'TENT5C',
#   'COPZ2',
#   'COL2A1',
#   'ATP4A',
#   'STAG3',
#   'CLPS',
#   'HNF1A',
#   'KLHDC8A',
#   'CHST2',
#   'ATP6V1B1',
#   'PTGFR',
#   'PNMT',
#   'LYPD3',
#   'SLC6A3',
#   'C5',
#   'TCL1A',
#   'KCNMB1',
#   'KCNN1',
#   'IL12B',
#   'SYNPO',
#   'LGALS7',
#   'BARD1',
#   'PDK2',
#   'EDN1',
#   'EDN2',
#   'SPHK2',
#   'FSHB',
#   'GP2',
#   'KRT13',
#   'PAX4',
#   'PAX3',
#   'GPRC5C',
#   'TG',
#   'CLDN16',
#   'MYOT',
#   'CYP11B2',
#   'KRT15',
#   'COQ8A',
#   'TFF2',
#   'AKR1B10',
#   'GPR19',
#   'SGK1',
#   'ZNF112',
#   'TENM2',
#   'BTG2',
#   'MEFV',
#   'CCDC106',
#   'TFCP2L1',
#   'SERPINA10',
#   'PTPRJ',
#   'KLK8',
#   'KLK7',
#   'HSD11B2',
#   'CCR8',
#   'SPTBN2',
#   'SERPINB2',
#   'GPR3',
#   'GP1BA',
#   'NR6A1',
#   'ABCB11',
#   'KCNQ2',
#   'CD40LG',
#   'SLC29A3',
#   'BRDT',
#   'RYR2',
#   'RYR1',
#   'LFNG',
#   'NUDT11',
#   'CHRNG',
#   'TFAP2B',
#   'TGFB2',
#   'CKM',
#   'ZBTB16',
#   'THNSL2',
#   'CDKAL1',
#   'EDAR',
#   'SELENOP',
#   'IFI44L',
#   'MSH5',
#   'SIDT1',
#   'YPEL1',
#   'ABCG4',
#   'PDCD1',
#   'PKP1',
#   'PRKN',
#   'IDUA',
#   'CD80',
#   'CELSR2',
#   'MACROH2A2',
#   'CAPN9',
#   'NTF3',
#   'SLC16A7',
#   'FGF22',
#   'IGFBP2',
#   'CPA2',
#   'KCND1',
#   'SLC30A3',
#   'ADRA2C',
#   'UPK3B',
#   'NR4A2',
#   'CCNA1',
#   'FGF16',
#   'GDNF',
#   'TLX1',
#   'CDH16',
#   'FGFR3',
#   'CALCB',
#   'KCNE2',
#   'CLSTN3',
#   'CPB1',
#   'KMT2D',
#   'IRS4',
#   'CACNA1F',
#   'TGM1',
#   'SNN',
#   'PRODH',
#   'SLC38A3',
#   'EFHD1',
#   'HTR1D',
#   'HTR1B',
#   'AMBN',
#   'SSTR4',
#   'WNT16',
#   'IL5',
#   'IFNG',
#   'ITGB1BP2',
#   'MAGIX',
#   'ARPP21',
#   'MYH7',
#   'BMPR1B',
#   'SHOX2',
#   'GTF3C5',
#   'NPY4R',
#   'MAST3',
#   'OXT',
#   'FGGY',
#   'VPS50',
#   'MFSD6',
#   'P2RY4',
#   'NRIP2',
#   'SKIL',
#   'TAS2R4',
#   'PROP1',
#   'CAMK1D',
#   'DCC',
#   'TCF7L1',
#   'GRID2',
#   'UGT2B17',
#   'NGB',
#   'DLK2',
#   'P2RX6',
#   'NPHS1',
#   'MYO15A',
#   'CLDN8',
#   'RGS11',
#   'PLAG1',
#   'THRB',
#   'ARHGDIG',
#   'YBX2',
#   'ACTC1',
#   'TNNI3',
#   'CACNG1',
#   'NOS1',
#   'PDE6B',
#   'SLC25A23',
#   'INSL5',
#   'TSHB'],
#  'Pancreas Beta Cells': ['LMO2',
#   'CHGA',
#   'SRP9',
#   'VDR',
#   'ABCC8',
#   'PKLR',
#   'PAX4',
#   'PDX1',
#   'ELP4',
#   'GCG',
#   'PAX6',
#   'ISL1',
#   'MAFB',
#   'G6PC2',
#   'GCK',
#   'SST',
#   'HNF1A',
#   'SPCS1',
#   'SYT13',
#   'IAPP',
#   'INSM1',
#   'SRPRB',
#   'DCX',
#   'NEUROG3',
#   'FOXA2',
#   'PCSK2',
#   'STXBP1',
#   'PCSK1',
#   'SEC11A',
#   'SLC2A2',
#   'SRP14',
#   'INS',
#   'DPP4',
#   'FOXO1',
#   'SCGN',
#   'AKT3',
#   'NKX2-2',
#   'NKX6-1',
#   'PAK3',
#   'NEUROD1']}

# %% [markdown]
# ## Getting the genesets for the selected pathways collections

# %%
import gseapy as gp
import pandas as pd

libraries = [
    'MSigDB_Hallmark_2020',
    'KEGG_2021_Human',
    'Reactome_Pathways_2024',
    'GO_Biological_Process_2025',
    'GO_Molecular_Function_2025'
]

combined_gene_sets = {}

# Download and merge all gene sets
for lib_name in libraries:
    print(f"Downloading library: {lib_name}")
    gs = gp.get_library(name=lib_name)
    combined_gene_sets.update(gs)

# Optional: convert to DataFrame
gene_set_df = pd.DataFrame([
    {'set_name': k, 'genes': ','.join(v)} for k, v in combined_gene_sets.items()
])

print(f"Total gene sets combined: {len(combined_gene_sets)}")
gene_set_df
# Out:
# Downloading library: MSigDB_Hallmark_2020
# Downloading library: KEGG_2021_Human
# Downloading library: Reactome_Pathways_2024
# Downloading library: GO_Biological_Process_2025
# Total gene sets combined: 7802
#                                                set_name  \
# 0                         TNF-alpha Signaling via NF-kB
# 1                                               Hypoxia
# 2                               Cholesterol Homeostasis
# 3                                       Mitotic Spindle
# 4                            Wnt-beta Catenin Signaling
# ...                                                 ...
# 7797  Zinc Ion Import Across Plasma Membrane (GO:007...
# 7798        Zinc Ion Import Into Organelle (GO:0062111)
# 7799      Zinc Ion Transmembrane Transport (GO:0071577)
# 7800                    Zinc Ion Transport (GO:0006829)
# 7801                    Zymogen Activation (GO:0031638)
#
#                                                   genes
# 0     MARCKS,IL23A,NINJ1,TNFSF9,SIK1,ATF3,SERPINE1,M...
# 1     WSB1,JMJD6,XPNPEP1,RRAGD,PPP1R3C,MT1E,TES,ATF3...
# 2     STARD4,GSTM2,CHKA,HMGCS1,TNFRSF12A,ANXA5,ECH1,...
# 3     ACTN4,PCGF5,APC,MARCKS,NIN,KIF20B,EPB41,STAU1,...
# 4     FZD1,JAG1,JAG2,FZD8,WNT5B,AXIN2,AXIN1,PTCH1,CS...
# ...                                                 ...
# 7797  SLC30A8,SLC39A10,SLC39A12,SLC39A6,SLC39A14,SLC...
# 7798  SLC30A8,SLC30A7,SLC30A4,SLC30A3,SLC30A6,SLC30A...
# 7799  SLC30A8,SLC39A1,SLC30A4,SLC30A3,SLC30A5,SLC39A...
# 7800  SLC30A8,SLC39A1,SLC30A9,SLC30A4,SLC30A3,SLC30A...
# 7801  FGB,FGG,F12,ZNF160,F9,MMP14,DLC1,KLKB1,C1R,KLK...
#
# [7802 rows x 2 columns]

# %% [markdown]
# ## Getting the gene targets for the drugs

# %%
# Load the IDG Drug Target 2022 library
idg = gp.get_library(name="IDG_Drug_Targets_2022")

# Inspect
print(len(idg), "drug-target sets loaded")

# Example: see which genes Palbociclib targets
# print(idg.get("Palbociclib"))
idg
# Out:
# 888 drug-target sets loaded
# {'Levobupivacaine': ['KCND3',
#   'PTGER1',
#   'CYP2D6',
#   'KCNA5',
#   'SCN4A',
#   'SCN1A',
#   'HTR3A',
#   'KCNH2'],
#  '(S)-nitrendipine': ['CACNA1C', 'CACNA1S', 'CACNA1D', 'KCNN4', 'CACNA1F'],
#  'Acamprosate': ['GRIN3A',
#   'GABRB3',
#   'GABRA1',
#   'GRIN2B',
#   'GRIN2A',
#   'GRIN3B',
#   'GRIN2D',
#   'GRIN2C',
#   'GRIN1',
#   'GABRG2'],
#  'Acarbose': ['MGAM', 'AMY2A', 'AMY1A', 'SI', 'GAA'],
#  'Paracetamol': ['CA13',
#   'CA12',
#   'NR1I3',
#   'ALOX15',
#   'ALOX5AP',
#   'TRPV1',
#   'PTGS2',
#   'CA2',
#   'CA1',
#   'CA4',
#   'MB',
#   'CA3',
#   'CNR1',
#   'CA7',
#   'CA9',
#   'CA14'],
#  'Acetazolamide': ['CA13',
#   'CA12',
#   'CA11',
#   'AQP1',
#   'CA2',
#   'CA1',
#   'CA4',
#   'CA3',
#   'CA5B',
#   'CA5A',
#   'CA6',
#   'CA7',
#   'CA9',
#   'CA14'],
#  'Acetoxolone': ['CES1', 'HSD11B2', 'HSD17B1', 'HSD17B2', 'CES2', 'HSD11B1'],
#  'Acetylcholine': ['CHRM3',
#   'CHRNA2',
#   'CHRND',
#   'CHRM4',
#   'CHRNB2',
#   'CHRM1',
#   'CHRNA4',
#   'CHRM2',
#   'CHRNA3',
#   'CHRNB4',
#   'CHRM5',
#   'CHRNA7'],
#  'Acetylcysteine': ['GSS', 'CYCS', 'SLC7A11', 'VEGFA', 'SOD2'],
#  'Acetyldigitoxin': ['FXYD2',
#   'ATP1A4',
#   'ATP1A3',
#   'ATP1A2',
#   'ATP1B3',
#   'ATP1A1',
#   'ATP1B2',
#   'ATP1B1'],
#  'Acetylsalicylic Acid': ['NAPRT', 'ASIC3', 'GGT1', 'PTGS1', 'PTGS2'],
#  'Aclarubicin': ['TOP2B', 'MMP2', 'TOP2A', 'HTR2B', 'TOP1'],
#  'Aclatonium': ['CHRM3', 'CHRM4', 'CHRM1', 'CHRM2', 'CHRM5'],
#  'Adenine': ['PI4KB', 'PI4KA', 'XDH', 'PI4K2B', 'PI4K2A'],
#  'Adenosine': ['DOT1L',
#   'AHCY',
#   'ADK',
#   'ADORA2B',
#   'PRKAR2B',
#   'ADORA2A',
#   'PRKAR2A',
#   'ADORA3',
#   'ADORA1',
#   'MAP3K7',
#   'PRKACB',
#   'ADA',
#   'GAPDH',
#   'PI4K2B',
#   'PI4K2A',
#   'PRKACA'],
#  'Adenosine Triphosphate': ['GPR17',
#   'P2RY13',
#   'P2RY11',
#   'HSPA8',
#   'TRAP1',
#   'AK2',
#   'HSP90B1',
#   'P2RX6',
#   'P2RX5',
#   'P2RX4',
#   'P2RX3',
#   'P2RY4',
#   'MAPKAPK2',
#   'P2RX2',
#   'P2RX1',
#   'P2RY2',
#   'HSPA1A',
#   'P2RY1',
#   'MAP3K7',
#   'TRPM4',
#   'JAK2'],
#  'Adenosine Phosphate': ['TRPM2',
#   'SRC',
#   'LDHA',
#   'AK2',
#   'DNPH1',
#   'FBP1',
#   'TRPM4'],
#  'Adinazolam': ['GABRA3',
#   'GABRA2',
#   'GABRB3',
#   'GABRA1',
#   'GABRB2',
#   'GABRB1',
#   'GABRA6',
#   'GABRA5',
#   'GABRA4',
#   'GABRG1',
#   'GABRG3',
#   'GABRG2',
#   'TSPO',
#   'GABRD'],
#  'Adiphenine': ['CHRM3', 'CHRM4', 'CHRM1', 'CHRM2', 'HRH1', 'CHRM5'],
#  'Agomelatine': ['MTNR1B', 'MTNR1A', 'HTR2C', 'HTR2A', 'HTR2B'],
#  'Alcuronium': ['CHRM3',
#   'CHRNA2',
#   'CHRND',
#   'CHRM4',
#   'CHRNA1',
#   'CHRM1',
#   'CHRNA4',
#   'CHRM2',
#   'CHRNB4',
#   'CHRNA7',
#   'CHRNB1'],
#  'Alfentanil': ['SIGMAR1', 'ABCB1', 'OPRD1', 'OPRK1', 'OPRM1'],
#  'Alfuzosin': ['ACHE', 'SLC22A1', 'ADRA1D', 'ADRA1B', 'ADRA1A'],
#  'Alfaxalone': ['GABRA3',
#   'GABRA2',
#   'GABRB3',
#   'GABRQ',
#   'GABRA1',
#   'GABRB2',
#   'GABRP',
#   'GABRB1',
#   'GABRA6',
#   'GABRA5',
#   'GABRA4',
#   'GABRG1',
#   'SLC6A1',
#   'GABRG3',
#   'GABRG2',
#   'GABRE',
#   'GABRD'],
#  'Alpidem': ['GABRA3',
#   'GABRA2',
#   'GABRB3',
#   'GABRQ',
#   'GABRA1',
#   'GABRB2',
#   'GABRP',
#   'GABRB1',
#   'GABRA6',
#   'GABRA5',
#   'GABRA4',
#   'GABRG1',
#   'GABRG3',
#   'GABRG2',
#   'ABCB11',
#   'TSPO',
#   'GABRE',
#   'GABRD'],
#  'Alprazolam': ['BRD4',
#   'GABRA3',
#   'GABRA2',
#   'GABRB3',
#   'GABRA1',
#   'GABRB2',
#   'CCKAR',
#   'GABRA5',
#   'PTAFR',
#   'CYP3A4',
#   'GABRG2'],
#  'Alprenolol': ['ADRB1', 'ADRB2', 'HTR2A', 'ADRB3', 'HTR1A', 'FDFT1'],
#  'Alprostadil': ['CATSPER2',
#   'CATSPER1',
#   'CATSPER4',
#   'CATSPER3',
#   'PTGER1',
#   'PTGER2',
#   'PTGIR',
#   'PTGER3',
#   'PTGER4',
#   'PTGDR'],
#  'Amantadine': ['GRIN3A',
#   'SIGMAR1',
#   'GRIN2B',
#   'SLC47A1',
#   'GRIN2A',
#   'GRIN3B',
#   'GRIN2D',
#   'GRIN2C',
#   'GRIN1'],
#  'Amidefrine': ['ADRA1D', 'ADRA1B', 'ADRA2C', 'ADRA1A', 'ADRA2B', 'ADRA2A'],
#  'Amiloride': ['AOC3',
#   'SLC22A1',
#   'MAOA',
#   'SCNN1A',
#   'PLAU',
#   'SLC9A1',
#   'SLC9A2',
#   'SCNN1G',
#   'SLC9A5',
#   'ADORA2A',
#   'SCNN1B',
#   'ASIC3',
#   'ASIC1',
#   'ASIC2'],
#  'Amiodarone': ['CCR2',
#   'HTR1B',
#   'OPRM1',
#   'TACR2',
#   'MC3R',
#   'CYP2C9',
#   'KDM5A',
#   'CHRM3',
#   'CHRM4',
#   'HCN4',
#   'ABCB1',
#   'CHRM1',
#   'CHRM2',
#   'OPRD1',
#   'CHRM5',
#   'HTR2C',
#   'ADRB1',
#   'HTR2A',
#   'ADRB3',
#   'CYP3A4',
#   'HTR2B',
#   'HRH2',
#   'ERBB2',
#   'ADORA3',
#   'BDKRB2',
#   'DRD1',
#   'DRD2',
#   'DRD3',
#   'DRD4',
#   'CCR4',
#   'FDFT1',
#   'KCNH2',
#   'SIGMAR1',
#   'OPRK1',
#   'THAP1',
#   'PGRMC1',
#   'ADRA2B',
#   'ADRA2A',
#   'AR',
#   'SQLE',
#   'MC5R',
#   'KDM7A',
#   'THRB',
#   'THRA',
#   'PHF2',
#   'KCNA7',
#   'SLC6A2',
#   'HTR6',
#   'SLC6A3',
#   'SLC6A4',
#   'CACNA1H',
#   'EDNRA',
#   'EBP',
#   'MC4R',
#   'SCN5A',
#   'FYN'],
#  'Amisulpride': ['HTR7',
#   'HTR1D',
#   'HTR1B',
#   'HTR2A',
#   'DRD2',
#   'HTR2B',
#   'DRD3',
#   'ADRA2C',
#   'DRD4',
#   'HTR6',
#   'ADRA2A'],
#  'Amitriptyline': ['SIGMAR1',
#   'KCNJ6',
#   'NTRK1',
#   'HTR1B',
#   'HTR1A',
#   'ADRA2C',
#   'ADRA2B',
#   'ADRA2A',
#   'SCN2A',
#   'CHRM3',
#   'CHRM4',
#   'RET',
#   'CHRM1',
#   'CHRM2',
#   'SLC22A1',
#   'CHRM5',
#   'SLC22A2',
#   'HTR2C',
#   'HTR2A',
#   'ADRA1D',
#   'HTR2B',
#   'SLC6A2',
#   'ADRA1B',
#   'HTR6',
#   'SLC6A3',
#   'ADRA1A',
#   'SLC6A4',
#   'HRH2',
#   'HTR7',
#   'HRH1',
#   'HRH4',
#   'SCN9A',
#   'AOX1',
#   'SCN5A',
#   'DRD1',
#   'DRD2',
#   'DRD3',
#   'DRD5',
#   'KCNH2'],
#  'Amlexanox': ['GPR35', 'TBK1', 'PDE4D', 'PDE4C', 'PDE4B', 'PDE4A', 'IKBKE'],
#  'Amlodipine': ['CACNA2D1',
#   'CACNA1C',
#   'ADRA1D',
#   'CACNA1D',
#   'ADRA1B',
#   'ADRA2C',
#   'HTR6',
#   'SLC6A3',
#   'ADRA1A',
#   'ADRA2A',
#   'CACNA1H',
#   'CA1',
#   'AOX1',
#   'CACNG1',
#   'KCNK2'],
#  'Amoxapine': ['GABRA1',
#   'HTR1A',
#   'ADRA2C',
#   'HTR3A',
#   'ADRA2B',
#   'ADRA2A',
#   'GABRG2',
#   'CHRM3',
#   'CHRM4',
#   'ABCB1',
#   'CHRM1',
#   'GABRB2',
#   'CHRM2',
#   'CHRM5',
#   'HTR2C',
#   'HTR2A',
#   'ADRA1D',
#   'HTR2B',
#   'SLC6A2',
#   'ADRA1B',
#   'HTR6',
#   'SLC6A3',
#   'ADRA1A',
#   'SLC6A4',
#   'SLC6A5',
#   'HTR7',
#   'HRH1',
#   'CYP2D6',
#   'DRD1',
#   'DRD2',
#   'DRD3',
#   'DRD4'],
#  'Amfetamine': ['HTR1F',
#   'HTR1D',
#   'MAOA',
#   'HTR1B',
#   'HTR2C',
#   'HTR2A',
#   'HTR3B',
#   'HTR1A',
#   'HTR2B',
#   'CARTPT',
#   'SLC6A2',
#   'TAAR1',
#   'HTR3A',
#   'HTR6',
#   'SLC6A3',
#   'ADRA1A',
#   'SLC6A4',
#   'ADRA2A',
#   'HTR4',
#   'HTR5A',
#   'HTR7'],
#  'Amrinone': ['PDE4D', 'PDE3B', 'PDE4C', 'PDE3A', 'PDE4B', 'PDE4A', 'TTK'],
#  'Amsacrine': ['TOP2B',
#   'SLC22A1',
#   'CYP2D6',
#   'TOP1MT',
#   'TOP2A',
#   'TOP1',
#   'KCNH2'],
#  'Androstenediol': ['AR', 'ESR1', 'ESR2', 'SERPINA6', 'SHBG'],
#  'Androstenedione': ['AR', 'HSD17B3', 'CYP19A1', 'SERPINA6', 'SHBG'],
#  'Anhydrovinblastine': ['ABCB1', 'ABCC2', 'ABCC10', 'ABCC1', 'TUBB4B'],
#  'Apomorphine': ['SIGMAR1',
#   'HTR1F',
#   'HTR1D',
#   'TRPA1',
#   'HTR1B',
#   'OPRK1',
#   'HTR3B',
#   'OPRM1',
#   'HTR1A',
#   'ADRA2C',
#   'HTR3A',
#   'ADRA2B',
#   'ADRA2A',
#   'HTR5A',
#   'MDM2',
#   'OPRD1',
#   'MPI',
#   'SLC22A1',
#   'HTR2C',
#   'HTR2A',
#   'ADRA1D',
#   'HTR2B',
#   'ADRA1B',
#   'HTR6',
#   'ADRA1A',
#   'HTR4',
#   'HTR7',
#   'DRD1',
#   'DRD2',
#   'DRD3',
#   'DRD4',
#   'DRD5'],
#  'Apraclonidine': ['ADRA1D', 'ADRA1B', 'ADRA2C', 'ADRA1A', 'ADRA2B', 'ADRA2A'],
#  'Aprindine': ['HCN4',
#   'CYP2D6',
#   'PSMA1',
#   'SCN5A',
#   'CALM2',
#   'CALM3',
#   'SLC8A1',
#   'CALM1',
#   'KCNH2'],
#  'Aripiprazole': ['HTR1D',
#   'HTR1E',
#   'HTR1B',
#   'HTR1A',
#   'ADRA2C',
#   'HTR3A',
#   'ADRA2B',
#   'ADRA2A',
#   'HTR5A',
#   'CHRM3',
#   'CHRM4',
#   'ABCB1',
#   'CHRM1',
#   'CHRM2',
#   'CHRM5',
#   'HTR2C',
#   'ADRB1',
#   'ADRB2',
#   'HTR2A',
#   'HTR2B',
#   'SLC6A2',
#   'ADRA1B',
#   'HTR6',
#   'SLC6A3',
#   'ADRA1A',
#   'SLC6A4',
#   'HTR7',
#   'HRH1',
#   'DRD1',
#   'DRD2',
#   'DRD3',
#   'DRD4',
#   'DRD5',
#   'KCNH2'],
#  'Astemizole': ['HTR1B',
#   'OPRM1',
#   'TACR1',
#   'HTR1A',
#   'TACR2',
#   'SSTR5',
#   'MC3R',
#   'CALM2',
#   'CALM3',
#   'ABCG2',
#   'CALM1',
#   'CHRM3',
#   'CHRM4',
#   'ABCB1',
#   'CHRM1',
#   'CHRM2',
#   'OPRD1',
#   'CHRM5',
#   'HTR2C',
#   'ADRB1',
#   'HTR2A',
#   'ADRA1D',
#   'ADRB3',
#   'CYP3A4',
#   'HTR2B',
#   'ADRA1B',
#   'EGFR',
#   'ADRA1A',
#   'HRH2',
#   'HRH1',
#   'HRH4',
#   'ERBB2',
#   'ADORA3',
#   'DRD1',
#   'DRD2',
#   'DRD3',
#   'DRD4',
#   'KCNH1',
#   'KCNH2',
#   'SIGMAR1',
#   'EED',
#   'OPRK1',
#   'HLA-A',
#   'ADRA2C',
#   'HTR3A',
#   'PGRMC1',
#   'ADRA2B',
#   'ADRA2A',
#   'LCK',
#   'MC5R',
#   'SLC28A1',
#   'SLC47A1',
#   'TMEM97',
#   'SLC6A2',
#   'HTR6',
#   'SLC6A3',
#   'SLC6A4',
#   'GLRA1',
#   'FNTB',
#   'FNTA',
#   'MC4R',
#   'FYN'],
#  'Atazanavir': ['ABCB1', 'CYP2C9', 'UGT1A1', 'CYP1A2', 'CYP3A4'],
#  'Atomoxetine': ['KCNJ5',
#   'KCNJ6',
#   'CYP2D6',
#   'KLF10',
#   'SLC6A2',
#   'SLC6A3',
#   'KCNJ3',
#   'SLC6A4',
#   'KCNH2'],
#  'Atorvastatin': ['HDAC6', 'HDAC1', 'HDAC2', 'NR1I3', 'HMGCR', 'CYP3A4'],
#  'Atracurium': ['CHRNA2',
#   'CHRND',
#   'CHRNA1',
#   'CHRNA4',
#   'CHRNA3',
#   'CHRNA7',
#   'KCNN3',
#   'CHRNB1'],
#  'Atropine': ['ACHE',
#   'CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'HRH1',
#   'SLC22A1',
#   'CHRM5',
#   'HTR2C',
#   'HTR2A',
#   'ADRA1D',
#   'ADRA2A'],
#  'Azapetine': ['ADRA1D', 'ADRA1B', 'ADRA2C', 'ADRA1A', 'ADRA2B', 'ADRA2A'],
#  'Azathioprine': ['ABCC4', 'ABCC5', 'TPMT', 'RAC1', 'ABCG2'],
#  'Azelastine': ['ABCB1',
#   'CHRM1',
#   'HRH1',
#   'HRH3',
#   'HTR2C',
#   'HTR2B',
#   'ADRA1B',
#   'ADRA1A',
#   'KCNH2'],
#  'Baclofen': ['GABRA3',
#   'GABRA2',
#   'GABRB3',
#   'GABRQ',
#   'GABBR2',
#   'GABRA1',
#   'GABRB2',
#   'GABRP',
#   'GABBR1',
#   'GABRB1',
#   'GABRA6',
#   'GABRA5',
#   'GABRA4',
#   'GABRG1',
#   'GABRG3',
#   'GABRG2',
#   'ADORA3',
#   'GABRE',
#   'GABRD'],
#  'Beclometasone Dipropionate': ['AR',
#   'IL5',
#   'ADGRG3',
#   'PGR',
#   'MMP9',
#   'NR3C2',
#   'NR3C1'],
#  'Bendamustine': ['HDAC6', 'HDAC3', 'HDAC1', 'HDAC10', 'HDAC2', 'HDAC8'],
#  'Bendroflumethiazide': ['SLC12A3', 'CA2', 'CA1', 'CA4', 'KCNMA1'],
#  'Benperidol': ['SIGMAR1', 'HTR2A', 'DRD2', 'DRD3', 'DRD4', 'KCNH2'],
#  'Diphenidol': ['CHRM3',
#   'SIGMAR1',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'CHRM5',
#   'HTR2A',
#   'ADRA1B',
#   'CYP2D6',
#   'SCN3A',
#   'DRD2',
#   'DRD3',
#   'SCN1A',
#   'SCN2A'],
#  'Benserazide': ['DDC', 'UBA2', 'ESR2', 'HK2', 'SAE1'],
#  'Benzbromarone': ['PTPN1',
#   'CYP2C9',
#   'EYA2',
#   'EYA3',
#   'AKR1C1',
#   'ADORA3',
#   'MAPK1',
#   'PDE4A',
#   'HTR2B',
#   'ABCC1',
#   'MAPK14',
#   'SLC22A12'],
#  'Benzocaine': ['SCN11A',
#   'SCN9A',
#   'SCN10A',
#   'SCN7A',
#   'SCN8A',
#   'SCN5A',
#   'SCN3A',
#   'SCN4A',
#   'SCN1A',
#   'SCN2A'],
#  'Benzquinamide': ['DRD2',
#   'DRD3',
#   'ADRA2C',
#   'DRD4',
#   'ADRA2B',
#   'ADRA2A',
#   'PTGS2'],
#  'Benzthiazide': ['SLC12A3', 'CA2', 'CA1', 'CA4', 'KCNMA1'],
#  'Benzatropine': ['CHRM3',
#   'SIGMAR1',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'SLC6A19',
#   'CHRM5',
#   'HTR2C',
#   'HTR2A',
#   'ADRA1D',
#   'HTR2B',
#   'SLC6A2',
#   'ADRA1B',
#   'ADRA2C',
#   'HTR6',
#   'PGRMC1',
#   'SLC6A3',
#   'ADRA1A',
#   'ADRA2B',
#   'SLC6A4',
#   'ADRA2A',
#   'HRH2',
#   'HRH1',
#   'DRD3'],
#  'Bepridil': ['HCN4',
#   'KCNT1',
#   'CACNA1A',
#   'CACNA1C',
#   'KCNQ4',
#   'SCN5A',
#   'SCN3A',
#   'CACNA1D',
#   'SCN1A',
#   'SCN2A',
#   'CACNA1H',
#   'KCNH2'],
#  'Bexarotene': ['CYP26A1',
#   'RXRA',
#   'CYP26B1',
#   'RXRB',
#   'RARG',
#   'NR1H3',
#   'NR1H2',
#   'RARB',
#   'PPARG',
#   'RARA',
#   'RXRG'],
#  'Bezafibrate': ['FABP2', 'PPARA', 'LPL', 'PPARG', 'HMGCR', 'PPARD', 'FABP1'],
#  'Biperiden': ['CHRM3', 'CHRNA2', 'CHRM4', 'CHRM1', 'CHRM2', 'CHRM5'],
#  'Bopindolol': ['CYP2D6',
#   'ADRB1',
#   'ADRB2',
#   'HTR2A',
#   'ADRB3',
#   'HTR1A',
#   'HTR2B'],
#  'Bortezomib': ['CA13',
#   'CA12',
#   'CTSA',
#   'PSD',
#   'CMA1',
#   'F2',
#   'NFKB1',
#   'NFKB2',
#   'PSMB9',
#   'PSMA1',
#   'CTRB1',
#   'RELA',
#   'CYP2C19',
#   'PSMB10',
#   'PSMB8',
#   'CA2',
#   'PSMB5',
#   'CA1',
#   'CA4',
#   'CA3',
#   'CA5B',
#   'CA5A',
#   'CA6',
#   'PSMB1',
#   'PSMB2',
#   'PSMD1',
#   'CA7',
#   'CA9',
#   'CTSG',
#   'CA14',
#   'ELANE'],
#  'Brimonidine': ['ADRA1D',
#   'HTR1A',
#   'ADRA1B',
#   'ADRA2C',
#   'ADRA1A',
#   'ADRA2B',
#   'ADRA2A'],
#  'Brinzolamide': ['CA13',
#   'CA12',
#   'CA2',
#   'CA1',
#   'CA4',
#   'CA5B',
#   'CA5A',
#   'CA6',
#   'CA7',
#   'CA9',
#   'CA14'],
#  'Bromocriptine': ['HTR1D',
#   'HTR1B',
#   'HTR2C',
#   'ADRB1',
#   'ADRB2',
#   'HTR2A',
#   'ADRA1D',
#   'CYP3A4',
#   'HTR1A',
#   'HTR2B',
#   'ADRA1B',
#   'ADRA2C',
#   'HTR6',
#   'ADRA1A',
#   'ADRA2B',
#   'ADRA2A',
#   'AR',
#   'HTR7',
#   'DRD1',
#   'SLC17A8',
#   'DRD2',
#   'DRD3',
#   'DRD4',
#   'DRD5'],
#  'Bromperidol': ['CHRM3',
#   'SIGMAR1',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'HRH1',
#   'CHRM5',
#   'DRD1',
#   'DRD2',
#   'DRD3',
#   'DRD4',
#   'ADRA1A'],
#  'Brompheniramine': ['HRH1', 'SCN3A', 'SCN1A', 'SCN2A', 'KCNH2'],
#  'Budesonide': ['AR', 'IL5', 'ABCB1', 'IFNG', 'PGR', 'MMP9', 'NR3C2', 'NR3C1'],
#  'Budipine': ['GRIN3A',
#   'GRIN2B',
#   'GRIN2A',
#   'GRIN3B',
#   'GRIN2D',
#   'GRIN2C',
#   'GRIN1',
#   'KCNH2'],
#  'Buflomedil': ['SIGMAR1',
#   'EBP',
#   'CACNG1',
#   'ADRA1D',
#   'ADRA1B',
#   'ADRA2C',
#   'ADRA1A',
#   'ADRA2A'],
#  'Levobunolol': ['SIGMAR1', 'ADRB1', 'ADRB2', 'ADRB3', 'HTR1A', 'SLC6A4'],
#  'Bupivacaine': ['KCND3',
#   'PTGER1',
#   'CYP2D6',
#   'SCN5A',
#   'KCNA5',
#   'SCN4A',
#   'SCN1A',
#   'HTR3A',
#   'KCNK3',
#   'KCNH2'],
#  'Buprenorphine': ['OPRD1', 'OPRK1', 'OPRM1', 'OPRL1', 'KCNH2'],
#  'Bupropion': ['CHRNB2',
#   'CHRNA3',
#   'CHRNB4',
#   'CYP2D6',
#   'CHRNA7',
#   'SLC6A2',
#   'CYP2C19',
#   'PGRMC1',
#   'SLC6A3',
#   'ADRA1A',
#   'SLC6A4'],
#  'Buspirone': ['SIGMAR1',
#   'HTR1F',
#   'HTR1D',
#   'HTR1B',
#   'HTR1A',
#   'ADRA2C',
#   'PGRMC1',
#   'ADRA2B',
#   'ADRA2A',
#   'SLC47A1',
#   'SLC47A2',
#   'SLC22A2',
#   'HTR2C',
#   'HTR2A',
#   'ADRA1D',
#   'CYP3A4',
#   'HTR2B',
#   'ADRA1B',
#   'ADRA1A',
#   'HTR7',
#   'DRD1',
#   'DRD2',
#   'DRD3',
#   'DRD4',
#   'DRD5',
#   'KCNH2'],
#  'Butenafine': ['ACHE',
#   'SIGMAR1',
#   'CYP2D6',
#   'SLC6A2',
#   'PGRMC1',
#   'SLC6A4',
#   'ADRA2A'],
#  'Cabergoline': ['HTR1D',
#   'HTR1B',
#   'HTR2C',
#   'HTR2A',
#   'ADRA1D',
#   'HTR1A',
#   'HTR2B',
#   'ADRA1B',
#   'ADRA2C',
#   'ADRA1A',
#   'ADRA2B',
#   'ADRA2A',
#   'DRD1',
#   'DRD2',
#   'DRD3',
#   'DRD4',
#   'DRD5'],
#  'Caffeine': ['ACHE',
#   'GDA',
#   'ADORA2B',
#   'ADORA2A',
#   'ADORA3',
#   'PIK3CD',
#   'ADORA1',
#   'PYGM',
#   'KCNH2'],
#  'Camostat': ['SLC47A1',
#   'PRSS1',
#   'SLC47A2',
#   'HPN',
#   'KLK1',
#   'SLC22A2',
#   'TMPRSS2',
#   'F2',
#   'PLG',
#   'HGFAC'],
#  'Candesartan Cilexetil': ['ADRB3',
#   'CYP3A4',
#   'SLC6A2',
#   'EGFR',
#   'ADRA2B',
#   'CYP2C9',
#   'ERBB2',
#   'TBXAS1',
#   'POLK',
#   'ADORA3',
#   'AGTR1',
#   'POLI',
#   'POLH'],
#  'Captopril': ['ACE', 'LTA4H', 'F2', 'REN', 'PTGS1', 'PTGS2'],
#  'Caramiphen': ['SIGMAR1', 'CHRM1', 'CHRM2', 'PRCP', 'SLC6A3'],
#  'Carbachol': ['ACHE',
#   'CHRM3',
#   'CHRNA2',
#   'CHRM4',
#   'CHRNA1',
#   'CHRNB2',
#   'CHRM1',
#   'CHRNA4',
#   'CHRM2',
#   'CHRNA3',
#   'CHRNB4',
#   'CHRM5',
#   'CHRNA7',
#   'CHRND'],
#  'Carbamazepine': ['CHRNA2',
#   'GABRA1',
#   'GABRB2',
#   'CHRNB4',
#   'HRH1',
#   'NR1I2',
#   'SCN9A',
#   'FZD8',
#   'SCN5A',
#   'SCN4A',
#   'SLC6A4',
#   'GABRG2'],
#  'Pentoxyverine': ['SIGMAR1', 'CHRM1', 'CHRM2', 'SLC22A1', 'PRCP', 'SLC6A3'],
#  'Carvedilol': ['KCNK10',
#   'HTR1B',
#   'HTR1A',
#   'ADRA2C',
#   'ADRA2B',
#   'ADRA2A',
#   'KCNK2',
#   'TLR4',
#   'APP',
#   'RYR2',
#   'SLC47A1',
#   'SLC22A1',
#   'SLC22A2',
#   'HTR2C',
#   'ADRB1',
#   'ADRB2',
#   'HTR2A',
#   'ADRA1D',
#   'ADRB3',
#   'HTR2B',
#   'SLC6A2',
#   'ADRA1B',
#   'HTR6',
#   'SLC6A3',
#   'ADRA1A',
#   'SLC6A4',
#   'HTR4',
#   'DRD1',
#   'DRD2',
#   'DRD3',
#   'KCNH2'],
#  'Cefotetan': ['MMP1', 'MMP2', 'MMP9', 'COMT', 'PTGS2'],
#  'Cefsulodin': ['GRK2', 'L3MBTL1', 'PTPN11', 'PTPN6', 'TPT1'],
#  'Celecoxib': ['CA13',
#   'CA12',
#   'PDPK1',
#   'ADRA2B',
#   'MAPK14',
#   'PDE5A',
#   'PGR',
#   'PTGES',
#   'HDAC6',
#   'HDAC1',
#   'ADRB3',
#   'SLC6A2',
#   'SLC6A3',
#   'PTGS1',
#   'SLC6A4',
#   'PTGS2',
#   'CA2',
#   'CA1',
#   'CA4',
#   'CA3',
#   'CA5B',
#   'CA5A',
#   'CA6',
#   'CYP2D6',
#   'ADORA3',
#   'CA7',
#   'DRD1',
#   'PDE4A',
#   'CA9',
#   'CA14'],
#  'Cefalotin': ['PTPN7', 'MMP9', 'SLC22A8', 'SSTR4', 'SLC22A11', 'PTGS2'],
#  'Cefapirin': ['SIGMAR1',
#   'OPRD1',
#   'MMP1',
#   'OPRK1',
#   'OPRM1',
#   'TACR1',
#   'CYP3A4',
#   'HTR1A',
#   'HTR2B',
#   'TACR2',
#   'CYP3A5',
#   'ADRA2C',
#   'SSTR4',
#   'NISCH',
#   'HRH2',
#   'CNR1',
#   'CYP2D6',
#   'DRD2',
#   'DRD3',
#   'DRD4'],
#  'Cevimeline': ['CHRM3', 'CHRM4', 'CHRM1', 'CHRM2', 'CHRM5'],
#  'Chlorambucil': ['OPRD1', 'AKR1B1', 'ADAM9', 'CTSE', 'CTSD'],
#  'Chlordiazepoxide': ['ACHE',
#   'GABRA3',
#   'TRHR',
#   'GABRA2',
#   'GABRB3',
#   'GABRQ',
#   'BCHE',
#   'GABRA1',
#   'GABRB2',
#   'GABRP',
#   'GABRB1',
#   'GABRA6',
#   'GABRA5',
#   'GABRA4',
#   'GABRG1',
#   'GABRG3',
#   'GABRG2',
#   'HRH1',
#   'CCKAR',
#   'CCKBR',
#   'TSPO',
#   'GABRE',
#   'GABRD'],
#  'Chlorhexidine': ['SLC47A1',
#   'SLC47A2',
#   'SLC22A1',
#   'SYNJ2',
#   'TPR',
#   'MMP2',
#   'SLC22A3',
#   'SLC22A2',
#   'RCE1',
#   'MMP9'],
#  'Chlormadinone': ['AR', 'ATP1A2', 'PGR', 'CYP2C19', 'NR3C1'],
#  'Chloroquine': ['APP',
#   'CHRM3',
#   'SIGMAR1',
#   'CHRM4',
#   'NQO2',
#   'CHRM1',
#   'CHRM2',
#   'CHRM5',
#   'PRNP',
#   'TMEM97',
#   'ADRA2C',
#   'ADRA2B',
#   'ADRA2A',
#   'BACE1',
#   'DHFR',
#   'KCNH2'],
#  'Chlorphenamine': ['L3MBTL1',
#   'L3MBTL3',
#   'HTR2B',
#   'SLC6A2',
#   'SLC6A3',
#   'SLC6A4',
#   'HRH1',
#   'HRH4',
#   'CYP2D6',
#   'MBTD1',
#   'SCN3A',
#   'SCN1A',
#   'SCN2A',
#   'KCNH2'],
#  'Chlorpromazine': ['HTR1D',
#   'HTR1E',
#   'HTR1B',
#   'OPRM1',
#   'TRPV1',
#   'HTR1A',
#   'TACR2',
#   'GRIN2D',
#   'GRIN2C',
#   'GRIN1',
#   'HTR5A',
#   'GRIN3A',
#   'MC3R',
#   'GRIN3B',
#   'CALM2',
#   'KCNK2',
#   'CALM3',
#   'CALM1',
#   'CHRM3',
#   'CHRM4',
#   'CHRNA1',
#   'ABCB1',
#   'CHRM1',
#   'CHRM2',
#   'OPRD1',
#   'ADCY1',
#   'CHRM5',
#   'ADCY5',
#   'ALOX15',
#   'HTR2C',
#   'ADCY4',
#   'ADCY3',
#   'HTR2A',
#   'ADCY2',
#   'ADRA1D',
#   'HTR2B',
#   'ADCY8',
#   'ADRA1B',
#   'EGFR',
#   'ADRA1A',
#   'ADCY6',
#   'HRH2',
#   'HRH1',
#   'HRH4',
#   'CYP2D6',
#   'ERBB2',
#   'AOX1',
#   'DRD1',
#   'SCN3A',
#   'DRD2',
#   'DRD3',
#   'DRD4',
#   'DRD5',
#   'KCNH2',
#   'SIGMAR1',
#   'PRNP',
#   'OPRK1',
#   'GFER',
#   'ADRA2C',
#   'HTR3A',
#   'PGRMC1',
#   'ADRA2B',
#   'ADRA2A',
#   'MC5R',
#   'SCN2A',
#   'RYR1',
#   'SLC22A1',
#   'SLC22A2',
#   'SLC6A2',
#   'HTR6',
#   'SLC6A3',
#   'SLC6A4',
#   'GRIN2B',
#   'HTR7',
#   'GRIN2A',
#   'TPR',
#   'MC4R',
#   'SMPD1',
#   'FYN',
#   'SCN1A'],
#  'Chlorprothixene': ['CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'SLC22A1',
#   'CHRM5',
#   'HTR2A',
#   'HTR6',
#   'HTR7',
#   'HRH1',
#   'DRD1',
#   'DRD2',
#   'DRD3',
#   'DRD4',
#   'DRD5'],
#  'Chlortalidone': ['CA13',
#   'SLC12A3',
#   'CA12',
#   'CA2',
#   'CA1',
#   'CA4',
#   'CA3',
#   'CA5B',
#   'CA5A',
#   'CA6',
#   'CA7',
#   'CA9',
#   'CA14'],
#  'Chlorzoxazone': ['NOS3', 'KCNMA1', 'KCNN2', 'NOS1', 'KCNN4', 'NOS2'],
#  'Cianidanol': ['APP',
#   'CA13',
#   'CA12',
#   'F2',
#   'DHODH',
#   'PTGS1',
#   'BACE1',
#   'PTGS2',
#   'CA2',
#   'CA1',
#   'CA4',
#   'KIT',
#   'CA3',
#   'CA5B',
#   'CA5A',
#   'CA6',
#   'CA7',
#   'CA9',
#   'CA14'],
#  'Cicaprost': ['PTGFR',
#   'PTGER1',
#   'PTGER2',
#   'PTGIR',
#   'PTGER3',
#   'PTGER4',
#   'PTGDR'],
#  'Cinnarizine': ['SIGMAR1',
#   'OPRM1',
#   'HTR1A',
#   'ADRA2C',
#   'PGRMC1',
#   'ADRA2B',
#   'ADRA2A',
#   'SCN2A',
#   'CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'CHRM5',
#   'HTR2A',
#   'ADRA1D',
#   'HTR2B',
#   'SLC6A2',
#   'ADRA1B',
#   'SLC6A3',
#   'ADRA1A',
#   'SLC6A4',
#   'HRH1',
#   'HRH4',
#   'SCN3A',
#   'DRD2',
#   'DRD3',
#   'SCN1A'],
#  'Ciprofloxacin': ['GABRA3',
#   'TOP2B',
#   'GABRA2',
#   'GABRB3',
#   'GABRQ',
#   'GABRA1',
#   'GABRB2',
#   'GABRP',
#   'GABRB1',
#   'GABRA6',
#   'GABRA5',
#   'GABRA4',
#   'TOP2A',
#   'GABRG1',
#   'GABRG3',
#   'GABRG2',
#   'HRH3',
#   'GABRE',
#   'GABRD'],
#  'Cisapride': ['SIGMAR1',
#   'HTR1F',
#   'HTR1D',
#   'HTR1B',
#   'HTR3D',
#   'HTR3E',
#   'HTR3B',
#   'HTR1A',
#   'HTR3C',
#   'ADRA2C',
#   'HTR3A',
#   'PGRMC1',
#   'ADRA2B',
#   'ADRA2A',
#   'HTR2C',
#   'HMGCR',
#   'HTR2A',
#   'ADRA1D',
#   'CYP3A4',
#   'HTR2B',
#   'ADRA1B',
#   'ADRA1A',
#   'SLC6A4',
#   'HTR4',
#   'HTR7',
#   'CYP2D6',
#   'DRD1',
#   'DRD2',
#   'DRD3',
#   'KCNH2'],
#  'Citalopram': ['SIGMAR1',
#   'CHRM1',
#   'SLC22A1',
#   'HTR2C',
#   'HTR2A',
#   'ADRA1D',
#   'HTR1A',
#   'HTR2B',
#   'SLC6A2',
#   'ADRA1B',
#   'SLC6A3',
#   'ADRA1A',
#   'SLC6A4',
#   'HRH1',
#   'KCNH2'],
#  'Clebopride': ['ACHE',
#   'HTR2C',
#   'HTR2A',
#   'HTR2B',
#   'ADRA2C',
#   'ADRA2B',
#   'ADRA2A',
#   'HTR4',
#   'DRD1',
#   'DRD2',
#   'DRD3',
#   'DRD4',
#   'KCNH2'],
#  'Clemastine': ['SIGMAR1',
#   'HTR1B',
#   'ADRA2C',
#   'PGRMC1',
#   'ADRA2B',
#   'ADRA2A',
#   'CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'SLC22A1',
#   'CHRM5',
#   'HTR2C',
#   'HTR2A',
#   'TMEM97',
#   'ADRA1D',
#   'HTR2B',
#   'SLC6A2',
#   'ADRA1B',
#   'CYP2C19',
#   'HTR6',
#   'SLC6A3',
#   'ADRA1A',
#   'HRH2',
#   'HRH1',
#   'CYP2D6',
#   'DRD1',
#   'DRD2',
#   'DRD3',
#   'KCNH2'],
#  'Clemizole': ['TRPC6', 'HRH4', 'TRPC4', 'TRPC5', 'TRPC3', 'HMOX2'],
#  'Clodronic Acid': ['PTPN1', 'SLC25A4', 'SLC17A9', 'SLC25A6', 'SLC25A5'],
#  'Clofarabine': ['POLA1', 'RRM2', 'UCK2', 'UCK1', 'RRM1', 'PRPS1', 'PDE2A'],
#  'Clomifene': ['SIGMAR1',
#   'TACR2',
#   'ESR1',
#   'ADRA2C',
#   'PGRMC1',
#   'ADRA2B',
#   'ADRA2A',
#   'AR',
#   'CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'CHRM5',
#   'HTR2C',
#   'HTR2A',
#   'ADRB3',
#   'HTR2B',
#   'SLC6A2',
#   'ADRA1B',
#   'EGFR',
#   'HTR6',
#   'SLC6A3',
#   'PTGS1',
#   'SLC6A4',
#   'EBP',
#   'HRH1',
#   'CYP2D6',
#   'ERBB2',
#   'ADORA3',
#   'FYN',
#   'DRD3',
#   'KCNH2'],
#  'Clomipramine': ['SIGMAR1',
#   'KCNJ6',
#   'HTR1F',
#   'HTR1D',
#   'HTR1B',
#   'HTR3B',
#   'HTR1A',
#   'ADRA2C',
#   'HTR3A',
#   'PGRMC1',
#   'ADRA2B',
#   'ADRA2A',
#   'HTR5A',
#   'CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'SLC22A1',
#   'CHRM5',
#   'GSTP1',
#   'HTR2C',
#   'HTR2A',
#   'ADRA1D',
#   'HTR2B',
#   'SLC6A2',
#   'ADRA1B',
#   'HTR6',
#   'SLC6A3',
#   'ADRA1A',
#   'SLC6A4',
#   'HTR4',
#   'HRH2',
#   'HTR7',
#   'HRH1',
#   'TPR',
#   'CYP2D6',
#   'AOX1',
#   'DRD1',
#   'DRD2',
#   'DRD3'],
#  'Clonazepam': ['GABRA3',
#   'GABRA2',
#   'GABRB3',
#   'GABRQ',
#   'GABRA1',
#   'GABRB2',
#   'GABRP',
#   'GABRB1',
#   'GABRA6',
#   'GABRA5',
#   'GABRA4',
#   'GABRG1',
#   'GABRG3',
#   'GABRG2',
#   'GABRE',
#   'GABRD'],
#  'Clonidine': ['HCN4',
#   'SLC47A1',
#   'SLC22A1',
#   'SLC22A2',
#   'ADRB1',
#   'ADRA1D',
#   'HTR1A',
#   'ADRA1B',
#   'ADRA2C',
#   'ADRA1A',
#   'ADRA2B',
#   'ADRA2A',
#   'NISCH',
#   'HCN1',
#   'HCN2'],
#  'Clorazepate': ['GABRA3',
#   'GABRA2',
#   'GABRB3',
#   'GABRA1',
#   'GABRB2',
#   'GABRA5',
#   'GABRG2'],
#  'Clotiapine': ['CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'CHRM5',
#   'HTR2C',
#   'DRD1',
#   'HTR2A',
#   'DRD2',
#   'HTR2B'],
#  'Clotrimazole': ['AVPR2',
#   'HTR1B',
#   'OPRM1',
#   'TACR1',
#   'HTR1A',
#   'TACR2',
#   'CYP2C9',
#   'ADORA2A',
#   'IDO1',
#   'IDO2',
#   'ACHE',
#   'CHRM3',
#   'CHRM4',
#   'ABCB1',
#   'CHRM1',
#   'CHRM2',
#   'OPRD1',
#   'NR1I2',
#   'NR1I3',
#   'HTR2C',
#   'ADRB1',
#   'HTR2A',
#   'ADRA1D',
#   'ADRB3',
#   'CYP3A4',
#   'HTR2B',
#   'EGFR',
#   'ADRA1A',
#   'CA2',
#   'HRH2',
#   'HRH1',
#   'CYSLTR1',
#   'ERBB2',
#   'ADORA3',
#   'DRD1',
#   'ADORA1',
#   'DRD2',
#   'DRD3',
#   'DRD4',
#   'CCR4',
#   'KCNH2',
#   'CYP51A1',
#   'OPRK1',
#   'NR1H4',
#   'CYP8B1',
#   'ADRA2B',
#   'ADRA2A',
#   'AR',
#   'TBXAS1',
#   'PGR',
#   'VCP',
#   'SLC22A1',
#   'PTAFR',
#   'KCNA3',
#   'SLC6A2',
#   'CYP2C19',
#   'HTR6',
#   'NR3C1',
#   'SLC6A3',
#   'CYP19A1',
#   'SLC6A4',
#   'PTGS2',
#   'CYP17A1',
#   'CXCR1',
#   'FYN',
#   'KCNN4',
#   'MDH1'],
#  'Clozapine': ['HTR1F',
#   'HTR1D',
#   'HTR1E',
#   'HTR1B',
#   'HTR1A',
#   'HTR5A',
#   'CALM1',
#   'CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'ADCY1',
#   'CHRM5',
#   'ADCY5',
#   'HTR2C',
#   'ADCY4',
#   'ADRB1',
#   'ADCY3',
#   'ADRB2',
#   'HTR2A',
#   'ADCY2',
#   'ADRA1D',
#   'HTR2B',
#   'ADCY8',
#   'ADRA1B',
#   'ADRA1A',
#   'ADCY6',
#   'HRH2',
#   'HRH1',
#   'HRH4',
#   'HRH3',
#   'AOX1',
#   'ADORA3',
#   'DRD1',
#   'DRD2',
#   'DRD3',
#   'DRD4',
#   'DRD5',
#   'KCNH2',
#   'SIGMAR1',
#   'HTR3B',
#   'ADRA2C',
#   'HTR3A',
#   'ADRA2B',
#   'ADRA2A',
#   'SLC6A2',
#   'HTR6',
#   'SLC6A4',
#   'HTR7',
#   'UGT1A4'],
#  'Cocaine': ['SIGMAR1',
#   'CHRM1',
#   'HTR1B',
#   'OPRK1',
#   'HTR3B',
#   'SLC6A1',
#   'CARTPT',
#   'SLC6A2',
#   'HTR3A',
#   'SLC6A3',
#   'ADRA1A',
#   'SLC6A4',
#   'HRH1',
#   'SCN11A',
#   'SCN5A',
#   'SCN3A',
#   'SCN1A',
#   'SCN2A',
#   'KCNH2'],
#  'Colchicine': ['BRD4',
#   'GLRA1',
#   'GLRA2',
#   'ABCB1',
#   'TUBB2B',
#   'TUBB',
#   'PIM1',
#   'CYP3A4',
#   'TPPP',
#   'TUBA1A',
#   'ABCC1',
#   'TUBB4B'],
#  'Colforsin Daropate': ['ADCY1', 'SLC2A1', 'SCN3A', 'SCN1A', 'SCN2A'],
#  'Cortisone Acetate': ['ANXA1',
#   'SLC47A1',
#   'FNTB',
#   'FNTA',
#   'KCNA1',
#   'NR3C1',
#   'SERPINA6',
#   'SHBG'],
#  'Coumarin': ['CA13',
#   'CA12',
#   'MAOB',
#   'MAOA',
#   'CA2',
#   'CA1',
#   'CA4',
#   'CA3',
#   'CA5B',
#   'CA5A',
#   'CA6',
#   'CA7',
#   'CA9',
#   'CA14'],
#  'Cyamemazine': ['CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'CHRM5',
#   'HTR2C',
#   'HTR2A',
#   'HTR1A',
#   'HTR3A',
#   'HTR7',
#   'DRD1',
#   'DRD2',
#   'DRD3'],
#  'Cyclizine': ['CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'MAOB',
#   'CHRM5',
#   'HTR2C',
#   'HTR2A',
#   'ADRA1D',
#   'HTR2B',
#   'ADRA1B',
#   'SLC6A3',
#   'ADRA2A',
#   'HRH1',
#   'CYP2D6',
#   'DRD3'],
#  'Cyclobenzaprine': ['CHRM3',
#   'RET',
#   'ABCB1',
#   'CHRM1',
#   'CHRM2',
#   'HTR2C',
#   'HTR2A',
#   'HTR2B',
#   'SLC6A2',
#   'HTR6',
#   'SLC6A4',
#   'HTR7',
#   'HRH1',
#   'AOX1'],
#  'Cycloserine': ['GRIN3A',
#   'GRIN2B',
#   'GRIN2A',
#   'GRIN3B',
#   'CYP3A4',
#   'GRIN2D',
#   'GRIN2C',
#   'GRIN1'],
#  'Ciclosporin': ['ABCB1',
#   'ABCC2',
#   'SLC10A1',
#   'FPR1',
#   'CYP3A4',
#   'TACR2',
#   'DHODH',
#   'PIK3CG',
#   'FKBP1B',
#   'PPP3CA',
#   'SLCO1B1',
#   'FKBP1A',
#   'PPIA',
#   'ABCB11',
#   'SLCO1B3',
#   'ABCC1',
#   'FKBP4',
#   'PPIB',
#   'ABCG2',
#   'PPID'],
#  'Cyclothiazide': ['GRIA2', 'SLC12A3', 'GRIA3', 'GRIA1', 'GRIA4'],
#  'Cyproheptadine': ['HTR1D',
#   'HTR1B',
#   'HTR1A',
#   'ADRA2C',
#   'ADRA2B',
#   'ADRA2A',
#   'CALM2',
#   'CALM3',
#   'SCN2A',
#   'CALM1',
#   'CHRM3',
#   'CHRM4',
#   'ABCB1',
#   'CHRM1',
#   'CHRM2',
#   'CHRM5',
#   'SETD7',
#   'HTR2C',
#   'HTR2A',
#   'ADRA1D',
#   'HTR2B',
#   'SLC6A2',
#   'ADRA1B',
#   'HTR6',
#   'ADRA1A',
#   'SLC6A4',
#   'HRH2',
#   'HTR7',
#   'HRH1',
#   'HRH4',
#   'DRD1',
#   'SCN3A',
#   'DRD2',
#   'DRD3',
#   'SCN1A',
#   'DRD4',
#   'DRD5',
#   'KCNH2'],
#  'Cyproterone Acetate': ['AR', 'OPRM1', 'ADORA1', 'PGR', 'NR3C1'],
#  'Cytarabine': ['POLA1', 'POLB', 'POLE', 'POLD1', 'MDM2'],
#  'Dabigatran Etexilate': ['NQO2',
#   'PRSS2',
#   'SLC47A1',
#   'PRSS1',
#   'SLC47A2',
#   'HPN',
#   'F10',
#   'SLC22A2',
#   'F2',
#   'PLAT',
#   'PLG',
#   'PROC',
#   'PRSS3'],
#  'Danazol': ['CHRM3',
#   'OPRK1',
#   'HTR2A',
#   'OPRM1',
#   'ADRB3',
#   'TACR2',
#   'ESR1',
#   'SLC6A2',
#   'ADRA2C',
#   'NR3C1',
#   'SLC6A3',
#   'ADRA2B',
#   'SLC6A4',
#   'ADRA2A',
#   'AR',
#   'STS',
#   'CYP2C9',
#   'ADORA3',
#   'DRD1',
#   'PGR',
#   'DRD3',
#   'SHBG'],
#  'Dapiprazole': ['HTR2C',
#   'HTR2A',
#   'ADRA1D',
#   'HTR1A',
#   'HTR2B',
#   'ADRA1B',
#   'ADRA1A',
#   'ADRA2B'],
#  'Darifenacin': ['CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'CHRM5',
#   'ADRB1',
#   'ADRB2',
#   'DRD2'],
#  'Dasatinib': ['EPHA6',
#   'MAP3K3',
#   'ACVR1',
#   'EPHA5',
#   'MAP3K4',
#   'PDGFRB',
#   'EPHA8',
#   'PDGFRA',
#   'MAP3K2',
#   'VRK2',
#   'MYT1',
#   'MAPK13',
#   'MAPK14',
#   'MAPK11',
#   'TEC',
#   'MAPK12',
#   'ULK3',
#   'SIK2',
#   'SIK3',
#   'EPHA2',
#   'TNIK',
#   'EPHA1',
#   'SIK1',
#   'EPHA4',
#   'EPHA3',
#   'FRK',
#   'RAF1',
#   'TESK1',
#   'AURKA',
#   'EGFR',
#   'AURKB',
#   'SLK',
#   'KDR',
#   'MAP3K7',
#   'YES1',
#   'MAP2K5',
#   'MAP2K2',
#   'SRMS',
#   'DMPK',
#   'MAP2K1',
#   'TNK2',
#   'MINK1',
#   'CSNK1E',
#   'PTK6',
#   'BCR',
#   'MAP3K19',
#   'STK25',
#   'STK26',
#   'FGFR1',
#   'BTK',
#   'FGFR3',
#   'FGFR2',
#   'MAP3K13',
#   'CSF1R',
#   'BLK',
#   'TXK',
#   'PKMYT1',
#   'NLK',
#   'STK10',
#   'ABL2',
#   'NEK2',
#   'ABL1',
#   'LYN',
#   'LIMK1',
#   'CDC42BPG',
#   'LIMK2',
#   'EIF2AK4',
#   'BRAF',
#   'CDC42BPB',
#   'TYK2',
#   'BMX',
#   'CDC42BPA',
#   'TGFBR1',
#   'ACVR2B',
#   'TGFBR2',
#   'ACVR2A',
#   'PIK3CA',
#   'COQ8A',
#   'BMPR1A',
#   'ITK',
#   'BMPR1B',
#   'DDR2',
#   'ACVRL1',
#   'DDR1',
#   'RET',
#   'STK4',
#   'STK35',
#   'ERBB4',
#   'STK36',
#   'ERBB2',
#   'ERBB3',
#   'RIPK2',
#   'MAP4K2',
#   'MAP4K3',
#   'MAP4K1',
#   'SYK',
#   'TNNI3K',
#   'MTOR',
#   'HCK',
#   'FGR',
#   'GAK',
#   'WEE1',
#   'LCK',
#   'SBK1',
#   'WEE2',
#   'KIT',
#   'TAOK2',
#   'TAOK3',
#   'NEK11',
#   'MYLK2',
#   'EPHB6',
#   'FLT1',
#   'SRC',
#   'FLT3',
#   'PIK3CD',
#   'TUBA1A',
#   'ACVR1B',
#   'EPHB1',
#   'CSK',
#   'FYN',
#   'EPHB3',
#   'JAK3',
#   'EPHB2',
#   'MAP4K4',
#   'EPHB4',
#   'JAK2',
#   'MAP4K5'],
#  'Daunorubicin': ['ABCB1', 'MMP2', 'ABCC6', 'TOP2A', 'ABCC1', 'ABCG2'],
#  'Decamethonium': ['ACHE',
#   'CHRND',
#   'CHRNA1',
#   'CHRNB2',
#   'CHRNE',
#   'CHRNA4',
#   'CHRM2',
#   'HRH3',
#   'CHRNG',
#   'CHRNB1'],
#  'Delorazepam': ['GABRA3',
#   'GABRA2',
#   'GABRB3',
#   'GABRQ',
#   'GABRA1',
#   'GABRB2',
#   'GABRP',
#   'GABRB1',
#   'GABRA6',
#   'GABRA5',
#   'GABRA4',
#   'GABRG1',
#   'GABRG3',
#   'GABRG2',
#   'GABRE',
#   'GABRD'],
#  'Desflurane': ['GABRA3',
#   'GABRA2',
#   'GABRB3',
#   'GABRQ',
#   'GABRA1',
#   'GABRB2',
#   'GABRP',
#   'GABRB1',
#   'KCNK10',
#   'KCNK9',
#   'GABRA6',
#   'GABRA5',
#   'GABRA4',
#   'GABRG1',
#   'KCNK18',
#   'GABRG3',
#   'GABRG2',
#   'GLRA1',
#   'GLRB',
#   'KCNK2',
#   'GABRE',
#   'KCNK3',
#   'GABRD'],
#  'Desipramine': ['KCNJ5',
#   'KCNJ6',
#   'HTR1F',
#   'HTR1D',
#   'HTR1B',
#   'HTR3B',
#   'HTR1A',
#   'HTR3A',
#   'ADRA2B',
#   'ADRA2A',
#   'HTR5A',
#   'SCN2A',
#   'SLC29A4',
#   'CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'SLC22A1',
#   'CHRM5',
#   'HTR2C',
#   'HTR2A',
#   'HTR2B',
#   'SLC6A2',
#   'HTR6',
#   'SLC6A3',
#   'ADRA1A',
#   'SLC6A4',
#   'HTR4',
#   'HTR7',
#   'HRH1',
#   'CACNG1',
#   'DRD1',
#   'SCN3A',
#   'DRD2',
#   'SCN1A',
#   'KCNH2'],
#  'Deslanoside': ['FXYD2',
#   'ATP1A4',
#   'ATP1A3',
#   'ATP1A2',
#   'ATP1B3',
#   'ATP1A1',
#   'ATP1B2',
#   'ATP1B1'],
#  'Desloratadine': ['CHRM3',
#   'CHRM4',
#   'ABCB1',
#   'CHRM1',
#   'CHRM2',
#   'CHRM5',
#   'HTR2C',
#   'HTR2A',
#   'HTR2B',
#   'SLC6A2',
#   'ADRA1B',
#   'HTR6',
#   'SLC6A3',
#   'ADRA2B',
#   'SLC6A4',
#   'HRH2',
#   'HRH1',
#   'HRH4',
#   'DRD3'],
#  'Nordazepam': ['GABRA3',
#   'GABRA2',
#   'GABRB3',
#   'GABRQ',
#   'GABBR2',
#   'GABRA1',
#   'GABRB2',
#   'GABRP',
#   'GABRB1',
#   'GABRA6',
#   'GABRA5',
#   'GABRA4',
#   'GABRG1',
#   'GABRG3',
#   'GABRG2',
#   'GABRR2',
#   'GABRE',
#   'GABRD'],
#  'Desoxycortone': ['HTR2C',
#   'HTR2A',
#   'HTR2B',
#   'NR3C2',
#   'NR3C1',
#   'SERPINA6',
#   'SHBG'],
#  'Dexamethasone': ['AR',
#   'IL5',
#   'IL4',
#   'ANXA1',
#   'NR1I2',
#   'PGR',
#   'NR3C2',
#   'NR3C1',
#   'FABP1',
#   'PTGS2'],
#  'Dexamethasone Palmitate': ['AR', 'PGR', 'NR3C2', 'NR3C1', 'FABP1'],
#  'Dexamethasone Valerate': ['AR', 'PGR', 'NR3C2', 'NR3C1', 'FABP1'],
#  'Dexetimide': ['CHRM3', 'CHRM4', 'CHRM1', 'CHRM2', 'CHRM5'],
#  'Dexfenfluramine': ['CHRM3',
#   'SIGMAR1',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'HTR1D',
#   'HTR1B',
#   'HTR2C',
#   'ADRB1',
#   'HTR2A',
#   'HTR1A',
#   'HTR2B',
#   'ADRA1B',
#   'ADRA2C',
#   'HTR6',
#   'ADRA1A',
#   'ADRA2B',
#   'SLC6A4',
#   'ADRA2A',
#   'HTR7'],
#  'Dexmedetomidine': ['ADRA1D',
#   'ADRA1B',
#   'ADRA2C',
#   'ADRA1A',
#   'ADRA2B',
#   'ADRA2A'],
#  'Dexmethylphenidate': ['DRD1',
#   'DRD2',
#   'DRD3',
#   'SLC6A2',
#   'DRD4',
#   'SLC6A3',
#   'DRD5'],
#  'Dexniguldipine': ['ABCB1',
#   'CACNA1C',
#   'ADRA1D',
#   'CACNA1D',
#   'ADRA1B',
#   'ADRA2C',
#   'ADRA1A',
#   'ADRA2B',
#   'ADRA2A',
#   'CACNA1H',
#   'CACNA1S',
#   'ADORA3',
#   'ADORA1',
#   'DRD2'],
#  'Dexamfetamine': ['HTR1F',
#   'HTR1D',
#   'MAOA',
#   'HTR1B',
#   'HTR2C',
#   'HTR2A',
#   'HTR3B',
#   'HTR1A',
#   'HTR2B',
#   'CARTPT',
#   'SLC6A2',
#   'TAAR1',
#   'HTR3A',
#   'HTR6',
#   'SLC6A3',
#   'ADRA1A',
#   'SLC6A4',
#   'ADRA2A',
#   'HTR4',
#   'HTR5A',
#   'HTR7',
#   'SLC18A2'],
#  'Dextromethorphan': ['SIGMAR1',
#   'SLC22A1',
#   'TAS2R46',
#   'GRIN2D',
#   'GRIN2C',
#   'GRIN1',
#   'SLC6A4',
#   'GRIN3A',
#   'GRIN2B',
#   'GRIN2A',
#   'GRIN3B',
#   'CYP2D6',
#   'SCN3A',
#   'SCN1A',
#   'SCN2A'],
#  'Dextrothyroxine': ['GRIN3A',
#   'GRIN2B',
#   'GRIN2A',
#   'GRIN3B',
#   'THRB',
#   'THRA',
#   'GRIN2D',
#   'GRIN2C',
#   'GRIN1'],
#  'Diazepam': ['GABRA3',
#   'TRHR',
#   'GABRA2',
#   'GABRQ',
#   'BCHE',
#   'GABRA1',
#   'GABRP',
#   'GABRA6',
#   'AKR1C2',
#   'GABRA5',
#   'AKR1C1',
#   'GABRA4',
#   'GABRG1',
#   'AKR1C3',
#   'GABRG3',
#   'GABRG2',
#   'FABP1',
#   'ACHE',
#   'GABRB3',
#   'GABRB2',
#   'GABRB1',
#   'CYP3A4',
#   'ADRA1A',
#   'ADORA3',
#   'TSPO',
#   'GABRE',
#   'GABRD'],
#  'Cinchocaine': ['SCN10A', 'SCN5A', 'SCN3A', 'SCN1A', 'SCN2A'],
#  'Dichlorphenamide': ['CA13',
#   'CA12',
#   'CA2',
#   'CYP2C9',
#   'CA1',
#   'CA4',
#   'CA5B',
#   'CA5A',
#   'CA6',
#   'CA7',
#   'CA9',
#   'CA14'],
#  'Diclofenac': ['CXCL8',
#   'UGT1A10',
#   'UGT1A1',
#   'TRPA1',
#   'AKR1C3',
#   'PTGS1',
#   'PTGS2',
#   'TTR',
#   'TRPM3',
#   'CXCR1',
#   'UGT1A6',
#   'PPARG',
#   'AKR1B10',
#   'ASIC3',
#   'UGT1A9',
#   'FABP1',
#   'UGT1A7'],
#  'Dicloxacillin': ['CHRM3',
#   'CHRM1',
#   'HRH2',
#   'ABCB11',
#   'CHRM2',
#   'PDE2A',
#   'SLC6A3'],
#  'Dicoumarol': ['NQO1',
#   'CYP2C9',
#   'VKORC1',
#   'GPR35',
#   'AKR1B1',
#   'MAPK1',
#   'PCSK7'],
#  'Dicycloverine': ['CHRM3',
#   'SIGMAR1',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'CHRM5',
#   'HTR2C',
#   'HTR2A',
#   'HTR2B',
#   'HTR6',
#   'PGRMC1',
#   'HRH2',
#   'SCN3A',
#   'DRD3',
#   'SCN1A',
#   'SCN2A',
#   'KCNH2'],
#  'Diethylstilbestrol': ['ESRRB',
#   'ESRRA',
#   'OPRK1',
#   'AVPR1A',
#   'OPRM1',
#   'ESRRG',
#   'TACR2',
#   'ESR1',
#   'ADRA2C',
#   'ESR2',
#   'ADRA2B',
#   'ADRA2A',
#   'MAPK14',
#   'AR',
#   'GALE',
#   'TBXAS1',
#   'ADORA2A',
#   'PGR',
#   'ACHE',
#   'CHRM3',
#   'CHRM1',
#   'SLC28A1',
#   'OPRD1',
#   'NR1I2',
#   'ALOX15',
#   'HTR2C',
#   'ADRB1',
#   'HTR2A',
#   'ADRA1D',
#   'HTR2B',
#   'SLC6A2',
#   'HTR6',
#   'NR3C1',
#   'SLC6A3',
#   'ADRA1A',
#   'PTGS1',
#   'SLC6A4',
#   'CYSLTR1',
#   'ADORA3',
#   'DRD1',
#   'ADORA1',
#   'DRD2',
#   'FYN',
#   'DRD3'],
#  'Diflunisal': ['TTR', 'CA2', 'CA1', 'PTGS1', 'DHFR', 'PTGS2'],
#  'Digitoxin': ['STAT3',
#   'FXYD2',
#   'ATP1A4',
#   'ATP1A3',
#   'ATP1A2',
#   'ATP1B3',
#   'ATP1A1',
#   'ATP1B2',
#   'ATP1B1',
#   'KCNH2'],
#  'Digoxin': ['STAT3',
#   'FXYD2',
#   'ATP1A4',
#   'ATP1A3',
#   'ATP1A2',
#   'ATP1B3',
#   'RORC',
#   'ATP1A1',
#   'ATP1B2',
#   'ATP1B1',
#   'KCNH2'],
#  'alpha-Ergocryptine': ['HTR1B',
#   'HTR2C',
#   'HTR2A',
#   'OPRM1',
#   'ADRA1D',
#   'ADRB3',
#   'CYP3A4',
#   'HTR1A',
#   'HTR2B',
#   'ADRA1B',
#   'ADRA2C',
#   'HTR6',
#   'ADRA1A',
#   'ADRA2B',
#   'ADRA2A',
#   'CYP2C9',
#   'DRD1',
#   'DRD2',
#   'DRD3'],
#  'Dihydroergocristine': ['HTR1D',
#   'HTR1B',
#   'HTR2C',
#   'HTR2A',
#   'OPRM1',
#   'ADRA1D',
#   'ADRB3',
#   'CYP3A4',
#   'HTR1A',
#   'HTR2B',
#   'ADRA1B',
#   'ADRA2C',
#   'CYP2C19',
#   'HTR6',
#   'ADRA1A',
#   'ADRA2B',
#   'ADRA2A',
#   'HTR4',
#   'CYP2C9',
#   'DRD1',
#   'DRD2',
#   'DRD3'],
#  'Dihydroergotamine': ['HTR1F',
#   'HTR1D',
#   'HTR1E',
#   'HTR1B',
#   'HTR1A',
#   'ADRA2C',
#   'ADRA2B',
#   'ADRA2A',
#   'HTR5A',
#   'CCKBR',
#   'SLC47A1',
#   'SLC47A2',
#   'SLC22A2',
#   'HTR2C',
#   'HTR2A',
#   'ADRA1D',
#   'CYP3A4',
#   'HTR2B',
#   'ADRA1B',
#   'HTR6',
#   'ADRA1A',
#   'HTR4',
#   'HTR7',
#   'DRD1',
#   'DRD2',
#   'DRD3'],
#  'Hydroquinidine': ['SCN5A', 'SCN4B', 'SCN2B', 'SCN3B', 'KCNH2', 'SCN1B'],
#  'Dilazep': ['SCN3A', 'SCN1A', 'SLC29A2', 'SCN2A', 'SLC29A1'],
#  'Dilevalol': ['ADRB1', 'ADRB2', 'HTR1A', 'ADRA1B', 'ADRA1A'],
#  'Diltiazem': ['ABCB1',
#   'KCNC1',
#   'SLC22A1',
#   'CACNA1C',
#   'HTR2A',
#   'CACNA1D',
#   'CYP3A4',
#   'KCNA7',
#   'CACNA1F',
#   'HTR3A',
#   'CACNA1H',
#   'CACNA1S',
#   'CACNG1',
#   'SCN3A',
#   'SCN1A',
#   'SCN2A',
#   'KCNH2'],
#  'Dimenhydrinate': ['CHRM3',
#   'SIGMAR1',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'CHRM5',
#   'HTR2C',
#   'HTR2A',
#   'ADRA1D',
#   'HTR2B',
#   'SLC6A2',
#   'SLC6A3',
#   'ADRA2B',
#   'ADRA2A',
#   'HRH1',
#   'CYP2D6'],
#  'Dimetindene': ['CHRM3', 'CHRM4', 'CHRM1', 'CHRM2', 'HRH1', 'CHRM5'],
#  'Dimethyltubocurarinium': ['CHRNA2', 'CHRND', 'CHRNA1', 'CHRNB2', 'CHRNB1'],
#  'Dinoprost': ['PTGFR',
#   'PTGDR2',
#   'PTGER1',
#   'TBXA2R',
#   'PTGER2',
#   'PTGER3',
#   'PTGER4',
#   'PTGDR'],
#  'Dinoprostone': ['CATSPER2',
#   'PTGFR',
#   'CATSPER1',
#   'CATSPER4',
#   'CATSPER3',
#   'SLC22A6',
#   'PTGDR2',
#   'PTGER1',
#   'PTGER2',
#   'PTGIR',
#   'PTGER3',
#   'PTGER4',
#   'TBXA2R',
#   'PTGDR'],
#  'Diphenhydramine': ['CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'CHRM5',
#   'SLC22A2',
#   'HTR2C',
#   'HTR2A',
#   'HTR2B',
#   'SLC6A2',
#   'SLC6A3',
#   'SLC6A4',
#   'HRH1',
#   'HRH4',
#   'CYP2D6',
#   'SCN3A',
#   'SCN1A',
#   'SCN2A',
#   'KCNH2'],
#  'Dipyridamole': ['SLC28A1',
#   'PDE1C',
#   'PDE6H',
#   'PDE1B',
#   'PDE6G',
#   'PDE1A',
#   'ALOX15',
#   'PDE11A',
#   'PDE10A',
#   'PDE2A',
#   'PDE3B',
#   'PDE3A',
#   'PDE6D',
#   'PDE4A',
#   'PDE6C',
#   'PDE5A',
#   'PDE6B',
#   'PDE6A',
#   'PDE7B',
#   'PDE7A',
#   'PDE8B',
#   'SLC29A1',
#   'PDE8A',
#   'SLC29A4'],
#  'Disopyramide': ['CHRM3',
#   'KCNJ5',
#   'HCN4',
#   'CHRM1',
#   'CHRM2',
#   'HRH1',
#   'SLC22A1',
#   'SCN5A',
#   'KCNH2'],
#  'Disulfiram': ['CCR2',
#   'GSDMD',
#   'HTR1B',
#   'OPRK1',
#   'OPRM1',
#   'PGRMC1',
#   'ADRA2B',
#   'ADRA2A',
#   'LOX',
#   'CYP1A2',
#   'MGLL',
#   'KDM5A',
#   'SLC28A1',
#   'MAOA',
#   'ALOX15',
#   'EHMT1',
#   'LOXL4',
#   'EHMT2',
#   'HTR2B',
#   'SLC6A2',
#   'HTR6',
#   'SLC6A3',
#   'LOXL2',
#   'LOXL3',
#   'CXCR2',
#   'ALDH2',
#   'MAPK3',
#   'ADORA3',
#   'DRD1',
#   'PDE4A',
#   'TSPO',
#   'DRD2',
#   'DRD3',
#   'CCR5',
#   'DRD4',
#   'CCR4'],
#  'Ditiocarb': ['CA13',
#   'CA12',
#   'GSDMD',
#   'CA2',
#   'CA1',
#   'CA4',
#   'EHMT1',
#   'EHMT2',
#   'CA9',
#   'CYP2E1'],
#  'Dobutamine': ['CA13',
#   'SIGMAR1',
#   'CA12',
#   'PGRMC1',
#   'ADRA2B',
#   'LCK',
#   'SLC22A1',
#   'ALOX15',
#   'ADRB1',
#   'ADRB2',
#   'ADRA1D',
#   'SLC6A2',
#   'ADRA1B',
#   'COMT',
#   'EGFR',
#   'SLC6A3',
#   'ADRA1A',
#   'SLC6A4',
#   'CA2',
#   'CA1',
#   'CA4',
#   'CA3',
#   'CA5B',
#   'CA5A',
#   'CA6',
#   'CA7',
#   'CA9',
#   'FYN',
#   'DRD3',
#   'CA14'],
#  'Docetaxel': ['ABCB1',
#   'TUBB',
#   'TUBB1',
#   'NOD2',
#   'CYP3A4',
#   'TACR2',
#   'TUBB2A',
#   'EGFR',
#   'TUBB4B',
#   'TUBB4A',
#   'GHRHR',
#   'TUBB8',
#   'ABCC10',
#   'TUBB2B',
#   'TUBB6',
#   'TUBB3'],
#  'Domperidone': ['OPRK1',
#   'OPRM1',
#   'ADRA2C',
#   'ADRA2B',
#   'ADRA2A',
#   'CALM2',
#   'CALM3',
#   'CALM1',
#   'ABCB1',
#   'SLC47A1',
#   'SLC47A2',
#   'SLC22A2',
#   'HTR2C',
#   'HTR2A',
#   'ADRA1D',
#   'HTR2B',
#   'SLC6A2',
#   'ADRA1B',
#   'ADRA1A',
#   'SLC6A4',
#   'RXRA',
#   'HRH1',
#   'CYP2D6',
#   'AOX1',
#   'DRD2',
#   'DRD3',
#   'KCNH2'],
#  'Donepezil': ['ACHE',
#   'SIGMAR1',
#   'ABCB1',
#   'BCHE',
#   'HRH3',
#   'MAOB',
#   'CHAT',
#   'SLC6A4',
#   'BACE1',
#   'KCNH2'],
#  'Dopamine': ['SIGMAR1',
#   'KDM4E',
#   'OPRK1',
#   'GFER',
#   'OPRM1',
#   'HTR1A',
#   'TAAR1',
#   'ADRA2C',
#   'ADRA2B',
#   'ADRA2A',
#   'MTNR1B',
#   'MTNR1A',
#   'ADORA2B',
#   'OPRD1',
#   'ADCY1',
#   'ADCY5',
#   'DBH',
#   'ADCY4',
#   'ADRB1',
#   'ADCY3',
#   'ADRB2',
#   'ADCY2',
#   'ADRA1D',
#   'SLC6A2',
#   'ADCY8',
#   'ADRA1B',
#   'SLC6A3',
#   'ADRA1A',
#   'ADCY6',
#   'DRD1',
#   'DRD2',
#   'DRD3',
#   'DRD4',
#   'DRD5'],
#  'Dorzolamide': ['CA13',
#   'CA12',
#   'CA2',
#   'CA1',
#   'CA4',
#   'CA3',
#   'CA5B',
#   'CA5A',
#   'CA6',
#   'CA7',
#   'CA9',
#   'CA14'],
#  'Dosulepin': ['CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'HRH1',
#   'CHRM5',
#   'HTR2A',
#   'SLC6A2',
#   'SLC6A3',
#   'ADRA1A',
#   'ADRA2B',
#   'SLC6A4'],
#  'Doxazosin': ['ABCB1',
#   'MMP1',
#   'HTR2C',
#   'ADRB2',
#   'HLA-A',
#   'ADRA1D',
#   'HTR2B',
#   'ADRA1B',
#   'ADRA2C',
#   'SLC6A3',
#   'ADRA1A',
#   'SLC6A4',
#   'ADRA2A',
#   'HTR4',
#   'KCNH2'],
#  'Doxepin': ['SIGMAR1',
#   'HTR1F',
#   'HTR1D',
#   'HTR1B',
#   'HTR3B',
#   'HTR1A',
#   'ADRA2C',
#   'HTR3A',
#   'ADRA2B',
#   'ADRA2A',
#   'HTR5A',
#   'CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'SLC22A1',
#   'CHRM5',
#   'SLC22A2',
#   'HTR2C',
#   'HTR2A',
#   'ADRA1D',
#   'HTR2B',
#   'SLC6A2',
#   'ADRA1B',
#   'HTR6',
#   'ADRA1A',
#   'SLC6A4',
#   'HTR4',
#   'HRH2',
#   'HTR7',
#   'HRH1',
#   'HRH4',
#   'DRD1',
#   'DRD2',
#   'DRD3'],
#  'Doxorubicin': ['TOP2B',
#   'ABCB1',
#   'ABCC2',
#   'CHRM1',
#   'MMP2',
#   'ABCC6',
#   'TOP2A',
#   'ALOX15',
#   'AURKA',
#   'HTR1B',
#   'CISD1',
#   'RNASE1',
#   'HTR4',
#   'LCK',
#   'TERT',
#   'ERBB2',
#   'CASP1',
#   'FYN',
#   'TOP1',
#   'ABCC1',
#   'ABCG2'],
#  'Doxycycline': ['MMP13', 'MMP7', 'MMP8', 'MMP2', 'RPL10', 'MMP3'],
#  'Droperidol': ['CHRM4',
#   'CHRM5',
#   'HTR2C',
#   'HTR2A',
#   'ADRA1D',
#   'HTR1A',
#   'HTR2B',
#   'ADRA1B',
#   'ADRA2C',
#   'PGRMC1',
#   'ADRA1A',
#   'ADRA2B',
#   'ADRA2A',
#   'HTR4',
#   'HRH1',
#   'DRD1',
#   'SCN3A',
#   'DRD2',
#   'DRD3',
#   'SCN1A',
#   'DRD4',
#   'SCN2A',
#   'KCNH2'],
#  'Droxidopa': ['CHRM1',
#   'ADRB1',
#   'ADRB2',
#   'ADRA1D',
#   'ADRB3',
#   'ADRA1B',
#   'ADRA2C',
#   'ADRA1A',
#   'ADRA2B',
#   'ADRA2A'],
#  'Duloxetine': ['HTR1F',
#   'HTR1D',
#   'SHMT2',
#   'HTR1E',
#   'HTR1B',
#   'HTR2C',
#   'HTR2A',
#   'HTR1A',
#   'HTR2B',
#   'SLC6A2',
#   'HTR6',
#   'SLC6A3',
#   'SLC6A4',
#   'HTR7',
#   'HRH1'],
#  'Ebastine': ['HTR1B',
#   'HTR1A',
#   'TACR2',
#   'ADRA2C',
#   'PGRMC1',
#   'ADRA2B',
#   'ADRA2A',
#   'ACHE',
#   'CHRM3',
#   'CHRM4',
#   'ABCB1',
#   'CHRM1',
#   'CHRM2',
#   'CHRM5',
#   'HTR2C',
#   'HTR2A',
#   'ADRA1D',
#   'ADRB3',
#   'HTR2B',
#   'SLC6A2',
#   'ADRA1B',
#   'EGFR',
#   'HTR6',
#   'SLC6A3',
#   'ADRA1A',
#   'SLC6A4',
#   'HRH2',
#   'HRH1',
#   'ERBB2',
#   'ADORA3',
#   'DRD1',
#   'DRD2',
#   'FYN',
#   'DRD3',
#   'DRD4',
#   'KCNH2'],
#  'Econazole': ['BCHE',
#   'HTR1B',
#   'OPRM1',
#   'TACR1',
#   'HTR1A',
#   'TACR2',
#   'MMP9',
#   'MC3R',
#   'CYP2C9',
#   'ADORA2A',
#   'CYP1A2',
#   'ORAI1',
#   'IDO1',
#   'IDO2',
#   'ACHE',
#   'CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'OPRD1',
#   'HTR2C',
#   'ADRB1',
#   'HTR2A',
#   'ADRA1D',
#   'ADRB3',
#   'CYP3A4',
#   'HTR2B',
#   'EGFR',
#   'ADRA1A',
#   'HRH2',
#   'CYP2D6',
#   'ERBB2',
#   'ADORA3',
#   'DRD1',
#   'ADORA1',
#   'DRD2',
#   'DRD3',
#   'DRD4',
#   'SIGMAR1',
#   'CYP51A1',
#   'OPRK1',
#   'CYP8B1',
#   'PGRMC1',
#   'ADRA2B',
#   'ADRA2A',
#   'AR',
#   'MC5R',
#   'TBXAS1',
#   'PGR',
#   'NPY2R',
#   'SLC6A2',
#   'CYP2C19',
#   'HTR6',
#   'SLC6A3',
#   'SLC6A4',
#   'CYP17A1',
#   'CNR1',
#   'FYN',
#   'MDH1'],
#  'Eletriptan': ['HTR1F', 'HTR1D', 'HTR1E', 'HTR1B', 'HTR1A'],
#  'Eltanolone': ['GABRA3',
#   'GABRA2',
#   'GABRB3',
#   'GABRQ',
#   'GABRA1',
#   'GABRB2',
#   'GABRP',
#   'GABRB1',
#   'GABRA6',
#   'GABRA5',
#   'GABRA4',
#   'GABRG1',
#   'GABRG3',
#   'GABRG2',
#   'GABRE',
#   'GABRD'],
#  'Emetine': ['RBBP9', 'ADRA1D', 'ADRA1B', 'ADRA2C', 'ADRA1A', 'ADRA2A'],
#  'Encainide': ['SCN5A', 'SCN4B', 'SCN2B', 'SCN3B', 'SCN1B'],
#  'Enflurane': ['GLRA1', 'KCNK10', 'KCNK9', 'KCNK18', 'KCNK2', 'KCNK3'],
#  'Enoximone': ['PDE4D', 'PDE4C', 'PDE3A', 'PDE4B', 'PDE4A'],
#  'Enprofylline': ['ADORA2B', 'ADORA2A', 'ADORA3', 'PDE4B', 'ADORA1'],
#  'Enprostil': ['PTGFR', 'PTGER1', 'PTGIR', 'PTGER3', 'PTGER4'],
#  'Epalrestat': ['AKR1B1', 'CYP4A11', 'AKR1A1', 'SORD', 'AKR1B10'],
#  'Epinastine': ['ABCB1',
#   'HRH2',
#   'SLC47A1',
#   'HRH1',
#   'SLC47A2',
#   'SLC22A2',
#   'HTR2A',
#   'ADRA1A',
#   'ADRA2A',
#   'KCNH2'],
#  'Epinephrine': ['ALOX15',
#   'ADRB1',
#   'ADRB2',
#   'OPRM1',
#   'ADRA1D',
#   'ADRB3',
#   'SLC6A2',
#   'ADRA1B',
#   'ADRA2C',
#   'ADRA1A',
#   'ADRA2B',
#   'ADRA2A',
#   'DRD1',
#   'DRD2'],
#  'Ergometrine': ['HTR1D',
#   'HTR1E',
#   'HTR1B',
#   'HTR2C',
#   'HTR2A',
#   'HTR1A',
#   'HTR2B',
#   'ADRA1B',
#   'HTR6',
#   'ADRA2B',
#   'ADRA2A',
#   'DRD1',
#   'DRD2',
#   'DRD3'],
#  'Ergotamine': ['HTR1F',
#   'HTR1D',
#   'HTR1E',
#   'HTR1B',
#   'HTR1A',
#   'ADRA2C',
#   'ADRA2B',
#   'ADRA2A',
#   'HTR5A',
#   'LCK',
#   'CCKBR',
#   'TBXAS1',
#   'CHRM1',
#   'CHRM2',
#   'HTR2C',
#   'ADRB1',
#   'ADRB2',
#   'HTR2A',
#   'ADRA1D',
#   'CYP3A4',
#   'HTR2B',
#   'ADRA1B',
#   'HTR6',
#   'ADRA1A',
#   'HTR4',
#   'HTR7',
#   'CCKAR',
#   'DRD1',
#   'DRD2',
#   'FYN',
#   'DRD3',
#   'DRD5'],
#  'Erlotinib': ['EPHA6',
#   'MAP3K3',
#   'EPHA5',
#   'PDGFRB',
#   'EPHA8',
#   'PDGFRA',
#   'EPHA7',
#   'MAP3K2',
#   'HIPK4',
#   'MAPK10',
#   'AXL',
#   'ULK3',
#   'SIK2',
#   'TNIK',
#   'EPHA3',
#   'FRK',
#   'AURKA',
#   'EGFR',
#   'AURKC',
#   'AURKB',
#   'SLK',
#   'CSNK1D',
#   'KDR',
#   'PIP4K2C',
#   'SRPK3',
#   'YES1',
#   'MAP2K5',
#   'PLK4',
#   'DMPK',
#   'MINK1',
#   'CSNK1E',
#   'PTK2',
#   'MAP3K19',
#   'BMP2K',
#   'FGFR2',
#   'BLK',
#   'DYRK2',
#   'SLC22A1',
#   'TXK',
#   'STK10',
#   'SLCO2B1',
#   'TBK1',
#   'ABL2',
#   'TNK1',
#   'ABL1',
#   'LYN',
#   'RIPK4',
#   'EIF2AK2',
#   'CDC42BPG',
#   'EIF2AK4',
#   'BRAF',
#   'TYK2',
#   'MERTK',
#   'COQ8A',
#   'AAK1',
#   'COQ8B',
#   'ALK',
#   'DDR1',
#   'RET',
#   'LRRK2',
#   'GRK4',
#   'ERBB4',
#   'STK36',
#   'MKNK1',
#   'ERBB2',
#   'MKNK2',
#   'ERBB3',
#   'RIPK2',
#   'DAPK3',
#   'TIE1',
#   'TNNI3K',
#   'CIT',
#   'HCK',
#   'FGR',
#   'GAK',
#   'LCK',
#   'SBK1',
#   'KIT',
#   'STK17A',
#   'STK17B',
#   'TYRO3',
#   'MET',
#   'MYLK2',
#   'CAMK2D',
#   'EPHB6',
#   'FLT1',
#   'SRC',
#   'LTK',
#   'FLT3',
#   'FLT4',
#   'TTK',
#   'TUBA1A',
#   'RPS6KA4',
#   'MAPK9',
#   'EPHB1',
#   'CSK',
#   'JAK3',
#   'EPHB4',
#   'JAK2',
#   'MAPK4'],
#  'Erythromycin': ['ABCB11', 'MLNR', 'AOX1', 'CYP1B1', 'KCNH2'],
#  'Escitalopram': ['CHRM1',
#   'HRH1',
#   'HTR2C',
#   'SLC6A2',
#   'SLC6A3',
#   'ADRA1A',
#   'SLC6A4'],
#  'Estazolam': ['GABRA3',
#   'GABRA2',
#   'GABRB3',
#   'GABRA1',
#   'GABRB2',
#   'GABRA5',
#   'GABRG2'],
#  'Estradiol': ['ESRRB',
#   'ESRRA',
#   'ALOX15',
#   'ESR1',
#   'ESR2',
#   'NR3C1',
#   'SLC6A3',
#   'SLC6A4',
#   'SERPINA6',
#   'AR',
#   'STS',
#   'KCNMA1',
#   'GPER1',
#   'AOX1',
#   'CYP1B1',
#   'PGR',
#   'SHBG'],
#  'Estradiol Benzoate': ['AR',
#   'ADORA3',
#   'FYN',
#   'HTR2B',
#   'PGR',
#   'ESR1',
#   'SLC6A2',
#   'ADRA2C',
#   'NR3C1',
#   'SLC6A4',
#   'SHBG'],
#  'Estriol Succinate': ['OR51E2',
#   'ALOX15',
#   'ESR1',
#   'ESR2',
#   'NR3C1',
#   'SLC6A4',
#   'SERPINA6',
#   'SHBG'],
#  'Eszopiclone': ['GABRA3',
#   'GABRA2',
#   'GABRA1',
#   'GABRB2',
#   'GABRA5',
#   'GABRA4',
#   'GABRG3',
#   'GABRG2'],
#  'Ethacrynic Acid': ['GALE', 'AKR1B1', 'GSTO1', 'SLC12A1', 'GSTP1', 'GSTA1'],
#  'Ethambutol': ['HTR2C', 'HTR2A', 'CYP3A4', 'HTR2B', 'CYP3A5'],
#  'Ethanol': ['GLRA1', 'GRIN3A', 'GLRA2', 'GABRB2', 'GABRA4', 'GABRD'],
#  'Ethinylestradiol': ['SLC47A1',
#   'SLC47A2',
#   'NR1I3',
#   'SLC22A2',
#   'ALOX15',
#   'OPRK1',
#   'OPRM1',
#   'ESR1',
#   'SLC6A2',
#   'ESR2',
#   'NR3C1',
#   'SLC6A3',
#   'SLC6A4',
#   'HTR4',
#   'AR',
#   'ADORA2A',
#   'AOX1',
#   'ADORA3',
#   'PGR',
#   'SHBG'],
#  'Profenamine': ['ACHE', 'GRIN3A', 'BCHE', 'CHRM1', 'CHRM2', 'SLC22A1'],
#  'Ethotoin': ['SCN11A',
#   'SCN9A',
#   'SCN10A',
#   'SCN7A',
#   'SCN8A',
#   'SCN5A',
#   'SCN3A',
#   'SCN4A',
#   'SCN1A',
#   'SCN2A'],
#  'Ethoxzolamide': ['CA13',
#   'CA12',
#   'CA2',
#   'CA1',
#   'CA4',
#   'CA3',
#   'CA5B',
#   'CA5A',
#   'CA6',
#   'CA7',
#   'CA9',
#   'CA14'],
#  'Ethylestrenol': ['ACHE',
#   'AR',
#   'CHRM2',
#   'PGR',
#   'ESR1',
#   'SLC6A2',
#   'CYP2C19',
#   'SLC6A4'],
#  'Etizolam': ['GABRA3',
#   'GABRA2',
#   'GABRB3',
#   'GABRA1',
#   'GABRB2',
#   'GABRA5',
#   'GABRG2'],
#  'Etomidate': ['CHRND',
#   'GABRA2',
#   'GABRA1',
#   'GABRB2',
#   'CYP11B2',
#   'CYP11B1',
#   'GABRG2'],
#  'Etoposide': ['TOP2B',
#   'ABCB1',
#   'ABCC2',
#   'ABCC3',
#   'NR1I2',
#   'ABCC6',
#   'TOP2A',
#   'ALOX15',
#   'ABCC1',
#   'ABCG2'],
#  'Etravirine': ['ABCB1', 'ABCC2', 'ABCC3', 'ABCC1', 'ABCG2'],
#  'Famotidine': ['CA13',
#   'CA12',
#   'SLC47A1',
#   'HSP90AA1',
#   'SLC47A2',
#   'SLC22A3',
#   'SLC22A2',
#   'CA2',
#   'HRH2',
#   'CA1',
#   'CA4',
#   'CA5B',
#   'CA5A',
#   'CA6',
#   'CA7',
#   'CA9',
#   'CA14'],
#  'Fasudil': ['RPS6KA5',
#   'ROCK1',
#   'ROCK2',
#   'PRKCE',
#   'PKN1',
#   'CCL2',
#   'PKN2',
#   'MYLK',
#   'KCNH2',
#   'PRKACA'],
#  'Felodipine': ['CYP2C9',
#   'AOX1',
#   'CACNA1C',
#   'ADORA3',
#   'NR1H4',
#   'SCN3A',
#   'CACNA1D',
#   'SCN1A',
#   'SCN2A',
#   'CACNA1H',
#   'CFTR'],
#  'Fenfluramine': ['CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'HTR1D',
#   'HTR1B',
#   'HTR2C',
#   'ADRB1',
#   'ADRB2',
#   'HTR2A',
#   'HTR1A',
#   'HTR2B',
#   'ADRA1B',
#   'ADRA2C',
#   'HTR6',
#   'ADRA1A',
#   'ADRA2B',
#   'SLC6A4',
#   'ADRA2A',
#   'HTR7'],
#  'Fenofibrate': ['ACHE',
#   'PPARA',
#   'HTR2C',
#   'ADORA3',
#   'PPARG',
#   'HTR2A',
#   'ADRB3',
#   'DRD3',
#   'SLC6A2',
#   'SLC6A3',
#   'FABP1'],
#  'Fenoldopam': ['ADORA2B',
#   'KDM4E',
#   'DRD1',
#   'GFER',
#   'ADRA1D',
#   'DRD2',
#   'ADRA1B',
#   'DRD4',
#   'ADRA1A',
#   'DRD5'],
#  'Fentanyl': ['SIGMAR1',
#   'HRH1',
#   'OPRD1',
#   'SLC22A1',
#   'MAOB',
#   'MAOA',
#   'OPRK1',
#   'OPRM1',
#   'KCNH2'],
#  'Finasteride': ['CYP2C9', 'SRD5A2', 'HSD3B1', 'SRD5A1', 'CYP2C19'],
#  'Flavoxate': ['PDE4D',
#   'PDE4C',
#   'PDE4B',
#   'PDE4A',
#   'PDE7B',
#   'PDE7A',
#   'PDE8B',
#   'PDE8A',
#   'KCNH2'],
#  'Flecainide': ['HCN4',
#   'KCNC1',
#   'KCND2',
#   'SCN5A',
#   'KCNA5',
#   'KCNA7',
#   'SCN4A',
#   'KCNH2'],
#  'Fludarabine Phosphate': ['POLA1',
#   'RRM2',
#   'RRM1',
#   'CA5A',
#   'ADORA2A',
#   'ADORA3',
#   'ADORA1'],
#  'Flufenamic Acid': ['AKR1B1',
#   'AKR1C2',
#   'AKR1C1',
#   'TRPA1',
#   'TAS2R14',
#   'AKR1C3',
#   'MPO',
#   'PTGS1',
#   'PTGS2',
#   'AR',
#   'TRPM2',
#   'TTR',
#   'KCNT2',
#   'NAPRT',
#   'AKR1B10',
#   'KCNK2',
#   'TRPM4',
#   'TEAD4',
#   'TRPM5'],
#  'Flumazenil': ['GABRA3',
#   'GABRA2',
#   'GABRB3',
#   'GABRQ',
#   'GABRA1',
#   'GABRB2',
#   'GABRP',
#   'GABRB1',
#   'GABRA6',
#   'GABRA5',
#   'GABRA4',
#   'GABRG1',
#   'GABRG3',
#   'GABRG2',
#   'GABRE',
#   'GABRD'],
#  'Flunarizine': ['SIGMAR1',
#   'OPRK1',
#   'OPRM1',
#   'HTR1A',
#   'ADRA2C',
#   'PGRMC1',
#   'ADRA2B',
#   'ADRA2A',
#   'KCNK2',
#   'SCN2A',
#   'CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'OPRD1',
#   'CHRM5',
#   'HTR2C',
#   'CACNA1B',
#   'HTR2A',
#   'ADRA1D',
#   'HTR2B',
#   'CACNA1G',
#   'SLC6A2',
#   'ADRA1B',
#   'SLC6A3',
#   'ADRA1A',
#   'CACNA1I',
#   'SLC6A4',
#   'CACNA1H',
#   'HRH1',
#   'CNR1',
#   'ADORA3',
#   'DRD1',
#   'RCE1',
#   'SCN3A',
#   'DRD2',
#   'DRD3',
#   'SCN1A',
#   'KCNH2'],
#  'Flunitrazepam': ['GABRA3',
#   'GABRA2',
#   'GABRB3',
#   'GABRQ',
#   'GABRA1',
#   'GABRB2',
#   'GABRP',
#   'GABRB1',
#   'GABRA6',
#   'GABRA5',
#   'GABRA4',
#   'GABRG1',
#   'GABRG3',
#   'GABRG2',
#   'GABRE',
#   'GABRD'],
#  'Fluoxetine': ['SIGMAR1',
#   'KCNJ6',
#   'HTR1F',
#   'HTR1D',
#   'HTR1B',
#   'HTR1A',
#   'ADRA2C',
#   'ADRA2B',
#   'ADRA2A',
#   'KCNK2',
#   'SLC29A4',
#   'ACHE',
#   'CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'KCNC1',
#   'CHRM5',
#   'HTR2C',
#   'ADRB1',
#   'HTR2A',
#   'ADRA1D',
#   'HTR2B',
#   'SLC6A2',
#   'ADRA1B',
#   'HTR6',
#   'SLC6A3',
#   'ADRA1A',
#   'SLC6A4',
#   'HRH1',
#   'HRH3',
#   'CYP2D6',
#   'DRD3',
#   'KCNH2'],
#  'Flupentixol': ['SIGMAR1',
#   'HRH1',
#   'SLC22A1',
#   'DRD1',
#   'HTR2A',
#   'DRD2',
#   'HTR1A',
#   'DRD3',
#   'KCNK2',
#   'DRD4',
#   'ADRA1A',
#   'DRD5'],
#  'Fluphenazine': ['HTR1D',
#   'HTR1E',
#   'HTR1B',
#   'OPRM1',
#   'HTR1A',
#   'TACR2',
#   'HTR5A',
#   'KCNK2',
#   'CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'OPRD1',
#   'ADCY1',
#   'CHRM5',
#   'ADCY5',
#   'HTR2C',
#   'ADCY4',
#   'ADCY3',
#   'HTR2A',
#   'ADCY2',
#   'ADRA1D',
#   'ADRB3',
#   'HTR2B',
#   'ADCY8',
#   'ADRA1B',
#   'EGFR',
#   'ADRA1A',
#   'ADCY6',
#   'HRH2',
#   'HRH1',
#   'ERBB2',
#   'ADORA3',
#   'DRD1',
#   'SCN3A',
#   'DRD2',
#   'DRD3',
#   'DRD4',
#   'DRD5',
#   'KCNH2',
#   'SIGMAR1',
#   'OPRK1',
#   'ADRA2C',
#   'PGRMC1',
#   'ADRA2B',
#   'ADRA2A',
#   'AR',
#   'MC5R',
#   'SCN2A',
#   'SLC6A2',
#   'HTR6',
#   'SLC6A3',
#   'SLC6A4',
#   'HTR7',
#   'TPR',
#   'FYN',
#   'SCN1A'],
#  'Fluphenazine Enanthate': ['HTR1D',
#   'HTR1E',
#   'HTR1B',
#   'HTR1A',
#   'ADRA2C',
#   'ADRA2B',
#   'ADRA2A',
#   'HTR5A',
#   'CHRM3',
#   'CHRM4',
#   'CHRM1',
#   'CHRM2',
#   'CHRM5',
#   'HTR2C',
#   'HTR2A',
#   'ADRA1B',
#   'HTR6',
#   'ADRA1A',
#   'SLC6A4',
#   'HRH2',
#   'HTR7',
#   'HRH1',
#   'DRD1',
#   'DRD2',
#   'DRD3',
#   'DRD4',
#   'DRD5'],
#  'Flurbiprofen': ['FABP2', 'AKR1C2', 'AKR1C3', 'PTGS1', 'FABP1', 'PTGS2'],
#  'Fluspirilene': ['HTR1D',
#   'HTR1E',
#   'HTR1B',
#   'ADRB1',
#   'ADRB2',
#   'HTR2A',
#   'HTR1A',
#   'HTR2B',
#   'OPRL1',
#   'ADRA2C',
#   'HTR6',
#   'ADRA2B',
#   'ADRA2A',
#   'GLRA1',
#   'HRH1',
#   'DRD2',
# ...
#   'HCK',
#   'TEC',
#   'FGR',
#   'LCK',
#   'FER',
#   'ERBB4',
#   'ERBB2',
#   'BTK',
#   'ABL1',
#   'CSK',
#   'FYN',
#   'JAK3',
#   'ITK',
#   'FGFR2',
#   'KCNH2'],
#  'Umeclidinium': ['CHRM3', 'CHRM4', 'CHRM1', 'CHRM2', 'CHRM5'],
#  'Empagliflozin': ['SLC5A9', 'SLC5A1', 'SLC5A10', 'SLC5A11', 'SLC5A2'],
#  'Afamelanotide': ['MC3R', 'MC1R', 'MC5R', 'MC4R', 'ADA'],
#  'Levomilnacipran': ['GRIN3A',
#   'GRIN2B',
#   'GRIN2A',
#   'GRIN3B',
#   'GRIN2D',
#   'SLC6A2',
#   'GRIN2C',
#   'SLC6A3',
#   'GRIN1',
#   'SLC6A4'],
#  'Ceritinib': ['NTRK2',
#   'INSR',
#   'LYN',
#   'PDGFRA',
#   'NTRK1',
#   'SYK',
#   'ETV6',
#   'FGR',
#   'LCK',
#   'ZAP70',
#   'KIT',
#   'CDK4',
#   'CDK2',
#   'BTK',
#   'MET',
#   'FGFR4',
#   'FGFR3',
#   'ALK',
#   'FGFR2',
#   'RET',
#   'ABCB1',
#   'SRC',
#   'FLT3',
#   'ROCK2',
#   'TSSK1B',
#   'EGFR',
#   'IGF1R',
#   'MKNK2',
#   'KDR',
#   'ABL1',
#   'JAK3',
#   'ROS1',
#   'JAK1',
#   'JAK2',
#   'KCNH2'],
#  'Dexrabeprazole': ['ATP4B',
#   'ATP4A',
#   'FASN',
#   'DDAH1',
#   'SARM1',
#   'IDE',
#   'ADORA3',
#   'DRD3',
#   'ADRA2B',
#   'ENGASE'],
#  'Belinostat': ['BRD4',
#   'HDAC5',
#   'HDAC6',
#   'HDAC3',
#   'HDAC4',
#   'HDAC1',
#   'HDAC11',
#   'HDAC10',
#   'HDAC2',
#   'HDAC9',
#   'HDAC7',
#   'HDAC8'],
#  'Idelalisib': ['PIK3CB', 'PIK3CA', 'PIK3CD', 'PRKDC', 'PIK3C3', 'PIK3CG'],
#  'Istradefylline': ['ADORA2B', 'MAOB', 'ADORA2A', 'ADORA3', 'ADORA1'],
#  'Nintedanib': ['CDK18',
#   'EPHA6',
#   'ACVR1',
#   'DCLK3',
#   'DCLK1',
#   'MAPK10',
#   'TEK',
#   'ULK3',
#   'SIK2',
#   'ULK2',
#   'ULK1',
#   'CDK14',
#   'EPHA2',
#   'EPHA1',
#   'SIK1',
#   'CDK16',
#   'CDK17',
#   'EPHA3',
#   'PRKAA2',
#   'PRKAA1',
#   'NUAK2',
#   'CHEK1',
#   'CSNK1D',
#   'KDR',
#   'PIP4K2B',
#   'MUSK',
#   'SRPK3',
#   'YES1',
#   'INSR',
#   'PLK4',
#   'CSNK1E',
#   'NUAK1',
#   'SRPK1',
#   'PTK2',
#   'SRPK2',
#   'LATS2',
#   'LATS1',
#   'PRKD1',
#   'BTK',
#   'PRKD3',
#   'PRKCQ',
#   'PRKD2',
#   'TXK',
#   'MYLK',
#   'TBK1',
#   'PIP5K1A',
#   'LYN',
#   'INSRR',
#   'RIPK4',
#   'TYK2',
#   'CAMK4',
#   'CAMK1',
#   'SGK3',
#   'ITK',
#   'DDR2',
#   'ACVRL1',
#   'DDR1',
#   'RET',
#   'STK33',
#   'STK35',
#   'STK39',
#   'RIPK1',
#   'MAP4K2',
#   'MAP4K3',
#   'MAP4K1',
#   'CSNK2A2',
#   'CSNK2A1',
#   'HCK',
#   'KIT',
#   'STK17A',
#   'STK17B',
#   'PKN1',
#   'PKN2',
#   'CDKL2',
#   'CAMKK1',
#   'CAMKK2',
#   'RIOK1',
#   'RIOK3',
#   'JAK3',
#   'IKBKE',
#   'JAK1',
#   'MAP4K4',
#   'JAK2',
#   'MAP4K5',
#   'MAP3K3',
#   'PDGFRB',
#   'PDGFRA',
#   'MAP3K2',
#   'PRPF4B',
#   'HIPK2',
#   'HIPK1',
#   'HIPK4',
#   'ERN1',
#   'HIPK3',
#   'MELK',
#   'AXL',
#   'TNIK',
#   'FRK',
#   'AURKC',
#   'AURKB',
#   'SLK',
#   'PAK2',
#   'MAP3K9',
#   'MAP3K7',
#   'PAK4',
#   'PAK3',
#   'KCNH2',
#   'PAK5',
#   'MAP2K4',
#   'MAP2K5',
#   'MAP2K2',
#   'MAP2K3',
#   'MAP2K1',
#   'TNK2',
#   'DYRK1B',
#   'MINK1',
#   'MAP3K19',
#   'STK24',
#   'STK26',
#   'FGFR1',
#   'MAP3K10',
#   'MAP3K11',
#   'BMP2K',
#   'FGFR4',
#   'MAP3K15',
#   'FGFR3',
#   'MAP3K12',
#   'FGFR2',
#   'MAP3K13',
#   'CSF1R',
#   'BLK',
#   'IGF1R',
#   'STK10',
#   'STK11',
#   'STK16',
#   'ABL2',
#   'MARK1',
#   'TNK1',
#   'ABL1',
#   'ROS1',
#   'MARK4',
#   'MARK3',
#   'MARK2',
#   'EIF2AK4',
#   'IRAK4',
#   'MERTK',
#   'TGFBR1',
#   'CLK4',
#   'CLK2',
#   'CLK1',
#   'FES',
#   'CDK7',
#   'FER',
#   'CDK4',
#   'MYO3B',
#   'CDK2',
#   'AAK1',
#   'ALK',
#   'MAST1',
#   'ABCB1',
#   'BMPR2',
#   'GSK3B',
#   'GSK3A',
#   'LRRK2',
#   'TSSK1B',
#   'STK3',
#   'STK4',
#   'GRK1',
#   'GRK4',
#   'IRAK3',
#   'GRK7',
#   'IRAK1',
#   'PRKG1',
#   'NTRK2',
#   'NTRK3',
#   'CAMK1D',
#   'NTRK1',
#   'DAPK2',
#   'CHUK',
#   'PDPK1',
#   'DAPK3',
#   'TIE1',
#   'OXSR1',
#   'SBK3',
#   'FGR',
#   'WEE1',
#   'LCK',
#   'SBK1',
#   'ZAP70',
#   'RPS6KB1',
#   'TYRO3',
#   'MET',
#   'CAMK1G',
#   'MYLK2',
#   'EPHB6',
#   'MYLK3',
#   'FLT1',
#   'SRC',
#   'LTK',
#   'FLT3',
#   'FLT4',
#   'CAMK2A',
#   'TTK',
#   'ACVR1B',
#   'MYLK4',
#   'RPS6KA5',
#   'RPS6KA4',
#   'MAPK8',
#   'RPS6KA6',
#   'PHKG2',
#   'RPS6KA1',
#   'PHKG1',
#   'RPS6KA3',
#   'RPS6KA2',
#   'PTK2B',
#   'EPHB1',
#   'FYN',
#   'MAPK7',
#   'EPHB4'],
#  'Olaparib': ['PARP6',
#   'PARP12',
#   'PARP4',
#   'PARP10',
#   'PARP2',
#   'PARP3',
#   'TNKS',
#   'PARP1',
#   'TNKS2',
#   'PARP15',
#   'PARP16'],
#  'Safinamide': ['SIGMAR1', 'SCN9A', 'MAOB', 'MAOA', 'SCN3A', 'SCN1A', 'SCN2A'],
#  'Alectinib': ['RET', 'KDR', 'ROS1', 'SRPK1', 'ALK'],
#  'Palbociclib': ['CCNA2',
#   'CDK9',
#   'CDK6',
#   'FLT3',
#   'RPS6KA1',
#   'CCND1',
#   'CDK4',
#   'CDK2',
#   'DYRK1A',
#   'JAK3'],
#  'Lenvatinib': ['PDGFRB',
#   'RET',
#   'FLT1',
#   'PDGFRA',
#   'KIT',
#   'FLT4',
#   'CA5A',
#   'FGFR1',
#   'KDR',
#   'EGFR'],
#  'Brentuximab Vedotin': ['TUBB8',
#   'TUBB2B',
#   'TUBB6',
#   'TUBB3',
#   'TUBB',
#   'TNFRSF8',
#   'TUBB1',
#   'TUBB2A',
#   'TUBB4B',
#   'TUBB4A'],
#  'Chidamide': ['HDAC3',
#   'HDAC1',
#   'HDAC11',
#   'NAMPT',
#   'HDAC10',
#   'HDAC2',
#   'HDAC8'],
#  'Trastuzumab Emtansine': ['TUBB8',
#   'TUBB2B',
#   'TUBB6',
#   'ERBB2',
#   'TUBB3',
#   'TUBB',
#   'TUBB1',
#   'TUBB2A',
#   'TUBB4B',
#   'TUBB4A'],
#  'Brexpiprazole': ['HTR1B',
#   'HTR2C',
#   'ADRB1',
#   'ADRB2',
#   'HTR2A',
#   'ADRA1D',
#   'HTR1A',
#   'HTR2B',
#   'SLC6A2',
#   'ADRA1B',
#   'ADRA2C',
#   'HTR6',
#   'SLC6A3',
#   'ADRA1A',
#   'ADRA2B',
#   'SLC6A4',
#   'ADRA2A',
#   'HTR5A',
#   'HTR7',
#   'HRH1',
#   'DRD1',
#   'DRD2',
#   'DRD3',
#   'DRD4'],
#  'Flibanserin': ['HTR2C',
#   'HTR2A',
#   'DRD2',
#   'HTR1A',
#   'HTR2B',
#   'DRD3',
#   'DRD4',
#   'HTR5A'],
#  'Cariprazine': ['HTR2C',
#   'HTR2A',
#   'ADRA1D',
#   'HTR1A',
#   'HTR2B',
#   'HTR7',
#   'HRH1',
#   'DRD1',
#   'DRD2',
#   'DRD3',
#   'DRD4',
#   'DRD5',
#   'KCNH2'],
#  'Tannic Acid': ['AKR1B1',
#   'ALOX15',
#   'HMGCR',
#   'LTC4S',
#   'MAPK14',
#   'CA2',
#   'CYP2C9',
#   'LCK',
#   'CA1',
#   'CA6',
#   'TBXAS1',
#   'CYP1A2',
#   'MAPK3',
#   'MAPK1',
#   'FYN',
#   'PDE5A'],
#  'Pitolisant': ['BCHE', 'HRH2', 'HRH1', 'HRH3', 'KCNH2'],
#  'Aripiprazole Lauroxil': ['HTR7',
#   'HRH1',
#   'HTR1D',
#   'HTR1B',
#   'HTR2C',
#   'HTR2A',
#   'DRD2',
#   'HTR1A',
#   'DRD3',
#   'DRD4',
#   'HTR6'],
#  'Osimertinib': ['INSR', 'ERBB3', 'EGFR', 'ALK', 'CTSC', 'KCNH2'],
#  'Migalastat': ['MGAM', 'GLB1', 'AGL', 'SI', 'GAA', 'GBA2', 'GLA', 'LCT'],
#  'Crisaborole': ['PDE1A', 'PDE4D', 'PDE4C', 'PDE4B', 'PDE4A', 'PDE7A'],
#  'Baricitinib': ['GAK', 'AAK1', 'BMP2K', 'JAK3', 'TYK2', 'JAK1', 'JAK2'],
#  'Rucaparib': ['PARP12',
#   'PARP4',
#   'PARP10',
#   'PARP2',
#   'PARP3',
#   'TNKS',
#   'PARP1',
#   'TNKS2',
#   'PARP15',
#   'PARP14'],
#  'Apatinib': ['RET', 'SRC', 'KIT', 'KDR', 'CSK'],
#  'Niraparib': ['PARP12',
#   'PARP4',
#   'PARP10',
#   'PARP2',
#   'PARP3',
#   'TNKS',
#   'PARP1',
#   'TNKS2',
#   'PARP15',
#   'PARP14'],
#  'Midostaurin': ['CDK19',
#   'MAPK10',
#   'TEK',
#   'ULK3',
#   'SIK2',
#   'SIK3',
#   'SIK1',
#   'PRKAA2',
#   'PRKAA1',
#   'NUAK2',
#   'CHEK1',
#   'AKT3',
#   'AKT1',
#   'AKT2',
#   'KDR',
#   'PIP4K2B',
#   'PRKCH',
#   'SRPK3',
#   'YES1',
#   'PLK4',
#   'DMPK',
#   'PRKCD',
#   'PRKCE',
#   'PRKCA',
#   'NUAK1',
#   'SRPK1',
#   'SRPK2',
#   'LATS2',
#   'LATS1',
#   'PRKD3',
#   'PRKCQ',
#   'PRKD2',
#   'MYLK',
#   'DSTYK',
#   'TBK1',
#   'PIP5K1A',
#   'PRKACB',
#   'PRKACA',
#   'LYN',
#   'TYK2',
#   'CAMK1',
#   'SGK3',
#   'DDR1',
#   'RET',
#   'STK33',
#   'MAP4K2',
#   'MAP4K3',
#   'MAP4K1',
#   'CSNK2A1',
#   'SYK',
#   'HCK',
#   'GAK',
#   'KIT',
#   'STK17A',
#   'STK17B',
#   'PKN1',
#   'PKN2',
#   'TUBA1A',
#   'CAMKK1',
#   'CAMKK2',
#   'IKBKB',
#   'RIOK1',
#   'RIOK3',
#   'RIOK2',
#   'JAK3',
#   'IKBKE',
#   'JAK1',
#   'MAP4K4',
#   'JAK2',
#   'MAP4K5',
#   'MAP3K3',
#   'PDGFRB',
#   'PDGFRA',
#   'MAP3K2',
#   'PRPF4B',
#   'HIPK2',
#   'HIPK4',
#   'ERN1',
#   'HIPK3',
#   'MELK',
#   'AXL',
#   'TNIK',
#   'FRK',
#   'ROCK1',
#   'ROCK2',
#   'AURKA',
#   'PRKX',
#   'EGFR',
#   'AURKC',
#   'AURKB',
#   'SLK',
#   'PAK2',
#   'PAK1',
#   'MAP3K9',
#   'MAP3K7',
#   'PAK3',
#   'MAP2K4',
#   'MAP2K3',
#   'TNK2',
#   'DYRK1B',
#   'MINK1',
#   'DYRK1A',
#   'MAP3K19',
#   'STK25',
#   'PRPF4',
#   'FGFR1',
#   'MAP3K10',
#   'MAP3K11',
#   'BMP2K',
#   'FGFR3',
#   'FGFR2',
#   'MAP3K13',
#   'BRSK1',
#   'CSF1R',
#   'BLK',
#   'BRSK2',
#   'STK10',
#   'STK11',
#   'STK16',
#   'MARK1',
#   'PIM2',
#   'TNK1',
#   'PIM1',
#   'ABL1',
#   'PIM3',
#   'ROS1',
#   'MARK4',
#   'MAP2K6',
#   'MARK3',
#   'MARK2',
#   'EIF2AK2',
#   'EIF2AK4',
#   'HUNK',
#   'MERTK',
#   'CLK4',
#   'CLK3',
#   'CLK2',
#   'CLK1',
#   'FER',
#   'PIK3CA',
#   'AAK1',
#   'ALK',
#   'MAST1',
#   'GSK3B',
#   'GSK3A',
#   'LRRK2',
#   'TSSK1B',
#   'STK3',
#   'STK4',
#   'GRK1',
#   'GRK4',
#   'ERBB4',
#   'IRAK3',
#   'MKNK2',
#   'GRK7',
#   'PRKG2',
#   'PRKG1',
#   'NTRK2',
#   'NTRK3',
#   'CAMK1D',
#   'NTRK1',
#   'DAPK2',
#   'CHUK',
#   'DAPK1',
#   'PDPK1',
#   'DAPK3',
#   'TIE1',
#   'FGR',
#   'WEE1',
#   'LCK',
#   'ZAP70',
#   'RPS6KB1',
#   'TYRO3',
#   'MET',
#   'CAMK1G',
#   'CAMK2D',
#   'EPHB6',
#   'MYLK3',
#   'FLT1',
#   'SRC',
#   'LTK',
#   'FLT3',
#   'FLT4',
#   'CAMK2A',
#   'CAMK2B',
#   'PIK3C2G',
#   'TNKS2',
#   'TTK',
#   'PIK3C2B',
#   'MYLK4',
#   'RPS6KA5',
#   'RPS6KA4',
#   'MAPK9',
#   'MAPK8',
#   'RPS6KA6',
#   'STK32A',
#   'PHKG2',
#   'RPS6KA1',
#   'PHKG1',
#   'RPS6KA3',
#   'RPS6KA2',
#   'PTK2B',
#   'CSK',
#   'FYN',
#   'CAMK2G'],
#  'Brigatinib': ['INSR', 'FLT3', 'ROS1', 'EGFR', 'IGF1R', 'ALK'],
#  'Neratinib': ['MAP3K3',
#   'MAP3K4',
#   'MAP3K2',
#   'HIPK4',
#   'MELK',
#   'MAPK10',
#   'AXL',
#   'TEK',
#   'SIK2',
#   'TNIK',
#   'SIK1',
#   'CDK16',
#   'MST1R',
#   'EGFR',
#   'SLK',
#   'NUAK2',
#   'PAK2',
#   'PAK1',
#   'CHEK1',
#   'CHEK2',
#   'KDR',
#   'MAP3K9',
#   'PAK6',
#   'YES1',
#   'INSR',
#   'MAP2K5',
#   'MAP2K2',
#   'MAP2K1',
#   'TNK2',
#   'MINK1',
#   'CSNK1E',
#   'NUAK1',
#   'PTK2',
#   'MAP3K19',
#   'STK24',
#   'STK25',
#   'STK26',
#   'MAP3K10',
#   'PRKD1',
#   'BTK',
#   'MAP3K11',
#   'PRKD3',
#   'PRKD2',
#   'MAP3K12',
#   'MAP3K13',
#   'CSF1R',
#   'BLK',
#   'TXK',
#   'STK10',
#   'DSTYK',
#   'NEK2',
#   'NEK3',
#   'ABL1',
#   'MAP2K7',
#   'LYN',
#   'INSRR',
#   'EIF2AK4',
#   'MERTK',
#   'FES',
#   'CDK7',
#   'FER',
#   'MAST1',
#   'STK3',
#   'STK4',
#   'STK33',
#   'STK35',
#   'ERBB4',
#   'STK36',
#   'ERBB2',
#   'ERBB3',
#   'IRAK1',
#   'MAP4K2',
#   'MAP4K3',
#   'CAMK1D',
#   'MAP4K1',
#   'SYK',
#   'TIE1',
#   'HCK',
#   'FGR',
#   'GAK',
#   'WEE1',
#   'LCK',
#   'WEE2',
#   'STK17A',
#   'STK17B',
#   'TAOK3',
#   'MET',
#   'CSNK1G3',
#   'CSNK1G2',
#   'EPHB6',
#   'SRC',
#   'FLT3',
#   'MAPK8',
#   'RPS6KA1',
#   'RPS6KA2',
#   'PTK2B',
#   'CSK',
#   'FYN',
#   'JAK3',
#   'STK32B',
#   'MAP4K4',
#   'MAP4K5'],
#  'Copanlisib': ['PIK3CB', 'PIK3CA', 'PIK3CD', 'MTOR', 'PIK3CG'],
#  'Tivozanib': ['PDGFRB',
#   'FLT1',
#   'PDGFRA',
#   'FLT3',
#   'KIT',
#   'FLT4',
#   'FGFR1',
#   'KDR',
#   'MET',
#   'EPHB2'],
#  'Abemaciclib': ['CDK9', 'CDK7', 'CDK6', 'CDK4', 'CDK1', 'KCNH2'],
#  'Acalabrutinib': ['TEC', 'LYN', 'ERBB4', 'ERBB2', 'TXK', 'BTK', 'BMX'],
#  'Cannabidiol': ['FAAH', 'GPR18', 'CNR2', 'CNR1', 'GPR55', 'TRPV1', 'TRPV2'],
#  'Dacomitinib': ['LCK', 'SRC', 'ERBB4', 'ERBB2', 'JAK3', 'EGFR'],
#  'Lorlatinib': ['NTRK2',
#   'NTRK3',
#   'FES',
#   'FER',
#   'LTK',
#   'NTRK1',
#   'TNK2',
#   'PTK2B',
#   'ROS1',
#   'ALK',
#   'FRK',
#   'PTK2'],
#  'Revefenacin': ['CHRM3', 'CHRM4', 'CHRM1', 'CHRM2', 'CHRM5'],
#  'Gilteritinib': ['RET',
#   'LTK',
#   'NTRK1',
#   'AXL',
#   'FLT3',
#   'ROS1',
#   'MERTK',
#   'ALK'],
#  'Brexanolone': ['GABRB3',
#   'GABRA1',
#   'GABRB2',
#   'G6PD',
#   'GABRA6',
#   'GABRA4',
#   'GABRD',
#   'GABRG2'],
#  'Siponimod': ['S1PR2', 'S1PR1', 'S1PR4', 'S1PR3', 'S1PR5'],
#  'Erdafitinib': ['FGFR1', 'KDR', 'FGFR4', 'FGFR3', 'FGFR2'],
#  'Bremelanotide': ['MC3R', 'MC2R', 'MC1R', 'MC5R', 'MC4R'],
#  'Polatuzumab Vedotin': ['CD79B',
#   'TUBB8',
#   'TUBB2B',
#   'TUBB6',
#   'TUBB3',
#   'TUBB',
#   'TUBB1',
#   'TUBB2A',
#   'TUBB4B',
#   'TUBB4A'],
#  'Quizartinib': ['EPHA6',
#   'NTRK2',
#   'LYN',
#   'NTRK3',
#   'PDGFRB',
#   'PDGFRA',
#   'EPHA7',
#   'NTRK1',
#   'TIE1',
#   'MAPK15',
#   'HIPK4',
#   'MAP3K19',
#   'LCK',
#   'KIT',
#   'TNIK',
#   'EPHA3',
#   'FRK',
#   'CSF1R',
#   'DDR2',
#   'DDR1',
#   'EPHB6',
#   'MYLK3',
#   'RET',
#   'FLT1',
#   'FLT3',
#   'FLT4',
#   'MYLK',
#   'SLK',
#   'STK10',
#   'MKNK2',
#   'KDR',
#   'RIPK2',
#   'ABL1',
#   'MUSK',
#   'RIPK1',
#   'MAP3K7',
#   'MAP4K4',
#   'MAP4K5'],
#  'Pexidartinib': ['CSF1R',
#   'CDK19',
#   'NTRK3',
#   'FLT1',
#   'LCK',
#   'FLT3',
#   'KIT',
#   'KDR'],
#  'Entrectinib': ['NTRK2',
#   'INSR',
#   'NTRK3',
#   'RET',
#   'NTRK1',
#   'FLT3',
#   'TNK2',
#   'AURKA',
#   'PTK6',
#   'IGF1R',
#   'AURKB',
#   'PTK2',
#   'JAK3',
#   'ROS1',
#   'JAK1',
#   'ALK',
#   'JAK2'],
#  'Fedratinib': ['CDK18',
#   'EPHA6',
#   'ACVR1',
#   'EPHA8',
#   'EPHA7',
#   'DCLK3',
#   'MAPK15',
#   'DCLK2',
#   'DCLK1',
#   'MAPK10',
#   'TEK',
#   'ULK3',
#   'SIK2',
#   'ULK2',
#   'ANKK1',
#   'SIK3',
#   'ULK1',
#   'CDK14',
#   'EPHA2',
#   'CDK15',
#   'EPHA1',
#   'SIK1',
#   'CDK16',
#   'EPHA4',
#   'CDK17',
#   'EPHA3',
#   'PRKAA2',
#   'TESK1',
#   'PRKAA1',
#   'NUAK2',
#   'CHEK1',
#   'KDR',
#   'PIP4K2B',
#   'PIP4K2C',
#   'MUSK',
#   'SRPK3',
#   'YES1',
#   'INSR',
#   'PLK4',
#   'SRMS',
#   'DMPK',
#   'PLK1',
#   'PLK3',
#   'PLK2',
#   'PRKCE',
#   'PTK6',
#   'NUAK1',
#   'SRPK1',
#   'PTK2',
#   'SRPK2',
#   'LATS2',
#   'BTK',
#   'PRKD3',
#   'TXK',
#   'MYLK',
#   'DSTYK',
#   'TBK1',
#   'PIP5K1A',
#   'LYN',
#   'INSRR',
#   'RIPK4',
#   'BRAF',
#   'TYK2',
#   'COQ8A',
#   'PI4KB',
#   'CAMK1',
#   'COQ8B',
#   'SGK3',
#   'ITK',
#   'DDR2',
#   'ACVRL1',
#   'DDR1',
#   'RET',
#   'STK33',
#   'STK36',
#   'STK38',
#   'STK39',
#   'RIPK2',
#   'RIPK1',
#   'BRD4',
#   'MAP4K2',
#   'MAP4K3',
#   'CDKL5',
#   'MAP4K1',
#   'CSNK2A2',
#   'CSNK2A1',
#   'SYK',
#   'TNNI3K',
#   'CIT',
#   'HCK',
#   'GAK',
#   'KIT',
#   'STK17A',
#   'STK17B',
#   'TAOK2',
#   'TAOK3',
#   'NEK11',
#   'PKN1',
#   'TAOK1',
#   'CDKL2',
#   'BRDT',
#   'CAMKK1',
#   'CAMKK2',
#   'IKBKB',
#   'RIOK1',
#   'RIOK3',
#   'RIOK2',
#   'JAK3',
#   'IKBKE',
#   'JAK1',
#   'JAK2',
#   'MAP3K3',
#   'MAP3K4',
#   'PDGFRB',
#   'PDGFRA',
#   'MAP3K2',
#   'MATK',
#   'PRPF4B',
#   'HIPK2',
#   'HIPK1',
#   'HIPK4',
#   'ERN1',
#   'HIPK3',
#   'MELK',
#   'AXL',
#   'FRK',
#   'ROCK1',
#   'ROCK2',
#   'AURKA',
#   'EGFR',
#   'AURKC',
#   'AURKB',
#   'SLK',
#   'PAK2',
#   'PAK1',
#   'MAP3K9',
#   'MAP3K7',
#   'PAK4',
#   'PAK6',
#   'PAK5',
#   'MAP2K4',
#   'NEK9',
#   'MAP2K5',
#   'MAP2K2',
#   'MAP2K3',
#   'NEK5',
#   'MAP2K1',
#   'NEK6',
#   'NEK7',
#   'TNK2',
#   'DYRK1B',
#   'MINK1',
#   'CASK',
#   'MAP3K19',
#   'STK25',
#   'STK26',
#   'FGFR1',
#   'MAP3K10',
#   'MAP3K11',
#   'BMP2K',
#   'FGFR4',
#   'FGFR3',
#   'MAP3K12',
#   'FGFR2',
#   'MAP3K13',
#   'CSF1R',
#   'BLK',
#   'IGF1R',
#   'STK10',
#   'STK11',
#   'STK16',
#   'ABL2',
#   'MARK1',
#   'NEK1',
#   'TNK1',
#   'NEK2',
#   'NEK3',
#   'ABL1',
#   'NEK4',
#   'ROS1',
#   'MARK4',
#   'MARK3',
#   'MARK2',
#   'LIMK1',
#   'EIF2AK2',
#   'EIF2AK1',
#   'LIMK2',
#   'EIF2AK4',
#   'IRAK4',
#   'BMX',
#   'MERTK',
#   'CLK4',
#   'TGFBR2',
#   'CLK2',
#   'CDK9',
#   'CLK1',
#   'FES',
#   'CDK7',
#   'FER',
#   'PIK3CA',
#   'CDK4',
#   'AAK1',
#   'ALK',
#   'BMPR1B',
#   'BMPR2',
#   'NIM1K',
#   'LRRK2',
#   'TSSK1B',
#   'GRK4',
#   'ERBB4',
#   'IRAK3',
#   'MKNK1',
#   'MKNK2',
#   'GRK7',
#   'IRAK1',
#   'PRKG2',
#   'PRKG1',
#   'NTRK2',
#   'NTRK3',
#   'CAMK1D',
#   'NTRK1',
#   'DAPK2',
#   'CHUK',
#   'DAPK1',
#   'DAPK3',
#   'TIE1',
#   'SBK3',
#   'FGR',
#   'WEE1',
#   'LCK',
#   'SBK1',
#   'WEE2',
#   'ZAP70',
#   'RPS6KB1',
#   'SNRK',
#   'MET',
#   'CAMK1G',
#   'MYLK2',
#   'CAMK2D',
#   'EPHB6',
#   'MYLK3',
#   'FLT1',
#   'SRC',
#   'LTK',
#   'FLT3',
#   'FLT4',
#   'CAMK2A',
#   'CAMK2B',
#   'TTK',
#   'ACVR1B',
#   'MYLK4',
#   'PIK3CG',
#   'RPS6KA5',
#   'RPS6KA4',
#   'MAPK9',
#   'MAPK8',
#   'RPS6KA6',
#   'PHKG2',
#   'RPS6KA1',
#   'PHKG1',
#   'RPS6KA3',
#   'RPS6KA2',
#   'PTK2B',
#   'TLK2',
#   'EPHB1',
#   'TLK1',
#   'CSK',
#   'FYN',
#   'CAMK2G',
#   'MAPK7',
#   'EPHB2',
#   'MAPK6',
#   'EPHB4'],
#  'Lumateperone': ['HTR2C',
#   'DRD1',
#   'HTR2A',
#   'DRD2',
#   'HTR1A',
#   'ADRA1B',
#   'DRD4',
#   'ADRA1A',
#   'SLC6A4'],
#  'Enfortumab Vedotin': ['TUBB8',
#   'TUBB2B',
#   'TUBB6',
#   'TUBB3',
#   'TUBB',
#   'TUBB1',
#   'TUBB2A',
#   'NECTIN4',
#   'TUBB4B',
#   'TUBB4A'],
#  'Ozanimod': ['S1PR2', 'S1PR1', 'S1PR4', 'S1PR3', 'S1PR5'],
#  'Ripretinib': ['CSF1R', 'PDGFRB', 'PDGFRA', 'KIT', 'TEK', 'KDR'],
#  'Remimazolam': ['GABRA3',
#   'GABRA2',
#   'GABRA1',
#   'GABRB2',
#   'GABRA5',
#   'GABRG1',
#   'GABRG3',
#   'GABRG2'],
#  'Oliceridine': ['CACNA1C', 'SCN5A', 'OPRM1', 'OPRL1', 'KCNH2'],
#  'Pralsetinib': ['DDR1',
#   'NTRK3',
#   'PDGFRB',
#   'RET',
#   'NTRK1',
#   'FLT3',
#   'FGFR1',
#   'KDR',
#   'JAK1',
#   'JAK2'],
#  'Lonafarnib': ['NRAS', 'FNTB', 'FNTA', 'HRAS', 'KRAS'],
#  'Filgotinib': ['CSF1R',
#   'FLT3',
#   'FLT4',
#   'JAK3',
#   'TYK2',
#   'JAK1',
#   'JAK2',
#   'KCNH2'],
#  'Vadadustat': ['EGLN2', 'EGLN1', 'EGLN3', 'OGFOD1', 'HIF1AN', 'VEGFA'],
#  'Tirabrutinib Hydrochloride': ['TEC',
#   'BLK',
#   'LCK',
#   'ERBB4',
#   'ERBB2',
#   'TXK',
#   'BTK',
#   'BMX'],
#  'Dotinurad': ['CYP2C9', 'SLC22A6', 'SLC22A8', 'ABCG2', 'SLC22A12'],
#  'Delgocitinib': ['ROCK2', 'JAK3', 'TYK2', 'JAK1', 'JAK2'],
#  'Umbralisib': ['PIK3CB', 'PIK3CA', 'CSNK1E', 'PIK3CD', 'PIK3CG'],
#  'Trilaciclib': ['CDK9',
#   'NUAK2',
#   'CDK7',
#   'CDK6',
#   'FLT3',
#   'CDK5',
#   'CDK4',
#   'CDK2',
#   'CDK1',
#   'NEK10'],
#  'Infigratinib': ['NTRK2',
#   'YES1',
#   'INSR',
#   'LYN',
#   'PDGFRA',
#   'SYK',
#   'BRAF',
#   'TYK2',
#   'BMX',
#   'LCK',
#   'KIT',
#   'SMO',
#   'FGFR1',
#   'TEK',
#   'MET',
#   'FGFR4',
#   'FGFR3',
#   'ALK',
#   'FGFR2',
#   'RET',
#   'FLT1',
#   'SRC',
#   'FLT3',
#   'FLT4',
#   'MST1R',
#   'KDR',
#   'EPHB1',
#   'ABL1',
#   'FYN',
#   'ROS1',
#   'JAK2']}

# %% [markdown]
# ## 6 drugs given to the UK65 patient

# %%
# List of drugs you want to keep
target_drugs = [
    "Doxorubicin",
    "Paclitaxel",
    "Zoledronic Acid",
    "Fulvestrant",
    "Palbociclib",
    "Gemcitabine"
]
target_drugs_lower = [d.lower() for d in target_drugs]


UK65_drug_administered_dict = {
    k: v for k, v in idg.items()
    if k.lower() in target_drugs_lower
}
UK65_drug_administered_dict
# Out:
# {'Doxorubicin': ['TOP2B',
#   'ABCB1',
#   'ABCC2',
#   'CHRM1',
#   'MMP2',
#   'ABCC6',
#   'TOP2A',
#   'ALOX15',
#   'AURKA',
#   'HTR1B',
#   'CISD1',
#   'RNASE1',
#   'HTR4',
#   'LCK',
#   'TERT',
#   'ERBB2',
#   'CASP1',
#   'FYN',
#   'TOP1',
#   'ABCC1',
#   'ABCG2'],
#  'Fulvestrant': ['ESRRA',
#   'NR1I2',
#   'EPHX2',
#   'GPER1',
#   'NR1H4',
#   'PGR',
#   'ESR1',
#   'ESR2'],
#  'Gemcitabine': ['POLA1',
#   'POLE',
#   'RRM2',
#   'POLD1',
#   'RRM1',
#   'DCK',
#   'TYMS',
#   'CMPK1'],
#  'Paclitaxel': ['ABCB1',
#   'OPRD1',
#   'NR1I2',
#   'TUBB',
#   'TUBB1',
#   'NOD2',
#   'TACR2',
#   'TUBB2A',
#   'MERTK',
#   'TUBB4B',
#   'TUBB4A',
#   'TUBB8',
#   'ABCB11',
#   'ABCC10',
#   'TUBB2B',
#   'TUBB6',
#   'CCKAR',
#   'ERBB2',
#   'MC5R',
#   'TUBB3',
#   'FYN'],
#  'Zoledronic Acid': ['FDPS',
#   'CA12',
#   'CA2',
#   'MMP14',
#   'MMP8',
#   'BTN3A1',
#   'MMP2',
#   'GGPS1',
#   'CA9',
#   'MMP9',
#   'CA14'],
#  'Palbociclib': ['CCNA2',
#   'CDK9',
#   'CDK6',
#   'FLT3',
#   'RPS6KA1',
#   'CCND1',
#   'CDK4',
#   'CDK2',
#   'DYRK1A',
#   'JAK3']}

# %% [markdown]
# ## Calculating the jaccard siliarity to get the top pathways for given drugs

# %%
from typing import Dict, List, Iterable

def jaccard_similarity(list1: Iterable[str], list2: Iterable[str]) -> float:
    """
    Compute Jaccard similarity between two gene lists (case-insensitive).
    Returns 0.0 if union is empty.
    """
    s1 = {g.upper() for g in list1 if isinstance(g, str) and g.strip()}
    s2 = {g.upper() for g in list2 if isinstance(g, str) and g.strip()}
    if not s1 and not s2:
        return 0.0
    inter = s1.intersection(s2)
    union = s1.union(s2)
    return len(inter) / len(union) if union else 0.0

def compute_jaccard_for_df(
    gene_set_df: pd.DataFrame,
    drug_targets: Dict[str, List[str]],
    gene_col: str = "genes",
    setname_col: str = "set_name",
    genes_separator: str = ",",
    case_insensitive: bool = True,
) -> pd.DataFrame:
    """
    Compute Jaccard similarity between each gene set in gene_set_df and each drug in drug_targets.

    Parameters
    ----------
    gene_set_df : pd.DataFrame
        DataFrame with at least two columns: set_name and genes (comma-separated string OR list).
    drug_targets : dict
        Mapping from drug name -> list of target genes (strings).
    gene_col : str
        Column name in gene_set_df that contains gene lists (string or list).
    setname_col : str
        Column name that contains pathway / gene set names.
    genes_separator : str
        If gene_col contains strings, split by this separator to get genes.
    case_insensitive : bool
        If True, matching is case-insensitive (recommended).

    Returns
    -------
    pd.DataFrame
        Rows = gene sets; columns = set_name + one column per drug with Jaccard scores (float).
    """
    # Validate input
    if setname_col not in gene_set_df.columns or gene_col not in gene_set_df.columns:
        raise ValueError(f"DataFrame must contain columns '{setname_col}' and '{gene_col}'")

    # Prepare drug targets (normalize case if requested)
    if case_insensitive:
        drug_targets_norm = {drug: [g.upper() for g in genes if isinstance(g, str)] for drug, genes in drug_targets.items()}
    else:
        drug_targets_norm = {drug: [g for g in genes if isinstance(g, str)] for drug, genes in drug_targets.items()}

    results = []
    for idx, row in gene_set_df.iterrows():
        set_name = row[setname_col]
        raw_genes = row[gene_col]
        # If genes are a string (comma-separated), split them
        if isinstance(raw_genes, str):
            genes_list = [g.strip() for g in raw_genes.split(genes_separator) if g.strip()]
        elif isinstance(raw_genes, (list, tuple, set, pd.Series)):
            genes_list = [str(g).strip() for g in raw_genes if pd.notna(g)]
        else:
            genes_list = []
        # Normalize case if requested
        if case_insensitive:
            genes_list_norm = [g.upper() for g in genes_list]
        else:
            genes_list_norm = genes_list

        # Compute jaccard vs each drug
        row_result = {setname_col: set_name}
        for drug, targets in drug_targets_norm.items():
            score = jaccard_similarity(genes_list_norm, targets)
            row_result[drug] = score
        results.append(row_result)

    out_df = pd.DataFrame(results)
    # Optional: keep set_name as first column
    cols = [setname_col] + [c for c in out_df.columns if c != setname_col]
    out_df = out_df[cols]
    return out_df

# %%
# Compute Jaccard scores
jaccard_df = compute_jaccard_for_df(gene_set_df, UK65_drug_administered_dict,
                                    gene_col='genes', setname_col='set_name',
                                    genes_separator=',', case_insensitive=True)

# Save results to CSV_
jaccard_df.to_csv("singscore_new_code/UK65_jaccard_for_6drugs_vs_pathways.csv", index=False)
jaccard_df
# Out:
#                                                set_name  Doxorubicin  \
# 0                         TNF-alpha Signaling via NF-kB     0.000000
# 1                                               Hypoxia     0.000000
# 2                               Cholesterol Homeostasis     0.000000
# 3                                       Mitotic Spindle     0.009174
# 4                            Wnt-beta Catenin Signaling     0.000000
# ...                                                 ...          ...
# 7797  Zinc Ion Import Across Plasma Membrane (GO:007...     0.000000
# 7798        Zinc Ion Import Into Organelle (GO:0062111)     0.000000
# 7799      Zinc Ion Transmembrane Transport (GO:0071577)     0.000000
# 7800                    Zinc Ion Transport (GO:0006829)     0.000000
# 7801                    Zymogen Activation (GO:0031638)     0.000000
#
#       Fulvestrant  Gemcitabine  Paclitaxel  Zoledronic Acid  Palbociclib
# 0             0.0          0.0    0.004545         0.000000     0.004785
# 1             0.0          0.0    0.000000         0.004762     0.000000
# 2             0.0          0.0    0.000000         0.011905     0.000000
# 3             0.0          0.0    0.000000         0.000000     0.000000
# 4             0.0          0.0    0.000000         0.000000     0.000000
# ...           ...          ...         ...              ...          ...
# 7797          0.0          0.0    0.000000         0.000000     0.000000
# 7798          0.0          0.0    0.000000         0.000000     0.000000
# 7799          0.0          0.0    0.000000         0.000000     0.000000
# 7800          0.0          0.0    0.000000         0.000000     0.000000
# 7801          0.0          0.0    0.000000         0.027027     0.000000
#
# [7802 rows x 7 columns]

# %% [markdown]
# ### Saving relevant pathways by filteritng jaccard score > 0 for each drug

# %%
def save_drug_relevant_pathways(drugname: str,
                                jaccard_df: pd.DataFrame,
                                gene_set_df: pd.DataFrame,
                                output_root: str = "singscore_new_code",
                                jaccard_col_check: bool = True,
                                save_json: bool = True) -> pd.DataFrame:
    """
    Filter gene_set_df for pathways relevant to a given drug using jaccard_df,
    save both a CSV and a JSON file.

    JSON format example:
    {
      "TNF-alpha Signaling via NF-kB": ["MARCKS", "IL23A", "NINJ1", ...],
      "MTOR_PATHWAY": ["G1", "G2"]
    }

    Parameters
    ----------
    drugname : str
        Drug name (must exist as a column in jaccard_df).
    jaccard_df : pd.DataFrame
        DataFrame containing 'set_name' and drug Jaccard scores.
    gene_set_df : pd.DataFrame
        DataFrame with columns ['set_name', 'genes'] (genes can be comma-separated string).
    output_root : str
        Folder where the subfolder per drug will be created.
    jaccard_col_check : bool
        Check column existence for safety.
    save_json : bool
        Whether to save a JSON version of the relevant pathways.

    Returns
    -------
    pd.DataFrame
        Filtered DataFrame containing relevant pathways.
    """


    # 2️⃣ Filter pathways with positive Jaccard similarity
    df1 = jaccard_df.sort_values(by=drugname, ascending=False)
    df2 = df1[df1[drugname] > 0]
    relevant_pathways = df2["set_name"].tolist()

    df4 = gene_set_df[gene_set_df["set_name"].isin(relevant_pathways)].reset_index(drop=True)

    # 3️⃣ Create output directory for this drug
    drug_dir = Path(output_root) / drugname.replace(" ", "_")
    drug_dir.mkdir(parents=True, exist_ok=True)

    # 5️⃣ Save JSON (key = set_name, value = list of genes)
    if save_json:
        json_dict = {}
        for _, row in df4.iterrows():
            genes = row["genes"]
            if isinstance(genes, str):
                gene_list = [g.strip() for g in genes.replace("\n", ",").split(",") if g.strip()]
            elif isinstance(genes, (list, tuple, set)):
                gene_list = list(genes)
            else:
                gene_list = []
            json_dict[row["set_name"]] = gene_list

        json_path = drug_dir / f"{drugname.replace(' ', '_')}_relevant_pathways.json"
        with open(json_path, "w", encoding="utf-8") as f:
            json.dump(json_dict, f, indent=2, ensure_ascii=False)

        print(f"✅ JSON saved to: {json_path}")

    return df4

# %%
for i in target_drugs:
    df4 = save_drug_relevant_pathways(f"{i}", jaccard_df, gene_set_df)
# Out:
# ✅ JSON saved to: singscore_new_code\Doxorubicin\Doxorubicin_relevant_pathways.json
# ✅ JSON saved to: singscore_new_code\Paclitaxel\Paclitaxel_relevant_pathways.json
# ✅ JSON saved to: singscore_new_code\Zoledronic_Acid\Zoledronic_Acid_relevant_pathways.json
# ✅ JSON saved to: singscore_new_code\Fulvestrant\Fulvestrant_relevant_pathways.json
# ✅ JSON saved to: singscore_new_code\Palbociclib\Palbociclib_relevant_pathways.json
# ✅ JSON saved to: singscore_new_code\Gemcitabine\Gemcitabine_relevant_pathways.json

# %% [markdown]
# ## SingScores for the hallmark genes for UK65 patient

# %%
hallmark  = gp.get_library(organism='Human', name ='MSigDB_Hallmark_2020')
hallmark
# Out:
# {'TNF-alpha Signaling via NF-kB': ['MARCKS',
#   'IL23A',
#   'NINJ1',
#   'TNFSF9',
#   'SIK1',
#   'ATF3',
#   'SERPINE1',
#   'MYC',
#   'HES1',
#   'CCN1',
#   'CCNL1',
#   'EGR1',
#   'EGR2',
#   'EGR3',
#   'JAG1',
#   'ABCA1',
#   'GADD45B',
#   'GADD45A',
#   'KLF10',
#   'PLK2',
#   'EIF1',
#   'EHD1',
#   'FOSL2',
#   'FOSL1',
#   'GPR183',
#   'PLPP3',
#   'IFIT2',
#   'ICAM1',
#   'ZC3H12A',
#   'IER2',
#   'IL12B',
#   'IER5',
#   'JUNB',
#   'IER3',
#   'STAT5A',
#   'DUSP5',
#   'EDN1',
#   'DUSP4',
#   'JUN',
#   'DUSP1',
#   'DUSP2',
#   'TSC22D1',
#   'CCL20',
#   'SPHK1',
#   'LIF',
#   'IL18',
#   'TUBB2A',
#   'RHOB',
#   'VEGFA',
#   'IL1A',
#   'PTPRE',
#   'TLR2',
#   'IL1B',
#   'BHLHE40',
#   'CLCF1',
#   'ID2',
#   'REL',
#   'FJX1',
#   'SGK1',
#   'BTG3',
#   'BTG2',
#   'BTG1',
#   'SDC4',
#   'LITAF',
#   'AREG',
#   'SOCS3',
#   'PANX1',
#   'RIPK2',
#   'NFIL3',
#   'SERPINB2',
#   'GCH1',
#   'IFNGR2',
#   'G0S2',
#   'FOS',
#   'F3',
#   'SERPINB8',
#   'SPSB1',
#   'FOSB',
#   'PER1',
#   'F2RL1',
#   'HBEGF',
#   'CD44',
#   'TRIP10',
#   'CDKN1A',
#   'PTGER4',
#   'PTGS2',
#   'IFIH1',
#   'NAMPT',
#   'OLR1',
#   'ICOSLG',
#   'PHLDA1',
#   'ZBTB10',
#   'TAP1',
#   'PNRC1',
#   'CXCL10',
#   'CXCL11',
#   'IL6ST',
#   'CD69',
#   'SQSTM1',
#   'RELA',
#   'CD83',
#   'CSF2',
#   'CSF1',
#   'CD80',
#   'PPP1R15A',
#   'TNC',
#   'TNF',
#   'RELB',
#   'TANK',
#   'ZFP36',
#   'CCND1',
#   'RNF19B',
#   'CCRL2',
#   'DENND5A',
#   'MAP3K8',
#   'PHLDA2',
#   'LDLR',
#   'SLC16A6',
#   'SMAD3',
#   'TGIF1',
#   'MAP2K3',
#   'DDX58',
#   'INHBA',
#   'TRAF1',
#   'NFKB1',
#   'NFKB2',
#   'GEM',
#   'MAFF',
#   'NR4A3',
#   'RCAN1',
#   'EFNA1',
#   'NR4A2',
#   'MXD1',
#   'BIRC2',
#   'BIRC3',
#   'YRDC',
#   'IL7R',
#   'PFKFB3',
#   'IRS2',
#   'SLC2A3',
#   'PLAU',
#   'SAT1',
#   'SLC2A6',
#   'ETS2',
#   'NR4A1',
#   'SNN',
#   'PMEPA1',
#   'TNFRSF9',
#   'MSC',
#   'TIPARP',
#   'LAMB3',
#   'GFPT2',
#   'CFLAR',
#   'TNIP1',
#   'IRF1',
#   'NFKBIA',
#   'BMP2',
#   'IL6',
#   'TNIP2',
#   'BCL6',
#   'BCL3',
#   'NFKBIE',
#   'NFE2L2',
#   'B4GALT1',
#   'NFAT5',
#   'BCL2A1',
#   'TNFAIP8',
#   'TNFAIP6',
#   'TNFAIP3',
#   'CXCL2',
#   'CXCL1',
#   'TNFAIP2',
#   'CXCL3',
#   'CXCL6',
#   'FUT4',
#   'DRAM1',
#   'DNAJB4',
#   'PDE4B',
#   'PDLIM5',
#   'MCL1',
#   'KDM6B',
#   'IL15RA',
#   'PLAUR',
#   'ATP2B1',
#   'KLF4',
#   'KLF2',
#   'SOD2',
#   'KLF9',
#   'KLF6',
#   'ACKR3',
#   'PTX3',
#   'B4GALT5',
#   'TRIB1',
#   'CEBPB',
#   'CEBPD',
#   'PLEK',
#   'CCL5',
#   'KYNU',
#   'CCL4',
#   'CCL2'],
#  'Hypoxia': ['WSB1',
#   'JMJD6',
#   'XPNPEP1',
#   'RRAGD',
#   'PPP1R3C',
#   'MT1E',
#   'TES',
#   'ATF3',
#   'SERPINE1',
#   'GLRX',
#   'UGP2',
#   'NOCT',
#   'MXI1',
#   'DPYSL4',
#   'CCN5',
#   'CCN2',
#   'PPARGC1A',
#   'CCN1',
#   'DTNA',
#   'SIAH2',
#   'MIF',
#   'PRKCA',
#   'EXT1',
#   'FOSL2',
#   'SLC6A6',
#   'SULT2B1',
#   'BCAN',
#   'LALBA',
#   'CHST2',
#   'SDC2',
#   'HOXB9',
#   'CHST3',
#   'LXN',
#   'NEDD4L',
#   'PDGFB',
#   'ENO1',
#   'ENO2',
#   'ENO3',
#   'RBPJ',
#   'MT2A',
#   'PLAC8',
#   'PRDX5',
#   'HMOX1',
#   'PDK1',
#   'IER3',
#   'PDK3',
#   'EDN2',
#   'ANXA2',
#   'JUN',
#   'DUSP1',
#   'TPI1',
#   'AMPD3',
#   'CP',
#   'VEGFA',
#   'P4HA1',
#   'P4HA2',
#   'BHLHE40',
#   'CCNG2',
#   'PAM',
#   'ALDOC',
#   'ALDOB',
#   'ALDOA',
#   'GPI',
#   'BTG1',
#   'CITED2',
#   'SDC3',
#   'SDC4',
#   'STC1',
#   'ADM',
#   'STC2',
#   'VLDLR',
#   'BRS3',
#   'LDHC',
#   'LDHA',
#   'CSRP2',
#   'IDS',
#   'NFIL3',
#   'PCK1',
#   'TPD52',
#   'PKLR',
#   'PGAM2',
#   'GAA',
#   'FOS',
#   'BGN',
#   'F3',
#   'TPST2',
#   'ANGPTL4',
#   'PLIN2',
#   'INHA',
#   'ERRFI1',
#   'SRPX',
#   'CDKN1B',
#   'CDKN1C',
#   'ERO1A',
#   'HEXA',
#   'CDKN1A',
#   'NCAN',
#   'GBE1',
#   'GCNT2',
#   'PYGM',
#   'GYS1',
#   'NDST2',
#   'NDST1',
#   'AKAP12',
#   'STBD1',
#   'CXCR4',
#   'CA12',
#   'HS3ST1',
#   'MAP3K1',
#   'TGFB3',
#   'CAVIN1',
#   'CAVIN3',
#   'KLHL24',
#   'PNRC1',
#   'SAP30',
#   'GCK',
#   'ILVBL',
#   'COL5A1',
#   'TGFBI',
#   'GAPDHS',
#   'S100A4',
#   'PKP1',
#   'PPP1R15A',
#   'HDLBP',
#   'EGFR',
#   'FOXO3',
#   'NDRG1',
#   'KIF5A',
#   'ZFP36',
#   'GPC1',
#   'HAS1',
#   'GPC4',
#   'GPC3',
#   'PPFIA4',
#   'IGFBP1',
#   'BNIP3L',
#   'IGFBP3',
#   'B3GALT6',
#   'PGF',
#   'MAFF',
#   'EFNA1',
#   'ISG20',
#   'EFNA3',
#   'LOX',
#   'PFKFB3',
#   'IRS2',
#   'SLC2A1',
#   'AK4',
#   'SLC2A3',
#   'SLC2A5',
#   'ETS1',
#   'RORA',
#   'TGM2',
#   'FAM162A',
#   'PIM1',
#   'ANKZF1',
#   'TIPARP',
#   'HSPA5',
#   'CAV1',
#   'GALK1',
#   'GRHPR',
#   'IL6',
#   'ADORA2B',
#   'MYH9',
#   'BCL2',
#   'FBP1',
#   'TMEM45A',
#   'SLC25A1',
#   'TNFAIP3',
#   'HK1',
#   'HK2',
#   'CASP6',
#   'PGK1',
#   'B4GALNT2',
#   'SLC37A4',
#   'TKTL1',
#   'TPBG',
#   'PLAUR',
#   'DCN',
#   'SELENBP1',
#   'KLF7',
#   'NAGK',
#   'KLF6',
#   'PFKL',
#   'DDIT4',
#   'DDIT3',
#   'ACKR3',
#   'KDELR3',
#   'GAPDH',
#   'PFKP',
#   'KDM3A',
#   'ZNF292',
#   'NR3C1',
#   'PHKG1',
#   'VHL',
#   'ATP7A',
#   'PGM2',
#   'SCARB1',
#   'LARGE1',
#   'PGM1'],
#  'Cholesterol Homeostasis': ['STARD4',
#   'GSTM2',
#   'CHKA',
#   'HMGCS1',
#   'TNFRSF12A',
#   'ANXA5',
#   'ECH1',
#   'GPX8',
#   'PNRC1',
#   'CPEB2',
#   'SCD',
#   'CD9',
#   'ETHE1',
#   'ALDOC',
#   'DHCR7',
#   'IDI1',
#   'ATF3',
#   'CLU',
#   'HSD17B7',
#   'ANTXR2',
#   'CXCL16',
#   'ACAT2',
#   'ATXN2',
#   'PMVK',
#   'SC5D',
#   'MAL2',
#   'STX5',
#   'NFIL3',
#   'ACSS2',
#   'FDFT1',
#   'LDLR',
#   'S100A11',
#   'ABCA2',
#   'FDPS',
#   'NIBAN1',
#   'SREBF2',
#   'JAG1',
#   'CYP51A1',
#   'PCYT2',
#   'ANXA13',
#   'TP53INP1',
#   'AVPR1A',
#   'LSS',
#   'PLAUR',
#   'SQLE',
#   'FABP5',
#   'PLSCR1',
#   'FASN',
#   'LGMN',
#   'PPARG',
#   'MVD',
#   'TRIB3',
#   'ATF5',
#   'ERRFI1',
#   'MVK',
#   'GLDC',
#   'CTNNB1',
#   'LPL',
#   'SEMA3B',
#   'ACTG1',
#   'HMGCR',
#   'TMEM97',
#   'GNAI1',
#   'TM7SF2',
#   'ADH4',
#   'CBS',
#   'LGALS3',
#   'EBP',
#   'NSDHL',
#   'ALCAM',
#   'FBXO6',
#   'GUSB',
#   'FADS2',
#   'PDK3'],
#  'Mitotic Spindle': ['ACTN4',
#   'PCGF5',
#   'APC',
#   'MARCKS',
#   'NIN',
#   'KIF20B',
#   'EPB41',
#   'STAU1',
#   'CD2AP',
#   'UXT',
#   'PPP4R2',
#   'CSNK1D',
#   'RACGAP1',
#   'CDC27',
#   'PREX1',
#   'STK38L',
#   'ARFIP2',
#   'PLK1',
#   'BCR',
#   'LATS1',
#   'CCDC88A',
#   'TPX2',
#   'BIN1',
#   'NET1',
#   'SASS6',
#   'EZR',
#   'TRIO',
#   'ITSN1',
#   'NUMA1',
#   'SMC4',
#   'SMC3',
#   'ABR',
#   'EPB41L2',
#   'CDK5RAP2',
#   'CEP72',
#   'KIFAP3',
#   'CEP192',
#   'SYNPO',
#   'RHOF',
#   'LRPPRC',
#   'ANLN',
#   'CENPE',
#   'CENPF',
#   'INCENP',
#   'CENPJ',
#   'PAFAH1B1',
#   'ARHGEF2',
#   'ARHGEF3',
#   'RAPGEF6',
#   'KPTN',
#   'ARHGEF7',
#   'RAPGEF5',
#   'RABGAP1',
#   'KIF11',
#   'PIF1',
#   'TOP2A',
#   'KIF15',
#   'NEDD9',
#   'RASAL2',
#   'BRCA2',
#   'CNTRL',
#   'KIF1B',
#   'SPTBN1',
#   'CEP57',
#   'DLGAP5',
#   'MAP1S',
#   'SORBS2',
#   'DYNLL2',
#   'MYO9B',
#   'FARP1',
#   'RANBP9',
#   'SEPTIN9',
#   'CLIP2',
#   'CLIP1',
#   'CTTN',
#   'TAOK2',
#   'LLGL1',
#   'ARF6',
#   'DYNC1H1',
#   'MAPRE1',
#   'RAB3GAP1',
#   'ALMS1',
#   'TUBD1',
#   'WASL',
#   'AKAP13',
#   'PCM1',
#   'OPHN1',
#   'NUSAP1',
#   'RICTOR',
#   'SPTAN1',
#   'GSN',
#   'RALBP1',
#   'ARHGAP29',
#   'TSC1',
#   'ARHGAP27',
#   'MID1',
#   'TUBA4A',
#   'ABI1',
#   'KIF4A',
#   'TUBGCP6',
#   'ARL8A',
#   'TUBGCP5',
#   'CNTROB',
#   'ROCK1',
#   'GEMIN4',
#   'AURKA',
#   'KATNB1',
#   'FGD4',
#   'BCL2L11',
#   'FGD6',
#   'KIF5B',
#   'CEP250',
#   'FLNA',
#   'CLASP1',
#   'FLNB',
#   'KNTC1',
#   'MYH10',
#   'PCNT',
#   'ARHGEF12',
#   'ARHGEF11',
#   'KIF22',
#   'TBCD',
#   'KIF23',
#   'CKAP5',
#   'NDC80',
#   'SSH2',
#   'DLG1',
#   'ARHGAP10',
#   'CDC42EP4',
#   'BIRC5',
#   'CDC42EP2',
#   'FSCN1',
#   'MAP3K11',
#   'CDC42EP1',
#   'KIF2C',
#   'VCL',
#   'DOCK4',
#   'NOTCH2',
#   'PXN',
#   'TUBGCP2',
#   'TUBGCP3',
#   'ARHGAP4',
#   'ARHGAP5',
#   'CCNB2',
#   'KIF3C',
#   'KIF3B',
#   'NEK2',
#   'ABL1',
#   'MARK4',
#   'SAC3D1',
#   'SUN2',
#   'ARFGEF1',
#   'RFC1',
#   'ARAP3',
#   'SHROOM1',
#   'SHROOM2',
#   'CDC42BPA',
#   'SMC1A',
#   'RASA1',
#   'HOOK3',
#   'ESPL1',
#   'RASA2',
#   'MYH9',
#   'CDK1',
#   'NF1',
#   'ATG4B',
#   'DOCK2',
#   'BCAR1',
#   'SOS1',
#   'YWHAE',
#   'LMNB1',
#   'KLC1',
#   'RHOT2',
#   'CAPZB',
#   'ECT2',
#   'WASF1',
#   'WASF2',
#   'PDLIM5',
#   'PLEKHG2',
#   'DST',
#   'CEP131',
#   'MID1IP1',
#   'KATNA1',
#   'PRC1',
#   'TIAM1',
#   'CDC42',
#   'MYO1E',
#   'PALLD',
#   'ALS2',
#   'HDAC6',
#   'TTK',
#   'PKD2',
#   'ARHGDIA',
#   'FBXO5',
#   'TLK1',
#   'BUB1',
#   'CYTH2',
#   'NCK1',
#   'NCK2'],
#  'Wnt-beta Catenin Signaling': ['FZD1',
#   'JAG1',
#   'JAG2',
#   'FZD8',
#   'WNT5B',
#   'AXIN2',
#   'AXIN1',
#   'PTCH1',
#   'CSNK1E',
#   'DKK1',
#   'DKK4',
#   'ADAM17',
#   'KAT2A',
#   'NCOR2',
#   'TCF7',
#   'PPARD',
#   'TP53',
#   'NUMB',
#   'HDAC5',
#   'LEF1',
#   'NOTCH4',
#   'NOTCH1',
#   'HDAC11',
#   'HDAC2',
#   'CTNNB1',
#   'MAML1',
#   'CUL1',
#   'PSEN2',
#   'DLL1',
#   'GNAI1',
#   'NKD1',
#   'RBPJ',
#   'WNT6',
#   'FRAT1',
#   'CCND2',
#   'HEY2',
#   'HEY1',
#   'DVL2',
#   'MYC',
#   'WNT1',
#   'NCSTN',
#   'SKP2'],
#  'TGF-beta Signaling': ['TGFB1',
#   'ACVR1',
#   'RHOA',
#   'SMURF2',
#   'SMURF1',
#   'HIPK2',
#   'TGFBR1',
#   'PPP1CA',
#   'CDK9',
#   'SKI',
#   'RAB31',
#   'APC',
#   'BMP2',
#   'NCOR2',
#   'ID1',
#   'ID3',
#   'ID2',
#   'BMPR1A',
#   'BCAR3',
#   'BMPR2',
#   'SERPINE1',
#   'UBE2D3',
#   'PPP1R15A',
#   'ARID4B',
#   'CDH1',
#   'MAP3K7',
#   'SKIL',
#   'SPTBN1',
#   'SMAD3',
#   'WWTR1',
#   'TGIF1',
#   'LEFTY2',
#   'NOG',
#   'IFNGR2',
#   'SMAD1',
#   'KLF10',
#   'SMAD7',
#   'SMAD6',
#   'PPM1A',
#   'FKBP1A',
#   'TJP1',
#   'XIAP',
#   'ENG',
#   'TRIM33',
#   'CDKN1C',
#   'HDAC1',
#   'FURIN',
#   'CTNNB1',
#   'SLC20A1',
#   'THBS1',
#   'LTBP2',
#   'FNTA',
#   'PMEPA1',
#   'JUNB'],
#  'IL-6/JAK/STAT3 Signaling': ['PTPN1',
#   'TGFB1',
#   'CCR1',
#   'PTPN2',
#   'IL4R',
#   'JUN',
#   'IL1R1',
#   'IL1R2',
#   'ITGA4',
#   'TNFRSF12A',
#   'IL10RB',
#   'PLA2G2A',
#   'DNTT',
#   'PTPN11',
#   'TYK2',
#   'OSMR',
#   'TNFRSF1A',
#   'TNFRSF1B',
#   'CXCL10',
#   'HAX1',
#   'TLR2',
#   'CXCL11',
#   'IL1B',
#   'IRF1',
#   'TNFRSF21',
#   'IL7',
#   'CXCL13',
#   'IL6',
#   'CD9',
#   'FAS',
#   'IL3RA',
#   'IL9R',
#   'IRF9',
#   'IL6ST',
#   'PF4',
#   'STAM2',
#   'CRLF2',
#   'IL18R1',
#   'CNTFR',
#   'ACVRL1',
#   'CSF3R',
#   'CXCL9',
#   'CSF2',
#   'CSF1',
#   'EBI3',
#   'PIK3R5',
#   'TNF',
#   'CXCL1',
#   'IL2RG',
#   'CXCL3',
#   'SOCS3',
#   'SOCS1',
#   'CD38',
#   'CD36',
#   'IL12RB1',
#   'MAP3K8',
#   'IL17RA',
#   'IL15RA',
#   'IFNGR1',
#   'STAT1',
#   'IFNGR2',
#   'STAT2',
#   'STAT3',
#   'INHBE',
#   'IL17RB',
#   'MYD88',
#   'LTBR',
#   'IL2RA',
#   'LTB',
#   'GRB2',
#   'IFNAR1',
#   'CD44',
#   'REG1A',
#   'ITGB3',
#   'PDGFC',
#   'CSF2RA',
#   'ACVR1B',
#   'CBL',
#   'CSF2RB',
#   'CCL7',
#   'HMOX1',
#   'LEPR',
#   'PIM1',
#   'BAK1',
#   'A2M',
#   'CD14',
#   'IL13RA1'],
#  'DNA Repair': ['DUT',
#   'BRF2',
#   'LIG1',
#   'PDE6G',
#   'ALYREF',
#   'UPF3B',
#   'GTF2F1',
#   'RBX1',
#   'TARBP2',
#   'POLR3C',
#   'POLE4',
#   'SRSF6',
#   'EIF1B',
#   'CDA',
#   'TP53',
#   'VPS28',
#   'PCNA',
#   'MPG',
#   'RNMT',
#   'RALA',
#   'GTF2B',
#   'TYMS',
#   'ADCY6',
#   'PNP',
#   'TAF1C',
#   'ZNF707',
#   'CLP1',
#   'NT5C',
#   'RAE1',
#   'STX3',
#   'SMAD5',
#   'SURF1',
#   'VPS37D',
#   'VPS37B',
#   'SUPT5H',
#   'SDCBP',
#   'BCAM',
#   'NT5C3A',
#   'ITPA',
#   'HPRT1',
#   'CCNO',
#   'TSG101',
#   'POM121',
#   'COX17',
#   'ARL6IP1',
#   'AK1',
#   'CSTF3',
#   'AK3',
#   'XPC',
#   'AAAS',
#   'DGUOK',
#   'MPC2',
#   'NELFE',
#   'NELFB',
#   'SAC3D1',
#   'GSDME',
#   'RFC4',
#   'RFC5',
#   'NCBP2',
#   'POLR3GL',
#   'RFC2',
#   'GPX4',
#   'RFC3',
#   'NME3',
#   'EDF1',
#   'NME4',
#   'ZWINT',
#   'NME1',
#   'POLA1',
#   'POLA2',
#   'AGO4',
#   'NFX1',
#   'RRM2B',
#   'ADA',
#   'UMPS',
#   'GTF2A2',
#   'GTF3C5',
#   'CETN2',
#   'ELL',
#   'NPR2',
#   'SUPT4H1',
#   'MRPL40',
#   'ZNRD1',
#   'SNAPC4',
#   'SNAPC5',
#   'NELFCD',
#   'PDE4B',
#   'DGCR8',
#   'TMED2',
#   'TK2',
#   'BCAP31',
#   'SF3A3',
#   'TAF13',
#   'ADRM1',
#   'TAF12',
#   'BOLA2',
#   'RPA2',
#   'GTF2H1',
#   'RPA3',
#   'TAF10',
#   'SSRP1',
#   'GTF2H3',
#   'GTF2H5',
#   'APRT',
#   'DDB2',
#   'DDB1',
#   'ERCC1',
#   'NUDT21',
#   'RAD51',
#   'NUDT9',
#   'RAD52',
#   'ERCC4',
#   'ERCC5',
#   'IMPDH2',
#   'DAD1',
#   'ERCC2',
#   'POLR1C',
#   'ERCC3',
#   'POLR1D',
#   'CMPK2',
#   'ERCC8',
#   'HCLS1',
#   'TAF9',
#   'TAF6',
#   'FEN1',
#   'CANT1',
#   'GMPR2',
#   'USP11',
#   'DCTN4',
#   'PRIM1',
#   'POLD4',
#   'POLB',
#   'GUK1',
#   'POLR2A',
#   'POLD1',
#   'POLR2C',
#   'POLR2D',
#   'SEC61A1',
#   'POLD3',
#   'POLR2E',
#   'ELOA',
#   'POLR2F',
#   'POLR2G',
#   'POLR2H',
#   'POLL',
#   'POLR2I',
#   'POLR2J',
#   'POLR2K',
#   'POLH',
#   'REV3L'],
#  'G2-M Checkpoint': ['H2AZ2',
#   'CASP8AP2',
#   'EGF',
#   'H2AZ1',
#   'KNL1',
#   'SLC12A2',
#   'HUS1',
#   'CDC20',
#   'MAPK14',
#   'PML',
#   'DDX39A',
#   'MARCKS',
#   'NUP98',
#   'HNRNPD',
#   'KIF20B',
#   'CCNF',
#   'HNRNPU',
#   'NOLC1',
#   'EWSR1',
#   'CHEK1',
#   'RACGAP1',
#   'CDC27',
#   'RAD54L',
#   'SNRPD1',
#   'E2F1',
#   'MYC',
#   'E2F2',
#   'E2F3',
#   'E2F4',
#   'PLK4',
#   'PLK1',
#   'SQLE',
#   'STAG1',
#   'TPX2',
#   'UCK2',
#   'EZH2',
#   'ATF5',
#   'JPT1',
#   'NUMA1',
#   'HIF1A',
#   'SMC4',
#   'SMC2',
#   'GSPT1',
#   'TMPO',
#   'MT2A',
#   'SYNCRIP',
#   'STMN1',
#   'MYBL2',
#   'BARD1',
#   'SS18',
#   'UPF1',
#   'CDC7',
#   'CDC6',
#   'CENPE',
#   'SLC7A5',
#   'CENPF',
#   'INCENP',
#   'MTF2',
#   'PAFAH1B1',
#   'CDKN3',
#   'DTYMK',
#   'KIF11',
#   'YTHDC1',
#   'SUV39H1',
#   'TOP2A',
#   'KIF15',
#   'RASAL2',
#   'BRCA2',
#   'CTCF',
#   'SLC7A1',
#   'HOXC10',
#   'PBK',
#   'MAP3K20',
#   'CDKN2C',
#   'PRMT5',
#   'RPA2',
#   'TRAIP',
#   'CKS2',
#   'TACC3',
#   'H2AX',
#   'CDKN1B',
#   'PRIM2',
#   'MKI67',
#   'CENPA',
#   'XPO1',
#   'WRN',
#   'DMD',
#   'NUSAP1',
#   'SRSF10',
#   'GINS2',
#   'TGFB1',
#   'TLE3',
#   'UBE2C',
#   'CDC25A',
#   'PRPF4B',
#   'LIG3',
#   'ILF3',
#   'CDC25B',
#   'SAP30',
#   'DKC1',
#   'UBE2S',
#   'KIF4A',
#   'PTTG3P',
#   'MAD2L1',
#   'CCNT1',
#   'ODC1',
#   'SRSF1',
#   'SRSF2',
#   'ARID4A',
#   'AURKA',
#   'EFNA5',
#   'HIRA',
#   'AURKB',
#   'CCND1',
#   'NSD2',
#   'PURA',
#   'KIF5B',
#   'PTTG1',
#   'KMT5A',
#   'HMGN2',
#   'KPNA2',
#   'SMAD3',
#   'SLC38A1',
#   'KIF22',
#   'ODF2',
#   'STIL',
#   'FANCC',
#   'KIF23',
#   'NASP',
#   'FOXN3',
#   'NDC80',
#   'CCNA2',
#   'TFDP1',
#   'NCL',
#   'BIRC5',
#   'TROAP',
#   'KIF2C',
#   'MNAT1',
#   'NOTCH2',
#   'CUL5',
#   'CUL3',
#   'CUL1',
#   'PDS5B',
#   'CHAF1A',
#   'CCNB2',
#   'G3BP1',
#   'CHMP1A',
#   'NEK2',
#   'ABL1',
#   'DR1',
#   'HSPA8',
#   'CBX1',
#   'RAD23B',
#   'HMGA1',
#   'SMC1A',
#   'CUL4A',
#   'NUP50',
#   'POLA2',
#   'MEIS2',
#   'RBL1',
#   'MEIS1',
#   'ESPL1',
#   'SFPQ',
#   'CDK4',
#   'H2BC12',
#   'BCL3',
#   'CDK1',
#   'MCM5',
#   'MCM6',
#   'TOP1',
#   'MCM2',
#   'MCM3',
#   'AMD1',
#   'CKS1B',
#   'HMGB3',
#   'HMMR',
#   'LMNB1',
#   'TENT4A',
#   'ORC6',
#   'ORC5',
#   'RAD21',
#   'LBR',
#   'TNPO2',
#   'RBM14',
#   'SMARCC1',
#   'ATRX',
#   'POLQ',
#   'KATNA1',
#   'PRC1',
#   'KPNB1',
#   'DBF4',
#   'TTK',
#   'RPS6KA5',
#   'CDC45',
#   'POLE',
#   'EXO1',
#   'TRA2B',
#   'FBXO5',
#   'BUB3',
#   'BUB1'],
#  'Apoptosis': ['GSN',
#   'PDGFRB',
#   'BIK',
#   'LUM',
#   'TGFB2',
#   'GSR',
#   'TAP1',
#   'CDC25B',
#   'EREG',
#   'MADD',
#   'CD2',
#   'FEZ1',
#   'FAS',
#   'CTH',
#   'BAX',
#   'PDCD4',
#   'CD69',
#   'SQSTM1',
#   'APP',
#   'DAP3',
#   'LEF1',
#   'ATF3',
#   'RELA',
#   'IFITM3',
#   'ROCK1',
#   'SATB1',
#   'RETSAT',
#   'CLU',
#   'TNF',
#   'LMNA',
#   'BCL2L11',
#   'PAK1',
#   'CCND2',
#   'BCL2L10',
#   'CCND1',
#   'SC5D',
#   'CREBBP',
#   'IGF2R',
#   'EGR3',
#   'F2R',
#   'IGFBP6',
#   'GADD45B',
#   'BNIP3L',
#   'GADD45A',
#   'HGF',
#   'AVPR1A',
#   'H1-0',
#   'SMAD7',
#   'PTK2',
#   'ISG20',
#   'CCNA1',
#   'BCL2L1',
#   'PPT1',
#   'BIRC3',
#   'BCL2L2',
#   'BCL10',
#   'PRF1',
#   'PSEN1',
#   'ENO2',
#   'FASLG',
#   'PLAT',
#   'PSEN2',
#   'SAT1',
#   'PPP3R1',
#   'LGALS3',
#   'EBP',
#   'ANKH',
#   'FDXR',
#   'HMOX1',
#   'PMAIP1',
#   'BMF',
#   'TNFSF10',
#   'CD14',
#   'IER3',
#   'DNM1L',
#   'GPX1',
#   'ANXA1',
#   'GPX3',
#   'JUN',
#   'GSTM1',
#   'GPX4',
#   'MMP2',
#   'TNFRSF12A',
#   'CAV1',
#   'CFLAR',
#   'EMP1',
#   'PPP2R5B',
#   'IL18',
#   'RHOB',
#   'TGFBR3',
#   'IL1A',
#   'DNAJC3',
#   'IL1B',
#   'IRF1',
#   'CYLD',
#   'BMP2',
#   'DAP',
#   'IL6',
#   'KRT18',
#   'DPYD',
#   'CDK2',
#   'ETF1',
#   'RARA',
#   'GUCY2D',
#   'BTG3',
#   'BTG2',
#   'DIABLO',
#   'TOP2A',
#   'PEA15',
#   'BRCA1',
#   'NEDD9',
#   'HMGB2',
#   'HSPB1',
#   'CASP8',
#   'CASP9',
#   'RHOT2',
#   'CASP6',
#   'CASP7',
#   'CASP4',
#   'ERBB2',
#   'ERBB3',
#   'CASP2',
#   'TIMP3',
#   'CASP3',
#   'CD38',
#   'TIMP1',
#   'CASP1',
#   'TIMP2',
#   'MCL1',
#   'BCAP31',
#   'DFFA',
#   'IFNGR1',
#   'MGMT',
#   'GCH1',
#   'BGN',
#   'F2',
#   'SOD1',
#   'DCN',
#   'SOD2',
#   'DNAJA1',
#   'WEE1',
#   'XIAP',
#   'TXNIP',
#   'DDIT3',
#   'VDAC2',
#   'PLCB2',
#   'CD44',
#   'CDKN1B',
#   'RNASEL',
#   'CDKN1A',
#   'PLPPR4',
#   'CTNNB1',
#   'SLC20A1',
#   'ADD1',
#   'GNA15',
#   'AIFM3',
#   'IFNB1',
#   'TSPO',
#   'NEFH',
#   'SPTAN1',
#   'BID'],
#  'Notch Signaling': ['FZD1',
#   'PSENEN',
#   'JAG1',
#   'TCF7L2',
#   'FBXW11',
#   'FZD5',
#   'WNT5A',
#   'FZD7',
#   'PRKCA',
#   'HEYL',
#   'RBX1',
#   'SAP30',
#   'KAT2A',
#   'PPARD',
#   'NOTCH3',
#   'NOTCH1',
#   'NOTCH2',
#   'MAML2',
#   'DTX1',
#   'CUL1',
#   'DTX2',
#   'DTX4',
#   'PSEN2',
#   'DLL1',
#   'APH1A',
#   'LFNG',
#   'ARRB1',
#   'CCND1',
#   'ST3GAL6',
#   'HES1',
#   'WNT2',
#   'SKP1'],
#  'Adipogenesis': ['ECH1',
#   'CIDEA',
#   'PEX14',
#   'LEP',
#   'UQCRC1',
#   'SPARCL1',
#   'PREB',
#   'SUCLG1',
#   'ITIH5',
#   'RETSAT',
#   'UQCR10',
#   'GHITM',
#   'RETN',
#   'ARAF',
#   'UQCR11',
#   'TOB1',
#   'ADCY6',
#   'SLC5A6',
#   'SNCG',
#   'STOM',
#   'COX8A',
#   'FZD4',
#   'ABCA1',
#   'OMD',
#   'GADD45A',
#   'TALDO1',
#   'RMDN3',
#   'CMBL',
#   'POR',
#   'UCK1',
#   'SSPN',
#   'CD302',
#   'PEMT',
#   'NMT1',
#   'ITSN1',
#   'BAZ2A',
#   'MGST3',
#   'MRPL15',
#   'MYLK',
#   'C3',
#   'PRDX3',
#   'SULT1A1',
#   'LIPE',
#   'GRPEL1',
#   'SCP2',
#   'APOE',
#   'SLC19A1',
#   'DECR1',
#   'STAT5A',
#   'CS',
#   'VEGFB',
#   'CCNG2',
#   'MRAP',
#   'ALDOA',
#   'MGLL',
#   'COX7B',
#   'MTARC2',
#   'ADIPOR2',
#   'ECHS1',
#   'NKIRAS1',
#   'CD36',
#   'ADIG',
#   'ADIPOQ',
#   'MAP4K3',
#   'CDKN2C',
#   'IFNGR1',
#   'MDH2',
#   'DGAT1',
#   'ELOVL6',
#   'ELMOD3',
#   'MCCC1',
#   'SQOR',
#   'SORBS1',
#   'DHRS7',
#   'COL4A1',
#   'FABP4',
#   'ESYT1',
#   'GPAM',
#   'NDUFAB1',
#   'LPCAT3',
#   'ANGPTL4',
#   'ATP5PO',
#   'PPARG',
#   'DLD',
#   'PLIN2',
#   'TKT',
#   'CMPK1',
#   'ORM1',
#   'SLC66A3',
#   'ATL2',
#   'PTGER3',
#   'GBE1',
#   'SAMM50',
#   'ACADM',
#   'ACADL',
#   'AIFM1',
#   'ENPP2',
#   'DLAT',
#   'GPAT4',
#   'RIOK3',
#   'ACADS',
#   'CAVIN1',
#   'PHYH',
#   'PTCD3',
#   'CAVIN2',
#   'APLP2',
#   'ATP1B3',
#   'LIFR',
#   'SDHB',
#   'FAH',
#   'SDHC',
#   'RAB34',
#   'UQCRQ',
#   'GPD2',
#   'PDCD4',
#   'DHCR7',
#   'CRAT',
#   'PPP1R15B',
#   'PHLDB1',
#   'SLC27A1',
#   'UCP2',
#   'SLC1A5',
#   'TANK',
#   'COX6A1',
#   'BCL2L13',
#   'ESRRA',
#   'IDH1',
#   'NABP1',
#   'EPHX2',
#   'CHCHD10',
#   'DNAJC15',
#   'ACLY',
#   'QDPR',
#   'REEP6',
#   'REEP5',
#   'PFKFB3',
#   'CD151',
#   'LPL',
#   'AK2',
#   'UBC',
#   'G3BP2',
#   'PIM3',
#   'ACAA2',
#   'CYC1',
#   'HADH',
#   'BCKDHA',
#   'GPX3',
#   'JAGN1',
#   'ANGPT1',
#   'GPX4',
#   'COQ9',
#   'COQ5',
#   'COQ3',
#   'BCL6',
#   'ACOX1',
#   'NDUFS3',
#   'ACO2',
#   'ITGA7',
#   'ARL4A',
#   'RTN3',
#   'SLC25A1',
#   'YWHAG',
#   'NDUFB7',
#   'ABCB8',
#   'HSPB8',
#   'DHRS7B',
#   'AGPAT3',
#   'DRAM2',
#   'DBT',
#   'CPT2',
#   'ME1',
#   'DNAJB9',
#   'RREB1',
#   'HIBCH',
#   'IDH3G',
#   'MIGA2',
#   'CHUK',
#   'NDUFA5',
#   'CYP4B1',
#   'IMMT',
#   'SOD1',
#   'PPM1B',
#   'PFKL',
#   'CAT',
#   'TST',
#   'SLC25A10',
#   'MTCH2',
#   'RNF11',
#   'SOWAHC',
#   'COL15A1',
#   'LAMA4',
#   'ETFB',
#   'GPHN',
#   'LTC4S',
#   'DDT',
#   'ALDH2',
#   'UBQLN1',
#   'IDH3A',
#   'SCARB1',
#   'PGM1'],
#  'Estrogen Response Early': ['TTC39A',
#   'AMFR',
#   'KRT8',
#   'MED13L',
#   'GLA',
#   'NBL1',
#   'RETREG1',
#   'AKAP1',
#   'ADCY1',
#   'PEX11A',
#   'ADCY9',
#   'AQP3',
#   'ABAT',
#   'TOB1',
#   'MUC1',
#   'MYB',
#   'MYC',
#   'CCN5',
#   'HES1',
#   'FDFT1',
#   'ABCA3',
#   'EGR3',
#   'XBP1',
#   'BCL11B',
#   'KLF10',
#   'SIAH2',
#   'PLAAT3',
#   'CBFA2T3',
#   'OVOL2',
#   'PDZK1',
#   'IL17RB',
#   'AR',
#   'SULT2B1',
#   'FASN',
#   'UNC119',
#   'PTGES',
#   'SLC22A5',
#   'RAPGEFL1',
#   'TSKU',
#   'SOX3',
#   'GJA1',
#   'INPP5F',
#   'SFN',
#   'MYBL1',
#   'SLC19A2',
#   'GREB1',
#   'ITPK1',
#   'MYOF',
#   'GAB2',
#   'KRT13',
#   'FAM102A',
#   'KLK10',
#   'RHOD',
#   'SLC7A5',
#   'KRT19',
#   'NCOR2',
#   'TUBB2B',
#   'KRT18',
#   'MAPT',
#   'MPPED2',
#   'BHLHE40',
#   'KRT15',
#   'TFF3',
#   'RARA',
#   'TFF1',
#   'RET',
#   'FOXC1',
#   'ABHD2',
#   'ENDOD1',
#   'STC2',
#   'TMPRSS3',
#   'AREG',
#   'SLC7A2',
#   'TMEM164',
#   'UGCG',
#   'SEC14L2',
#   'CLIC3',
#   'ELOVL2',
#   'SVIL',
#   'ELOVL5',
#   'FOS',
#   'SNX24',
#   'GFRA1',
#   'DHRS2',
#   'DHRS3',
#   'FARP1',
#   'MYBBP1A',
#   'DLC1',
#   'CD44',
#   'TJP3',
#   'LAD1',
#   'PRSS23',
#   'OLFML3',
#   'TBC1D30',
#   'ANXA9',
#   'RRP12',
#   'DEPTOR',
#   'JAK2',
#   'CA12',
#   'TFAP2C',
#   'MREG',
#   'SLC16A1',
#   'NPY1R',
#   'KAZN',
#   'OLFM1',
#   'CXCL12',
#   'RAB31',
#   'PPIF',
#   'IL6ST',
#   'DHCR7',
#   'FKBP5',
#   'FKBP4',
#   'FRK',
#   'SLC27A2',
#   'CELSR1',
#   'SLC1A1',
#   'SCNN1A',
#   'HR',
#   'SLC1A4',
#   'ASB13',
#   'CELSR2',
#   'PAPSS2',
#   'ABLIM1',
#   'CCND1',
#   'FLNB',
#   'SH3BP5',
#   'SLC39A6',
#   'RBBP8',
#   'MICB',
#   'OPN3',
#   'TGIF2',
#   'WFS1',
#   'CISH',
#   'IGFBP4',
#   'INHBB',
#   'SLC9A3R1',
#   'MED24',
#   'REEP1',
#   'PGR',
#   'BLVRB',
#   'FCMR',
#   'SLC26A2',
#   'WWC1',
#   'MINDY1',
#   'SLC2A1',
#   'ARL3',
#   'ISG20L2',
#   'IGF1R',
#   'RHOBTB3',
#   'TGM2',
#   'CALCR',
#   'RASGRP1',
#   'PODXL',
#   'BAG1',
#   'ALDH3B1',
#   'PMAIP1',
#   'SYBU',
#   'SLC37A1',
#   'KDM4B',
#   'TIPARP',
#   'NAV2',
#   'ELF1',
#   'ELF3',
#   'CHPT1',
#   'ESRP2',
#   'BCL2',
#   'KCNK5',
#   'B4GALT1',
#   'MAST4',
#   'HSPB8',
#   'AFF1',
#   'SYNGR1',
#   'CALB2',
#   'CYP26B1',
#   'PDLIM3',
#   'NRIP1',
#   'P2RY2',
#   'ZNF185',
#   'DYNLT3',
#   'TPBG',
#   'KCNK15',
#   'KLF4',
#   'TIAM1',
#   'TPD52L1',
#   'CLDN7',
#   'MLPH',
#   'SYT12',
#   'RAB17',
#   'SLC24A3',
#   'CANT1',
#   'NXT1',
#   'SEMA3B',
#   'FHL2',
#   'ADD3',
#   'NADSYN1',
#   'THSD4',
#   'RPS6KA2',
#   'LRIG1',
#   'MSMB',
#   'SCARB1'],
#  'Estrogen Response Late': ['UNC13B',
#   'HOMER2',
#   'CACNA2D2',
#   'AMFR',
#   'MAPK13',
#   'CDC20',
#   'ASS1',
#   'CD9',
#   'GLA',
#   'KIF20A',
#   'NBL1',
#   'TOB1',
#   'ASCL1',
#   'MYB',
#   'CCN5',
#   'MEST',
#   'FDFT1',
#   'ABCA3',
#   'PLK4',
#   'EGR3',
#   'CHST8',
#   'XBP1',
#   'ST14',
#   'TNNC1',
#   'XRCC3',
#   'SIAH2',
#   'PLAAT3',
#   'OVOL2',
#   'PDZK1',
#   'IL17RB',
#   'SULT2B1',
#   'GJB3',
#   'IGSF1',
#   'HPRT1',
#   'PTGES',
#   'HSPA4L',
#   'SLC22A5',
#   'TSTA3',
#   'RAPGEFL1',
#   'SOX3',
#   'PRKAR2B',
#   'PLAC1',
#   'SFN',
#   'TPSAB1',
#   'DUSP2',
#   'ITPK1',
#   'MYOF',
#   'EMP2',
#   'KRT13',
#   'CDC6',
#   'FAM102A',
#   'KLK10',
#   'COX6C',
#   'KLK11',
#   'SLC7A5',
#   'UGDH',
#   'KRT19',
#   'NCOR2',
#   'TH',
#   'MAPT',
#   'NMU',
#   'ID2',
#   'TFF3',
#   'TFF1',
#   'MOCS2',
#   'SGK1',
#   'SERPINA3',
#   'RET',
#   'BTG3',
#   'SERPINA1',
#   'FOXC1',
#   'ABHD2',
#   'TOP2A',
#   'TMPRSS3',
#   'AREG',
#   'SERPINA5',
#   'CLIC3',
#   'ELOVL5',
#   'METTL3',
#   'FOS',
#   'DHRS2',
#   'FARP1',
#   'GAL',
#   'FABP5',
#   'SLC29A1',
#   'LLGL2',
#   'CD44',
#   'TJP3',
#   'PTGER3',
#   'PRSS23',
#   'SNX10',
#   'IMPA2',
#   'CKB',
#   'ANXA9',
#   'AGR2',
#   'JAK1',
#   'JAK2',
#   'GINS2',
#   'CA12',
#   'TFAP2C',
#   'PRLR',
#   'SLC16A1',
#   'TFPI2',
#   'NPY1R',
#   'BATF',
#   'OLFM1',
#   'CXCL12',
#   'RAB31',
#   'PCP4',
#   'PKP3',
#   'PDCD4',
#   'PPIF',
#   'IL6ST',
#   'PLXNB1',
#   'DHCR7',
#   'FKBP5',
#   'FKBP4',
#   'PTPN6',
#   'S100A9',
#   'FRK',
#   'SLC27A2',
#   'SCNN1A',
#   'HR',
#   'SLC1A4',
#   'CELSR2',
#   'CXCL14',
#   'PAPSS2',
#   'SCUBE2',
#   'ZFP36',
#   'CCND1',
#   'CDH1',
#   'PERP',
#   'FLNB',
#   'RBBP8',
#   'MICB',
#   'OPN3',
#   'WFS1',
#   'CISH',
#   'STIL',
#   'IDH2',
#   'IGFBP4',
#   'DNAJC12',
#   'CYP4F11',
#   'SLC9A3R1',
#   'ALDH3A2',
#   'ISG20',
#   'CCNA1',
#   'DLG5',
#   'PGR',
#   'RNASEH2A',
#   'BLVRB',
#   'FGFR3',
#   'SLC26A2',
#   'NAB2',
#   'ARL3',
#   'SLC2A8',
#   'CALCR',
#   'BAG1',
#   'ALDH3B1',
#   'HMGCS2',
#   'CAV1',
#   'SORD',
#   'RABEP1',
#   'DNAJC1',
#   'ACOX2',
#   'CHPT1',
#   'CPE',
#   'BCL2',
#   'KCNK5',
#   'ST6GALNAC2',
#   'HSPB8',
#   'LAMC2',
#   'AFF1',
#   'CA2',
#   'MDK',
#   'CYP26B1',
#   'PDLIM3',
#   'NRIP1',
#   'GPER1',
#   'DYNLT3',
#   'DCXR',
#   'TPBG',
#   'ATP2B4',
#   'LSR',
#   'KLF4',
#   'TIAM1',
#   'TPD52L1',
#   'GALE',
#   'TST',
#   'LTF',
#   'SLC24A3',
#   'NXT1',
#   'SEMA3B',
#   'ETFB',
#   'TSPAN13',
#   'ADD3',
#   'TRIM29',
#   'RPS6KA2',
#   'SCARB1',
#   'LARGE1'],
#  'Androgen Response': ['UBE2I',
#   'GUCY1A1',
#   'ACSL3',
#   'GSR',
#   'HOMER2',
#   'ACTN1',
#   'KRT8',
#   'ZBTB10',
#   'LIFR',
#   'SELENOP',
#   'SCD',
#   'AZGP1',
#   'GPD1L',
#   'FKBP5',
#   'SEC24D',
#   'HPGD',
#   'NDRG1',
#   'SPDEF',
#   'CCND3',
#   'HERC3',
#   'ZMIZ1',
#   'CCND1',
#   'AKT1',
#   'B2M',
#   'SLC38A2',
#   'TMEM50A',
#   'XRCC5',
#   'XRCC6',
#   'ARID5B',
#   'H1-0',
#   'ELL2',
#   'PIAS1',
#   'INPP4B',
#   'MAF',
#   'MYL12A',
#   'APPBP2',
#   'MAK',
#   'SMS',
#   'PLPP1',
#   'SRP19',
#   'SLC26A2',
#   'NGLY1',
#   'INSIG1',
#   'SAT1',
#   'CDC14B',
#   'UBE2J1',
#   'ELK4',
#   'PMEPA1',
#   'ANKH',
#   'NKX3-1',
#   'RAB4A',
#   'ABCC4',
#   'HMGCS1',
#   'TSC22D1',
#   'NCOA4',
#   'PA2G4',
#   'DHCR24',
#   'SORD',
#   'MERTK',
#   'KRT19',
#   'CDK6',
#   'CENPN',
#   'BMPR1B',
#   'SGK1',
#   'IDI1',
#   'B4GALT1',
#   'KLK2',
#   'TNFAIP8',
#   'ABHD2',
#   'PTPN21',
#   'TMPRSS2',
#   'DBI',
#   'IQGAP2',
#   'KLK3',
#   'UAP1',
#   'STK39',
#   'MAP7',
#   'DNAJB9',
#   'PDLIM5',
#   'TPD52',
#   'ELOVL5',
#   'ADRM1',
#   'SPCS3',
#   'VAPA',
#   'ALDH1A3',
#   'STEAP4',
#   'SRF',
#   'HMGCR',
#   'HSD17B14',
#   'CAMKK2',
#   'GNAI3',
#   'LMAN1',
#   'AKAP12',
#   'ADAMTS1',
#   'RPS6KA3',
#   'PTK2B',
#   'PGM3',
#   'RRP12',
#   'ITGAV',
#   'FADS1'],
#  'Myogenesis': ['IFRD1',
#   'ACTN3',
#   'ACSL1',
#   'ACTN2',
#   'DES',
#   'COL1A1',
#   'MAPK12',
#   'MYL7',
#   'PC',
#   'SCD',
#   'MYL1',
#   'MYL2',
#   'PPP1R3C',
#   'MYL3',
#   'MYL4',
#   'APP',
#   'RB1',
#   'TAGLN',
#   'VIPR1',
#   'ADCY9',
#   'SPDEF',
#   'AKT2',
#   'SH3BGR',
#   'WWTR1',
#   'DTNA',
#   'GABARAPL2',
#   'DMPK',
#   'ATP6AP1',
#   'GADD45B',
#   'TNNC1',
#   'TNNC2',
#   'IGF1',
#   'OCEL1',
#   'PTP4A3',
#   'SLC6A8',
#   'MYLPF',
#   'TNNT1',
#   'SMTN',
#   'TNNT2',
#   'BIN1',
#   'TNNT3',
#   'PKIA',
#   'SSPN',
#   'CRYAB',
#   'CFD',
#   'SPARC',
#   'SCHIP1',
#   'ENO3',
#   'MYLK',
#   'GJA5',
#   'APOD',
#   'MYBPC3',
#   'MYOG',
#   'SPHK1',
#   'SIRT2',
#   'FXYD1',
#   'MRAS',
#   'COL3A1',
#   'BHLHE40',
#   'HRC',
#   'ACHE',
#   'FLII',
#   'STC2',
#   'AEBP1',
#   'CSRP3',
#   'ANKRD2',
#   'CD36',
#   'TEAD4',
#   'NQO1',
#   'MEF2A',
#   'MEF2D',
#   'SVIL',
#   'MEF2C',
#   'PGAM2',
#   'PICK1',
#   'GAA',
#   'ADAM12',
#   'SORBS1',
#   'SORBS3',
#   'MYBPH',
#   'FKBP1B',
#   'FABP3',
#   'COL4A2',
#   'RIT1',
#   'TCAP',
#   'HBEGF',
#   'MAPRE3',
#   'RYR1',
#   'CTF1',
#   'CDKN1A',
#   'PYGM',
#   'CHRNG',
#   'CKB',
#   'DMD',
#   'SPTAN1',
#   'MYOZ1',
#   'GSN',
#   'TGFB1',
#   'AGL',
#   'CKM',
#   'TPM3',
#   'TPM2',
#   'TSC2',
#   'APLNR',
#   'PLXNB2',
#   'CHRNB1',
#   'CRAT',
#   'AGRN',
#   'CHRNA1',
#   'CLU',
#   'COX6A2',
#   'FOXO4',
#   'ABLIM1',
#   'SLN',
#   'SH2B1',
#   'MYH11',
#   'KCNH1',
#   'PPFIA4',
#   'KCNH2',
#   'FDPS',
#   'PRNP',
#   'DENND2B',
#   'FST',
#   'IGFBP3',
#   'REEP1',
#   'KIFC3',
#   'COL6A3',
#   'COL6A2',
#   'CDH13',
#   'CASQ1',
#   'CASQ2',
#   'MYF6',
#   'PVALB',
#   'MYOM1',
#   'MYOM2',
#   'NOTCH1',
#   'AK1',
#   'PSEN2',
#   'COX7A1',
#   'FGF2',
#   'MYL6B',
#   'CACNA1H',
#   'CNN3',
#   'BAG1',
#   'IGFBP7',
#   'GPX3',
#   'CAV3',
#   'NAV2',
#   'MYH1',
#   'MYH2',
#   'ACTA1',
#   'MYH3',
#   'LPIN1',
#   'MYH4',
#   'GNAO1',
#   'MYH9',
#   'ITGA7',
#   'MYH7',
#   'MYH8',
#   'NCAM1',
#   'HSPB8',
#   'HSPB2',
#   'SYNGR2',
#   'MB',
#   'ERBB3',
#   'BDKRB2',
#   'PDLIM7',
#   'PTGIS',
#   'DAPK2',
#   'PDE4DIP',
#   'KLF5',
#   'SOD3',
#   'TPD52L1',
#   'MYO1C',
#   'PFKM',
#   'HDAC5',
#   'EIF4A2',
#   'ITGB1',
#   'LSP1',
#   'COL15A1',
#   'ITGB5',
#   'LAMA2',
#   'FHL1',
#   'ITGB4',
#   'CAMK2B',
#   'ATP2A1',
#   'LDB3',
#   'ACTC1',
#   'EFS',
#   'CKMT2',
#   'SGCG',
#   'SGCD',
#   'SGCA',
#   'SPEG',
#   'TNNI2',
#   'CACNG1',
#   'NOS1',
#   'EPHB3',
#   'LARGE1',
#   'TNNI1'],
#  'Protein Secretion': ['ARFGEF2',
#   'ARFGEF1',
#   'RAB2A',
#   'CAV2',
#   'YIPF6',
#   'OCRL',
#   'AP3B1',
#   'SCAMP1',
#   'SCAMP3',
#   'ZW10',
#   'KRT18',
#   'TMX1',
#   'RER1',
#   'ANP32E',
#   'GLA',
#   'PAM',
#   'ERGIC3',
#   'SEC24D',
#   'COPE',
#   'STX16',
#   'TMED10',
#   'ARF1',
#   'SGMS1',
#   'SNAP23',
#   'NAPA',
#   'VPS4B',
#   'CLTC',
#   'CLTA',
#   'ATP1A1',
#   'EGFR',
#   'NAPG',
#   'STX12',
#   'SNX2',
#   'LAMP2',
#   'STX7',
#   'AP2S1',
#   'TMED2',
#   'YKT6',
#   'ARFIP1',
#   'KIF1B',
#   'CTSC',
#   'IGF2R',
#   'MON2',
#   'TPD52',
#   'ABCA1',
#   'GBF1',
#   'DST',
#   'AP2B1',
#   'COG2',
#   'M6PR',
#   'ADAM10',
#   'STAM',
#   'ARCN1',
#   'SOD1',
#   'ARFGAP3',
#   'GALC',
#   'VAMP7',
#   'DOP1A',
#   'RAB14',
#   'TOM1L1',
#   'RAB9A',
#   'USO1',
#   'VPS45',
#   'GNAS',
#   'PPT1',
#   'SSPN',
#   'RAB5A',
#   'SEC22B',
#   'ATP6V1B1',
#   'VAMP3',
#   'VAMP4',
#   'BET1',
#   'TSG101',
#   'CD63',
#   'COPB2',
#   'COPB1',
#   'GOSR2',
#   'ICA1',
#   'CLCN3',
#   'RAB22A',
#   'CLN5',
#   'LMAN1',
#   'GOLGA4',
#   'AP1G1',
#   'SCRN1',
#   'RPS6KA3',
#   'TSPAN8',
#   'AP3S1',
#   'BNIP3',
#   'MAPK1',
#   'SEC31A',
#   'ATP7A',
#   'ATP6V1H',
#   'AP2M1',
#   'DNM1L',
#   'SH3GL2'],
#  'Interferon Alpha Response': ['CD74',
#   'IL4R',
#   'MX1',
#   'SP110',
#   'RSAD2',
#   'TAP1',
#   'PSMB9',
#   'CXCL10',
#   'CXCL11',
#   'IFI44L',
#   'LAP3',
#   'LPAR6',
#   'IFI27',
#   'TRAFD1',
#   'LY6E',
#   'TRIM14',
#   'IFITM2',
#   'IFITM3',
#   'SAMD9',
#   'CSF1',
#   'IFITM1',
#   'SAMD9L',
#   'UBE2L6',
#   'RNF31',
#   'HERC6',
#   'LAMP3',
#   'CCRL2',
#   'MVB12A',
#   'B2M',
#   'CMTR1',
#   'GBP2',
#   'EPSTI1',
#   'GBP4',
#   'BATF2',
#   'HLA-C',
#   'TENT5A',
#   'ISG15',
#   'TDRD7',
#   'IFI44',
#   'PARP14',
#   'MOV10',
#   'ISG20',
#   'PARP12',
#   'PLSCR1',
#   'PROCR',
#   'SELL',
#   'PSME2',
#   'PSME1',
#   'CNP',
#   'LGALS3BP',
#   'IFI35',
#   'IFIT2',
#   'IFI30',
#   'DDX60',
#   'IFIT3',
#   'HELZ2',
#   'NUB1',
#   'PNPT1',
#   'IL15',
#   'NCOA7',
#   'EIF2AK2',
#   'NMI',
#   'OAS1',
#   'BST2',
#   'ELF1',
#   'IRF1',
#   'IL7',
#   'IRF2',
#   'IRF9',
#   'IRF7',
#   'UBA7',
#   'GMPR',
#   'ADAR',
#   'CASP8',
#   'TRIM5',
#   'RIPK2',
#   'CASP1',
#   'STAT2',
#   'WARS1',
#   'PARP9',
#   'PSMA3',
#   'CMPK2',
#   'TXNIP',
#   'CD47',
#   'RTP4',
#   'C1S',
#   'OGFR',
#   'TMEM140',
#   'USP18',
#   'OASL',
#   'SLC25A28',
#   'IFIH1',
#   'PSMB8',
#   'DHX58',
#   'TRIM25',
#   'TRIM26',
#   'TRIM21'],
#  'Interferon Gamma Response': ['GBP6',
#   'MX1',
#   'SP110',
#   'MX2',
#   'RSAD2',
#   'PSMB9',
#   'PML',
#   'NUP93',
#   'LAP3',
#   'MTHFD2',
#   'IFI27',
#   'TRIM14',
#   'RBCK1',
#   'IDO1',
#   'IFITM2',
#   'IFITM3',
#   'FGL2',
#   'NOD1',
#   'UBE2L6',
#   'PSMB10',
#   'APOL6',
#   'HERC6',
#   'PNP',
#   'ST3GAL5',
#   'SLAMF7',
#   'B2M',
#   'EPSTI1',
#   'GBP4',
#   'BATF2',
#   'ST8SIA4',
#   'PLA2G4A',
#   'HLA-A',
#   'HLA-B',
#   'HLA-G',
#   'IFI44',
#   'PARP14',
#   'LATS2',
#   'PARP12',
#   'PLSCR1',
#   'VAMP8',
#   'BANK1',
#   'PSME2',
#   'SERPING1',
#   'PSME1',
#   'SSPN',
#   'VAMP5',
#   'CFB',
#   'HLA-DRB1',
#   'CFH',
#   'IFI35',
#   'HIF1A',
#   'IFIT2',
#   'IFI30',
#   'IFIT1',
#   'ICAM1',
#   'IFIT3',
#   'RNF213',
#   'HELZ2',
#   'MT2A',
#   'KLRK1',
#   'TNFSF10',
#   'CMKLR1',
#   'GPR18',
#   'NCOA3',
#   'PNPT1',
#   'IL15',
#   'IL10RA',
#   'NMI',
#   'BST2',
#   'RAPGEF6',
#   'IL18BP',
#   'CD40',
#   'BTG1',
#   'SECTM1',
#   'FPR1',
#   'SOCS3',
#   'SOCS1',
#   'CD38',
#   'RIPK2',
#   'RIPK1',
#   'HLA-DQA1',
#   'P2RY14',
#   'STAT1',
#   'GCH1',
#   'STAT2',
#   'STAT3',
#   'STAT4',
#   'PSMA2',
#   'PSMA3',
#   'CMPK2',
#   'PELI1',
#   'MARCHF1',
#   'CDKN1A',
#   'OGFR',
#   'PTGS2',
#   'IFIH1',
#   'PSMB8',
#   'NAMPT',
#   'PSMB2',
#   'METTL7B',
#   'HLA-DMA',
#   'JAK2',
#   'PTPN1',
#   'PTPN2',
#   'ZBP1',
#   'CD74',
#   'IL4R',
#   'TOR1B',
#   'TAP1',
#   'VCAM1',
#   'CXCL10',
#   'CXCL11',
#   'IFI44L',
#   'ZNFX1',
#   'FAS',
#   'TRAFD1',
#   'LY6E',
#   'CD69',
#   'PTPN6',
#   'CD86',
#   'SAMD9L',
#   'RNF31',
#   'CMTR1',
#   'DDX58',
#   'AUTS2',
#   'ARID5B',
#   'ISG15',
#   'TDRD7',
#   'NFKB1',
#   'ISG20',
#   'MYD88',
#   'SELP',
#   'XAF1',
#   'IFNAR2',
#   'CD274',
#   'LGALS3BP',
#   'SPPL2A',
#   'CSF2RB',
#   'DDX60',
#   'PIM1',
#   'EIF2AK2',
#   'XCL1',
#   'TAPBP',
#   'IRF1',
#   'NFKBIA',
#   'IL7',
#   'IL6',
#   'IRF4',
#   'OAS2',
#   'IRF5',
#   'OAS3',
#   'IRF2',
#   'IRF8',
#   'IRF9',
#   'IRF7',
#   'LCP2',
#   'EIF4E3',
#   'ARL4A',
#   'CXCL9',
#   'TNFAIP6',
#   'TNFAIP3',
#   'NLRC5',
#   'TNFAIP2',
#   'ADAR',
#   'CASP8',
#   'CASP7',
#   'CASP4',
#   'CASP3',
#   'ISOC1',
#   'PDE4B',
#   'CASP1',
#   'CIITA',
#   'IL15RA',
#   'GZMA',
#   'LYSMD2',
#   'BPGM',
#   'WARS1',
#   'SOD2',
#   'IL2RB',
#   'TXNIP',
#   'PFKP',
#   'C1R',
#   'RTP4',
#   'C1S',
#   'MVP',
#   'SRI',
#   'USP18',
#   'OASL',
#   'SAMHD1',
#   'SLC25A28',
#   'FCGR1A',
#   'CCL7',
#   'DHX58',
#   'CCL5',
#   'TRIM25',
#   'TRIM26',
#   'CCL2',
#   'ITGB7',
#   'TRIM21',
#   'UPP1'],
#  'Apical Junction': ['GAMT',
#   'ACTN4',
#   'CADM2',
#   'ACTN3',
#   'CADM3',
#   'ACTN2',
#   'ACTN1',
#   'MAPK13',
#   'MAPK14',
#   'MAPK11',
#   'CD209',
#   'COL9A1',
#   'MYL9',
#   'PFN1',
#   'SKAP2',
#   'MYL12B',
#   'PARD6G',
#   'ACTB',
#   'TIAL1',
#   'AKT3',
#   'AKT2',
#   'FYB1',
#   'TUBG1',
#   'ALOX15B',
#   'PBX2',
#   'PTK2',
#   'VASP',
#   'WNK4',
#   'GRB7',
#   'DMP1',
#   'ICAM4',
#   'ICAM5',
#   'ICAM1',
#   'ICAM2',
#   'EPB41L2',
#   'DHX16',
#   'PLCG1',
#   'TSPAN4',
#   'TMEM8B',
#   'CDSN',
#   'JUP',
#   'RHOF',
#   'VAV2',
#   'CLDN11',
#   'PTPRC',
#   'CLDN15',
#   'CLDN14',
#   'CLDN19',
#   'EXOC4',
#   'CLDN18',
#   'ARHGEF6',
#   'SDC3',
#   'TNFRSF11B',
#   'THY1',
#   'CX3CL1',
#   'RRAS',
#   'MPZL1',
#   'RSU1',
#   'MAP3K20',
#   'CD34',
#   'MPZL2',
#   'MAP4K2',
#   'CAP1',
#   'MPP5',
#   'SYK',
#   'SORBS3',
#   'LIMA1',
#   'TJP1',
#   'ADAM15',
#   'TAOK2',
#   'CRB3',
#   'AMIGO1',
#   'AMIGO2',
#   'ADAM23',
#   'WASL',
#   'GNAI1',
#   'GNAI2',
#   'CTNNA1',
#   'HRAS',
#   'LDLRAP1',
#   'RAC2',
#   'IKBKG',
#   'GTF2F1',
#   'TSC1',
#   'VCAM1',
#   'ITGA10',
#   'TGFBI',
#   'ZYX',
#   'ADAM9',
#   'DSC1',
#   'CRAT',
#   'DSC3',
#   'CNTN1',
#   'CD86',
#   'COL16A1',
#   'CTNND1',
#   'NEXN',
#   'ATP1A3',
#   'INPPL1',
#   'EGFR',
#   'CDH8',
#   'CDH6',
#   'CDH4',
#   'CDH3',
#   'CDH1',
#   'NRAP',
#   'SLIT2',
#   'FLNC',
#   'STX4',
#   'MYH10',
#   'JAM3',
#   'KCNH2',
#   'SLC30A3',
#   'TRAF1',
#   'LAYN',
#   'KRT31',
#   'DLG1',
#   'CDH11',
#   'ARPC2',
#   'FSCN1',
#   'CDH15',
#   'FBN1',
#   'VCL',
#   'CD276',
#   'CD274',
#   'COL17A1',
#   'IRS1',
#   'INSIG1',
#   'ACTG1',
#   'ACTG2',
#   'CNN2',
#   'PDZD3',
#   'SIRPA',
#   'NRTN',
#   'HADH',
#   'CD99',
#   'LAMB3',
#   'MMP2',
#   'ITGA3',
#   'MSN',
#   'ITGA2',
#   'SHROOM2',
#   'MMP9',
#   'BAIAP2',
#   'PARVA',
#   'RASA1',
#   'VCAN',
#   'ACTA1',
#   'CDK8',
#   'BMP1',
#   'PIK3CB',
#   'ITGA9',
#   'MYH9',
#   'NF2',
#   'NF1',
#   'PECAM1',
#   'B4GALT1',
#   'NLGN2',
#   'NLGN3',
#   'SHC1',
#   'NRXN2',
#   'PIK3R3',
#   'LAMC2',
#   'ADRA1B',
#   'TRO',
#   'MDK',
#   'CALB2',
#   'MADCAM1',
#   'SYMPK',
#   'AMH',
#   'YWHAH',
#   'NEGR1',
#   'VWF',
#   'CLDN7',
#   'CLDN6',
#   'CLDN5',
#   'CLDN4',
#   'NFASC',
#   'PPP2R2C',
#   'CLDN9',
#   'CLDN8',
#   'NECTIN1',
#   'CERCAM',
#   'EVL',
#   'MVD',
#   'NECTIN4',
#   'NECTIN3',
#   'NECTIN2',
#   'ITGB1',
#   'PKD1',
#   'SRC',
#   'LAMA3',
#   'ITGB4',
#   'PTEN',
#   'ACTC1',
#   'THBS3',
#   'ADAMTS5',
#   'SGCE',
#   'SPEG',
#   'PCDH1'],
#  'Apical Surface': ['LYN',
#   'SLC34A3',
#   'GSTM3',
#   'AFAP1L2',
#   'NTNG1',
#   'NCOA6',
#   'ATP8B1',
#   'CD160',
#   'ADAM10',
#   'PLAUR',
#   'SHROOM2',
#   'SULF2',
#   'DCBLD2',
#   'RTN4RL1',
#   'GAS1',
#   'IL2RB',
#   'MAL',
#   'GHRL',
#   'RHCG',
#   'APP',
#   'CRYBG1',
#   'SRPX',
#   'B4GALT1',
#   'MDGA1',
#   'CROCC',
#   'LYPD3',
#   'AKAP7',
#   'BRCA1',
#   'PCSK9',
#   'SLC2A4',
#   'IL2RG',
#   'ADIPOR2',
#   'GATA3',
#   'THY1',
#   'CX3CL1',
#   'EFNA5',
#   'HSPB1',
#   'SCUBE1',
#   'PKHD1',
#   'FLOT2',
#   'ATP6V0A4',
#   'TMEM8B',
#   'EPHB4',
#   'SLC22A12'],
#  'Hedgehog Signaling': ['TLE3',
#   'TLE1',
#   'UNC5C',
#   'PTCH1',
#   'VEGFA',
#   'L1CAM',
#   'PML',
#   'RASA1',
#   'CDK6',
#   'MYH9',
#   'NF1',
#   'CDK5R1',
#   'SCG2',
#   'ACHE',
#   'CNTFR',
#   'NRP1',
#   'NRP2',
#   'RTN1',
#   'CELSR1',
#   'LDB1',
#   'CRMP1',
#   'PLG',
#   'THY1',
#   'VLDLR',
#   'ETS2',
#   'GLI1',
#   'AMOT',
#   'DPYSL2',
#   'SHH',
#   'HEY2',
#   'HEY1',
#   'OPHN1',
#   'SLIT1',
#   'NRCAM',
#   'ADGRG1',
#   'NKX6-1'],
#  'Complement': ['ACTN2',
#   'HPCAL4',
#   'PSMB9',
#   'XPNPEP1',
#   'LAP3',
#   'FDX1',
#   'HSPA1A',
#   'CALM3',
#   'PFN1',
#   'CDA',
#   'CALM1',
#   'LRP1',
#   'SERPINE1',
#   'C4BPB',
#   'CBLB',
#   'PRCP',
#   'ITIH1',
#   'RNF4',
#   'GNG2',
#   'S100A13',
#   'SPOCK2',
#   'PRSS3',
#   'S100A12',
#   'APOBEC3F',
#   'APOBEC3G',
#   'PRKCD',
#   'PLA2G4A',
#   'EHD1',
#   'PLSCR1',
#   'LGMN',
#   'SERPING1',
#   'GRB2',
#   'ZFPM2',
#   'CFB',
#   'GMFB',
#   'CFH',
#   'PDGFB',
#   'PREP',
#   'GATA3',
#   'PLA2G7',
#   'C2',
#   'LIPA',
#   'C3',
#   'LGALS3',
#   'PPP4C',
#   'C9',
#   'LTA4H',
#   'CTSB',
#   'DUSP5',
#   'DUSP6',
#   'LYN',
#   'ANXA5',
#   'FN1',
#   'SIRT6',
#   'RHOG',
#   'CP',
#   'RBSN',
#   'GP9',
#   'MMP13',
#   'ZEB1',
#   'MMP12',
#   'MMP15',
#   'MMP14',
#   'KLKB1',
#   'SERPINA1',
#   'TMPRSS6',
#   'KLK1',
#   'PCSK9',
#   'CTSV',
#   'CTSS',
#   'GNGT2',
#   'CTSO',
#   'CSRP1',
#   'CASP10',
#   'CTSL',
#   'HNF4A',
#   'CTSH',
#   'RCE1',
#   'TIMP1',
#   'TIMP2',
#   'CD36',
#   'FCER1G',
#   'CTSD',
#   'CTSC',
#   'SERPINB2',
#   'PRSS36',
#   'F2',
#   'GP1BA',
#   'F3',
#   'RABIF',
#   'F5',
#   'F7',
#   'F8',
#   'PDP1',
#   'COL4A2',
#   'CD40LG',
#   'CDK5R1',
#   'CD46',
#   'MSRB1',
#   'C1QC',
#   'C1QA',
#   'SERPINC1',
#   'WAS',
#   'GNAI2',
#   'GNAI3',
#   'PHEX',
#   'PCLO',
#   'PPP2CB',
#   'CD59',
#   'AKAP10',
#   'OLR1',
#   'CD55',
#   'JAK2',
#   'USP8',
#   'BRPF3',
#   'F10',
#   'GCA',
#   'TFPI2',
#   'GPD2',
#   'ADAM9',
#   'SCG3',
#   'S100A9',
#   'FCN1',
#   'RAF1',
#   'DGKH',
#   'DGKG',
#   'PRDM4',
#   'CLU',
#   'DOCK10',
#   'LAMP2',
#   'STX4',
#   'SH2B3',
#   'ADRA2B',
#   'MAFF',
#   'KIF2A',
#   'GNB2',
#   'CDH13',
#   'GNB4',
#   'NOTCH4',
#   'DOCK4',
#   'DYRK2',
#   'DOCK9',
#   'PSEN1',
#   'PLAT',
#   'VCPIP1',
#   'RASGRP1',
#   'PIM1',
#   'MMP8',
#   'KCNIP2',
#   'HSPA5',
#   'KCNIP3',
#   'MT3',
#   'APOA4',
#   'IRF1',
#   'IL6',
#   'PIK3CA',
#   'IRF2',
#   'IRF7',
#   'LCP2',
#   'CPM',
#   'CPQ',
#   'L3MBTL4',
#   'PIK3R5',
#   'TNFAIP3',
#   'CXCL1',
#   'DPP4',
#   'CA2',
#   'CASP9',
#   'CASP7',
#   'CASP4',
#   'CASP5',
#   'CASP3',
#   'ME1',
#   'CASP1',
#   'CR1',
#   'CR2',
#   'GZMB',
#   'ERAP2',
#   'GZMA',
#   'PLAUR',
#   'ATOX1',
#   'GZMK',
#   'LCK',
#   'APOC1',
#   'ANG',
#   'LTF',
#   'USP14',
#   'CEBPB',
#   'USP15',
#   'C1R',
#   'SRC',
#   'USP16',
#   'PLEK',
#   'C1S',
#   'PLG',
#   'ITGAM',
#   'PIK3CG',
#   'CCL5',
#   'KYNU',
#   'FYN'],
#  'Unfolded Protein Response': ['IMP3',
#   'ZBTB17',
#   'YIF1A',
#   'ERN1',
#   'CNOT6',
#   'DKC1',
#   'MTHFD2',
#   'PSAT1',
#   'CNOT2',
#   'CNOT4',
#   'PREB',
#   'TARS1',
#   'DCP1A',
#   'NHP2',
#   'ATF3',
#   'ATP6V0D1',
#   'GEMIN4',
#   'NOLC1',
#   'PARN',
#   'SLC1A4',
#   'SDAD1',
#   'HSP90B1',
#   'KHSRP',
#   'EXOSC10',
#   'TATDN2',
#   'EXOSC5',
#   'IARS1',
#   'EXOSC9',
#   'KIF5B',
#   'CHAC1',
#   'BANF1',
#   'EXOSC4',
#   'EXOSC2',
#   'EXOSC1',
#   'TTC37',
#   'IGFBP1',
#   'NOP14',
#   'TSPYL2',
#   'XBP1',
#   'WFS1',
#   'EDEM1',
#   'NABP1',
#   'SLC30A5',
#   'LSM1',
#   'EEF2',
#   'EIF2S1',
#   'LSM4',
#   'PDIA6',
#   'PDIA5',
#   'ARFGAP1',
#   'EIF4G1',
#   'SRPRB',
#   'HYOU1',
#   'ATF6',
#   'ATF4',
#   'EIF4EBP1',
#   'POP4',
#   'SRPRA',
#   'IFIT1',
#   'RRP9',
#   'EDC4',
#   'BAG3',
#   'SEC31A',
#   'RPS14',
#   'HSPA9',
#   'FUS',
#   'HSPA5',
#   'ASNS',
#   'EIF2AK3',
#   'WIPI1',
#   'TUBB2A',
#   'VEGFA',
#   'SLC7A5',
#   'DNAJC3',
#   'ALDH18A1',
#   'CALR',
#   'EXOC2',
#   'SHC1',
#   'CKS1B',
#   'STC2',
#   'SSR1',
#   'DNAJB9',
#   'EIF4E',
#   'NPM1',
#   'NFYB',
#   'DDX10',
#   'YWHAZ',
#   'SPCS3',
#   'SPCS1',
#   'XPOT',
#   'DDIT4',
#   'DNAJA4',
#   'KDELR3',
#   'DCP2',
#   'NOP56',
#   'EIF4A3',
#   'CEBPB',
#   'EIF4A2',
#   'H2AX',
#   'EIF4A1',
#   'SEC11A',
#   'ERO1A',
#   'CEBPG',
#   'FKBP14',
#   'GOSR2',
#   'CXXC1',
#   'DCTN1',
#   'HERPUD1',
#   'SERP1',
#   'MTREX',
#   'CCL2',
#   'NFYA',
#   'PAIP1'],
#  'PI3K/AKT/mTOR  Signaling': ['TSC2',
#   'PPP1CA',
#   'MAPK10',
#   'SQSTM1',
#   'PFN1',
#   'RAF1',
#   'UBE2N',
#   'PRKAA2',
#   'RALB',
#   'ATF1',
#   'SLA',
#   'UBE2D3',
#   'NOD1',
#   'ADCY2',
#   'IL2RG',
#   'EGFR',
#   'HSP90B1',
#   'E2F1',
#   'AKT1',
#   'CFL1',
#   'MAP3K7',
#   'PAK4',
#   'PITX2',
#   'FGF22',
#   'SMAD2',
#   'MAP2K3',
#   'PRKCB',
#   'TRAF2',
#   'FGF17',
#   'MYD88',
#   'ARPC3',
#   'CSNK2B',
#   'GRB2',
#   'PIN1',
#   'SLC2A1',
#   'FASLG',
#   'DAPP1',
#   'FGF6',
#   'TBK1',
#   'THEM4',
#   'PRKAR2A',
#   'PLCG1',
#   'SFN',
#   'PDK1',
#   'MAP2K6',
#   'AP2M1',
#   'ACTR3',
#   'ACTR2',
#   'DUSP3',
#   'PTPN11',
#   'IRAK4',
#   'TNFRSF1A',
#   'VAV3',
#   'NFKBIB',
#   'IL4',
#   'ECSIT',
#   'PIKFYVE',
#   'AKT1S1',
#   'CDK4',
#   'CDK2',
#   'CAMK4',
#   'CDK1',
#   'CALR',
#   'GSK3B',
#   'YWHAB',
#   'ARF1',
#   'CAB39L',
#   'MAPKAP1',
#   'CLTC',
#   'ITPR2',
#   'PIK3R3',
#   'ACACA',
#   'GRK2',
#   'GNGT1',
#   'MKNK1',
#   'MKNK2',
#   'RIPK1',
#   'EIF4E',
#   'PLA2G12A',
#   'STAT2',
#   'NGF',
#   'TIAM1',
#   'LCK',
#   'RIT1',
#   'DDIT3',
#   'TRIB3',
#   'PLCB1',
#   'CDKN1B',
#   'CDKN1A',
#   'CAB39',
#   'PTEN',
#   'PRKAG1',
#   'GNA14',
#   'ARHGDIA',
#   'RPTOR',
#   'MAPK9',
#   'MAPK8',
#   'RPS6KA1',
#   'PPP2R1B',
#   'CXCR4',
#   'RPS6KA3',
#   'HRAS',
#   'MAPK1',
#   'RAC1',
#   'NCK1'],
#  'mTORC1 Signaling': ['STARD4',
#   'ACSL3',
#   'IFRD1',
#   'SYTL2',
#   'PPA1',
#   'HSPE1',
#   'CCT6A',
#   'DDX39A',
#   'PSMC6',
#   'SCD',
#   'HMBS',
#   'MTHFD2',
#   'PSMC4',
#   'CD9',
#   'MTHFD2L',
#   'PSMC2',
#   'CTH',
#   'POLR3G',
#   'GLA',
#   'SKAP2',
#   'TES',
#   'NUP205',
#   'FGL2',
#   'CCNF',
#   'ARPC5L',
#   'GLRX',
#   'PNP',
#   'XBP1',
#   'PLK1',
#   'EDEM1',
#   'TUBG1',
#   'DHFR',
#   'UCHL5',
#   'SLC6A6',
#   'SQLE',
#   'MLLT11',
#   'EPRS1',
#   'LGMN',
#   'PSME3',
#   'HPRT1',
#   'NMT1',
#   'TFRC',
#   'PITPNB',
#   'ENO1',
#   'TMEM97',
#   'CFP',
#   'IFI30',
#   'RRP9',
#   'TBK1',
#   'FDXR',
#   'PRDX1',
#   'LTA4H',
#   'PNO1',
#   'SERPINH1',
#   'PDK1',
#   'SDF2L1',
#   'TPI1',
#   'SLC7A5',
#   'P4HA1',
#   'BHLHE40',
#   'CCNG1',
#   'CALR',
#   'ALDOA',
#   'EEF1E1',
#   'GPI',
#   'BTG2',
#   'RPN1',
#   'STC1',
#   'ADIPOR2',
#   'SLC7A11',
#   'VLDLR',
#   'ACACA',
#   'STIP1',
#   'LDHA',
#   'SSR1',
#   'NFIL3',
#   'PHGDH',
#   'CTSC',
#   'EGLN3',
#   'ELOVL5',
#   'ELOVL6',
#   'NFYC',
#   'CACYBP',
#   'GTF2H1',
#   'RPA1',
#   'PSMA4',
#   'PSMA3',
#   'RIT1',
#   'CANX',
#   'USO1',
#   'TCEA1',
#   'TOMM40',
#   'ERO1A',
#   'CDKN1A',
#   'GBE1',
#   'UNG',
#   'PSMB5',
#   'SERP1',
#   'NAMPT',
#   'CXCR4',
#   'FADS2',
#   'FADS1',
#   'G6PD',
#   'GSR',
#   'CDC25A',
#   'PDAP1',
#   'TUBA4A',
#   'COPS5',
#   'PPIA',
#   'NUPR1',
#   'PSAT1',
#   'DHCR7',
#   'SQSTM1',
#   'RAB1A',
#   'FKBP2',
#   'SLA',
#   'UBE2D3',
#   'PPP1R15A',
#   'AURKA',
#   'SLC1A4',
#   'SLC1A5',
#   'PLOD2',
#   'HSP90B1',
#   'GGA2',
#   'SC5D',
#   'YKT6',
#   'LDLR',
#   'ABCF2',
#   'IDH1',
#   'NIBAN1',
#   'MAP2K3',
#   'GOT1',
#   'IGFBP5',
#   'M6PR',
#   'EIF2S2',
#   'SLC9A3R1',
#   'ACLY',
#   'QDPR',
#   'GCLC',
#   'BCAT1',
#   'ATP6V1D',
#   'INSIG1',
#   'SLC2A1',
#   'AK4',
#   'SLC2A3',
#   'CORO1A',
#   'ATP5MC1',
#   'DAPP1',
#   'TM7SF2',
#   'EBP',
#   'SRD5A1',
#   'PSPH',
#   'ACTR3',
#   'CYB5B',
#   'HSPA9',
#   'ACTR2',
#   'HMGCS1',
#   'HSPA5',
#   'TXNRD1',
#   'ASNS',
#   'HSPA4',
#   'DHCR24',
#   'SORD',
#   'NFKBIB',
#   'MCM4',
#   'ETF1',
#   'PSMG1',
#   'MCM2',
#   'IDI1',
#   'GSK3B',
#   'NUFIP1',
#   'PSMD13',
#   'PSMD12',
#   'PSMD14',
#   'SHMT2',
#   'GMPS',
#   'PIK3R3',
#   'HK2',
#   'RDH11',
#   'ME1',
#   'PGK1',
#   'SLC37A4',
#   'RRM2',
#   'CYP51A1',
#   'IMMT',
#   'WARS1',
#   'PFKL',
#   'UFM1',
#   'DDIT4',
#   'DDIT3',
#   'TRIB3',
#   'GAPDH',
#   'ITGB2',
#   'SEC11A',
#   'ATP2A2',
#   'HMGCR',
#   'HSPD1',
#   'ADD3',
#   'BUB1',
#   'PGM1'],
#  'E2F Targets': ['DUT',
#   'H2AZ1',
#   'DEK',
#   'HUS1',
#   'CDC20',
#   'PHF5A',
#   'ZW10',
#   'DDX39A',
#   'MTHFD2',
#   'CCP110',
#   'ANP32E',
#   'ASF1A',
#   'HNRNPD',
#   'ASF1B',
#   'TP53',
#   'RAN',
#   'NUP205',
#   'NOLC1',
#   'PNN',
#   'EXOSC8',
#   'CHEK1',
#   'RACGAP1',
#   'CHEK2',
#   'MYC',
#   'TIPIN',
#   'E2F8',
#   'PLK4',
#   'PLK1',
#   'XRCC6',
#   'TUBG1',
#   'STAG1',
#   'EZH2',
#   'JPT1',
#   'POP7',
#   'CDCA3',
#   'TFRC',
#   'CDCA8',
#   'PRKDC',
#   'SMC6',
#   'SMC4',
#   'GSPT1',
#   'SMC3',
#   'PRDX4',
#   'TMPO',
#   'SYNCRIP',
#   'STMN1',
#   'MYBL2',
#   'BARD1',
#   'TCF19',
#   'TUBB',
#   'NME1',
#   'CENPE',
#   'RAD51C',
#   'CENPM',
#   'DEPDC1',
#   'CDKN3',
#   'SLBP',
#   'SUV39H1',
#   'TOP2A',
#   'BRCA1',
#   'BRCA2',
#   'CTCF',
#   'PSMC3IP',
#   'RAD51AP1',
#   'TK1',
#   'LYAR',
#   'DLGAP5',
#   'ATAD2',
#   'CDKN2C',
#   'HELLS',
#   'MLH1',
#   'CDKN2A',
#   'RANBP1',
#   'RPA2',
#   'RPA3',
#   'RPA1',
#   'CIT',
#   'SPC24',
#   'NUDT21',
#   'CCNE1',
#   'CKS2',
#   'NCAPD2',
#   'TRIP13',
#   'TACC3',
#   'TIMELESS',
#   'RAD1',
#   'SPC25',
#   'H2AX',
#   'CDKN1B',
#   'CDKN1A',
#   'DSCC1',
#   'PRIM2',
#   'MKI67',
#   'UNG',
#   'XPO1',
#   'ING3',
#   'PPP1R8',
#   'GINS3',
#   'GINS1',
#   'LIG1',
#   'GINS4',
#   'CDC25A',
#   'DONSON',
#   'MSH2',
#   'ILF3',
#   'CDC25B',
#   'MELK',
#   'UBE2S',
#   'UBE2T',
#   'BUB1B',
#   'KIF4A',
#   'POLE4',
#   'CNOT9',
#   'MRE11',
#   'MAD2L1',
#   'SNRPB',
#   'PCNA',
#   'DCLRE1B',
#   'SRSF1',
#   'SRSF2',
#   'AURKA',
#   'TBRG4',
#   'AURKB',
#   'PTTG1',
#   'NBN',
#   'CSE1L',
#   'USP1',
#   'RBBP7',
#   'PMS2',
#   'KPNA2',
#   'KIF22',
#   'NUP153',
#   'CTPS1',
#   'NASP',
#   'EIF2S1',
#   'MMS22L',
#   'PAN2',
#   'DIAPH3',
#   'KIF18B',
#   'BIRC5',
#   'KIF2C',
#   'RNASEH2A',
#   'DNMT1',
#   'MXD3',
#   'AK2',
#   'IPO7',
#   'PDS5B',
#   'CCNB2',
#   'PAICS',
#   'CBX5',
#   'RFC2',
#   'RFC3',
#   'RFC1',
#   'PA2G4',
#   'HMGA1',
#   'NAP1L1',
#   'SMC1A',
#   'POLA2',
#   'ESPL1',
#   'CDK4',
#   'BRMS1L',
#   'MCM4',
#   'CDK1',
#   'MCM5',
#   'DCTPP1',
#   'MCM6',
#   'MCM7',
#   'NAA38',
#   'LUC7L3',
#   'MCM2',
#   'MCM3',
#   'SHMT1',
#   'CKS1B',
#   'HMGB3',
#   'HMMR',
#   'LMNB1',
#   'PSIP1',
#   'HMGB2',
#   'ORC6',
#   'RAD21',
#   'ORC2',
#   'UBR7',
#   'LBR',
#   'EED',
#   'RRM2',
#   'SPAG5',
#   'DCK',
#   'SSRP1',
#   'RAD50',
#   'WEE1',
#   'PPM1D',
#   'NOP56',
#   'NUP107',
#   'PRPS1',
#   'WDR90',
#   'POLE',
#   'POLD1',
#   'POLD2',
#   'POLD3',
#   'TRA2B'],
#  'Myc Targets V1': ['SSB',
#   'DUT',
#   'H2AZ1',
#   'IFRD1',
#   'RPL22',
#   'STARD7',
#   'CNBP',
#   'DEK',
#   'MRPS18B',
#   'HSPE1',
#   'CDC20',
#   'PSMC6',
#   'PSMC4',
#   'CLNS1A',
#   'SERBP1',
#   'HNRNPC',
#   'HNRNPD',
#   'RAN',
#   'SF3B3',
#   'HNRNPU',
#   'NOLC1',
#   'HNRNPR',
#   'UBE2L3',
#   'FAM120A',
#   'EXOSC7',
#   'PSMD7',
#   'PSMD8',
#   'IARS1',
#   'SNRPD3',
#   'SNRPD2',
#   'PSMD3',
#   'SNRPD1',
#   'MYC',
#   'PSMD1',
#   'RPL14',
#   'RPL18',
#   'XRCC6',
#   'TOMM70',
#   'SRPK1',
#   'AIMP2',
#   'EPRS1',
#   'RNPS1',
#   'HPRT1',
#   'SET',
#   'RPL6',
#   'PHB2',
#   'PWP1',
#   'RPL34',
#   'PCBP1',
#   'RRP9',
#   'GSPT1',
#   'PRDX4',
#   'PRDX3',
#   'SYNCRIP',
#   'MRPL9',
#   'DHX15',
#   'CSTF2',
#   'RPS10',
#   'PTGES3',
#   'TCP1',
#   'GNL3',
#   'NME1',
#   'MRPL23',
#   'PABPC4',
#   'PABPC1',
#   'LDHA',
#   'C1QBP',
#   'CCT4',
#   'CCT3',
#   'NPM1',
#   'CCT2',
#   'RANBP1',
#   'UBE2E1',
#   'PSMA6',
#   'RSL1D1',
#   'PSMA7',
#   'PSMA4',
#   'HNRNPA2B1',
#   'PSMA2',
#   'XPOT',
#   'NDUFAB1',
#   'APEX1',
#   'PSMA1',
#   'CANX',
#   'PRPF31',
#   'HDGF',
#   'SF3A1',
#   'COX5A',
#   'RPLP0',
#   'XPO1',
#   'PSMB3',
#   'PSMB2',
#   'AP3S1',
#   'RACK1',
#   'CCT7',
#   'CCT5',
#   'TUFM',
#   'EIF1AX',
#   'RPS6',
#   'ILF2',
#   'COPS5',
#   'SNRPA',
#   'PPIA',
#   'POLE3',
#   'SRSF3',
#   'SNRPG',
#   'SRSF7',
#   'TARDBP',
#   'MAD2L1',
#   'NHP2',
#   'HDDC2',
#   'PCNA',
#   'KARS1',
#   'ODC1',
#   'SRSF1',
#   'SRSF2',
#   'TYMS',
#   'FBL',
#   'RUVBL2',
#   'RPS5',
#   'USP1',
#   'RPS2',
#   'RPS3',
#   'TXNL4A',
#   'KPNA2',
#   'NOP16',
#   'GOT2',
#   'LSM2',
#   'CTPS1',
#   'EIF2S2',
#   'EIF2S1',
#   'CCNA2',
#   'TFDP1',
#   'LSM7',
#   'UBA2',
#   'ERH',
#   'EIF4G2',
#   'PHB',
#   'CUL1',
#   'EEF1B2',
#   'G3BP1',
#   'CYC1',
#   'RFC4',
#   'NCBP2',
#   'VBP1',
#   'CBX3',
#   'NCBP1',
#   'PA2G4',
#   'RAD23B',
#   'NAP1L1',
#   'CDK4',
#   'CDK2',
#   'MCM4',
#   'ETF1',
#   'MCM5',
#   'MCM6',
#   'MCM7',
#   'MCM2',
#   'SLC25A3',
#   'YWHAE',
#   'PSMD14',
#   'GLO1',
#   'ORC2',
#   'YWHAQ',
#   'PGK1',
#   'EIF4H',
#   'ACP1',
#   'EIF4E',
#   'DDX18',
#   'SMARCC1',
#   'CAD',
#   'RRM1',
#   'KPNB1',
#   'IMPDH2',
#   'EIF3J',
#   'VDAC3',
#   'SSBP1',
#   'SNRPA1',
#   'VDAC1',
#   'EIF3D',
#   'EIF3B',
#   'ABCE1',
#   'NOP56',
#   'PRPS2',
#   'EIF4A1',
#   'HSP90AB1',
#   'HDAC2',
#   'DDX21',
#   'U2AF1',
#   'HSPD1',
#   'SRM',
#   'PPM1G',
#   'CDC45',
#   'POLD2',
#   'TRA2B',
#   'SNRPB2',
#   'TRIM28',
#   'BUB3',
#   'HNRNPA3',
#   'HNRNPA1'],
#  'Myc Targets V2': ['DUSP2',
#   'IMP4',
#   'CBX3',
#   'PUS1',
#   'PA2G4',
#   'SORD',
#   'WDR74',
#   'GNL3',
#   'HSPE1',
#   'BYSL',
#   'MRTO4',
#   'LAS1L',
#   'CDK4',
#   'MCM4',
#   'MCM5',
#   'DCTPP1',
#   'NIP7',
#   'NOP2',
#   'NOLC1',
#   'NOC4L',
#   'TBRG4',
#   'HK2',
#   'EXOSC5',
#   'PPRC1',
#   'TCOF1',
#   'MYC',
#   'PES1',
#   'MAP3K6',
#   'DDX18',
#   'NPM1',
#   'PLK4',
#   'NOP16',
#   'PLK1',
#   'PRMT3',
#   'TFB2M',
#   'SUPV3L1',
#   'AIMP2',
#   'MYBBP1A',
#   'RCL1',
#   'GRWD1',
#   'NDUFAF4',
#   'SLC29A2',
#   'FARSA',
#   'NOP56',
#   'MPHOSPH10',
#   'PHB',
#   'IPO4',
#   'PPAN',
#   'WDR43',
#   'TMEM97',
#   'HSPD1',
#   'RABEPK',
#   'SRM',
#   'UNG',
#   'RRP9',
#   'RRP12',
#   'UTP20',
#   'SLC19A1'],
#  'Epithelial Mesenchymal Transition': ['LUM',
#   'CADM1',
#   'DKK1',
#   'P3H1',
#   'COL1A2',
#   'SFRP4',
#   'COL1A1',
#   'MGP',
#   'VIM',
#   'MXRA5',
#   'MYL9',
#   'PFN2',
#   'PRSS2',
#   'LRP1',
#   'TAGLN',
#   'COL12A1',
#   'SERPINE1',
#   'SERPINE2',
#   'SFRP1',
#   'DPYSL3',
#   'ABI3BP',
#   'SPOCK1',
#   'CCN2',
#   'MEST',
#   'CCN1',
#   'GADD45B',
#   'FZD8',
#   'GADD45A',
#   'FERMT2',
#   'SLC6A8',
#   'SDC1',
#   'SNAI2',
#   'SPARC',
#   'OXTR',
#   'ENO2',
#   'MYLK',
#   'GJA1',
#   'LGALS1',
#   'ANPEP',
#   'SERPINH1',
#   'FUCA1',
#   'JUN',
#   'IL15',
#   'TNFRSF12A',
#   'MAGEE1',
#   'VEGFC',
#   'FN1',
#   'EMP3',
#   'RHOB',
#   'VEGFA',
#   'CRLF1',
#   'COL3A1',
#   'MMP14',
#   'GAS1',
#   'ID2',
#   'CALU',
#   'FOXC2',
#   'ELN',
#   'SDC4',
#   'TNFRSF11B',
#   'AREG',
#   'THY1',
#   'TIMP3',
#   'QSOX1',
#   'TIMP1',
#   'CAP2',
#   'IL32',
#   'ADAM12',
#   'BGN',
#   'COL4A1',
#   'COL4A2',
#   'FMOD',
#   'CD44',
#   'LRRC15',
#   'ECM1',
#   'ECM2',
#   'FSTL1',
#   'CAPG',
#   'FSTL3',
#   'COL11A1',
#   'CD59',
#   'TGFB1',
#   'PDGFRB',
#   'APLP1',
#   'PRRX1',
#   'TPM4',
#   'TFPI2',
#   'WNT5A',
#   'TPM2',
#   'VCAM1',
#   'CXCL12',
#   'COL5A2',
#   'PLOD1',
#   'COL5A1',
#   'FAP',
#   'FAS',
#   'COL5A3',
#   'TGFBI',
#   'PMP22',
#   'SCG2',
#   'PPIB',
#   'COL16A1',
#   'TNC',
#   'FBLN2',
#   'PLOD3',
#   'PVR',
#   'FBLN1',
#   'PLOD2',
#   'LOXL1',
#   'LOXL2',
#   'FBLN5',
#   'CDH6',
#   'COMP',
#   'NT5E',
#   'BASP1',
#   'CDH2',
#   'GPC1',
#   'FLNA',
#   'SLIT2',
#   'TPM1',
#   'MSX1',
#   'SLIT3',
#   'SPP1',
#   'IGFBP2',
#   'POSTN',
#   'IGFBP4',
#   'IGFBP3',
#   'INHBA',
#   'GEM',
#   'LOX',
#   'CDH11',
#   'COL6A3',
#   'COL6A2',
#   'MATN2',
#   'FBN1',
#   'FBN2',
#   'MATN3',
#   'COPA',
#   'NOTCH2',
#   'NTM',
#   'HTRA1',
#   'FGF2',
#   'SAT1',
#   'TGM2',
#   'EFEMP2',
#   'GLIPR1',
#   'RGS4',
#   'CALD1',
#   'PMEPA1',
#   'EDIL3',
#   'ITGA5',
#   'MMP1',
#   'MMP2',
#   'BDNF',
#   'GPX7',
#   'MMP3',
#   'ITGA2',
#   'TGFBR3',
#   'ACTA2',
#   'MFAP5',
#   'VCAN',
#   'DAB2',
#   'IL6',
#   'BMP1',
#   'COL7A1',
#   'MCM7',
#   'CXCL8',
#   'NNMT',
#   'LAMC1',
#   'TNFAIP3',
#   'CXCL1',
#   'LAMC2',
#   'NID2',
#   'CXCL6',
#   'PDLIM4',
#   'DST',
#   'PCOLCE',
#   'PLAUR',
#   'DCN',
#   'PTHLH',
#   'SNTB1',
#   'GREM1',
#   'COL8A2',
#   'PCOLCE2',
#   'PTX3',
#   'ITGB1',
#   'LAMA3',
#   'WIPF1',
#   'ITGB5',
#   'LAMA2',
#   'ITGB3',
#   'LAMA1',
#   'THBS1',
#   'THBS2',
#   'SGCG',
#   'SGCD',
#   'SGCB',
#   'ITGAV',
#   'COLGALT1',
#   'CTHRC1'],
#  'Inflammatory Response': ['IL1R1',
#   'EREG',
#   'MARCO',
#   'TNFSF9',
#   'VIP',
#   'SLAMF1',
#   'SGMS2',
#   'IFITM1',
#   'AQP9',
#   'SERPINE1',
#   'C3AR1',
#   'NOD2',
#   'MYC',
#   'PROK2',
#   'MSR1',
#   'ABCA1',
#   'TNFSF15',
#   'FZD5',
#   'SLC11A2',
#   'RNF144B',
#   'GPR183',
#   'CHST2',
#   'MEP1A',
#   'NPFFR2',
#   'HPN',
#   'ICAM4',
#   'HIF1A',
#   'ICAM1',
#   'LPAR1',
#   'KCNMB2',
#   'IL12B',
#   'SCARF1',
#   'FFAR2',
#   'TNFSF10',
#   'CD14',
#   'CMKLR1',
#   'SCN1B',
#   'EDN1',
#   'LYN',
#   'CCL24',
#   'GABBR1',
#   'IL10',
#   'CCL22',
#   'IL15',
#   'CCL20',
#   'IL10RA',
#   'SPHK1',
#   'NMI',
#   'TACR3',
#   'LIF',
#   'EMP3',
#   'TACR1',
#   'IL18',
#   'RHOG',
#   'OSMR',
#   'DCBLD2',
#   'IL1A',
#   'PTPRE',
#   'TLR2',
#   'BST2',
#   'IL1B',
#   'TLR1',
#   'MMP14',
#   'IL18R1',
#   'TLR3',
#   'BTG2',
#   'CD40',
#   'MEFV',
#   'EBI3',
#   'ADM',
#   'FPR1',
#   'SLC7A1',
#   'CX3CL1',
#   'SLC7A2',
#   'RIPK2',
#   'TIMP1',
#   'CCR7',
#   'KIF1B',
#   'GCH1',
#   'IFNGR2',
#   'GP1BA',
#   'F3',
#   'CD48',
#   'HBEGF',
#   'CDKN1A',
#   'PTGER2',
#   'PTAFR',
#   'KCNA3',
# ...
#   'SEC14L1',
#   'HBQ1',
#   'HTATIP2',
#   'CLIC2',
#   'CTSE',
#   'HBZ',
#   'DMTN',
#   'MOCOS',
#   'MPP1',
#   'TCEA1',
#   'HDGF',
#   'RHAG',
#   'RNF123',
#   'MARCHF2',
#   'SLC66A2',
#   'PIGQ',
#   'RHD',
#   'TRAK2',
#   'NUDT4',
#   'XPO7',
#   'MARCHF8',
#   'RIOK3',
#   'AHSP',
#   'LMO2',
#   'RHCE',
#   'SLC25A38',
#   'XK',
#   'SIDT2',
#   'LRP10',
#   'YPEL5',
#   'ABCG2',
#   'SLC25A37',
#   'OSBP2',
#   'ALDH1L1',
#   'UCP2',
#   'CPOX',
#   'FOXO3',
#   'CCND3',
#   'LAMP2',
#   'RNF19A',
#   'CIR1',
#   'ARHGEF12',
#   'CAST',
#   'MAP2K3',
#   'BNIP3L',
#   'NEK7',
#   'UROS',
#   'VEZF1',
#   'SLC30A1',
#   'FBXO34',
#   'MFHAS1',
#   'SDCBP',
#   'MINPP1',
#   'PICALM',
#   'GCLC',
#   'RCL1',
#   'TFDP2',
#   'SYNJ1',
#   'MKRN1',
#   'BMP2K',
#   'GCLM',
#   'BLVRB',
#   'BLVRA',
#   'NARF',
#   'SLC2A1',
#   'HTRA2',
#   'UROD',
#   'MARK3',
#   'FN3K',
#   'EIF2AK1',
#   'ASNS',
#   'PPP2R5B',
#   'RAD23A',
#   'SPTB',
#   'ARL2BP',
#   'TSPO2',
#   'HAGH',
#   'TRIM58',
#   'ATG4A',
#   'LPIN2',
#   'TOP1',
#   'NFE2L1',
#   'TNRC6B',
#   'FECH',
#   'ABCB6',
#   'GMPS',
#   'RAP1GAP',
#   'AGPAT4',
#   'MOSPD1',
#   'CA2',
#   'ALAD',
#   'CA1',
#   'HEBP1',
#   'ACP5',
#   'RBM38',
#   'SMOX',
#   'GLRX5',
#   'KHNYN',
#   'KLF1',
#   'MBOAT2',
#   'FOXJ2',
#   'BPGM',
#   'EPOR',
#   'KLF3',
#   'SELENBP1',
#   'ACKR1',
#   'CAT',
#   'DAAM1',
#   'USP15',
#   'ALAS2',
#   'CCDC28A',
#   'SLC4A1',
#   'CLCN3',
#   'NR3C1',
#   'ADD2',
#   'FTCD',
#   'ADD1',
#   'RBM5',
#   'PGLS',
#   'DCAF10',
#   'FBXO7',
#   'DCAF11',
#   'FBXO9'],
#  'Coagulation': ['GSN',
#   'F11',
#   'F10',
#   'S100A1',
#   'TFPI2',
#   'F12',
#   'CD9',
#   'ISCU',
#   'ADAM9',
#   'PF4',
#   'GDA',
#   'LRP1',
#   'SERPINE1',
#   'PROS1',
#   'CLU',
#   'ITIH1',
#   'COMP',
#   'LAMP2',
#   'CAPN5',
#   'S100A13',
#   'CAPN2',
#   'SH2B2',
#   'MAFF',
#   'PROC',
#   'GNB2',
#   'LGMN',
#   'SERPING1',
#   'F13B',
#   'MEP1A',
#   'PEF1',
#   'FBN1',
#   'CFB',
#   'CFD',
#   'SPARC',
#   'CPB2',
#   'CFI',
#   'HPN',
#   'CFH',
#   'PDGFB',
#   'PREP',
#   'PLAU',
#   'HTRA1',
#   'PLAT',
#   'C2',
#   'C3',
#   'C9',
#   'LTA4H',
#   'A2M',
#   'CTSB',
#   'DUSP6',
#   'ANXA1',
#   'MMP7',
#   'MMP8',
#   'HMGCS2',
#   'MMP1',
#   'MMP2',
#   'MMP3',
#   'MST1',
#   'ITGA2',
#   'FN1',
#   'MMP9',
#   'GNG12',
#   'SIRT2',
#   'GP9',
#   'MMP11',
#   'MMP10',
#   'TF',
#   'MMP15',
#   'MMP14',
#   'BMP1',
#   'ACOX2',
#   'APOA1',
#   'PECAM1',
#   'RAPGEF3',
#   'KLKB1',
#   'HRG',
#   'ARF4',
#   'CPQ',
#   'SERPINA1',
#   'TMPRSS6',
#   'PROZ',
#   'C8A',
#   'CTSV',
#   'C8B',
#   'DUSP14',
#   'KLK8',
#   'DPP4',
#   'C8G',
#   'CASP9',
#   'CTSO',
#   'CSRP1',
#   'CTSK',
#   'HNF4A',
#   'P2RY1',
#   'TIMP3',
#   'CTSH',
#   'TIMP1',
#   'CTSE',
#   'FGA',
#   'LEFTY2',
#   'SERPINB2',
#   'FGG',
#   'VWF',
#   'F2',
#   'GP1BA',
#   'F3',
#   'RABIF',
#   'F8',
#   'F9',
#   'KLF7',
#   'APOC1',
#   'DCT',
#   'APOC3',
#   'APOC2',
#   'ANG',
#   'F2RL2',
#   'RGN',
#   'MASP2',
#   'MSRB2',
#   'C1QA',
#   'C1R',
#   'WDR1',
#   'PLEK',
#   'SERPINC1',
#   'C1S',
#   'FURIN',
#   'USP11',
#   'ITGB3',
#   'THBS1',
#   'PLG',
#   'PRSS23',
#   'CRIP2',
#   'CPN1',
#   'THBD',
#   'RAC1',
#   'FYN',
#   'MBL2',
#   'OLR1'],
#  'IL-2/STAT5 Signaling': ['IL1R2',
#   'TTC39B',
#   'RRAGD',
#   'ITIH5',
#   'CYFIP1',
#   'IFITM3',
#   'AHNAK',
#   'FGL2',
#   'PNP',
#   'MUC1',
#   'FLT3LG',
#   'MYC',
#   'WLS',
#   'GBP4',
#   'ST3GAL4',
#   'PRKCH',
#   'BATF3',
#   'RABGAP1L',
#   'GABARAPL1',
#   'XBP1',
#   'GADD45B',
#   'CDCP1',
#   'PLSCR1',
#   'UCK2',
#   'PLPP1',
#   'CDC42SE2',
#   'RNH1',
#   'IKZF2',
#   'ENO3',
#   'IKZF4',
#   'GATA1',
#   'CD79B',
#   'ALCAM',
#   'TNFSF11',
#   'TNFSF10',
#   'NCOA3',
#   'IL10',
#   'ANXA4',
#   'IL13',
#   'IL10RA',
#   'EMP1',
#   'RHOH',
#   'LIF',
#   'PTCH1',
#   'CDC6',
#   'FAM126B',
#   'RHOB',
#   'P4HA1',
#   'BHLHE40',
#   'ETFBKMT',
#   'TLR7',
#   'UMPS',
#   'IL18R1',
#   'CTSZ',
#   'PTH1R',
#   'SHE',
#   'SOCS1',
#   'SOCS2',
#   'PENK',
#   'SH3BGRL2',
#   'CTLA4',
#   'MAP6',
#   'NFIL3',
#   'SNX9',
#   'CCR4',
#   'ICOS',
#   'IFNGR1',
#   'GSTO1',
#   'DHRS3',
#   'SERPINB6',
#   'ADAM19',
#   'CCNE1',
#   'F2RL2',
#   'PTRH2',
#   'CD48',
#   'PLIN2',
#   'SLC29A2',
#   'CD44',
#   'EEF1AKMT1',
#   'NRP1',
#   'ECM1',
#   'AHCY',
#   'CDKN1C',
#   'SERPINC1',
#   'PTGER2',
#   'SNX14',
#   'CAPG',
#   'CST7',
#   'PDCD2L',
#   'ENPP1',
#   'NCS1',
#   'PLAGL1',
#   'DCPS',
#   'EOMES',
#   'IL4R',
#   'PHLDA1',
#   'APLP1',
#   'S100A1',
#   'PRAF2',
#   'PUS1',
#   'HUWE1',
#   'HIPK2',
#   'FAH',
#   'BATF',
#   'CXCL10',
#   'MAPKAPK2',
#   'CD86',
#   'CD83',
#   'CSF2',
#   'CSF1',
#   'CD81',
#   'ODC1',
#   'RGS16',
#   'GPR65',
#   'AHR',
#   'SLC1A5',
#   'LCLAT1',
#   'NDRG1',
#   'NT5E',
#   'CCND3',
#   'CCND2',
#   'CAPN3',
#   'DENND5A',
#   'SLC39A8',
#   'SPP1',
#   'MAP3K8',
#   'IGF2R',
#   'SWAP70',
#   'CISH',
#   'PRNP',
#   'TRAF1',
#   'CKAP4',
#   'HOPX',
#   'MAFF',
#   'MXD1',
#   'SELP',
#   'AMACR',
#   'COL6A1',
#   'SELL',
#   'BCL2L1',
#   'DRC1',
#   'GUCY1B1',
#   'SLC2A3',
#   'AGER',
#   'GPR83',
#   'RORA',
#   'IGF1R',
#   'TGM2',
#   'GLIPR2',
#   'SCN9A',
#   'TNFRSF8',
#   'PIM1',
#   'TNFRSF9',
#   'TNFRSF4',
#   'POU2F1',
#   'GPX4',
#   'NFKBIZ',
#   'ETV4',
#   'TNFRSF1B',
#   'TNFRSF21',
#   'BMP2',
#   'IRF4',
#   'ITGAE',
#   'IL3RA',
#   'IRF8',
#   'BCL2',
#   'IRF6',
#   'ITGA6',
#   'PLEC',
#   'ARL4A',
#   'ABCB1',
#   'BMPR2',
#   'NOP2',
#   'PHTF2',
#   'HK2',
#   'CA2',
#   'SYNGR2',
#   'CASP3',
#   'TNFRSF18',
#   'TIAM1',
#   'MYO1E',
#   'TWSG1',
#   'MYO1C',
#   'KLF6',
#   'P2RX4',
#   'IL2RA',
#   'IL2RB',
#   'SYT11',
#   'LTB',
#   'SPRY4',
#   'SMPDL3A',
#   'GALM',
#   'FURIN',
#   'COCH',
#   'IL1RL1',
#   'SPRED2',
#   'LRIG1',
#   'ITGAV',
#   'LRRC8C'],
#  'Bile Acid Metabolism': ['ABCG8',
#   'HSD3B7',
#   'PEX19',
#   'PHYH',
#   'ACSL1',
#   'DIO1',
#   'HSD3B1',
#   'DIO2',
#   'ACSL5',
#   'PEX12',
#   'PEX13',
#   'CYP39A1',
#   'PEX16',
#   'SOAT2',
#   'RBP1',
#   'PEX11G',
#   'ABCG4',
#   'ALDH8A1',
#   'OPTN',
#   'SLC27A2',
#   'AKR1D1',
#   'PEX11A',
#   'RETSAT',
#   'AQP9',
#   'SLC23A2',
#   'SLC35B2',
#   'SLC23A1',
#   'HSD17B4',
#   'HSD17B6',
#   'CH25H',
#   'PEX26',
#   'RXRA',
#   'PIPOX',
#   'LONP2',
#   'RXRG',
#   'ABCA2',
#   'ABCA3',
#   'IDH1',
#   'GSTK1',
#   'ABCA1',
#   'ABCA6',
#   'ABCA4',
#   'IDH2',
#   'ABCA5',
#   'EPHX2',
#   'ABCA8',
#   'NR0B2',
#   'ABCA9',
#   'AR',
#   'CYP27A1',
#   'SULT2B1',
#   'AMACR',
#   'GNPAT',
#   'SLCO1A2',
#   'GCLM',
#   'SLC27A5',
#   'PECR',
#   'CYP46A1',
#   'LIPE',
#   'PRDX5',
#   'FDXR',
#   'SCP2',
#   'HACL1',
#   'BBOX1',
#   'PEX1',
#   'CYP7B1',
#   'DHCR24',
#   'NPC1',
#   'BMP6',
#   'SULT1B1',
#   'APOA1',
#   'PEX7',
#   'PXMP2',
#   'PEX6',
#   'EFHC1',
#   'PAOX',
#   'IDI1',
#   'BCAR3',
#   'NR1I2',
#   'TFCP2L1',
#   'CROT',
#   'CYP7A1',
#   'SERPINA6',
#   'SLC22A18',
#   'ISOC1',
#   'HAO1',
#   'ATXN1',
#   'PNPLA8',
#   'KLF1',
#   'NR1H4',
#   'CYP8B1',
#   'GNMT',
#   'SOD1',
#   'LCK',
#   'PFKM',
#   'ALDH1A1',
#   'CAT',
#   'NEDD4',
#   'ALDH9A1',
#   'SLC29A1',
#   'AGXT',
#   'ABCD3',
#   'NR3C2',
#   'HSD17B11',
#   'NUDT12',
#   'TTR',
#   'MLYCD',
#   'GC',
#   'ABCD1',
#   'ABCD2',
#   'FADS2',
#   'FADS1'],
#  'Pperoxisome': ['HSD3B7',
#   'ACOT8',
#   'ACSL1',
#   'DIO1',
#   'ECH1',
#   'CADM1',
#   'CNBP',
#   'ACSL5',
#   'ACSL4',
#   'MSH2',
#   'PEX13',
#   'PEX14',
#   'SCGB1A1',
#   'CRAT',
#   'SLC27A2',
#   'PEX11A',
#   'RETSAT',
#   'CRABP1',
#   'PEX11B',
#   'SLC23A2',
#   'SLC35B2',
#   'CRABP2',
#   'HSD17B4',
#   'STS',
#   'LONP2',
#   'RXRG',
#   'FDPS',
#   'FIS1',
#   'SIAH1',
#   'IDH1',
#   'GSTK1',
#   'IDH2',
#   'EPHX2',
#   'CEL',
#   'CTPS1',
#   'ESR2',
#   'SULT2B1',
#   'DLG4',
#   'GNPAT',
#   'CTBP1',
#   'ECI2',
#   'BCL10',
#   'CACNA1B',
#   'PRDX5',
#   'PRDX1',
#   'SCP2',
#   'ACAA1',
#   'ABCC5',
#   'ABCC8',
#   'DHCR24',
#   'PEX2',
#   'CDK7',
#   'PEX5',
#   'ITGB1BP1',
#   'ACOX1',
#   'ALB',
#   'PEX6',
#   'PABPC1',
#   'IDI1',
#   'ABCB4',
#   'ABCB1',
#   'SLC25A4',
#   'NR1I2',
#   'TOP2A',
#   'VPS4B',
#   'IDE',
#   'EHHADH',
#   'ABCB9',
#   'SERPINA6',
#   'HSD11B2',
#   'RDH11',
#   'ISOC1',
#   'HAO2',
#   'ATXN1',
#   'YWHAH',
#   'SMARCC1',
#   'ELOVL5',
#   'UGT2B17',
#   'DHRS3',
#   'SOD1',
#   'SOD2',
#   'SLC25A17',
#   'ERCC1',
#   'SLC25A19',
#   'ALDH1A1',
#   'CAT',
#   'FABP6',
#   'ERCC3',
#   'ALDH9A1',
#   'ABCD3',
#   'MVP',
#   'SEMA3C',
#   'CLN8',
#   'HSD17B11',
#   'CLN6',
#   'HMGCL',
#   'TTR',
#   'NUDT19',
#   'HRAS',
#   'MLYCD',
#   'TSPO',
#   'ABCD1',
#   'ABCD2',
#   'FADS1'],
#  'Allograft Rejection': ['KRT1',
#   'EREG',
#   'CD2',
#   'CD4',
#   'CD7',
#   'IL2RG',
#   'IL27RA',
#   'PSMB10',
#   'AKT1',
#   'APBB1',
#   'B2M',
#   'GBP2',
#   'ELANE',
#   'FYB1',
#   'PRKCG',
#   'ST8SIA4',
#   'HLA-A',
#   'PRKCB',
#   'HLA-G',
#   'HLA-E',
#   'RPL3L',
#   'SPI1',
#   'BCL10',
#   'PRF1',
#   'CD1D',
#   'HIF1A',
#   'RPL9',
#   'CFP',
#   'C2',
#   'ICAM1',
#   'CD79A',
#   'MRPL3',
#   'RPS19',
#   'IL12B',
#   'RPL39',
#   'IL12A',
#   'CCR2',
#   'IL11',
#   'CCR1',
#   'LYN',
#   'IL10',
#   'CCL22',
#   'IL15',
#   'IL16',
#   'IL13',
#   'LIF',
#   'IL18',
#   'NME1',
#   'TLR2',
#   'IL1B',
#   'TLR1',
#   'PTPRC',
#   'NCR1',
#   'CD28',
#   'TLR6',
#   'ITK',
#   'TLR3',
#   'ACHE',
#   'IGSF6',
#   'CD40',
#   'BRCA1',
#   'CD3G',
#   'THY1',
#   'CD3E',
#   'CD3D',
#   'CTSS',
#   'SOCS1',
#   'RIPK2',
#   'TIMP1',
#   'CCR5',
#   'SOCS5',
#   'HLA-DQA1',
#   'NPM1',
#   'TPD52',
#   'MAP4K1',
#   'CDKN2A',
#   'IFNGR1',
#   'STAT1',
#   'IFNGR2',
#   'STAT4',
#   'F2',
#   'HCLS1',
#   'CD40LG',
#   'CD47',
#   'CCL13',
#   'CCL11',
#   'GCNT1',
#   'WAS',
#   'CAPG',
#   'IKBKB',
#   'HLA-DMB',
#   'STAB1',
#   'CXCR3',
#   'CCL19',
#   'HLA-DMA',
#   'ICOSLG',
#   'JAK2',
#   'TGFB1',
#   'CD74',
#   'IL4R',
#   'RARS1',
#   'TGFB2',
#   'RPS9',
#   'CRTAM',
#   'TAP2',
#   'TAP1',
#   'CXCL13',
#   'ABI1',
#   'FAS',
#   'KLRD1',
#   'PF4',
#   'DEGS1',
#   'PTPN6',
#   'UBE2N',
#   'CD86',
#   'CSF1',
#   'CD80',
#   'UBE2D1',
#   'GPR65',
#   'TNF',
#   'EGFR',
#   'CCND3',
#   'CCND2',
#   'FLNA',
#   'NLRP3',
#   'HLA-DOB',
#   'MAP3K7',
#   'IL12RB1',
#   'HLA-DOA',
#   'CD96',
#   'F2R',
#   'GLMN',
#   'INHBA',
#   'LY86',
#   'INHBB',
#   'TRAF2',
#   'CARTPT',
#   'DARS1',
#   'CD8B',
#   'CD8A',
#   'BCAT1',
#   'EIF4G3',
#   'IFNAR2',
#   'DYRK3',
#   'NCF4',
#   'LY75',
#   'FASLG',
#   'ETS1',
#   'IL18RAP',
#   'SIT1',
#   'EIF5A',
#   'SRGN',
#   'GALNT1',
#   'RPS3A',
#   'MMP9',
#   'TAPBP',
#   'ACVR2A',
#   'IL2',
#   'IL4',
#   'IL7',
#   'FCGR2B',
#   'IL6',
#   'ELF4',
#   'IL9',
#   'IRF4',
#   'IFNG',
#   'BCL3',
#   'HLA-DRA',
#   'IRF8',
#   'IRF7',
#   'LCP2',
#   'CD247',
#   'CXCL9',
#   'MTIF2',
#   'AARS1',
#   'EIF3A',
#   'GZMB',
#   'GZMA',
#   'WARS1',
#   'FGR',
#   'LCK',
#   'ZAP70',
#   'IL2RA',
#   'EIF3J',
#   'IL2RB',
#   'LTB',
#   'EIF3D',
#   'ABCE1',
#   'ITGB2',
#   'HDAC9',
#   'ITGAL',
#   'CCL7',
#   'CCL5',
#   'CCL4',
#   'CCL2',
#   'TRAT1',
#   'CSK',
#   'NOS2',
#   'MBL2',
#   'NCK1'],
#  'Spermatogenesis': ['TLE4',
#   'PRM2',
#   'HSPA1L',
#   'SLC12A2',
#   'ZPBP',
#   'CHFR',
#   'HTR5A',
#   'CCT6B',
#   'ADAM2',
#   'THEG',
#   'ZC2HC1C',
#   'CNIH2',
#   'IFT88',
#   'MTNR1A',
#   'DPEP3',
#   'GAPDHS',
#   'SCG5',
#   'STAM2',
#   'SCG3',
#   'CHRM4',
#   'HOXB1',
#   'CLPB',
#   'AURKA',
#   'NCAPH',
#   'PEBP1',
#   'TUBA3C',
#   'AKAP4',
#   'CLGN',
#   'NPHP1',
#   'TEKT2',
#   'ADAD1',
#   'IL12RB2',
#   'JAM3',
#   'TALDO1',
#   'PIAS2',
#   'RPL39L',
#   'H1-6',
#   'CCNA1',
#   'MLLT10',
#   'GPR182',
#   'MEP1B',
#   'RAD17',
#   'KIF2C',
#   'EZH2',
#   'CFTR',
#   'CRISP2',
#   'HSPA4L',
#   'DDX4',
#   'ACTL7B',
#   'GFI1',
#   'SLC2A5',
#   'GMCL1',
#   'ACRBP',
#   'ART3',
#   'CCNB2',
#   'PRKAR2A',
#   'PAPOLB',
#   'NEK2',
#   'ODF1',
#   'AGFG1',
#   'ZC3H14',
#   'PCSK1N',
#   'IL13RA2',
#   'TCP11',
#   'ACE',
#   'GSTM3',
#   'RFC4',
#   'NPY5R',
#   'PDHA2',
#   'STRBP',
#   'HSPA2',
#   'BRAF',
#   'SIRT1',
#   'MLF1',
#   'SNAP91',
#   'LPIN1',
#   'DMC1',
#   'NF2',
#   'ACRV1',
#   'CAMK4',
#   'CDK1',
#   'ARL4A',
#   'PSMG1',
#   'CDKN3',
#   'MAST2',
#   'ALOX15',
#   'IDE',
#   'SPATA6',
#   'OAZ3',
#   'SHE',
#   'PCSK4',
#   'COIL',
#   'LDHC',
#   'PGS1',
#   'PGK2',
#   'TOPBP1',
#   'MAP7',
#   'DNAJB8',
#   'IP6K1',
#   'HBZ',
#   'DCC',
#   'TKTL1',
#   'PACRG',
#   'CSNK2A2',
#   'NAA11',
#   'PARP2',
#   'ELOVL3',
#   'DMRT1',
#   'GAD1',
#   'SEPTIN4',
#   'MTOR',
#   'TSN',
#   'ADCYAP1',
#   'POMC',
#   'DBF4',
#   'VDAC3',
#   'TNP2',
#   'TSSK2',
#   'TNP1',
#   'DDX25',
#   'SYCP1',
#   'TTK',
#   'TULP2',
#   'YBX2',
#   'CST8',
#   'PHF7',
#   'ZNRF4',
#   'GRM8',
#   'GSG1',
#   'PHKG2',
#   'TNNI3',
#   'NOS1',
#   'NEFH',
#   'BUB1',
#   'CLVS1'],
#  'KRAS Signaling Up': ['ATG10',
#   'CIDEA',
#   'EREG',
#   'MALL',
#   'NIN',
#   'RBP4',
#   'SLPI',
#   'ITGBL1',
#   'SPARCL1',
#   'ZNF277',
#   'ADAMDEC1',
#   'SATB1',
#   'C3AR1',
#   'RETN',
#   'GLRX',
#   'IL2RG',
#   'TFPI',
#   'ADGRA2',
#   'AKT2',
#   'RABGAP1L',
#   'ST6GAL1',
#   'GADD45G',
#   'PPBP',
#   'AMMECR1',
#   'NR0B2',
#   'IGF2',
#   'BTC',
#   'TNNT2',
#   'CCSER2',
#   'STRN',
#   'CFB',
#   'SPON1',
#   'CFH',
#   'PLEK2',
#   'IKZF1',
#   'GNG11',
#   'EPB41L3',
#   'TSPAN7',
#   'ANKH',
#   'SOX9',
#   'KCNN4',
#   'CMKLR1',
#   'TSPAN1',
#   'APOD',
#   'SCN1B',
#   'GABRA3',
#   'DUSP6',
#   'FUCA1',
#   'ACE',
#   'JUP',
#   'CCL20',
#   'IL10RA',
#   'EMP1',
#   'LIF',
#   'PDCD1LG2',
#   'SNAP91',
#   'DCBLD2',
#   'MMP11',
#   'WDR33',
#   'MMP10',
#   'VWA5A',
#   'IL1B',
#   'LAT2',
#   'GPRC5B',
#   'CFHR2',
#   'ID2',
#   'TLR8',
#   'SDCCAG8',
#   'ADGRL4',
#   'AVL9',
#   'SERPINA3',
#   'TPH1',
#   'GYPC',
#   'PTPRR',
#   'CAB39L',
#   'CROT',
#   'TOR1AIP2',
#   'CTSS',
#   'MAP7',
#   'CD37',
#   'FCER1G',
#   'MPZL2',
#   'PRELID3B',
#   'HSD11B1',
#   'IL33',
#   'MMD',
#   'MAP4K1',
#   'ARG1',
#   'TMEM176A',
#   'G0S2',
#   'TMEM176B',
#   'WNT7A',
#   'LAPTM5',
#   'NR1H4',
#   'ANO1',
#   'TMEM158',
#   'ADAM17',
#   'ANGPTL4',
#   'F2RL1',
#   'ENG',
#   'HBEGF',
#   'NRP1',
#   'ERO1A',
#   'MTMR10',
#   'F13A1',
#   'PIGR',
#   'HOXD11',
#   'PTGS2',
#   'PSMB8',
#   'AKAP12',
#   'CXCR4',
#   'GPNMB',
#   'CBR4',
#   'MAP3K1',
#   'PTCD2',
#   'GUCY1A1',
#   'PRRX1',
#   'H2BC3',
#   'CXCL10',
#   'MYCN',
#   'PCP4',
#   'CLEC4A',
#   'ADAM8',
#   'SCG5',
#   'SCG3',
#   'PLVAP',
#   'CSF2',
#   'PPP1R15A',
#   'RGS16',
#   'PRDM1',
#   'RELN',
#   'CCND2',
#   'KIF5C',
#   'SPP1',
#   'IGFBP3',
#   'INHBA',
#   'TRAF1',
#   'MAFB',
#   'DNMBP',
#   'BIRC3',
#   'YRDC',
#   'IL7R',
#   'PLAU',
#   'PLAT',
#   'CSF2RA',
#   'ETS1',
#   'TMEM100',
#   'FGF9',
#   'BTBD3',
#   'PCSK1N',
#   'CDADC1',
#   'CBX8',
#   'GALNT3',
#   'PEG3',
#   'GFPT2',
#   'ITGA2',
#   'ETV1',
#   'NAP1L2',
#   'ETV4',
#   'MMP9',
#   'ETV5',
#   'TNFRSF1B',
#   'BMP2',
#   'LCP1',
#   'CPE',
#   'ZNF639',
#   'IRF8',
#   'PECAM1',
#   'DOCK2',
#   'SNAP25',
#   'ABCB1',
#   'TNFAIP3',
#   'LY96',
#   'PTBP2',
#   'CA2',
#   'EVI5',
#   'PRKG2',
#   'ANXA10',
#   'PLAUR',
#   'BPGM',
#   'KLF4',
#   'NGF',
#   'ALDH1A3',
#   'ALDH1A2',
#   'HKDC1',
#   'SPRY2',
#   'TRIB2',
#   'TRIB1',
#   'ITGB2',
#   'FLT4',
#   'SEMA3B',
#   'USP12',
#   'HDAC9',
#   'TSPAN13',
#   'CBL',
#   'USH1C',
#   'RBM4',
#   'IL1RL2',
#   'FBXO4',
#   'EPHB2'],
#  'KRAS Signaling Dn': ['KRT1',
#   'SLC12A3',
#   'EPHA5',
#   'GAMT',
#   'EGF',
#   'KRT5',
#   'MX1',
#   'KRT4',
#   'ENTPD7',
#   'RSAD2',
#   'SOX10',
#   'CYP39A1',
#   'ZC2HC1C',
#   'SCGB1A1',
#   'SCN10A',
#   'PCDHB1',
#   'ASB7',
#   'CD207',
#   'CPEB3',
#   'CNTFR',
#   'SPRR3',
#   'ITIH3',
#   'SMPX',
#   'ALOX12B',
#   'CALML5',
#   'SLC5A5',
#   'VPREB1',
#   'RIBC2',
#   'SNCB',
#   'DTNB',
#   'MTHFR',
#   'SLC6A14',
#   'TEX15',
#   'TENT5C',
#   'COPZ2',
#   'COL2A1',
#   'ATP4A',
#   'STAG3',
#   'CLPS',
#   'HNF1A',
#   'KLHDC8A',
#   'CHST2',
#   'ATP6V1B1',
#   'PTGFR',
#   'PNMT',
#   'LYPD3',
#   'SLC6A3',
#   'C5',
#   'TCL1A',
#   'KCNMB1',
#   'KCNN1',
#   'IL12B',
#   'SYNPO',
#   'LGALS7',
#   'BARD1',
#   'PDK2',
#   'EDN1',
#   'EDN2',
#   'SPHK2',
#   'FSHB',
#   'GP2',
#   'KRT13',
#   'PAX4',
#   'PAX3',
#   'GPRC5C',
#   'TG',
#   'CLDN16',
#   'MYOT',
#   'CYP11B2',
#   'KRT15',
#   'COQ8A',
#   'TFF2',
#   'AKR1B10',
#   'GPR19',
#   'SGK1',
#   'ZNF112',
#   'TENM2',
#   'BTG2',
#   'MEFV',
#   'CCDC106',
#   'TFCP2L1',
#   'SERPINA10',
#   'PTPRJ',
#   'KLK8',
#   'KLK7',
#   'HSD11B2',
#   'CCR8',
#   'SPTBN2',
#   'SERPINB2',
#   'GPR3',
#   'GP1BA',
#   'NR6A1',
#   'ABCB11',
#   'KCNQ2',
#   'CD40LG',
#   'SLC29A3',
#   'BRDT',
#   'RYR2',
#   'RYR1',
#   'LFNG',
#   'NUDT11',
#   'CHRNG',
#   'TFAP2B',
#   'TGFB2',
#   'CKM',
#   'ZBTB16',
#   'THNSL2',
#   'CDKAL1',
#   'EDAR',
#   'SELENOP',
#   'IFI44L',
#   'MSH5',
#   'SIDT1',
#   'YPEL1',
#   'ABCG4',
#   'PDCD1',
#   'PKP1',
#   'PRKN',
#   'IDUA',
#   'CD80',
#   'CELSR2',
#   'MACROH2A2',
#   'CAPN9',
#   'NTF3',
#   'SLC16A7',
#   'FGF22',
#   'IGFBP2',
#   'CPA2',
#   'KCND1',
#   'SLC30A3',
#   'ADRA2C',
#   'UPK3B',
#   'NR4A2',
#   'CCNA1',
#   'FGF16',
#   'GDNF',
#   'TLX1',
#   'CDH16',
#   'FGFR3',
#   'CALCB',
#   'KCNE2',
#   'CLSTN3',
#   'CPB1',
#   'KMT2D',
#   'IRS4',
#   'CACNA1F',
#   'TGM1',
#   'SNN',
#   'PRODH',
#   'SLC38A3',
#   'EFHD1',
#   'HTR1D',
#   'HTR1B',
#   'AMBN',
#   'SSTR4',
#   'WNT16',
#   'IL5',
#   'IFNG',
#   'ITGB1BP2',
#   'MAGIX',
#   'ARPP21',
#   'MYH7',
#   'BMPR1B',
#   'SHOX2',
#   'GTF3C5',
#   'NPY4R',
#   'MAST3',
#   'OXT',
#   'FGGY',
#   'VPS50',
#   'MFSD6',
#   'P2RY4',
#   'NRIP2',
#   'SKIL',
#   'TAS2R4',
#   'PROP1',
#   'CAMK1D',
#   'DCC',
#   'TCF7L1',
#   'GRID2',
#   'UGT2B17',
#   'NGB',
#   'DLK2',
#   'P2RX6',
#   'NPHS1',
#   'MYO15A',
#   'CLDN8',
#   'RGS11',
#   'PLAG1',
#   'THRB',
#   'ARHGDIG',
#   'YBX2',
#   'ACTC1',
#   'TNNI3',
#   'CACNG1',
#   'NOS1',
#   'PDE6B',
#   'SLC25A23',
#   'INSL5',
#   'TSHB'],
#  'Pancreas Beta Cells': ['LMO2',
#   'CHGA',
#   'SRP9',
#   'VDR',
#   'ABCC8',
#   'PKLR',
#   'PAX4',
#   'PDX1',
#   'ELP4',
#   'GCG',
#   'PAX6',
#   'ISL1',
#   'MAFB',
#   'G6PC2',
#   'GCK',
#   'SST',
#   'HNF1A',
#   'SPCS1',
#   'SYT13',
#   'IAPP',
#   'INSM1',
#   'SRPRB',
#   'DCX',
#   'NEUROG3',
#   'FOXA2',
#   'PCSK2',
#   'STXBP1',
#   'PCSK1',
#   'SEC11A',
#   'SLC2A2',
#   'SRP14',
#   'INS',
#   'DPP4',
#   'FOXO1',
#   'SCGN',
#   'AKT3',
#   'NKX2-2',
#   'NKX6-1',
#   'PAK3',
#   'NEUROD1']}

# %%
import os
import json
from pathlib import Path
from typing import List, Dict, Any, Optional
import pandas as pd

# Import singscore functions (adjust path if your package layout differs)
from singscore.singscore import *

def extract_single_numeric_from_df(df: pd.DataFrame, preferred_cols: Optional[List[str]] = None) -> Optional[float]:
    """
    Extract a single numeric value from a one-row DataFrame.
    pref_cols: list of column name substrings to try in order (case-insensitive)
    """
    if df is None:
        return None
    # if DataFrame has a single row and single numeric column, return it
    try:
        # If one row and one numeric column, return that
        if df.shape[0] == 1:
            numeric_cols = [c for c in df.columns if pd.api.types.is_numeric_dtype(df[c])]
            # If preferred_cols provided, try to find match
            if preferred_cols:
                for pc in preferred_cols:
                    for c in df.columns:
                        if pc.lower() in c.lower() and (pd.api.types.is_numeric_dtype(df[c]) or pd.api.types.is_numeric_dtype(df.iloc[:, df.columns.get_loc(c)])):
                            return float(df.iloc[0][c])
            if numeric_cols:
                return float(df.iloc[0][numeric_cols[0]])
            # else try first column convertible to float
            first_val = df.iloc[0, 0]
            try:
                return float(first_val)
            except Exception:
                return None
        else:
            # more than one row: pick first row and try same logic
            first_row = df.iloc[0:1]
            numeric_cols = [c for c in first_row.columns if pd.api.types.is_numeric_dtype(first_row[c])]
            if numeric_cols:
                return float(first_row[numeric_cols[0]].iloc[0])
            first_val = first_row.iloc[0, 0]
            try:
                return float(first_val)
            except Exception:
                return None
    except Exception:
        return None

def compute_pathway_score_for_upgenes(
    data: pd.DataFrame,
    up_genes: List[str],
    norm_method: str = "theoretical",
    perms: int = 10000
) -> Dict[str, Any]:
    """
    Given expression DataFrame and up_genes list, compute up-only singscore and empirical p-value.
    Returns dict with gene_set_info, scores, statistics.
    """
    # Genes present
    up_present = [g for g in up_genes if g in data.index]
    n_up_used = len(up_present)

    # compute score (up only). down_gene=False per user snippet
    scored = score(up_gene=up_genes, down_gene=False, sample=data, norm_method=norm_method, full_data=False)
    total_score = extract_single_numeric_from_df(scored, preferred_cols=['total_score', 'total'])

    # permutations matched to n_up_used
    permd = permutate(data, n_up=n_up_used, n_down=False, reps=perms, norm_method=norm_method)
    pvals = empiricalpval(permutations=permd, score=scored)
    empirical_p = extract_single_numeric_from_df(pvals, preferred_cols=['empirical', 'p', 'empirical p'])

    result = {
        "gene_set_info": {
            "geneset_size": len(up_genes),
            "geneset_covered_in_sample": n_up_used
        },
        "scores": {
            "total_singscore": total_score
        },
        "statistics": {
            "p_value": empirical_p,
            "method": "permutation (empirical)",
            "permutations": perms
        }
    }
    return result

def run_singscore_on_drug_folder(
    drug_dir: Path,
    entrez_sample_path: str,
    norm_method: str = "theoretical",
    perms: int = 10000,
    output_root: Optional[Path] = None
) -> Dict[str, Any]:
    """
    Given a folder containing {drug}_relevant_pathways.json, read it and compute singscore for each pathway.
    Returns result dict for the drug and writes a JSON file <drug>_singscore_results.json in the drug folder (or output_root).
    """
    # discover json file
    drug_name = drug_dir.name
    in_json = None
    # accept "{drug}_relevant_pathways.json" or anything ending with "_relevant_pathways.json"
    for p in drug_dir.glob("*_relevant_pathways.json"):
        in_json = p
        break
    if in_json is None:
        # fallback: look for exact name
        candidate = drug_dir / f"{drug_name}_relevant_pathways.json"
        if candidate.exists():
            in_json = candidate
    if in_json is None:
        raise FileNotFoundError(f"No '*_relevant_pathways.json' found in {drug_dir}")

    # read expression data once
    if not Path(entrez_sample_path).exists():
        raise FileNotFoundError(f"Expression file not found: {entrez_sample_path}")
    df_expr = pd.read_csv(open(entrez_sample_path, 'r'), header='infer', sep='\t', index_col=0)
    # ensure index matches gene naming used in json (assumes 'GeneName' or similar; user used set_index(keys='GeneName'))
    # If index name is not 'GeneName' but first column is 'GeneName', above already set index_col=0.
    # Convert index to str for safety
    df_expr.index = df_expr.index.map(str)

    # read gene sets json
    with open(in_json, "r", encoding="utf-8") as f:
        pathway_dict = json.load(f)

    result_per_drug: Dict[str, Any] = {}
    for pathway_name, gene_list in pathway_dict.items():
        # gene_list expected to be list of gene symbols/ids
        # compute
        res = compute_pathway_score_for_upgenes(df_expr, gene_list, norm_method=norm_method, perms=perms)
        result_per_drug[pathway_name] = res

    # prepare output path
    if output_root is None:
        out_dir = drug_dir
    else:
        out_dir = Path(output_root) / drug_name
        out_dir.mkdir(parents=True, exist_ok=True)
    out_json = out_dir / f"{drug_name}_singscore_results.json"

    # wrap in top-level dict {Drug: {pathway...}}
    final_output = {drug_name: result_per_drug}
    with open(out_json, "w", encoding="utf-8") as f:
        json.dump(final_output, f, indent=2, ensure_ascii=False)
    print(f"Wrote results for '{drug_name}' to {out_json}")

    return final_output

def batch_run_on_drug_dirs(
    drug_dirs: List[str],
    entrez_sample_path: str,
    norm_method: str = "theoretical",
    perms: int = 10000,
    output_root: Optional[str] = None
) -> Dict[str, Any]:
    """
    Loop over a list of drug directory paths and run scoring for each.
    Returns a combined dict of all results.
    """
    combined = {}
    for d in drug_dirs:
        drug_dir = Path(d)
        if not drug_dir.exists() or not drug_dir.is_dir():
            print(f"Skipping non-directory: {d}")
            continue
        try:
            result = run_singscore_on_drug_folder(drug_dir, entrez_sample_path, norm_method=norm_method, perms=perms, output_root=output_root)
            combined.update(result)
        except Exception as e:
            print(f"Error processing {d}: {e}")
    return combined

# %%
import os
import json
from pathlib import Path
from typing import List, Dict, Any, Optional
import pandas as pd
from tqdm import tqdm  # ✅ added for progress bars

# Import singscore functions (adjust path if needed)
from singscore.singscore import score, permutate, empiricalpval


def extract_single_numeric_from_df(df: pd.DataFrame, preferred_cols: Optional[List[str]] = None) -> Optional[float]:
    """Extract a single numeric value from a one-row DataFrame."""
    if df is None:
        return None
    try:
        if df.shape[0] == 1:
            numeric_cols = [c for c in df.columns if pd.api.types.is_numeric_dtype(df[c])]
            if preferred_cols:
                for pc in preferred_cols:
                    for c in df.columns:
                        if pc.lower() in c.lower() and pd.api.types.is_numeric_dtype(df[c]):
                            return float(df.iloc[0][c])
            if numeric_cols:
                return float(df.iloc[0][numeric_cols[0]])
            return float(df.iloc[0, 0])
        else:
            first_row = df.iloc[0:1]
            numeric_cols = [c for c in first_row.columns if pd.api.types.is_numeric_dtype(first_row[c])]
            if numeric_cols:
                return float(first_row[numeric_cols[0]].iloc[0])
            return float(first_row.iloc[0, 0])
    except Exception:
        return None


def compute_pathway_score_for_upgenes(
    data: pd.DataFrame,
    up_genes: List[str],
    norm_method: str = "theoretical",
    perms: int = 5000
) -> Dict[str, Any]:
    """
    Given expression DataFrame and up_genes list, compute up-only singScore and empirical p-value.
    """
    up_present = [g for g in up_genes if g in data.index]
    n_up_used = len(up_present)

    # Calculate singscore (up only)
    scored = score(up_gene=up_genes, down_gene=False, sample=data, norm_method=norm_method, full_data=False)
    total_score = extract_single_numeric_from_df(scored, preferred_cols=['total_score', 'total'])

    # Calculate permutation-based p-value
    permd = permutate(data, n_up=n_up_used, n_down=False, reps=perms, norm_method=norm_method)
    pvals = empiricalpval(permutations=permd, score=scored)
    empirical_p = extract_single_numeric_from_df(pvals, preferred_cols=['empirical', 'p', 'empirical p'])

    result = {
        "gene_set_info": {
            "geneset_size": len(up_genes),
            "geneset_covered_in_sample": n_up_used
        },
        "scores": {
            "total_singscore": total_score
        },
        "statistics": {
            "p_value": empirical_p,
            "method": "permutation (empirical)",
            "permutations": perms
        }
    }
    return result


def run_singscore_on_drug_folder(
    drug_dir: Path,
    entrez_sample_path: str,
    norm_method: str = "theoretical",
    perms: int = 5000,
    output_root: Optional[Path] = None
) -> Dict[str, Any]:
    """
    Given a folder containing {drug}_relevant_pathways.json, read it and compute singScore for each pathway.
    """
    drug_name = drug_dir.name
    # Find input JSON file
    in_json = None
    for p in drug_dir.glob("*_relevant_pathways.json"):
        in_json = p
        break
    if in_json is None:
        candidate = drug_dir / f"{drug_name}_relevant_pathways.json"
        if candidate.exists():
            in_json = candidate
    if in_json is None:
        raise FileNotFoundError(f"No '*_relevant_pathways.json' found in {drug_dir}")

    # Load expression data
    if not Path(entrez_sample_path).exists():
        raise FileNotFoundError(f"Expression file not found: {entrez_sample_path}")
    df_expr = pd.read_csv(open(entrez_sample_path, 'r'), header='infer', sep='\t', index_col=0)
    df_expr.index = df_expr.index.map(str)

    # Load pathways JSON
    with open(in_json, "r", encoding="utf-8") as f:
        pathway_dict = json.load(f)

    result_per_drug: Dict[str, Any] = {}

    # ✅ tqdm progress bar for pathways
    for pathway_name, gene_list in tqdm(pathway_dict.items(), desc=f"Processing pathways for {drug_name}", leave=False):
        try:
            res = compute_pathway_score_for_upgenes(df_expr, gene_list, norm_method=norm_method, perms=perms)
            result_per_drug[pathway_name] = res
        except Exception as e:
            print(f"⚠️ Error computing {pathway_name} for {drug_name}: {e}")

    # Prepare output
    if output_root is None:
        out_dir = drug_dir
    else:
        out_dir = Path(output_root) / drug_name
        out_dir.mkdir(parents=True, exist_ok=True)

    out_json = out_dir / f"{drug_name}_singscore_results.json"

    final_output = {drug_name: result_per_drug}
    with open(out_json, "w", encoding="utf-8") as f:
        json.dump(final_output, f, indent=2, ensure_ascii=False)

    print(f"✅ Wrote results for '{drug_name}' → {out_json}")
    return final_output


def batch_run_on_drug_dirs(
    drug_dirs: List[str],
    entrez_sample_path: str,
    norm_method: str = "theoretical",
    perms: int = 5000,
    output_root: Optional[str] = None
) -> Dict[str, Any]:
    """
    Loop over a list of drug directories and run singScore for each.
    """
    combined = {}
    # ✅ tqdm for drugs
    for d in tqdm(drug_dirs, desc="Processing drugs"):
        drug_dir = Path(d)
        if not drug_dir.exists() or not drug_dir.is_dir():
            print(f"⚠️ Skipping non-directory: {d}")
            continue
        try:
            result = run_singscore_on_drug_folder(
                drug_dir,
                entrez_sample_path,
                norm_method=norm_method,
                perms=perms,
                output_root=output_root
            )
            combined.update(result)
        except Exception as e:
            print(f"❌ Error processing {d}: {e}")
    return combined

# %%
# -----------------------
# Example usage:
# -----------------------
# Suppose you have a parent folder "singscore_new_code" with subfolders:
# singscore_new_code/Doxorubicin/
# singscore_new_code/Paclitaxel/
# each containing Doxorubicin_relevant_pathways.json etc.
#
drug_dirs = ["singscore_new_code/Doxorubicin"] #"singscore_new_code/Paclitaxel", "singscore_new_code/Palbociclib", "singscore_new_code/Zoledronic_Acid", "singscore_new_code/Gemcitabine", "singscore_new_code/Fulvestrant"]
entrez_sample_path = "singscore_new_code/UK65_clean_gene_log_tpm.txt"

# drug_dirs_1 = ["singscore_new_code/Gemcitabine", "singscore_new_code/Fulvestrant"]
#
results = batch_run_on_drug_dirs(drug_dirs, entrez_sample_path, norm_method='theoretical', perms=5000)
#
# This writes per-drug JSON files and returns a dict of all results.
# Out:
# Processing drugs:   0%|          | 0/1 [01:05<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[68], line 14
#      10 entrez_sample_path = "singscore_new_code/UK65_clean_gene_log_tpm.txt"
#      12 # drug_dirs_1 = ["singscore_new_code/Gemcitabine", "singscore_new_code/Fulvestrant"]
#      13 #
# ---> 14 results = batch_run_on_drug_dirs(drug_dirs, entrez_sample_path, norm_method='theoretical', perms=5000)
#      15 #
#      16 # This writes per-drug JSON files and returns a dict of all results.
#
# Cell In[67], line 153, in batch_run_on_drug_dirs(drug_dirs, entrez_sample_path, norm_method, perms, output_root)
#     151     continue
#     152 try:
# --> 153     result = run_singscore_on_drug_folder(
#     154         drug_dir,
#     155         entrez_sample_path,
#     156         norm_method=norm_method,
#     157         perms=perms,
#     158         output_root=output_root
#     159     )
#     160     combined.update(result)
#     161 except Exception as e:
#
# Cell In[67], line 113, in run_singscore_on_drug_folder(drug_dir, entrez_sample_path, norm_method, perms, output_root)
#     111 for pathway_name, gene_list in tqdm(pathway_dict.items(), desc=f"Processing pathways for {drug_name}", leave=False):
#     112     try:
# --> 113         res = compute_pathway_score_for_upgenes(df_expr, gene_list, norm_method=norm_method, perms=perms)
#     114         result_per_drug[pathway_name] = res
#     115     except Exception as e:
#
# Cell In[67], line 54, in compute_pathway_score_for_upgenes(data, up_genes, norm_method, perms)
#      51 total_score = extract_single_numeric_from_df(scored, preferred_cols=['total_score', 'total'])
#      53 # Calculate permutation-based p-value
# ---> 54 permd = permutate(data, n_up=n_up_used, n_down=False, reps=perms, norm_method=norm_method)
#      55 pvals = empiricalpval(permutations=permd, score=scored)
#      56 empirical_p = extract_single_numeric_from_df(pvals, preferred_cols=['empirical', 'p', 'empirical p'])
#
# File d:\GS\PySingscore_replicate\singscore\singscore.py:730, in permutate(sample, n_up, n_down, reps, norm_method, rs_down, centering)
#     727 # permutate
#     728 for r in range(reps):
#     729     # select n_up genes at random
# --> 730     up_gene = numpy.random.choice(sample.index, n_up,
#     731                                   replace=False)
#     732     ru = [] # empty list to append up score to
#     733     # find the rank of the genes
#
# KeyboardInterrupt:

# %% [markdown]
# ## getting scores for each drug-related pathway

# %%
import os
from singscore.singscore import *
import pandas as pd
import json
from tqdm import tqdm

# %%
import os
from singscore.singscore import *
import pandas as pd
import json
from tqdm import tqdm

## loading the patient uk65 data 
uk65 = pd.read_csv("singscore_new_code/UK65_clean_gene_log_tpm.txt", header='infer', sep='\t')
uk65 = uk65.set_index(keys='GeneName')
uk65
# Out:
#                log2_TPM
# GeneName
# 7SK           17.004583
# A1BG           5.457517
# A1BG-AS1       7.251618
# A1CF           1.187320
# A2M            8.725599
# ...                 ...
# ZYG11B         4.011921
# ZYX            7.907273
# ZZEF1          6.529184
# ZZZ3           8.051912
# hsa-mir-1253   4.325359
#
# [24510 rows x 1 columns]

# %%
import os
from singscore.singscore import *
import pandas as pd
import json
from tqdm import tqdm

## loading the patient uk65 data 
uk65 = pd.read_csv("singscore_new_code/UK65_clean_gene_log_tpm.txt", header='infer', sep='\t')
uk65 = uk65.set_index(keys='GeneName')

#loading drug_data
drug_data = json.load(open("singscore_new_code/Doxorubicin/Doxorubicin_relevant_pathways.json"))
count = len(drug_data)
print("Number of items:", count)
# Out:
# Number of items: 796
# {'Mitotic Spindle': ['ACTN4',
#   'PCGF5',
#   'APC',
#   'MARCKS',
#   'NIN',
#   'KIF20B',
#   'EPB41',
#   'STAU1',
#   'CD2AP',
#   'UXT',
#   'PPP4R2',
#   'CSNK1D',
#   'RACGAP1',
#   'CDC27',
#   'PREX1',
#   'STK38L',
#   'ARFIP2',
#   'PLK1',
#   'BCR',
#   'LATS1',
#   'CCDC88A',
#   'TPX2',
#   'BIN1',
#   'NET1',
#   'SASS6',
#   'EZR',
#   'TRIO',
#   'ITSN1',
#   'NUMA1',
#   'SMC4',
#   'SMC3',
#   'ABR',
#   'EPB41L2',
#   'CDK5RAP2',
#   'CEP72',
#   'KIFAP3',
#   'CEP192',
#   'SYNPO',
#   'RHOF',
#   'LRPPRC',
#   'ANLN',
#   'CENPE',
#   'CENPF',
#   'INCENP',
#   'CENPJ',
#   'PAFAH1B1',
#   'ARHGEF2',
#   'ARHGEF3',
#   'RAPGEF6',
#   'KPTN',
#   'ARHGEF7',
#   'RAPGEF5',
#   'RABGAP1',
#   'KIF11',
#   'PIF1',
#   'TOP2A',
#   'KIF15',
#   'NEDD9',
#   'RASAL2',
#   'BRCA2',
#   'CNTRL',
#   'KIF1B',
#   'SPTBN1',
#   'CEP57',
#   'DLGAP5',
#   'MAP1S',
#   'SORBS2',
#   'DYNLL2',
#   'MYO9B',
#   'FARP1',
#   'RANBP9',
#   'SEPTIN9',
#   'CLIP2',
#   'CLIP1',
#   'CTTN',
#   'TAOK2',
#   'LLGL1',
#   'ARF6',
#   'DYNC1H1',
#   'MAPRE1',
#   'RAB3GAP1',
#   'ALMS1',
#   'TUBD1',
#   'WASL',
#   'AKAP13',
#   'PCM1',
#   'OPHN1',
#   'NUSAP1',
#   'RICTOR',
#   'SPTAN1',
#   'GSN',
#   'RALBP1',
#   'ARHGAP29',
#   'TSC1',
#   'ARHGAP27',
#   'MID1',
#   'TUBA4A',
#   'ABI1',
#   'KIF4A',
#   'TUBGCP6',
#   'ARL8A',
#   'TUBGCP5',
#   'CNTROB',
#   'ROCK1',
#   'GEMIN4',
#   'AURKA',
#   'KATNB1',
#   'FGD4',
#   'BCL2L11',
#   'FGD6',
#   'KIF5B',
#   'CEP250',
#   'FLNA',
#   'CLASP1',
#   'FLNB',
#   'KNTC1',
#   'MYH10',
#   'PCNT',
#   'ARHGEF12',
#   'ARHGEF11',
#   'KIF22',
#   'TBCD',
#   'KIF23',
#   'CKAP5',
#   'NDC80',
#   'SSH2',
#   'DLG1',
#   'ARHGAP10',
#   'CDC42EP4',
#   'BIRC5',
#   'CDC42EP2',
#   'FSCN1',
#   'MAP3K11',
#   'CDC42EP1',
#   'KIF2C',
#   'VCL',
#   'DOCK4',
#   'NOTCH2',
#   'PXN',
#   'TUBGCP2',
#   'TUBGCP3',
#   'ARHGAP4',
#   'ARHGAP5',
#   'CCNB2',
#   'KIF3C',
#   'KIF3B',
#   'NEK2',
#   'ABL1',
#   'MARK4',
#   'SAC3D1',
#   'SUN2',
#   'ARFGEF1',
#   'RFC1',
#   'ARAP3',
#   'SHROOM1',
#   'SHROOM2',
#   'CDC42BPA',
#   'SMC1A',
#   'RASA1',
#   'HOOK3',
#   'ESPL1',
#   'RASA2',
#   'MYH9',
#   'CDK1',
#   'NF1',
#   'ATG4B',
#   'DOCK2',
#   'BCAR1',
#   'SOS1',
#   'YWHAE',
#   'LMNB1',
#   'KLC1',
#   'RHOT2',
#   'CAPZB',
#   'ECT2',
#   'WASF1',
#   'WASF2',
#   'PDLIM5',
#   'PLEKHG2',
#   'DST',
#   'CEP131',
#   'MID1IP1',
#   'KATNA1',
#   'PRC1',
#   'TIAM1',
#   'CDC42',
#   'MYO1E',
#   'PALLD',
#   'ALS2',
#   'HDAC6',
#   'TTK',
#   'PKD2',
#   'ARHGDIA',
#   'FBXO5',
#   'TLK1',
#   'BUB1',
#   'CYTH2',
#   'NCK1',
#   'NCK2'],
#  'G2-M Checkpoint': ['H2AZ2',
#   'CASP8AP2',
#   'EGF',
#   'H2AZ1',
#   'KNL1',
#   'SLC12A2',
#   'HUS1',
#   'CDC20',
#   'MAPK14',
#   'PML',
#   'DDX39A',
#   'MARCKS',
#   'NUP98',
#   'HNRNPD',
#   'KIF20B',
#   'CCNF',
#   'HNRNPU',
#   'NOLC1',
#   'EWSR1',
#   'CHEK1',
#   'RACGAP1',
#   'CDC27',
#   'RAD54L',
#   'SNRPD1',
#   'E2F1',
#   'MYC',
#   'E2F2',
#   'E2F3',
#   'E2F4',
#   'PLK4',
#   'PLK1',
#   'SQLE',
#   'STAG1',
#   'TPX2',
#   'UCK2',
#   'EZH2',
#   'ATF5',
#   'JPT1',
#   'NUMA1',
#   'HIF1A',
#   'SMC4',
#   'SMC2',
#   'GSPT1',
#   'TMPO',
#   'MT2A',
#   'SYNCRIP',
#   'STMN1',
#   'MYBL2',
#   'BARD1',
#   'SS18',
#   'UPF1',
#   'CDC7',
#   'CDC6',
#   'CENPE',
#   'SLC7A5',
#   'CENPF',
#   'INCENP',
#   'MTF2',
#   'PAFAH1B1',
#   'CDKN3',
#   'DTYMK',
#   'KIF11',
#   'YTHDC1',
#   'SUV39H1',
#   'TOP2A',
#   'KIF15',
#   'RASAL2',
#   'BRCA2',
#   'CTCF',
#   'SLC7A1',
#   'HOXC10',
#   'PBK',
#   'MAP3K20',
#   'CDKN2C',
#   'PRMT5',
#   'RPA2',
#   'TRAIP',
#   'CKS2',
#   'TACC3',
#   'H2AX',
#   'CDKN1B',
#   'PRIM2',
#   'MKI67',
#   'CENPA',
#   'XPO1',
#   'WRN',
#   'DMD',
#   'NUSAP1',
#   'SRSF10',
#   'GINS2',
#   'TGFB1',
#   'TLE3',
#   'UBE2C',
#   'CDC25A',
#   'PRPF4B',
#   'LIG3',
#   'ILF3',
#   'CDC25B',
#   'SAP30',
#   'DKC1',
#   'UBE2S',
#   'KIF4A',
#   'PTTG3P',
#   'MAD2L1',
#   'CCNT1',
#   'ODC1',
#   'SRSF1',
#   'SRSF2',
#   'ARID4A',
#   'AURKA',
#   'EFNA5',
#   'HIRA',
#   'AURKB',
#   'CCND1',
#   'NSD2',
#   'PURA',
#   'KIF5B',
#   'PTTG1',
#   'KMT5A',
#   'HMGN2',
#   'KPNA2',
#   'SMAD3',
#   'SLC38A1',
#   'KIF22',
#   'ODF2',
#   'STIL',
#   'FANCC',
#   'KIF23',
#   'NASP',
#   'FOXN3',
#   'NDC80',
#   'CCNA2',
#   'TFDP1',
#   'NCL',
#   'BIRC5',
#   'TROAP',
#   'KIF2C',
#   'MNAT1',
#   'NOTCH2',
#   'CUL5',
#   'CUL3',
#   'CUL1',
#   'PDS5B',
#   'CHAF1A',
#   'CCNB2',
#   'G3BP1',
#   'CHMP1A',
#   'NEK2',
#   'ABL1',
#   'DR1',
#   'HSPA8',
#   'CBX1',
#   'RAD23B',
#   'HMGA1',
#   'SMC1A',
#   'CUL4A',
#   'NUP50',
#   'POLA2',
#   'MEIS2',
#   'RBL1',
#   'MEIS1',
#   'ESPL1',
#   'SFPQ',
#   'CDK4',
#   'H2BC12',
#   'BCL3',
#   'CDK1',
#   'MCM5',
#   'MCM6',
#   'TOP1',
#   'MCM2',
#   'MCM3',
#   'AMD1',
#   'CKS1B',
#   'HMGB3',
#   'HMMR',
#   'LMNB1',
#   'TENT4A',
#   'ORC6',
#   'ORC5',
#   'RAD21',
#   'LBR',
#   'TNPO2',
#   'RBM14',
#   'SMARCC1',
#   'ATRX',
#   'POLQ',
#   'KATNA1',
#   'PRC1',
#   'KPNB1',
#   'DBF4',
#   'TTK',
#   'RPS6KA5',
#   'CDC45',
#   'POLE',
#   'EXO1',
#   'TRA2B',
#   'FBXO5',
#   'BUB3',
#   'BUB1'],
#  'Estrogen Response Late': ['UNC13B',
#   'HOMER2',
#   'CACNA2D2',
#   'AMFR',
#   'MAPK13',
#   'CDC20',
#   'ASS1',
#   'CD9',
#   'GLA',
#   'KIF20A',
#   'NBL1',
#   'TOB1',
#   'ASCL1',
#   'MYB',
#   'CCN5',
#   'MEST',
#   'FDFT1',
#   'ABCA3',
#   'PLK4',
#   'EGR3',
#   'CHST8',
#   'XBP1',
#   'ST14',
#   'TNNC1',
#   'XRCC3',
#   'SIAH2',
#   'PLAAT3',
#   'OVOL2',
#   'PDZK1',
#   'IL17RB',
#   'SULT2B1',
#   'GJB3',
#   'IGSF1',
#   'HPRT1',
#   'PTGES',
#   'HSPA4L',
#   'SLC22A5',
#   'TSTA3',
#   'RAPGEFL1',
#   'SOX3',
#   'PRKAR2B',
#   'PLAC1',
#   'SFN',
#   'TPSAB1',
#   'DUSP2',
#   'ITPK1',
#   'MYOF',
#   'EMP2',
#   'KRT13',
#   'CDC6',
#   'FAM102A',
#   'KLK10',
#   'COX6C',
#   'KLK11',
#   'SLC7A5',
#   'UGDH',
#   'KRT19',
#   'NCOR2',
#   'TH',
#   'MAPT',
#   'NMU',
#   'ID2',
#   'TFF3',
#   'TFF1',
#   'MOCS2',
#   'SGK1',
#   'SERPINA3',
#   'RET',
#   'BTG3',
#   'SERPINA1',
#   'FOXC1',
#   'ABHD2',
#   'TOP2A',
#   'TMPRSS3',
#   'AREG',
#   'SERPINA5',
#   'CLIC3',
#   'ELOVL5',
#   'METTL3',
#   'FOS',
#   'DHRS2',
#   'FARP1',
#   'GAL',
#   'FABP5',
#   'SLC29A1',
#   'LLGL2',
#   'CD44',
#   'TJP3',
#   'PTGER3',
#   'PRSS23',
#   'SNX10',
#   'IMPA2',
#   'CKB',
#   'ANXA9',
#   'AGR2',
#   'JAK1',
#   'JAK2',
#   'GINS2',
#   'CA12',
#   'TFAP2C',
#   'PRLR',
#   'SLC16A1',
#   'TFPI2',
#   'NPY1R',
#   'BATF',
#   'OLFM1',
#   'CXCL12',
#   'RAB31',
#   'PCP4',
#   'PKP3',
#   'PDCD4',
#   'PPIF',
#   'IL6ST',
#   'PLXNB1',
#   'DHCR7',
#   'FKBP5',
#   'FKBP4',
#   'PTPN6',
#   'S100A9',
#   'FRK',
#   'SLC27A2',
#   'SCNN1A',
#   'HR',
#   'SLC1A4',
#   'CELSR2',
#   'CXCL14',
#   'PAPSS2',
#   'SCUBE2',
#   'ZFP36',
#   'CCND1',
#   'CDH1',
#   'PERP',
#   'FLNB',
#   'RBBP8',
#   'MICB',
#   'OPN3',
#   'WFS1',
#   'CISH',
#   'STIL',
#   'IDH2',
#   'IGFBP4',
#   'DNAJC12',
#   'CYP4F11',
#   'SLC9A3R1',
#   'ALDH3A2',
#   'ISG20',
#   'CCNA1',
#   'DLG5',
#   'PGR',
#   'RNASEH2A',
#   'BLVRB',
#   'FGFR3',
#   'SLC26A2',
#   'NAB2',
#   'ARL3',
#   'SLC2A8',
#   'CALCR',
#   'BAG1',
#   'ALDH3B1',
#   'HMGCS2',
#   'CAV1',
#   'SORD',
#   'RABEP1',
#   'DNAJC1',
#   'ACOX2',
#   'CHPT1',
#   'CPE',
#   'BCL2',
#   'KCNK5',
#   'ST6GALNAC2',
#   'HSPB8',
#   'LAMC2',
#   'AFF1',
#   'CA2',
#   'MDK',
#   'CYP26B1',
#   'PDLIM3',
#   'NRIP1',
#   'GPER1',
#   'DYNLT3',
#   'DCXR',
#   'TPBG',
#   'ATP2B4',
#   'LSR',
#   'KLF4',
#   'TIAM1',
#   'TPD52L1',
#   'GALE',
#   'TST',
#   'LTF',
#   'SLC24A3',
#   'NXT1',
#   'SEMA3B',
#   'ETFB',
#   'TSPAN13',
#   'ADD3',
#   'TRIM29',
#   'RPS6KA2',
#   'SCARB1',
#   'LARGE1'],
#  'Interferon Alpha Response': ['CD74',
#   'IL4R',
#   'MX1',
#   'SP110',
#   'RSAD2',
#   'TAP1',
#   'PSMB9',
#   'CXCL10',
#   'CXCL11',
#   'IFI44L',
#   'LAP3',
#   'LPAR6',
#   'IFI27',
#   'TRAFD1',
#   'LY6E',
#   'TRIM14',
#   'IFITM2',
#   'IFITM3',
#   'SAMD9',
#   'CSF1',
#   'IFITM1',
#   'SAMD9L',
#   'UBE2L6',
#   'RNF31',
#   'HERC6',
#   'LAMP3',
#   'CCRL2',
#   'MVB12A',
#   'B2M',
#   'CMTR1',
#   'GBP2',
#   'EPSTI1',
#   'GBP4',
#   'BATF2',
#   'HLA-C',
#   'TENT5A',
#   'ISG15',
#   'TDRD7',
#   'IFI44',
#   'PARP14',
#   'MOV10',
#   'ISG20',
#   'PARP12',
#   'PLSCR1',
#   'PROCR',
#   'SELL',
#   'PSME2',
#   'PSME1',
#   'CNP',
#   'LGALS3BP',
#   'IFI35',
#   'IFIT2',
#   'IFI30',
#   'DDX60',
#   'IFIT3',
#   'HELZ2',
#   'NUB1',
#   'PNPT1',
#   'IL15',
#   'NCOA7',
#   'EIF2AK2',
#   'NMI',
#   'OAS1',
#   'BST2',
#   'ELF1',
#   'IRF1',
#   'IL7',
#   'IRF2',
#   'IRF9',
#   'IRF7',
#   'UBA7',
#   'GMPR',
#   'ADAR',
#   'CASP8',
#   'TRIM5',
#   'RIPK2',
#   'CASP1',
#   'STAT2',
#   'WARS1',
#   'PARP9',
#   'PSMA3',
#   'CMPK2',
#   'TXNIP',
#   'CD47',
#   'RTP4',
#   'C1S',
#   'OGFR',
#   'TMEM140',
#   'USP18',
#   'OASL',
#   'SLC25A28',
#   'IFIH1',
#   'PSMB8',
#   'DHX58',
#   'TRIM25',
#   'TRIM26',
#   'TRIM21'],
#  'Interferon Gamma Response': ['GBP6',
#   'MX1',
#   'SP110',
#   'MX2',
#   'RSAD2',
#   'PSMB9',
#   'PML',
#   'NUP93',
#   'LAP3',
#   'MTHFD2',
#   'IFI27',
#   'TRIM14',
#   'RBCK1',
#   'IDO1',
#   'IFITM2',
#   'IFITM3',
#   'FGL2',
#   'NOD1',
#   'UBE2L6',
#   'PSMB10',
#   'APOL6',
#   'HERC6',
#   'PNP',
#   'ST3GAL5',
#   'SLAMF7',
#   'B2M',
#   'EPSTI1',
#   'GBP4',
#   'BATF2',
#   'ST8SIA4',
#   'PLA2G4A',
#   'HLA-A',
#   'HLA-B',
#   'HLA-G',
#   'IFI44',
#   'PARP14',
#   'LATS2',
#   'PARP12',
#   'PLSCR1',
#   'VAMP8',
#   'BANK1',
#   'PSME2',
#   'SERPING1',
#   'PSME1',
#   'SSPN',
#   'VAMP5',
#   'CFB',
#   'HLA-DRB1',
#   'CFH',
#   'IFI35',
#   'HIF1A',
#   'IFIT2',
#   'IFI30',
#   'IFIT1',
#   'ICAM1',
#   'IFIT3',
#   'RNF213',
#   'HELZ2',
#   'MT2A',
#   'KLRK1',
#   'TNFSF10',
#   'CMKLR1',
#   'GPR18',
#   'NCOA3',
#   'PNPT1',
#   'IL15',
#   'IL10RA',
#   'NMI',
#   'BST2',
#   'RAPGEF6',
#   'IL18BP',
#   'CD40',
#   'BTG1',
#   'SECTM1',
#   'FPR1',
#   'SOCS3',
#   'SOCS1',
#   'CD38',
#   'RIPK2',
#   'RIPK1',
#   'HLA-DQA1',
#   'P2RY14',
#   'STAT1',
#   'GCH1',
#   'STAT2',
#   'STAT3',
#   'STAT4',
#   'PSMA2',
#   'PSMA3',
#   'CMPK2',
#   'PELI1',
#   'MARCHF1',
#   'CDKN1A',
#   'OGFR',
#   'PTGS2',
#   'IFIH1',
#   'PSMB8',
#   'NAMPT',
#   'PSMB2',
#   'METTL7B',
#   'HLA-DMA',
#   'JAK2',
#   'PTPN1',
#   'PTPN2',
#   'ZBP1',
#   'CD74',
#   'IL4R',
#   'TOR1B',
#   'TAP1',
#   'VCAM1',
#   'CXCL10',
#   'CXCL11',
#   'IFI44L',
#   'ZNFX1',
#   'FAS',
#   'TRAFD1',
#   'LY6E',
#   'CD69',
#   'PTPN6',
#   'CD86',
#   'SAMD9L',
#   'RNF31',
#   'CMTR1',
#   'DDX58',
#   'AUTS2',
#   'ARID5B',
#   'ISG15',
#   'TDRD7',
#   'NFKB1',
#   'ISG20',
#   'MYD88',
#   'SELP',
#   'XAF1',
#   'IFNAR2',
#   'CD274',
#   'LGALS3BP',
#   'SPPL2A',
#   'CSF2RB',
#   'DDX60',
#   'PIM1',
#   'EIF2AK2',
#   'XCL1',
#   'TAPBP',
#   'IRF1',
#   'NFKBIA',
#   'IL7',
#   'IL6',
#   'IRF4',
#   'OAS2',
#   'IRF5',
#   'OAS3',
#   'IRF2',
#   'IRF8',
#   'IRF9',
#   'IRF7',
#   'LCP2',
#   'EIF4E3',
#   'ARL4A',
#   'CXCL9',
#   'TNFAIP6',
#   'TNFAIP3',
#   'NLRC5',
#   'TNFAIP2',
#   'ADAR',
#   'CASP8',
#   'CASP7',
#   'CASP4',
#   'CASP3',
#   'ISOC1',
#   'PDE4B',
#   'CASP1',
#   'CIITA',
#   'IL15RA',
#   'GZMA',
#   'LYSMD2',
#   'BPGM',
#   'WARS1',
#   'SOD2',
#   'IL2RB',
#   'TXNIP',
#   'PFKP',
#   'C1R',
#   'RTP4',
#   'C1S',
#   'MVP',
#   'SRI',
#   'USP18',
#   'OASL',
#   'SAMHD1',
#   'SLC25A28',
#   'FCGR1A',
#   'CCL7',
#   'DHX58',
#   'CCL5',
#   'TRIM25',
#   'TRIM26',
#   'CCL2',
#   'ITGB7',
#   'TRIM21',
#   'UPP1'],
#  'Apical Junction': ['GAMT',
#   'ACTN4',
#   'CADM2',
#   'ACTN3',
#   'CADM3',
#   'ACTN2',
#   'ACTN1',
#   'MAPK13',
#   'MAPK14',
#   'MAPK11',
#   'CD209',
#   'COL9A1',
#   'MYL9',
#   'PFN1',
#   'SKAP2',
#   'MYL12B',
#   'PARD6G',
#   'ACTB',
#   'TIAL1',
#   'AKT3',
#   'AKT2',
#   'FYB1',
#   'TUBG1',
#   'ALOX15B',
#   'PBX2',
#   'PTK2',
#   'VASP',
#   'WNK4',
#   'GRB7',
#   'DMP1',
#   'ICAM4',
#   'ICAM5',
#   'ICAM1',
#   'ICAM2',
#   'EPB41L2',
#   'DHX16',
#   'PLCG1',
#   'TSPAN4',
#   'TMEM8B',
#   'CDSN',
#   'JUP',
#   'RHOF',
#   'VAV2',
#   'CLDN11',
#   'PTPRC',
#   'CLDN15',
#   'CLDN14',
#   'CLDN19',
#   'EXOC4',
#   'CLDN18',
#   'ARHGEF6',
#   'SDC3',
#   'TNFRSF11B',
#   'THY1',
#   'CX3CL1',
#   'RRAS',
#   'MPZL1',
#   'RSU1',
#   'MAP3K20',
#   'CD34',
#   'MPZL2',
#   'MAP4K2',
#   'CAP1',
#   'MPP5',
#   'SYK',
#   'SORBS3',
#   'LIMA1',
#   'TJP1',
#   'ADAM15',
#   'TAOK2',
#   'CRB3',
#   'AMIGO1',
#   'AMIGO2',
#   'ADAM23',
#   'WASL',
#   'GNAI1',
#   'GNAI2',
#   'CTNNA1',
#   'HRAS',
#   'LDLRAP1',
#   'RAC2',
#   'IKBKG',
#   'GTF2F1',
#   'TSC1',
#   'VCAM1',
#   'ITGA10',
#   'TGFBI',
#   'ZYX',
#   'ADAM9',
#   'DSC1',
#   'CRAT',
#   'DSC3',
#   'CNTN1',
#   'CD86',
#   'COL16A1',
#   'CTNND1',
#   'NEXN',
#   'ATP1A3',
#   'INPPL1',
#   'EGFR',
#   'CDH8',
#   'CDH6',
#   'CDH4',
#   'CDH3',
#   'CDH1',
#   'NRAP',
#   'SLIT2',
#   'FLNC',
#   'STX4',
#   'MYH10',
#   'JAM3',
#   'KCNH2',
#   'SLC30A3',
#   'TRAF1',
#   'LAYN',
#   'KRT31',
#   'DLG1',
#   'CDH11',
#   'ARPC2',
#   'FSCN1',
#   'CDH15',
#   'FBN1',
#   'VCL',
#   'CD276',
#   'CD274',
#   'COL17A1',
#   'IRS1',
#   'INSIG1',
#   'ACTG1',
#   'ACTG2',
#   'CNN2',
#   'PDZD3',
#   'SIRPA',
#   'NRTN',
#   'HADH',
#   'CD99',
#   'LAMB3',
#   'MMP2',
#   'ITGA3',
#   'MSN',
#   'ITGA2',
#   'SHROOM2',
#   'MMP9',
#   'BAIAP2',
#   'PARVA',
#   'RASA1',
#   'VCAN',
#   'ACTA1',
#   'CDK8',
#   'BMP1',
#   'PIK3CB',
#   'ITGA9',
#   'MYH9',
#   'NF2',
#   'NF1',
#   'PECAM1',
#   'B4GALT1',
#   'NLGN2',
#   'NLGN3',
#   'SHC1',
#   'NRXN2',
#   'PIK3R3',
#   'LAMC2',
#   'ADRA1B',
#   'TRO',
#   'MDK',
#   'CALB2',
#   'MADCAM1',
#   'SYMPK',
#   'AMH',
#   'YWHAH',
#   'NEGR1',
#   'VWF',
#   'CLDN7',
#   'CLDN6',
#   'CLDN5',
#   'CLDN4',
#   'NFASC',
#   'PPP2R2C',
#   'CLDN9',
#   'CLDN8',
#   'NECTIN1',
#   'CERCAM',
#   'EVL',
#   'MVD',
#   'NECTIN4',
#   'NECTIN3',
#   'NECTIN2',
#   'ITGB1',
#   'PKD1',
#   'SRC',
#   'LAMA3',
#   'ITGB4',
#   'PTEN',
#   'ACTC1',
#   'THBS3',
#   'ADAMTS5',
#   'SGCE',
#   'SPEG',
#   'PCDH1'],
#  'Complement': ['ACTN2',
#   'HPCAL4',
#   'PSMB9',
#   'XPNPEP1',
#   'LAP3',
#   'FDX1',
#   'HSPA1A',
#   'CALM3',
#   'PFN1',
#   'CDA',
#   'CALM1',
#   'LRP1',
#   'SERPINE1',
#   'C4BPB',
#   'CBLB',
#   'PRCP',
#   'ITIH1',
#   'RNF4',
#   'GNG2',
#   'S100A13',
#   'SPOCK2',
#   'PRSS3',
#   'S100A12',
#   'APOBEC3F',
#   'APOBEC3G',
#   'PRKCD',
#   'PLA2G4A',
#   'EHD1',
#   'PLSCR1',
#   'LGMN',
#   'SERPING1',
#   'GRB2',
#   'ZFPM2',
#   'CFB',
#   'GMFB',
#   'CFH',
#   'PDGFB',
#   'PREP',
#   'GATA3',
#   'PLA2G7',
#   'C2',
#   'LIPA',
#   'C3',
#   'LGALS3',
#   'PPP4C',
#   'C9',
#   'LTA4H',
#   'CTSB',
#   'DUSP5',
#   'DUSP6',
#   'LYN',
#   'ANXA5',
#   'FN1',
#   'SIRT6',
#   'RHOG',
#   'CP',
#   'RBSN',
#   'GP9',
#   'MMP13',
#   'ZEB1',
#   'MMP12',
#   'MMP15',
#   'MMP14',
#   'KLKB1',
#   'SERPINA1',
#   'TMPRSS6',
#   'KLK1',
#   'PCSK9',
#   'CTSV',
#   'CTSS',
#   'GNGT2',
#   'CTSO',
#   'CSRP1',
#   'CASP10',
#   'CTSL',
#   'HNF4A',
#   'CTSH',
#   'RCE1',
#   'TIMP1',
#   'TIMP2',
#   'CD36',
#   'FCER1G',
#   'CTSD',
#   'CTSC',
#   'SERPINB2',
#   'PRSS36',
#   'F2',
#   'GP1BA',
#   'F3',
#   'RABIF',
#   'F5',
#   'F7',
#   'F8',
#   'PDP1',
#   'COL4A2',
#   'CD40LG',
#   'CDK5R1',
#   'CD46',
#   'MSRB1',
#   'C1QC',
#   'C1QA',
#   'SERPINC1',
#   'WAS',
#   'GNAI2',
#   'GNAI3',
#   'PHEX',
#   'PCLO',
#   'PPP2CB',
#   'CD59',
#   'AKAP10',
#   'OLR1',
#   'CD55',
#   'JAK2',
#   'USP8',
#   'BRPF3',
#   'F10',
#   'GCA',
#   'TFPI2',
#   'GPD2',
#   'ADAM9',
#   'SCG3',
#   'S100A9',
#   'FCN1',
#   'RAF1',
#   'DGKH',
#   'DGKG',
#   'PRDM4',
#   'CLU',
#   'DOCK10',
#   'LAMP2',
#   'STX4',
#   'SH2B3',
#   'ADRA2B',
#   'MAFF',
#   'KIF2A',
#   'GNB2',
#   'CDH13',
#   'GNB4',
#   'NOTCH4',
#   'DOCK4',
#   'DYRK2',
#   'DOCK9',
#   'PSEN1',
#   'PLAT',
#   'VCPIP1',
#   'RASGRP1',
#   'PIM1',
#   'MMP8',
#   'KCNIP2',
#   'HSPA5',
#   'KCNIP3',
#   'MT3',
#   'APOA4',
#   'IRF1',
#   'IL6',
#   'PIK3CA',
#   'IRF2',
#   'IRF7',
#   'LCP2',
#   'CPM',
#   'CPQ',
#   'L3MBTL4',
#   'PIK3R5',
#   'TNFAIP3',
#   'CXCL1',
#   'DPP4',
#   'CA2',
#   'CASP9',
#   'CASP7',
#   'CASP4',
#   'CASP5',
#   'CASP3',
#   'ME1',
#   'CASP1',
#   'CR1',
#   'CR2',
#   'GZMB',
#   'ERAP2',
#   'GZMA',
#   'PLAUR',
#   'ATOX1',
#   'GZMK',
#   'LCK',
#   'APOC1',
#   'ANG',
#   'LTF',
#   'USP14',
#   'CEBPB',
#   'USP15',
#   'C1R',
#   'SRC',
#   'USP16',
#   'PLEK',
#   'C1S',
#   'PLG',
#   'ITGAM',
#   'PIK3CG',
#   'CCL5',
#   'KYNU',
#   'FYN'],
#  'PI3K/AKT/mTOR  Signaling': ['TSC2',
#   'PPP1CA',
#   'MAPK10',
#   'SQSTM1',
#   'PFN1',
#   'RAF1',
#   'UBE2N',
#   'PRKAA2',
#   'RALB',
#   'ATF1',
#   'SLA',
#   'UBE2D3',
#   'NOD1',
#   'ADCY2',
#   'IL2RG',
#   'EGFR',
#   'HSP90B1',
#   'E2F1',
#   'AKT1',
#   'CFL1',
#   'MAP3K7',
#   'PAK4',
#   'PITX2',
#   'FGF22',
#   'SMAD2',
#   'MAP2K3',
#   'PRKCB',
#   'TRAF2',
#   'FGF17',
#   'MYD88',
#   'ARPC3',
#   'CSNK2B',
#   'GRB2',
#   'PIN1',
#   'SLC2A1',
#   'FASLG',
#   'DAPP1',
#   'FGF6',
#   'TBK1',
#   'THEM4',
#   'PRKAR2A',
#   'PLCG1',
#   'SFN',
#   'PDK1',
#   'MAP2K6',
#   'AP2M1',
#   'ACTR3',
#   'ACTR2',
#   'DUSP3',
#   'PTPN11',
#   'IRAK4',
#   'TNFRSF1A',
#   'VAV3',
#   'NFKBIB',
#   'IL4',
#   'ECSIT',
#   'PIKFYVE',
#   'AKT1S1',
#   'CDK4',
#   'CDK2',
#   'CAMK4',
#   'CDK1',
#   'CALR',
#   'GSK3B',
#   'YWHAB',
#   'ARF1',
#   'CAB39L',
#   'MAPKAP1',
#   'CLTC',
#   'ITPR2',
#   'PIK3R3',
#   'ACACA',
#   'GRK2',
#   'GNGT1',
#   'MKNK1',
#   'MKNK2',
#   'RIPK1',
#   'EIF4E',
#   'PLA2G12A',
#   'STAT2',
#   'NGF',
#   'TIAM1',
#   'LCK',
#   'RIT1',
#   'DDIT3',
#   'TRIB3',
#   'PLCB1',
#   'CDKN1B',
#   'CDKN1A',
#   'CAB39',
#   'PTEN',
#   'PRKAG1',
#   'GNA14',
#   'ARHGDIA',
#   'RPTOR',
#   'MAPK9',
#   'MAPK8',
#   'RPS6KA1',
#   'PPP2R1B',
#   'CXCR4',
#   'RPS6KA3',
#   'HRAS',
#   'MAPK1',
#   'RAC1',
#   'NCK1'],
#  'mTORC1 Signaling': ['STARD4',
#   'ACSL3',
#   'IFRD1',
#   'SYTL2',
#   'PPA1',
#   'HSPE1',
#   'CCT6A',
#   'DDX39A',
#   'PSMC6',
#   'SCD',
#   'HMBS',
#   'MTHFD2',
#   'PSMC4',
#   'CD9',
#   'MTHFD2L',
#   'PSMC2',
#   'CTH',
#   'POLR3G',
#   'GLA',
#   'SKAP2',
#   'TES',
#   'NUP205',
#   'FGL2',
#   'CCNF',
#   'ARPC5L',
#   'GLRX',
#   'PNP',
#   'XBP1',
#   'PLK1',
#   'EDEM1',
#   'TUBG1',
#   'DHFR',
#   'UCHL5',
#   'SLC6A6',
#   'SQLE',
#   'MLLT11',
#   'EPRS1',
#   'LGMN',
#   'PSME3',
#   'HPRT1',
#   'NMT1',
#   'TFRC',
#   'PITPNB',
#   'ENO1',
#   'TMEM97',
#   'CFP',
#   'IFI30',
#   'RRP9',
#   'TBK1',
#   'FDXR',
#   'PRDX1',
#   'LTA4H',
#   'PNO1',
#   'SERPINH1',
#   'PDK1',
#   'SDF2L1',
#   'TPI1',
#   'SLC7A5',
#   'P4HA1',
#   'BHLHE40',
#   'CCNG1',
#   'CALR',
#   'ALDOA',
#   'EEF1E1',
#   'GPI',
#   'BTG2',
#   'RPN1',
#   'STC1',
#   'ADIPOR2',
#   'SLC7A11',
#   'VLDLR',
#   'ACACA',
#   'STIP1',
#   'LDHA',
#   'SSR1',
#   'NFIL3',
#   'PHGDH',
#   'CTSC',
#   'EGLN3',
#   'ELOVL5',
#   'ELOVL6',
#   'NFYC',
#   'CACYBP',
#   'GTF2H1',
#   'RPA1',
#   'PSMA4',
#   'PSMA3',
#   'RIT1',
#   'CANX',
#   'USO1',
#   'TCEA1',
#   'TOMM40',
#   'ERO1A',
#   'CDKN1A',
#   'GBE1',
#   'UNG',
#   'PSMB5',
#   'SERP1',
#   'NAMPT',
#   'CXCR4',
#   'FADS2',
#   'FADS1',
#   'G6PD',
#   'GSR',
#   'CDC25A',
#   'PDAP1',
#   'TUBA4A',
#   'COPS5',
#   'PPIA',
#   'NUPR1',
#   'PSAT1',
#   'DHCR7',
#   'SQSTM1',
#   'RAB1A',
#   'FKBP2',
#   'SLA',
#   'UBE2D3',
#   'PPP1R15A',
#   'AURKA',
#   'SLC1A4',
#   'SLC1A5',
#   'PLOD2',
#   'HSP90B1',
#   'GGA2',
#   'SC5D',
#   'YKT6',
#   'LDLR',
#   'ABCF2',
#   'IDH1',
#   'NIBAN1',
#   'MAP2K3',
#   'GOT1',
#   'IGFBP5',
#   'M6PR',
#   'EIF2S2',
#   'SLC9A3R1',
#   'ACLY',
#   'QDPR',
#   'GCLC',
#   'BCAT1',
#   'ATP6V1D',
#   'INSIG1',
#   'SLC2A1',
#   'AK4',
#   'SLC2A3',
#   'CORO1A',
#   'ATP5MC1',
#   'DAPP1',
#   'TM7SF2',
#   'EBP',
#   'SRD5A1',
#   'PSPH',
#   'ACTR3',
#   'CYB5B',
#   'HSPA9',
#   'ACTR2',
#   'HMGCS1',
#   'HSPA5',
#   'TXNRD1',
#   'ASNS',
#   'HSPA4',
#   'DHCR24',
#   'SORD',
#   'NFKBIB',
#   'MCM4',
#   'ETF1',
#   'PSMG1',
#   'MCM2',
#   'IDI1',
#   'GSK3B',
#   'NUFIP1',
#   'PSMD13',
#   'PSMD12',
#   'PSMD14',
#   'SHMT2',
#   'GMPS',
#   'PIK3R3',
#   'HK2',
#   'RDH11',
#   'ME1',
#   'PGK1',
#   'SLC37A4',
#   'RRM2',
#   'CYP51A1',
#   'IMMT',
#   'WARS1',
#   'PFKL',
#   'UFM1',
#   'DDIT4',
#   'DDIT3',
#   'TRIB3',
#   'GAPDH',
#   'ITGB2',
#   'SEC11A',
#   'ATP2A2',
#   'HMGCR',
#   'HSPD1',
#   'ADD3',
#   'BUB1',
#   'PGM1'],
#  'E2F Targets': ['DUT',
#   'H2AZ1',
#   'DEK',
#   'HUS1',
#   'CDC20',
#   'PHF5A',
#   'ZW10',
#   'DDX39A',
#   'MTHFD2',
#   'CCP110',
#   'ANP32E',
#   'ASF1A',
#   'HNRNPD',
#   'ASF1B',
#   'TP53',
#   'RAN',
#   'NUP205',
#   'NOLC1',
#   'PNN',
#   'EXOSC8',
#   'CHEK1',
#   'RACGAP1',
#   'CHEK2',
#   'MYC',
#   'TIPIN',
#   'E2F8',
#   'PLK4',
#   'PLK1',
#   'XRCC6',
#   'TUBG1',
#   'STAG1',
#   'EZH2',
#   'JPT1',
#   'POP7',
#   'CDCA3',
#   'TFRC',
#   'CDCA8',
#   'PRKDC',
#   'SMC6',
#   'SMC4',
#   'GSPT1',
#   'SMC3',
#   'PRDX4',
#   'TMPO',
#   'SYNCRIP',
#   'STMN1',
#   'MYBL2',
#   'BARD1',
#   'TCF19',
#   'TUBB',
#   'NME1',
#   'CENPE',
#   'RAD51C',
#   'CENPM',
#   'DEPDC1',
#   'CDKN3',
#   'SLBP',
#   'SUV39H1',
#   'TOP2A',
#   'BRCA1',
#   'BRCA2',
#   'CTCF',
#   'PSMC3IP',
#   'RAD51AP1',
#   'TK1',
#   'LYAR',
#   'DLGAP5',
#   'ATAD2',
#   'CDKN2C',
#   'HELLS',
#   'MLH1',
#   'CDKN2A',
#   'RANBP1',
#   'RPA2',
#   'RPA3',
#   'RPA1',
#   'CIT',
#   'SPC24',
#   'NUDT21',
#   'CCNE1',
#   'CKS2',
#   'NCAPD2',
#   'TRIP13',
#   'TACC3',
#   'TIMELESS',
#   'RAD1',
#   'SPC25',
#   'H2AX',
#   'CDKN1B',
#   'CDKN1A',
#   'DSCC1',
#   'PRIM2',
#   'MKI67',
#   'UNG',
#   'XPO1',
#   'ING3',
#   'PPP1R8',
#   'GINS3',
#   'GINS1',
#   'LIG1',
#   'GINS4',
#   'CDC25A',
#   'DONSON',
#   'MSH2',
#   'ILF3',
#   'CDC25B',
#   'MELK',
#   'UBE2S',
#   'UBE2T',
#   'BUB1B',
#   'KIF4A',
#   'POLE4',
#   'CNOT9',
#   'MRE11',
#   'MAD2L1',
#   'SNRPB',
#   'PCNA',
#   'DCLRE1B',
#   'SRSF1',
#   'SRSF2',
#   'AURKA',
#   'TBRG4',
#   'AURKB',
#   'PTTG1',
#   'NBN',
#   'CSE1L',
#   'USP1',
#   'RBBP7',
#   'PMS2',
#   'KPNA2',
#   'KIF22',
#   'NUP153',
#   'CTPS1',
#   'NASP',
#   'EIF2S1',
#   'MMS22L',
#   'PAN2',
#   'DIAPH3',
#   'KIF18B',
#   'BIRC5',
#   'KIF2C',
#   'RNASEH2A',
#   'DNMT1',
#   'MXD3',
#   'AK2',
#   'IPO7',
#   'PDS5B',
#   'CCNB2',
#   'PAICS',
#   'CBX5',
#   'RFC2',
#   'RFC3',
#   'RFC1',
#   'PA2G4',
#   'HMGA1',
#   'NAP1L1',
#   'SMC1A',
#   'POLA2',
#   'ESPL1',
#   'CDK4',
#   'BRMS1L',
#   'MCM4',
#   'CDK1',
#   'MCM5',
#   'DCTPP1',
#   'MCM6',
#   'MCM7',
#   'NAA38',
#   'LUC7L3',
#   'MCM2',
#   'MCM3',
#   'SHMT1',
#   'CKS1B',
#   'HMGB3',
#   'HMMR',
#   'LMNB1',
#   'PSIP1',
#   'HMGB2',
#   'ORC6',
#   'RAD21',
#   'ORC2',
#   'UBR7',
#   'LBR',
#   'EED',
#   'RRM2',
#   'SPAG5',
#   'DCK',
#   'SSRP1',
#   'RAD50',
#   'WEE1',
#   'PPM1D',
#   'NOP56',
#   'NUP107',
#   'PRPS1',
#   'WDR90',
#   'POLE',
#   'POLD1',
#   'POLD2',
#   'POLD3',
#   'TRA2B'],
#  'Epithelial Mesenchymal Transition': ['LUM',
#   'CADM1',
#   'DKK1',
#   'P3H1',
#   'COL1A2',
#   'SFRP4',
#   'COL1A1',
#   'MGP',
#   'VIM',
#   'MXRA5',
#   'MYL9',
#   'PFN2',
#   'PRSS2',
#   'LRP1',
#   'TAGLN',
#   'COL12A1',
#   'SERPINE1',
#   'SERPINE2',
#   'SFRP1',
#   'DPYSL3',
#   'ABI3BP',
#   'SPOCK1',
#   'CCN2',
#   'MEST',
#   'CCN1',
#   'GADD45B',
#   'FZD8',
#   'GADD45A',
#   'FERMT2',
#   'SLC6A8',
#   'SDC1',
#   'SNAI2',
#   'SPARC',
#   'OXTR',
#   'ENO2',
#   'MYLK',
#   'GJA1',
#   'LGALS1',
#   'ANPEP',
#   'SERPINH1',
#   'FUCA1',
#   'JUN',
#   'IL15',
#   'TNFRSF12A',
#   'MAGEE1',
#   'VEGFC',
#   'FN1',
#   'EMP3',
#   'RHOB',
#   'VEGFA',
#   'CRLF1',
#   'COL3A1',
#   'MMP14',
#   'GAS1',
#   'ID2',
#   'CALU',
#   'FOXC2',
#   'ELN',
#   'SDC4',
#   'TNFRSF11B',
#   'AREG',
#   'THY1',
#   'TIMP3',
#   'QSOX1',
#   'TIMP1',
#   'CAP2',
#   'IL32',
#   'ADAM12',
#   'BGN',
#   'COL4A1',
#   'COL4A2',
#   'FMOD',
#   'CD44',
#   'LRRC15',
#   'ECM1',
#   'ECM2',
#   'FSTL1',
#   'CAPG',
#   'FSTL3',
#   'COL11A1',
#   'CD59',
#   'TGFB1',
#   'PDGFRB',
#   'APLP1',
#   'PRRX1',
#   'TPM4',
#   'TFPI2',
#   'WNT5A',
#   'TPM2',
#   'VCAM1',
#   'CXCL12',
#   'COL5A2',
#   'PLOD1',
#   'COL5A1',
#   'FAP',
#   'FAS',
#   'COL5A3',
#   'TGFBI',
#   'PMP22',
#   'SCG2',
#   'PPIB',
#   'COL16A1',
#   'TNC',
#   'FBLN2',
#   'PLOD3',
#   'PVR',
#   'FBLN1',
#   'PLOD2',
#   'LOXL1',
#   'LOXL2',
#   'FBLN5',
#   'CDH6',
#   'COMP',
#   'NT5E',
#   'BASP1',
#   'CDH2',
#   'GPC1',
#   'FLNA',
#   'SLIT2',
#   'TPM1',
#   'MSX1',
#   'SLIT3',
#   'SPP1',
#   'IGFBP2',
#   'POSTN',
#   'IGFBP4',
#   'IGFBP3',
#   'INHBA',
#   'GEM',
#   'LOX',
#   'CDH11',
#   'COL6A3',
#   'COL6A2',
#   'MATN2',
#   'FBN1',
#   'FBN2',
#   'MATN3',
#   'COPA',
#   'NOTCH2',
#   'NTM',
#   'HTRA1',
#   'FGF2',
#   'SAT1',
#   'TGM2',
#   'EFEMP2',
#   'GLIPR1',
#   'RGS4',
#   'CALD1',
#   'PMEPA1',
#   'EDIL3',
#   'ITGA5',
#   'MMP1',
#   'MMP2',
#   'BDNF',
#   'GPX7',
#   'MMP3',
#   'ITGA2',
#   'TGFBR3',
#   'ACTA2',
#   'MFAP5',
#   'VCAN',
#   'DAB2',
#   'IL6',
#   'BMP1',
#   'COL7A1',
#   'MCM7',
#   'CXCL8',
#   'NNMT',
#   'LAMC1',
#   'TNFAIP3',
#   'CXCL1',
#   'LAMC2',
#   'NID2',
#   'CXCL6',
#   'PDLIM4',
#   'DST',
#   'PCOLCE',
#   'PLAUR',
#   'DCN',
#   'PTHLH',
#   'SNTB1',
#   'GREM1',
#   'COL8A2',
#   'PCOLCE2',
#   'PTX3',
#   'ITGB1',
#   'LAMA3',
#   'WIPF1',
#   'ITGB5',
#   'LAMA2',
#   'ITGB3',
#   'LAMA1',
#   'THBS1',
#   'THBS2',
#   'SGCG',
#   'SGCD',
#   'SGCB',
#   'ITGAV',
#   'COLGALT1',
#   'CTHRC1'],
#  'Inflammatory Response': ['IL1R1',
#   'EREG',
#   'MARCO',
#   'TNFSF9',
#   'VIP',
#   'SLAMF1',
#   'SGMS2',
#   'IFITM1',
#   'AQP9',
#   'SERPINE1',
#   'C3AR1',
#   'NOD2',
#   'MYC',
#   'PROK2',
#   'MSR1',
#   'ABCA1',
#   'TNFSF15',
#   'FZD5',
#   'SLC11A2',
#   'RNF144B',
#   'GPR183',
#   'CHST2',
#   'MEP1A',
#   'NPFFR2',
#   'HPN',
#   'ICAM4',
#   'HIF1A',
#   'ICAM1',
#   'LPAR1',
#   'KCNMB2',
#   'IL12B',
#   'SCARF1',
#   'FFAR2',
#   'TNFSF10',
#   'CD14',
#   'CMKLR1',
#   'SCN1B',
#   'EDN1',
#   'LYN',
#   'CCL24',
#   'GABBR1',
#   'IL10',
#   'CCL22',
#   'IL15',
#   'CCL20',
#   'IL10RA',
#   'SPHK1',
#   'NMI',
#   'TACR3',
#   'LIF',
#   'EMP3',
#   'TACR1',
#   'IL18',
#   'RHOG',
#   'OSMR',
#   'DCBLD2',
#   'IL1A',
#   'PTPRE',
#   'TLR2',
#   'BST2',
#   'IL1B',
#   'TLR1',
#   'MMP14',
#   'IL18R1',
#   'TLR3',
#   'BTG2',
#   'CD40',
#   'MEFV',
#   'EBI3',
#   'ADM',
#   'FPR1',
#   'SLC7A1',
#   'CX3CL1',
#   'SLC7A2',
#   'RIPK2',
#   'TIMP1',
#   'CCR7',
#   'KIF1B',
#   'GCH1',
#   'IFNGR2',
#   'GP1BA',
#   'F3',
#   'CD48',
#   'HBEGF',
#   'CDKN1A',
#   'PTGER2',
#   'PTAFR',
#   'KCNA3',
#   'PTGER4',
#   'CXCR6',
#   'GNAI3',
#   'GPR132',
#   'NAMPT',
#   'STAB1',
#   'CCL17',
#   'OLR1',
#   'CD55',
#   'ICOSLG',
#   'IL4R',
#   'SLC31A2',
#   'CD70',
#   'SEMA4D',
#   'OSM',
#   'SLC31A1',
#   'CXCL10',
#   'CXCL11',
#   'AXL',
#   'SELENOS',
#   'ABI1',
#   'LY6E',
#   'APLNR',
#   'CD69',
#   'SLC28A2',
#   'RAF1',
#   'RELA',
#   'CSF3R',
#   'CSF3',
#   'CD82',
#   'CSF1',
#   'RGS16',
#   'SLC1A2',
#   'AHR',
#   'PVR',
#   'ATP2C1',
#   'BEST1',
#   'PDPN',
#   'HAS2',
#   'LAMP3',
#   'CCRL2',
#   'NLRP3',
#   'GPC3',
#   'LDLR',
#   'INHBA',
#   'CYBB',
#   'SELE',
#   'NFKB1',
#   'MXD1',
#   'SELL',
#   'NMUR1',
#   'IFNAR1',
#   'IL7R',
#   'CALCRL',
#   'C5AR1',
#   'PSEN1',
#   'IL18RAP',
#   'RASGRP1',
#   'RGS1',
#   'CLEC5A',
#   'NDP',
#   'TNFRSF9',
#   'ROS1',
#   'ITGA5',
#   'EIF2AK2',
#   'TAPBP',
#   'ACVR2A',
#   'TNFRSF1B',
#   'IRF1',
#   'NFKBIA',
#   'IL6',
#   'ADORA2B',
#   'IRF7',
#   'LCP2',
#   'CXCL8',
#   'CXCL9',
#   'TNFAIP6',
#   'PIK3R5',
#   'CXCL6',
#   'ADGRE1',
#   'HRH1',
#   'IRAK2',
#   'BDKRB1',
#   'P2RY2',
#   'PDE4B',
#   'IL15RA',
#   'PTGIR',
#   'ADRM1',
#   'TPBG',
#   'OPRK1',
#   'PLAUR',
#   'ATP2B1',
#   'P2RX7',
#   'LCK',
#   'KLF6',
#   'P2RX4',
#   'IL2RB',
#   'LTA',
#   'MET',
#   'RTP4',
#   'ITGB3',
#   'SRI',
#   'ATP2A2',
#   'SLC4A4',
#   'ACVR1B',
#   'GNA15',
#   'CCL7',
#   'CCL5',
#   'PCDH7',
#   'CCL2',
#   'ITGB8',
#   'KCNJ2'],
#  'Xenobiotic Metabolism': ['SLC12A4',
#   'IL1R1',
#   'ENTPD5',
#   'ECH1',
#   'UPB1',
#   'PC',
#   'NINJ1',
#   'SPINT2',
#   'RBP4',
#   'MTHFD1',
#   'CYP1A2',
#   'CYP1A1',
#   'EPHA2',
#   'CDO1',
#   'CDA',
#   'CES1',
#   'CYFIP2',
#   'ENPEP',
#   'ITIH4',
#   'SLC46A3',
#   'ADH1C',
#   'RETSAT',
#   'AQP9',
#   'SERPINE1',
#   'SLC35B1',
#   'LCAT',
#   'ITIH1',
#   'PSMB10',
#   'NFS1',
#   'HES6',
#   'LONP1',
#   'PTGDS',
#   'GABARAPL1',
#   'CYP4F2',
#   'PMM1',
#   'IGF1',
#   'SLC6A12',
#   'SLC6A6',
#   'CYP27A1',
#   'VNN1',
#   'POR',
#   'CYP2S1',
#   'HPRT1',
#   'PEMT',
#   'PTGES',
#   'CFB',
#   'NMT1',
#   'SLC22A1',
#   'SLC35D1',
#   'ACSM1',
#   'TMEM97',
#   'ARPP19',
#   'ADH7',
#   'ADH5',
#   'MT2A',
#   'TDO2',
#   'HMOX1',
#   'ASL',
#   'PDK4',
#   'APOE',
#   'CCL25',
#   'GSTM4',
#   'JUP',
#   'PTGES3',
#   'SSR3',
#   'TYR',
#   'UGDH',
#   'ID2',
#   'GART',
#   'HRG',
#   'MAOA',
#   'ABHD6',
#   'CROT',
#   'CSAD',
#   'SERPINA6',
#   'HNF4A',
#   'TTPA',
#   'CD36',
#   'HSD11B1',
#   'MPP2',
#   'NQO1',
#   'CBR1',
#   'ARG1',
#   'ELOVL5',
#   'ARG2',
#   'GCH1',
#   'AKR1C2',
#   'GSTO1',
#   'GAD1',
#   'MCCC2',
#   'TMEM176B',
#   'FMO1',
#   'AKR1C3',
#   'FMO3',
#   'DHRS1',
#   'GNMT',
#   'PGRMC1',
#   'PTGR1',
#   'DHRS7',
#   'TPST1',
#   'ANGPTL3',
#   'CYP2E1',
#   'PPARD',
#   'FABP1',
#   'AHCY',
#   'GCNT2',
#   'PTS',
#   'CYP17A1',
#   'SERTAD1',
#   'XDH',
#   'MARCHF6',
#   'G6PC',
#   'TGFB2',
#   'F11',
#   'GSR',
#   'F10',
#   'GSS',
#   'FAH',
#   'PINK1',
#   'FAS',
#   'GSTA3',
#   'FETUB',
#   'KARS1',
#   'PROS1',
#   'SLC1A5',
#   'FBLN1',
#   'COMT',
#   'NDRG2',
#   'CNDP2',
#   'PAPSS2',
#   'ATOH8',
#   'HSD17B2',
#   'IDH1',
#   'IGFBP1',
#   'GCKR',
#   'EPHX1',
#   'IGFBP4',
#   'AP4B1',
#   'ESR1',
#   'PGD',
#   'GCLC',
#   'DDAH2',
#   'ALDH3A1',
#   'BCAT1',
#   'BLVRB',
#   'REG1A',
#   'GSTT2',
#   'ETS2',
#   'CYP2C18',
#   'VTN',
#   'HACL1',
#   'CYP2J2',
#   'ABCC2',
#   'ABCC3',
#   'DHPS',
#   'PYCR1',
#   'NPC1',
#   'CYB5A',
#   'TNFRSF1A',
#   'CYP26A1',
#   'ACOX3',
#   'ACOX2',
#   'ACOX1',
#   'IRF8',
#   'ACO2',
#   'TMBIM6',
#   'FBP1',
#   'LPIN2',
#   'BCAR1',
#   'SAR1B',
#   'LEAP2',
#   'SHMT2',
#   'TAT',
#   'ETFDH',
#   'RAP1GAP',
#   'CA2',
#   'CASP6',
#   'TKFC',
#   'AOX1',
#   'MAN1A1',
#   'ACP1',
#   'ACP2',
#   'PDLIM5',
#   'HGFAC',
#   'SMOX',
#   'DCXR',
#   'CAT',
#   'ALDH9A1',
#   'CRP',
#   'DDC',
#   'ALAS1',
#   'ATP2A2',
#   'PLG',
#   'BPHL',
#   'DDT',
#   'ALDH2',
#   'KYNU',
#   'UPP1',
#   'ABCD2',
#   'MBL2'],
#  'Fatty Acid Metabolism': ['ACOT9',
#   'MECR',
#   'ACOT8',
#   'PHYH',
#   'ACSL3',
#   'ACSL1',
#   'ACSL6',
#   'ACSL5',
#   'ACSL4',
#   'TECRL',
#   'PRKAB2',
#   'CYP2C9',
#   'SCD',
#   'CYP2C8',
#   'CYP2U1',
#   'MAPKAPK2',
#   'CYP1A2',
#   'ACOT2',
#   'CYP1A1',
#   'DPEP2',
#   'ACOT1',
#   'DPEP1',
#   'ACOT7L',
#   'ACOT7',
#   'CRAT',
#   'ACOT4',
#   'PRKAA2',
#   'SLC27A2',
#   'SLC27A1',
#   'PON1',
#   'HPGD',
#   'PON3',
#   'PON2',
#   'HSD17B4',
#   'ALOX12B',
#   'HSD17B8',
#   'HPGDS',
#   'RXRA',
#   'ALOX5',
#   'HSD17B3',
#   'CYP1B1',
#   'AWAT1',
#   'MORC2',
#   'RPP14',
#   'ALOXE3',
#   'PTGDS',
#   'ACBD7',
#   'GGT5',
#   'ACBD6',
#   'HBG1',
#   'ACBD5',
#   'CYP4F2',
#   'CYP4F3',
#   'EPHX2',
#   'PLA2G4A',
#   'CYP4F11',
#   'CYP4F8',
#   'MCAT',
#   'ACSF3',
#   'ALOX15B',
#   'ACSF2',
#   'ACLY',
#   'ALDH3A2',
#   'AMACR',
#   'FASN',
#   'PRXL2B',
#   'TBXAS1',
#   'PPT2',
#   'PPT1',
#   'ACSBG2',
#   'ACBD4',
#   'SLC27A3',
#   'PTGES',
#   'SLC22A5',
#   'FAAH',
#   'HACD2',
#   'HACD1',
#   'ACSM3',
#   'ECI1',
#   'ECI2',
#   'PECR',
#   'ACSM6',
#   'HACD4',
#   'CYP2C19',
#   'HACD3',
#   'THEM4',
#   'SCP2',
#   'THEM5',
#   'ACAD10',
#   'LTA4H',
#   'MMUT',
#   'HACL1',
#   'ACAA2',
#   'ACAA1',
#   'ACAD11',
#   'GGT1',
#   'HADH',
#   'DECR1',
#   'CYP2J2',
#   'DECR2',
#   'GPX1',
#   'GPX2',
#   'PTGES2',
#   'GPX4',
#   'PTGES3',
#   'CYP4A11',
#   'ACOX3',
#   'PCCB',
#   'ACOX2',
#   'PCCA',
#   'ACOX1',
#   'FAAH2',
#   'TECR',
#   'THRSP',
#   'ABCC1',
#   'ALOX15',
#   'EHHADH',
#   'ALOX12',
#   'CYP4F22',
#   'DBI',
#   'CROT',
#   'ECHS1',
#   'ACACB',
#   'ACACA',
#   'CPT2',
#   'HAO2',
#   'ELOVL1',
#   'ELOVL2',
#   'CBR1',
#   'CPT1B',
#   'PTGIS',
#   'CPT1A',
#   'ELOVL5',
#   'ELOVL6',
#   'ACOT11',
#   'ELOVL3',
#   'OLAH',
#   'SCD5',
#   'ACOT12',
#   'ELOVL4',
#   'MID1IP1',
#   'ACOT13',
#   'ALOX5AP',
#   'CYP4B1',
#   'AKR1C3',
#   'ELOVL7',
#   'CYP8B1',
#   'PTGR2',
#   'PTGR1',
#   'SLC25A17',
#   'HADHB',
#   'HADHA',
#   'NDUFAB1',
#   'PPARD',
#   'ACADVL',
#   'CYP4A22',
#   'PRKAG2',
#   'PCTP',
#   'HSD17B12',
#   'NUDT7',
#   'PTGS1',
#   'LTC4S',
#   'PTGS2',
#   'MCEE',
#   'ACOXL',
#   'ACADM',
#   'ACADL',
#   'SLC25A20',
#   'NUDT19',
#   'MLYCD',
#   'MMAA',
#   'ABCD1',
#   'ACADS',
#   'FADS2',
#   'CBR4',
#   'FADS1'],
#  'Reactive Oxygen Species Pathway': ['GPX3',
#   'G6PD',
#   'GSR',
#   'GPX4',
#   'TXNRD2',
#   'TXNRD1',
#   'FES',
#   'SELENOS',
#   'NDUFS2',
#   'ABCC1',
#   'NDUFB4',
#   'MPO',
#   'GLRX',
#   'PDLIM1',
#   'PTPA',
#   'SBNO2',
#   'EGLN2',
#   'NQO1',
#   'CDKN2D',
#   'NDUFA6',
#   'PRNP',
#   'GLRX2',
#   'OXSR1',
#   'IPCEF1',
#   'SOD1',
#   'ATOX1',
#   'SCAF4',
#   'SOD2',
#   'MSRA',
#   'GCLC',
#   'CAT',
#   'STK25',
#   'ERCC2',
#   'FTL',
#   'LAMTOR5',
#   'GCLM',
#   'PFKP',
#   'SRXN1',
#   'LSP1',
#   'TXN',
#   'MGST1',
#   'PRDX4',
#   'PRDX6',
#   'HHEX',
#   'PRDX2',
#   'PRDX1',
#   'HMOX2',
#   'MBP',
#   'JUNB'],
#  'p53 Pathway': ['HEXIM1',
#   'PRKAB1',
#   'TM4SF1',
#   'NINJ1',
#   'CCP110',
#   'BAX',
#   'TNFSF9',
#   'EPHA2',
#   'TP53',
#   'APP',
#   'ATF3',
#   'CYFIP2',
#   'RB1',
#   'GLS2',
#   'CCNK',
#   'EI24',
#   'RETSAT',
#   'ABAT',
#   'CDKN2AIP',
#   'TOB1',
#   'NHLH2',
#   'STOM',
#   'S100A10',
#   'RPL18',
#   'JAG2',
#   'TSPYL2',
#   'PMM1',
#   'ST14',
#   'GADD45A',
#   'PLK3',
#   'PLK2',
#   'DNTTIP2',
#   'H1-2',
#   'ALOX15B',
#   'VAMP8',
#   'TCN2',
#   'SDC1',
#   'HSPA4L',
#   'POM121',
#   'RRP8',
#   'SLC35D1',
#   'PDGFA',
#   'XPC',
#   'IFI30',
#   'FDXR',
#   'HMOX1',
#   'RPL36',
#   'SFN',
#   'IER5',
#   'RPS12',
#   'IER3',
#   'SLC19A2',
#   'TP63',
#   'ZNF365',
#   'FUCA1',
#   'BLCAP',
#   'JUN',
#   'TSC22D1',
#   'SPHK1',
#   'LIF',
#   'VWA5A',
#   'IL1A',
#   'PTPRE',
#   'RAD51C',
#   'RAP2B',
#   'H2AJ',
#   'KRT17',
#   'CCNG1',
#   'COQ8A',
#   'TAX1BP3',
#   'ADA',
#   'H2AW',
#   'CSRNP2',
#   'BTG2',
#   'BTG1',
#   'RRAD',
#   'ABHD4',
#   'RPS27L',
#   'TGFA',
#   'SLC7A11',
#   'KLK8',
#   'HINT1',
#   'LDHB',
#   'SOCS1',
#   'CTSF',
#   'CTSD',
#   'SERPINB5',
#   'CDKN2A',
#   'CDKN2B',
#   'PRMT2',
#   'ELP1',
#   'FOS',
#   'WWP1',
#   'AEN',
#   'DDB2',
#   'CDK5R1',
#   'HBEGF',
#   'ANKRA2',
#   'CDKN1A',
#   'SERTAD3',
#   'KIF13B',
#   'HRAS',
#   'RACK1',
#   'NUDT15',
#   'TGFB1',
#   'FBXW7',
#   'ZBTB16',
#   'IRAG2',
#   'TAP1',
#   'CGRRF1',
#   'DEF6',
#   'NUPR1',
#   'FAS',
#   'TRAFD1',
#   'MAPKAPK3',
#   'ISCU',
#   'PLXNB2',
#   'S100A4',
#   'STEAP3',
#   'PCNA',
#   'CD82',
#   'CD81',
#   'DGKA',
#   'PPP1R15A',
#   'PVT1',
#   'RGS16',
#   'NOL8',
#   'ZFP36L1',
#   'FOXO3',
#   'RCHY1',
#   'NDRG1',
#   'RXRA',
#   'CCND3',
#   'RAB40C',
#   'CCND2',
#   'RNF19B',
#   'PERP',
#   'PHLDA3',
#   'EPHX1',
#   'F2R',
#   'INHBB',
#   'MXD1',
#   'TRAF4',
#   'PROCR',
#   'CDH13',
#   'FGF13',
#   'MXD4',
#   'RAD9A',
#   'MDM2',
#   'NOTCH1',
#   'AK1',
#   'TRIAP1',
#   'SAT1',
#   'TM7SF3',
#   'SESN1',
#   'ZMAT3',
#   'FAM162A',
#   'CLCA2',
#   'ABCC5',
#   'VDR',
#   'GPX2',
#   'APAF1',
#   'OSGIN1',
#   'TPRKB',
#   'PTPN14',
#   'BAIAP2',
#   'SP1',
#   'BMP2',
#   'SLC3A2',
#   'PITPNC1',
#   'DRAM1',
#   'MKNK2',
#   'IRAK1',
#   'CASP1',
#   'IP6K2',
#   'RALGDS',
#   'PIDD1',
#   'RHBDF2',
#   'DCXR',
#   'KLF4',
#   'TPD52L1',
#   'WRAP73',
#   'PPM1D',
#   'ERCC5',
#   'DDIT4',
#   'TXNIP',
#   'DDIT3',
#   'TRIB3',
#   'CEBPA',
#   'HDAC3',
#   'ITGB4',
#   'TCHH',
#   'ACVR1B',
#   'GM2A',
#   'SEC61A1',
#   'EPS8L2',
#   'BAK1',
#   'UPP1',
#   'POLH',
#   'TNNI1'],
#  'UV Response Up': ['KLHDC3',
#   'STARD3',
#   'PLCL1',
#   'PDAP1',
#   'TAP1',
#   'CCK',
#   'MAPK8IP2',
#   'TUBA4A',
#   'OLFM1',
#   'POLE3',
#   'PSMC3',
#   'CYP1A1',
#   'PPIF',
#   'SELENOW',
#   'IL6ST',
#   'NPTXR',
#   'SQSTM1',
#   'TARS1',
#   'CDO1',
#   'FKBP4',
#   'GRINA',
#   'ATF3',
#   'CHRNA5',
#   'HNRNPU',
#   'C4BPB',
#   'AQP3',
#   'GLS',
#   'NXF1',
#   'BCL2L11',
#   'CCND3',
#   'RXRB',
#   'BSG',
#   'AP2S1',
#   'MSX1',
#   'YKT6',
#   'E2F5',
#   'NPTX2',
#   'NKX2-5',
#   'KCNH2',
#   'IGFBP2',
#   'SIGMAR1',
#   'EPHX1',
#   'PRKCD',
#   'RAB27A',
#   'SLC6A12',
#   'NAT1',
#   'EIF2S3',
#   'HLA-F',
#   'COL2A1',
#   'FGF18',
#   'EIF5',
#   'SLC6A8',
#   'DLG4',
#   'STK25',
#   'LHX2',
#   'PRPF3',
#   'PPT1',
#   'POLG2',
#   'CNP',
#   'TFRC',
#   'ENO2',
#   'ICAM1',
#   'NR4A1',
#   'SULT1A1',
#   'APOM',
#   'HTR7',
#   'RASGRP1',
#   'GRPEL1',
#   'UROD',
#   'PPAT',
#   'HMOX1',
#   'ATP6V1F',
#   'JUNB',
#   'ACAA1',
#   'ATP6V1C1',
#   'CYB5R1',
#   'MARK2',
#   'PRKACA',
#   'CYB5B',
#   'LYN',
#   'GPX3',
#   'RFC4',
#   'CHKA',
#   'GGH',
#   'ASNS',
#   'CDC5L',
#   'HSPA2',
#   'TACR3',
#   'RHOB',
#   'MRPL23',
#   'IRF1',
#   'NFKBIA',
#   'BMP2',
#   'IL6',
#   'MMP14',
#   'PTPRD',
#   'AGO2',
#   'CDK2',
#   'NUP58',
#   'TMBIM6',
#   'ALDOA',
#   'SHOX2',
#   'RET',
#   'ABCB1',
#   'BTG3',
#   'SLC25A4',
#   'BTG2',
#   'BTG1',
#   'RRAD',
#   'AMD1',
#   'MAOA',
#   'ONECUT1',
#   'RPN1',
#   'TGFBRAP1',
#   'CLTB',
#   'CXCL2',
#   'CTSV',
#   'STIP1',
#   'CA2',
#   'DNAJB1',
#   'EPCAM',
#   'PDLIM3',
#   'SPR',
#   'CASP3',
#   'NTRK3',
#   'PARP2',
#   'CDKN2B',
#   'DGAT1',
#   'GCH1',
#   'FMO1',
#   'FOS',
#   'CREG1',
#   'SOD2',
#   'GAL',
#   'DNAJA1',
#   'CDC34',
#   'TST',
#   'CCNE1',
#   'FOSB',
#   'TYRO3',
#   'FEN1',
#   'H2AX',
#   'CDKN1C',
#   'ALAS1',
#   'FURIN',
#   'CEBPG',
#   'WIZ',
#   'DDX21',
#   'TCHH',
#   'ARRB2',
#   'CLCN2',
#   'HSPA13',
#   'PPP1R2',
#   'HYAL2',
#   'BAK1',
#   'POLR2H',
#   'BID',
#   'MGAT1'],
#  'UV Response Dn': ['CDON',
#   'PDGFRB',
#   'SFMBT1',
#   'RUNX1',
#   'PEX14',
#   'MAPK14',
#   'COL1A2',
#   'COL1A1',
#   'COL5A2',
#   'SCN8A',
#   'PMP22',
#   'CDK13',
#   'MT1E',
#   'SERPINE1',
#   'PRDM2',
#   'ATP2C1',
#   'TFPI',
#   'FBLN5',
#   'MTA1',
#   'RXRA',
#   'SCAF8',
#   'ZMIZ1',
#   'AKT3',
#   'HAS2',
#   'MYC',
#   'APBB2',
#   'SPOP',
#   'CCN1',
#   'LDLR',
#   'FZD2',
#   'SMAD3',
#   'DMAC2L',
#   'MAP2K5',
#   'IGFBP5',
#   'NEK7',
#   'PRKCE',
#   'RBPMS',
#   'DYRK1A',
#   'NR1D2',
#   'PRKCA',
#   'SMAD7',
#   'NFKB1',
#   'PIAS3',
#   'INPP4B',
#   'DLG1',
#   'SYNJ2',
#   'KCNMA1',
#   'DDAH1',
#   'SNAI2',
#   'SDC2',
#   'AMPH',
#   'PLPP3',
#   'PTGFR',
#   'NOTCH2',
#   'IRS1',
#   'SCHIP1',
#   'CACNA1A',
#   'INSIG1',
#   'LTBP1',
#   'IGF1R',
#   'LPAR1',
#   'EFEMP1',
#   'GJA1',
#   'NIPBL',
#   'RGS4',
#   'PRKAR2B',
#   'BCKDHB',
#   'WDR37',
#   'ANXA2',
#   'DUSP1',
#   'ANXA4',
#   'BDNF',
#   'CAV1',
#   'CDC42BPA',
#   'TGFBR2',
#   'VAV2',
#   'ACVR2A',
#   'TGFBR3',
#   'COL3A1',
#   'DAB2',
#   'ADORA2B',
#   'ID1',
#   'MMP16',
#   'BHLHE40',
#   'RASA2',
#   'ADGRL2',
#   'ABCC1',
#   'ARHGEF9',
#   'MGLL',
#   'BMPR1A',
#   'CITED2',
#   'YTHDC1',
#   'CELF2',
#   'LAMC1',
#   'PTPN21',
#   'PTPRM',
#   'PIK3R3',
#   'TENT4A',
#   'SLC7A1',
#   'VLDLR',
#   'KALRN',
#   'DBP',
#   'GRK5',
#   'SLC22A18',
#   'ERBB2',
#   'MIOS',
#   'ATXN1',
#   'PDLIM5',
#   'CAP2',
#   'MAGI2',
#   'MGMT',
#   'ATRX',
#   'ATP2B4',
#   'ATP2B1',
#   'F3',
#   'ATRN',
#   'TJP1',
#   'PLCB4',
#   'KIT',
#   'NFIB',
#   'DLC1',
#   'MAP1B',
#   'PPARG',
#   'MET',
#   'AGGF1',
#   'NRP1',
#   'PHF3',
#   'CDKN1B',
#   'GCNT1',
#   'FHL2',
#   'ITGB3',
#   'SRI',
#   'SYNE1',
#   'PTEN',
#   'PIK3CD',
#   'ICA1',
#   'MRPS31',
#   'RND3',
#   'NR3C1',
#   'ADD3',
#   'SIPA1L1',
#   'TOGARAM1',
#   'COL11A1',
#   'FYN'],
#  'heme Metabolism': ['ACSL6',
#   'CTNS',
#   'GAPVD1',
#   'UBAC1',
#   'PC',
#   'HMBS',
#   'MYL4',
#   'TMCC2',
#   'TRIM10',
#   'OPTN',
#   'EPB41',
#   'EPB42',
#   'AQP3',
#   'BACH1',
#   'PPOX',
#   'PSMD9',
#   'BSG',
#   'CDC27',
#   'MXI1',
#   'E2F2',
#   'BTRC',
#   'SNCA',
#   'NFE2',
#   'SLC11A2',
#   'H1-0',
#   'ANK1',
#   'ELL2',
#   'TENT5C',
#   'KEL',
#   'SLC6A8',
#   'BCAM',
#   'SLC6A9',
#   'EZH1',
#   'KDM7A',
#   'TMEM9B',
#   'SLC22A4',
#   'ISCA1',
#   'TFRC',
#   'GDE1',
#   'ICAM4',
#   'MGST3',
#   'DCUN1D1',
#   'SLC30A10',
#   'GATA1',
#   'C3',
#   'TNS1',
#   'PRDX2',
#   'TSPAN5',
#   'H4C3',
#   'ERMAP',
#   'ATP6V0A1',
#   'CDR2',
#   'CTSB',
#   'CROCCP2',
#   'NCOA4',
#   'SLC10A3',
#   'TYR',
#   'PDZK1IP1',
#   'KAT2B',
#   'ALDH6A1',
#   'P4HA2',
#   'TAL1',
#   'HBBP1',
#   'RANBP10',
#   'GYPB',
#   'BTG2',
#   'GYPA',
#   'GYPC',
#   'HBB',
#   'GYPE',
#   'IGSF3',
#   'HBD',
#   'ENDOD1',
#   'ADIPOR1',
#   'SLC7A11',
#   'SPTA1',
#   'NNT',
#   'SEC14L1',
#   'HBQ1',
#   'HTATIP2',
#   'CLIC2',
#   'CTSE',
#   'HBZ',
#   'DMTN',
#   'MOCOS',
#   'MPP1',
#   'TCEA1',
#   'HDGF',
#   'RHAG',
#   'RNF123',
#   'MARCHF2',
#   'SLC66A2',
#   'PIGQ',
#   'RHD',
#   'TRAK2',
#   'NUDT4',
#   'XPO7',
#   'MARCHF8',
#   'RIOK3',
#   'AHSP',
#   'LMO2',
#   'RHCE',
#   'SLC25A38',
#   'XK',
#   'SIDT2',
#   'LRP10',
#   'YPEL5',
#   'ABCG2',
#   'SLC25A37',
#   'OSBP2',
#   'ALDH1L1',
#   'UCP2',
#   'CPOX',
#   'FOXO3',
#   'CCND3',
#   'LAMP2',
#   'RNF19A',
#   'CIR1',
#   'ARHGEF12',
#   'CAST',
#   'MAP2K3',
#   'BNIP3L',
#   'NEK7',
#   'UROS',
#   'VEZF1',
#   'SLC30A1',
#   'FBXO34',
#   'MFHAS1',
#   'SDCBP',
#   'MINPP1',
#   'PICALM',
#   'GCLC',
#   'RCL1',
#   'TFDP2',
#   'SYNJ1',
#   'MKRN1',
#   'BMP2K',
#   'GCLM',
#   'BLVRB',
#   'BLVRA',
#   'NARF',
#   'SLC2A1',
#   'HTRA2',
#   'UROD',
#   'MARK3',
#   'FN3K',
#   'EIF2AK1',
#   'ASNS',
#   'PPP2R5B',
#   'RAD23A',
#   'SPTB',
#   'ARL2BP',
#   'TSPO2',
#   'HAGH',
#   'TRIM58',
#   'ATG4A',
#   'LPIN2',
#   'TOP1',
#   'NFE2L1',
#   'TNRC6B',
#   'FECH',
#   'ABCB6',
#   'GMPS',
#   'RAP1GAP',
#   'AGPAT4',
#   'MOSPD1',
#   'CA2',
#   'ALAD',
#   'CA1',
#   'HEBP1',
#   'ACP5',
#   'RBM38',
#   'SMOX',
#   'GLRX5',
#   'KHNYN',
#   'KLF1',
#   'MBOAT2',
#   'FOXJ2',
#   'BPGM',
#   'EPOR',
#   'KLF3',
#   'SELENBP1',
#   'ACKR1',
#   'CAT',
#   'DAAM1',
#   'USP15',
#   'ALAS2',
#   'CCDC28A',
#   'SLC4A1',
#   'CLCN3',
#   'NR3C1',
#   'ADD2',
#   'FTCD',
#   'ADD1',
#   'RBM5',
#   'PGLS',
#   'DCAF10',
#   'FBXO7',
#   'DCAF11',
#   'FBXO9'],
#  'Coagulation': ['GSN',
#   'F11',
#   'F10',
#   'S100A1',
#   'TFPI2',
#   'F12',
#   'CD9',
#   'ISCU',
#   'ADAM9',
#   'PF4',
#   'GDA',
#   'LRP1',
#   'SERPINE1',
#   'PROS1',
#   'CLU',
#   'ITIH1',
#   'COMP',
#   'LAMP2',
#   'CAPN5',
#   'S100A13',
#   'CAPN2',
#   'SH2B2',
#   'MAFF',
#   'PROC',
#   'GNB2',
#   'LGMN',
#   'SERPING1',
#   'F13B',
#   'MEP1A',
#   'PEF1',
#   'FBN1',
#   'CFB',
#   'CFD',
#   'SPARC',
#   'CPB2',
#   'CFI',
#   'HPN',
#   'CFH',
#   'PDGFB',
#   'PREP',
#   'PLAU',
#   'HTRA1',
#   'PLAT',
#   'C2',
#   'C3',
#   'C9',
#   'LTA4H',
#   'A2M',
#   'CTSB',
#   'DUSP6',
#   'ANXA1',
#   'MMP7',
#   'MMP8',
#   'HMGCS2',
#   'MMP1',
#   'MMP2',
#   'MMP3',
#   'MST1',
#   'ITGA2',
#   'FN1',
#   'MMP9',
#   'GNG12',
#   'SIRT2',
#   'GP9',
#   'MMP11',
#   'MMP10',
#   'TF',
#   'MMP15',
#   'MMP14',
#   'BMP1',
#   'ACOX2',
#   'APOA1',
#   'PECAM1',
#   'RAPGEF3',
#   'KLKB1',
#   'HRG',
#   'ARF4',
#   'CPQ',
#   'SERPINA1',
#   'TMPRSS6',
#   'PROZ',
#   'C8A',
#   'CTSV',
#   'C8B',
#   'DUSP14',
#   'KLK8',
#   'DPP4',
#   'C8G',
#   'CASP9',
#   'CTSO',
#   'CSRP1',
#   'CTSK',
#   'HNF4A',
#   'P2RY1',
#   'TIMP3',
#   'CTSH',
#   'TIMP1',
#   'CTSE',
#   'FGA',
#   'LEFTY2',
#   'SERPINB2',
#   'FGG',
#   'VWF',
#   'F2',
#   'GP1BA',
#   'F3',
#   'RABIF',
#   'F8',
#   'F9',
#   'KLF7',
#   'APOC1',
#   'DCT',
#   'APOC3',
#   'APOC2',
#   'ANG',
#   'F2RL2',
#   'RGN',
#   'MASP2',
#   'MSRB2',
#   'C1QA',
#   'C1R',
#   'WDR1',
#   'PLEK',
#   'SERPINC1',
#   'C1S',
#   'FURIN',
#   'USP11',
#   'ITGB3',
#   'THBS1',
#   'PLG',
#   'PRSS23',
#   'CRIP2',
#   'CPN1',
#   'THBD',
#   'RAC1',
#   'FYN',
#   'MBL2',
#   'OLR1'],
#  'IL-2/STAT5 Signaling': ['IL1R2',
#   'TTC39B',
#   'RRAGD',
#   'ITIH5',
#   'CYFIP1',
#   'IFITM3',
#   'AHNAK',
#   'FGL2',
#   'PNP',
#   'MUC1',
#   'FLT3LG',
#   'MYC',
#   'WLS',
#   'GBP4',
#   'ST3GAL4',
#   'PRKCH',
#   'BATF3',
#   'RABGAP1L',
#   'GABARAPL1',
#   'XBP1',
#   'GADD45B',
#   'CDCP1',
#   'PLSCR1',
#   'UCK2',
#   'PLPP1',
#   'CDC42SE2',
#   'RNH1',
#   'IKZF2',
#   'ENO3',
#   'IKZF4',
#   'GATA1',
#   'CD79B',
#   'ALCAM',
#   'TNFSF11',
#   'TNFSF10',
#   'NCOA3',
#   'IL10',
#   'ANXA4',
#   'IL13',
#   'IL10RA',
#   'EMP1',
#   'RHOH',
#   'LIF',
#   'PTCH1',
#   'CDC6',
#   'FAM126B',
#   'RHOB',
#   'P4HA1',
#   'BHLHE40',
#   'ETFBKMT',
#   'TLR7',
#   'UMPS',
#   'IL18R1',
#   'CTSZ',
#   'PTH1R',
#   'SHE',
#   'SOCS1',
#   'SOCS2',
#   'PENK',
#   'SH3BGRL2',
#   'CTLA4',
#   'MAP6',
#   'NFIL3',
#   'SNX9',
#   'CCR4',
#   'ICOS',
#   'IFNGR1',
#   'GSTO1',
#   'DHRS3',
#   'SERPINB6',
#   'ADAM19',
#   'CCNE1',
#   'F2RL2',
#   'PTRH2',
#   'CD48',
#   'PLIN2',
#   'SLC29A2',
#   'CD44',
#   'EEF1AKMT1',
#   'NRP1',
#   'ECM1',
#   'AHCY',
#   'CDKN1C',
#   'SERPINC1',
#   'PTGER2',
#   'SNX14',
#   'CAPG',
#   'CST7',
#   'PDCD2L',
#   'ENPP1',
#   'NCS1',
#   'PLAGL1',
#   'DCPS',
#   'EOMES',
#   'IL4R',
#   'PHLDA1',
#   'APLP1',
#   'S100A1',
#   'PRAF2',
#   'PUS1',
#   'HUWE1',
#   'HIPK2',
#   'FAH',
#   'BATF',
#   'CXCL10',
#   'MAPKAPK2',
#   'CD86',
#   'CD83',
#   'CSF2',
#   'CSF1',
#   'CD81',
#   'ODC1',
#   'RGS16',
#   'GPR65',
#   'AHR',
#   'SLC1A5',
#   'LCLAT1',
#   'NDRG1',
#   'NT5E',
#   'CCND3',
#   'CCND2',
#   'CAPN3',
#   'DENND5A',
#   'SLC39A8',
#   'SPP1',
#   'MAP3K8',
#   'IGF2R',
#   'SWAP70',
#   'CISH',
#   'PRNP',
#   'TRAF1',
#   'CKAP4',
#   'HOPX',
#   'MAFF',
#   'MXD1',
#   'SELP',
#   'AMACR',
#   'COL6A1',
#   'SELL',
#   'BCL2L1',
#   'DRC1',
#   'GUCY1B1',
#   'SLC2A3',
#   'AGER',
#   'GPR83',
#   'RORA',
#   'IGF1R',
#   'TGM2',
#   'GLIPR2',
#   'SCN9A',
#   'TNFRSF8',
#   'PIM1',
#   'TNFRSF9',
#   'TNFRSF4',
#   'POU2F1',
#   'GPX4',
#   'NFKBIZ',
#   'ETV4',
#   'TNFRSF1B',
#   'TNFRSF21',
#   'BMP2',
#   'IRF4',
#   'ITGAE',
#   'IL3RA',
#   'IRF8',
#   'BCL2',
#   'IRF6',
#   'ITGA6',
#   'PLEC',
#   'ARL4A',
#   'ABCB1',
#   'BMPR2',
#   'NOP2',
#   'PHTF2',
#   'HK2',
#   'CA2',
#   'SYNGR2',
#   'CASP3',
#   'TNFRSF18',
#   'TIAM1',
#   'MYO1E',
#   'TWSG1',
#   'MYO1C',
#   'KLF6',
#   'P2RX4',
#   'IL2RA',
#   'IL2RB',
#   'SYT11',
#   'LTB',
#   'SPRY4',
#   'SMPDL3A',
#   'GALM',
#   'FURIN',
#   'COCH',
#   'IL1RL1',
#   'SPRED2',
#   'LRIG1',
#   'ITGAV',
#   'LRRC8C'],
#  'Bile Acid Metabolism': ['ABCG8',
#   'HSD3B7',
#   'PEX19',
#   'PHYH',
#   'ACSL1',
#   'DIO1',
#   'HSD3B1',
#   'DIO2',
#   'ACSL5',
#   'PEX12',
#   'PEX13',
#   'CYP39A1',
#   'PEX16',
#   'SOAT2',
#   'RBP1',
#   'PEX11G',
#   'ABCG4',
#   'ALDH8A1',
#   'OPTN',
#   'SLC27A2',
#   'AKR1D1',
#   'PEX11A',
#   'RETSAT',
#   'AQP9',
#   'SLC23A2',
#   'SLC35B2',
#   'SLC23A1',
#   'HSD17B4',
#   'HSD17B6',
#   'CH25H',
#   'PEX26',
#   'RXRA',
#   'PIPOX',
#   'LONP2',
#   'RXRG',
#   'ABCA2',
#   'ABCA3',
#   'IDH1',
#   'GSTK1',
#   'ABCA1',
#   'ABCA6',
#   'ABCA4',
#   'IDH2',
#   'ABCA5',
#   'EPHX2',
#   'ABCA8',
#   'NR0B2',
#   'ABCA9',
#   'AR',
#   'CYP27A1',
#   'SULT2B1',
#   'AMACR',
#   'GNPAT',
#   'SLCO1A2',
#   'GCLM',
#   'SLC27A5',
#   'PECR',
#   'CYP46A1',
#   'LIPE',
#   'PRDX5',
#   'FDXR',
#   'SCP2',
#   'HACL1',
#   'BBOX1',
#   'PEX1',
#   'CYP7B1',
#   'DHCR24',
#   'NPC1',
#   'BMP6',
#   'SULT1B1',
#   'APOA1',
#   'PEX7',
#   'PXMP2',
#   'PEX6',
#   'EFHC1',
#   'PAOX',
#   'IDI1',
#   'BCAR3',
#   'NR1I2',
#   'TFCP2L1',
#   'CROT',
#   'CYP7A1',
#   'SERPINA6',
#   'SLC22A18',
#   'ISOC1',
#   'HAO1',
#   'ATXN1',
#   'PNPLA8',
#   'KLF1',
#   'NR1H4',
#   'CYP8B1',
#   'GNMT',
#   'SOD1',
#   'LCK',
#   'PFKM',
#   'ALDH1A1',
#   'CAT',
#   'NEDD4',
#   'ALDH9A1',
#   'SLC29A1',
#   'AGXT',
#   'ABCD3',
#   'NR3C2',
#   'HSD17B11',
#   'NUDT12',
#   'TTR',
#   'MLYCD',
#   'GC',
#   'ABCD1',
#   'ABCD2',
#   'FADS2',
#   'FADS1'],
#  'Pperoxisome': ['HSD3B7',
#   'ACOT8',
#   'ACSL1',
#   'DIO1',
#   'ECH1',
#   'CADM1',
#   'CNBP',
#   'ACSL5',
#   'ACSL4',
#   'MSH2',
#   'PEX13',
#   'PEX14',
#   'SCGB1A1',
#   'CRAT',
#   'SLC27A2',
#   'PEX11A',
#   'RETSAT',
#   'CRABP1',
#   'PEX11B',
#   'SLC23A2',
#   'SLC35B2',
#   'CRABP2',
#   'HSD17B4',
#   'STS',
#   'LONP2',
#   'RXRG',
#   'FDPS',
#   'FIS1',
#   'SIAH1',
#   'IDH1',
#   'GSTK1',
#   'IDH2',
#   'EPHX2',
#   'CEL',
#   'CTPS1',
#   'ESR2',
#   'SULT2B1',
#   'DLG4',
#   'GNPAT',
#   'CTBP1',
#   'ECI2',
#   'BCL10',
#   'CACNA1B',
#   'PRDX5',
#   'PRDX1',
#   'SCP2',
#   'ACAA1',
#   'ABCC5',
#   'ABCC8',
#   'DHCR24',
#   'PEX2',
#   'CDK7',
#   'PEX5',
#   'ITGB1BP1',
#   'ACOX1',
#   'ALB',
#   'PEX6',
#   'PABPC1',
#   'IDI1',
#   'ABCB4',
#   'ABCB1',
#   'SLC25A4',
#   'NR1I2',
#   'TOP2A',
#   'VPS4B',
#   'IDE',
#   'EHHADH',
#   'ABCB9',
#   'SERPINA6',
#   'HSD11B2',
#   'RDH11',
#   'ISOC1',
#   'HAO2',
#   'ATXN1',
#   'YWHAH',
#   'SMARCC1',
#   'ELOVL5',
#   'UGT2B17',
#   'DHRS3',
#   'SOD1',
#   'SOD2',
#   'SLC25A17',
#   'ERCC1',
#   'SLC25A19',
#   'ALDH1A1',
#   'CAT',
#   'FABP6',
#   'ERCC3',
#   'ALDH9A1',
#   'ABCD3',
#   'MVP',
#   'SEMA3C',
#   'CLN8',
#   'HSD17B11',
#   'CLN6',
#   'HMGCL',
#   'TTR',
#   'NUDT19',
#   'HRAS',
#   'MLYCD',
#   'TSPO',
#   'ABCD1',
#   'ABCD2',
#   'FADS1'],
#  'Allograft Rejection': ['KRT1',
#   'EREG',
#   'CD2',
#   'CD4',
#   'CD7',
#   'IL2RG',
#   'IL27RA',
#   'PSMB10',
#   'AKT1',
#   'APBB1',
#   'B2M',
#   'GBP2',
#   'ELANE',
#   'FYB1',
#   'PRKCG',
#   'ST8SIA4',
#   'HLA-A',
#   'PRKCB',
#   'HLA-G',
#   'HLA-E',
#   'RPL3L',
#   'SPI1',
#   'BCL10',
#   'PRF1',
#   'CD1D',
#   'HIF1A',
#   'RPL9',
#   'CFP',
#   'C2',
#   'ICAM1',
#   'CD79A',
#   'MRPL3',
#   'RPS19',
#   'IL12B',
#   'RPL39',
#   'IL12A',
#   'CCR2',
#   'IL11',
#   'CCR1',
#   'LYN',
#   'IL10',
#   'CCL22',
#   'IL15',
#   'IL16',
#   'IL13',
#   'LIF',
#   'IL18',
#   'NME1',
#   'TLR2',
#   'IL1B',
#   'TLR1',
#   'PTPRC',
#   'NCR1',
#   'CD28',
#   'TLR6',
#   'ITK',
#   'TLR3',
#   'ACHE',
#   'IGSF6',
#   'CD40',
#   'BRCA1',
#   'CD3G',
#   'THY1',
#   'CD3E',
#   'CD3D',
#   'CTSS',
#   'SOCS1',
#   'RIPK2',
#   'TIMP1',
#   'CCR5',
#   'SOCS5',
#   'HLA-DQA1',
#   'NPM1',
#   'TPD52',
#   'MAP4K1',
#   'CDKN2A',
#   'IFNGR1',
#   'STAT1',
#   'IFNGR2',
#   'STAT4',
#   'F2',
#   'HCLS1',
#   'CD40LG',
#   'CD47',
#   'CCL13',
#   'CCL11',
#   'GCNT1',
#   'WAS',
#   'CAPG',
#   'IKBKB',
#   'HLA-DMB',
#   'STAB1',
#   'CXCR3',
#   'CCL19',
#   'HLA-DMA',
#   'ICOSLG',
#   'JAK2',
#   'TGFB1',
#   'CD74',
#   'IL4R',
#   'RARS1',
#   'TGFB2',
#   'RPS9',
#   'CRTAM',
#   'TAP2',
#   'TAP1',
#   'CXCL13',
#   'ABI1',
#   'FAS',
#   'KLRD1',
#   'PF4',
#   'DEGS1',
#   'PTPN6',
#   'UBE2N',
#   'CD86',
#   'CSF1',
#   'CD80',
#   'UBE2D1',
#   'GPR65',
#   'TNF',
#   'EGFR',
#   'CCND3',
#   'CCND2',
#   'FLNA',
#   'NLRP3',
#   'HLA-DOB',
#   'MAP3K7',
#   'IL12RB1',
#   'HLA-DOA',
#   'CD96',
#   'F2R',
#   'GLMN',
#   'INHBA',
#   'LY86',
#   'INHBB',
#   'TRAF2',
#   'CARTPT',
#   'DARS1',
#   'CD8B',
#   'CD8A',
#   'BCAT1',
#   'EIF4G3',
#   'IFNAR2',
#   'DYRK3',
#   'NCF4',
#   'LY75',
#   'FASLG',
#   'ETS1',
#   'IL18RAP',
#   'SIT1',
#   'EIF5A',
#   'SRGN',
#   'GALNT1',
#   'RPS3A',
#   'MMP9',
#   'TAPBP',
#   'ACVR2A',
#   'IL2',
#   'IL4',
#   'IL7',
#   'FCGR2B',
#   'IL6',
#   'ELF4',
#   'IL9',
#   'IRF4',
#   'IFNG',
#   'BCL3',
#   'HLA-DRA',
#   'IRF8',
#   'IRF7',
#   'LCP2',
#   'CD247',
#   'CXCL9',
#   'MTIF2',
#   'AARS1',
#   'EIF3A',
#   'GZMB',
#   'GZMA',
#   'WARS1',
#   'FGR',
#   'LCK',
#   'ZAP70',
#   'IL2RA',
#   'EIF3J',
#   'IL2RB',
#   'LTB',
#   'EIF3D',
#   'ABCE1',
#   'ITGB2',
#   'HDAC9',
#   'ITGAL',
#   'CCL7',
#   'CCL5',
#   'CCL4',
#   'CCL2',
#   'TRAT1',
#   'CSK',
#   'NOS2',
#   'MBL2',
#   'NCK1'],
#  'Spermatogenesis': ['TLE4',
#   'PRM2',
#   'HSPA1L',
#   'SLC12A2',
#   'ZPBP',
#   'CHFR',
#   'HTR5A',
#   'CCT6B',
#   'ADAM2',
#   'THEG',
#   'ZC2HC1C',
#   'CNIH2',
#   'IFT88',
#   'MTNR1A',
#   'DPEP3',
#   'GAPDHS',
#   'SCG5',
#   'STAM2',
#   'SCG3',
#   'CHRM4',
#   'HOXB1',
#   'CLPB',
#   'AURKA',
#   'NCAPH',
#   'PEBP1',
#   'TUBA3C',
#   'AKAP4',
#   'CLGN',
#   'NPHP1',
#   'TEKT2',
#   'ADAD1',
#   'IL12RB2',
#   'JAM3',
#   'TALDO1',
#   'PIAS2',
#   'RPL39L',
#   'H1-6',
#   'CCNA1',
#   'MLLT10',
#   'GPR182',
#   'MEP1B',
#   'RAD17',
#   'KIF2C',
#   'EZH2',
#   'CFTR',
#   'CRISP2',
#   'HSPA4L',
#   'DDX4',
#   'ACTL7B',
#   'GFI1',
#   'SLC2A5',
#   'GMCL1',
#   'ACRBP',
#   'ART3',
#   'CCNB2',
#   'PRKAR2A',
#   'PAPOLB',
#   'NEK2',
#   'ODF1',
#   'AGFG1',
#   'ZC3H14',
#   'PCSK1N',
#   'IL13RA2',
#   'TCP11',
#   'ACE',
#   'GSTM3',
#   'RFC4',
#   'NPY5R',
#   'PDHA2',
#   'STRBP',
#   'HSPA2',
#   'BRAF',
#   'SIRT1',
#   'MLF1',
#   'SNAP91',
#   'LPIN1',
#   'DMC1',
#   'NF2',
#   'ACRV1',
#   'CAMK4',
#   'CDK1',
#   'ARL4A',
#   'PSMG1',
#   'CDKN3',
#   'MAST2',
#   'ALOX15',
#   'IDE',
#   'SPATA6',
#   'OAZ3',
#   'SHE',
#   'PCSK4',
#   'COIL',
#   'LDHC',
#   'PGS1',
#   'PGK2',
#   'TOPBP1',
#   'MAP7',
#   'DNAJB8',
#   'IP6K1',
#   'HBZ',
#   'DCC',
#   'TKTL1',
#   'PACRG',
#   'CSNK2A2',
#   'NAA11',
#   'PARP2',
#   'ELOVL3',
#   'DMRT1',
#   'GAD1',
#   'SEPTIN4',
#   'MTOR',
#   'TSN',
#   'ADCYAP1',
#   'POMC',
#   'DBF4',
#   'VDAC3',
#   'TNP2',
#   'TSSK2',
#   'TNP1',
#   'DDX25',
#   'SYCP1',
#   'TTK',
#   'TULP2',
#   'YBX2',
#   'CST8',
#   'PHF7',
#   'ZNRF4',
#   'GRM8',
#   'GSG1',
#   'PHKG2',
#   'TNNI3',
#   'NOS1',
#   'NEFH',
#   'BUB1',
#   'CLVS1'],
#  'KRAS Signaling Up': ['ATG10',
#   'CIDEA',
#   'EREG',
#   'MALL',
#   'NIN',
#   'RBP4',
#   'SLPI',
#   'ITGBL1',
#   'SPARCL1',
#   'ZNF277',
#   'ADAMDEC1',
#   'SATB1',
#   'C3AR1',
#   'RETN',
#   'GLRX',
#   'IL2RG',
#   'TFPI',
#   'ADGRA2',
#   'AKT2',
#   'RABGAP1L',
#   'ST6GAL1',
#   'GADD45G',
#   'PPBP',
#   'AMMECR1',
#   'NR0B2',
#   'IGF2',
#   'BTC',
#   'TNNT2',
#   'CCSER2',
#   'STRN',
#   'CFB',
#   'SPON1',
#   'CFH',
#   'PLEK2',
#   'IKZF1',
#   'GNG11',
#   'EPB41L3',
#   'TSPAN7',
#   'ANKH',
#   'SOX9',
#   'KCNN4',
#   'CMKLR1',
#   'TSPAN1',
#   'APOD',
#   'SCN1B',
#   'GABRA3',
#   'DUSP6',
#   'FUCA1',
#   'ACE',
#   'JUP',
#   'CCL20',
#   'IL10RA',
#   'EMP1',
#   'LIF',
#   'PDCD1LG2',
#   'SNAP91',
#   'DCBLD2',
#   'MMP11',
#   'WDR33',
#   'MMP10',
#   'VWA5A',
#   'IL1B',
#   'LAT2',
#   'GPRC5B',
#   'CFHR2',
#   'ID2',
#   'TLR8',
#   'SDCCAG8',
#   'ADGRL4',
#   'AVL9',
#   'SERPINA3',
#   'TPH1',
#   'GYPC',
#   'PTPRR',
#   'CAB39L',
#   'CROT',
#   'TOR1AIP2',
#   'CTSS',
#   'MAP7',
#   'CD37',
#   'FCER1G',
#   'MPZL2',
#   'PRELID3B',
#   'HSD11B1',
#   'IL33',
#   'MMD',
#   'MAP4K1',
#   'ARG1',
#   'TMEM176A',
#   'G0S2',
#   'TMEM176B',
#   'WNT7A',
#   'LAPTM5',
#   'NR1H4',
#   'ANO1',
#   'TMEM158',
#   'ADAM17',
#   'ANGPTL4',
#   'F2RL1',
#   'ENG',
#   'HBEGF',
#   'NRP1',
#   'ERO1A',
#   'MTMR10',
#   'F13A1',
#   'PIGR',
#   'HOXD11',
#   'PTGS2',
#   'PSMB8',
#   'AKAP12',
#   'CXCR4',
#   'GPNMB',
#   'CBR4',
#   'MAP3K1',
#   'PTCD2',
#   'GUCY1A1',
#   'PRRX1',
#   'H2BC3',
#   'CXCL10',
#   'MYCN',
#   'PCP4',
#   'CLEC4A',
#   'ADAM8',
#   'SCG5',
#   'SCG3',
#   'PLVAP',
#   'CSF2',
# ...
#   'RAPGEF6',
#   'SOS2',
#   'ERAS',
#   'RAPGEF4',
#   'ARHGEF7',
#   'RAPGEF5',
#   'SOS1',
#   'RASGRF1',
#   'RRAD',
#   'ARHGEF1',
#   'LRRK2',
#   'RASGRF2',
#   'BRK1',
#   'PLD2',
#   'RAP1A',
#   'RAP1B',
#   'RASGEF1A',
#   'NKIRAS1',
#   'RASGEF1B',
#   'NKIRAS2',
#   'RASGEF1C',
#   'RRAS2',
#   'RRAS',
#   'PHACTR4',
#   'WASF1',
#   'RALGDS',
#   'RAB6C',
#   'FARP2',
#   'PLEKHG5',
#   'CDKN2A',
#   'DBNL',
#   'PLEKHG7',
#   'CDPF1',
#   'MYO9B',
#   'RNASE1',
#   'TIAM1',
#   'TIAM2',
#   'RIT2',
#   'SGSM3',
#   'NUCB1',
#   'NUCB2',
#   'RAB18',
#   'RERG',
#   'PRKCSH',
#   'GDI1',
#   'NCKAP1',
#   'DIRAS3',
#   'ROPN1B',
#   'WAS',
#   'ARHGDIG',
#   'AIF1',
#   'ARHGDIA',
#   'ARHGDIB',
#   'GNA12',
#   'GNA13',
#   'EPS8L1',
#   'EPS8L2',
#   'KRIT1',
#   'EPS8L3',
#   'HRAS',
#   'CTNNAL1'],
#  'Sphingolipid Biosynthetic Process (GO:0030148)': ['B3GALNT1',
#   'MECR',
#   'TLCD3B',
#   'AGK',
#   'SPHK2',
#   'SPHK1',
#   'SPNS2',
#   'DEGS2',
#   'ABCC1',
#   'DEGS1',
#   'ABCG2',
#   'ASAH2',
#   'GAL3ST1',
#   'SAMD8',
#   'SGMS2',
#   'CERK',
#   'SGMS1',
#   'FUT1',
#   'ALOX12B',
#   'CYP4F22',
#   'ASAH1',
#   'FUT2',
#   'FUT4',
#   'FUT6',
#   'FUT9',
#   'UGCG',
#   'UGT8',
#   'KDSR',
#   'ORMDL3',
#   'SPTSSA',
#   'ST3GAL5',
#   'ST8SIA5',
#   'SPTSSB',
#   'ST3GAL2',
#   'ALOXE3',
#   'ST3GAL3',
#   'CERS4',
#   'ELOVL1',
#   'ELOVL2',
#   'CERS6',
#   'ELOVL5',
#   'ST8SIA1',
#   'ELOVL6',
#   'ELOVL3',
#   'ST8SIA3',
#   'ELOVL4',
#   'ORMDL1',
#   'B3GALT4',
#   'ORMDL2',
#   'ABCA8',
#   'ELOVL7',
#   'FA2H',
#   'TM9SF2',
#   'ACER1',
#   'VAPA',
#   'B3GNT5',
#   'PRKD1',
#   'PRKD3',
#   'PRKD2',
#   'CERS1',
#   'PNPLA1',
#   'ST6GALNAC5',
#   'CERS2',
#   'ST6GALNAC6',
#   'B4GALT6',
#   'CERS3',
#   'CSNK1G2',
#   'HACD2',
#   'HACD1',
#   'GBA1',
#   'PPM1L',
#   'HACD4',
#   'CLN8',
#   'HACD3',
#   'SMPD4',
#   'SPTLC1',
#   'SPTLC2',
#   'OSBP',
#   'SPTLC3',
#   'SMPD2',
#   'SMPD1',
#   'LARGE1',
#   'MFSD2B'],
#  'Sphingolipid Metabolic Process (GO:0006665)': ['SPHK2',
#   'SPHK1',
#   'TEX2',
#   'SPNS2',
#   'TECR',
#   'DEGS2',
#   'SERINC1',
#   'ABCC1',
#   'DEGS1',
#   'ABCG2',
#   'NSMAF',
#   'ASAH2',
#   'GAL3ST1',
#   'ST6GALNAC3',
#   'SGMS2',
#   'CERK',
#   'SGMS1',
#   'ALOX12B',
#   'FUT3',
#   'FUT5',
#   'FUT7',
#   'FUT6',
#   'SGPL1',
#   'KDSR',
#   'ARV1',
#   'ORMDL3',
#   'SPTSSA',
#   'B4GALNT1',
#   'SPTSSB',
#   'ALOXE3',
#   'ABCA2',
#   'CERS4',
#   'ELOVL1',
#   'ELOVL2',
#   'CERS6',
#   'ELOVL5',
#   'ELOVL6',
#   'ELOVL3',
#   'ELOVL4',
#   'ORMDL1',
#   'ORMDL2',
#   'ELOVL7',
#   'SGPP2',
#   'SGPP1',
#   'FA2H',
#   'ACER2',
#   'TM9SF2',
#   'ACER1',
#   'PLA2G15',
#   'PRKD1',
#   'PPT1',
#   'PRKD3',
#   'PRKD2',
#   'CERS1',
#   'PLPP3',
#   'CERS2',
#   'PLPP2',
#   'ST6GALNAC6',
#   'CERS3',
#   'CSNK1G2',
#   'PLPP1',
#   'CERKL',
#   'HACD2',
#   'HACD1',
#   'PPM1L',
#   'HACD4',
#   'CLN8',
#   'HACD3',
#   'SMPD3',
#   'SPTLC1',
#   'SPTLC2',
#   'SPTLC3',
#   'ALDH3B2',
#   'SMPD2',
#   'ALDH3B1',
#   'SMPD1',
#   'ENPP2',
#   'ENPP7',
#   'MFSD2B'],
#  'Sphingosine-1-Phosphate Receptor Signaling Pathway (GO:0003376)': ['PIK3CB',
#   'S1PR2',
#   'SPNS2',
#   'S1PR1',
#   'EZR',
#   'RNASE1',
#   'MFSD2B',
#   'PIK3CG'],
#  'Stimulatory C-type Lectin Receptor Signaling Pathway (GO:0002223)': ['CREBBP',
#   'LYN',
#   'SRC',
#   'KLRC3',
#   'KLRC4',
#   'SYK',
#   'TYROBP',
#   'IKBKB',
#   'CLEC7A',
#   'CLEC6A',
#   'EP300',
#   'TRAF6',
#   'PKN1',
#   'KLRD1',
#   'KLRC1',
#   'FYN',
#   'KLRC2',
#   'PKN2',
#   'PLCG2',
#   'MAP3K7'],
#  'Substrate Adhesion-Dependent Cell Spreading (GO:0034446)': ['RHOA',
#   'SRCIN1',
#   'ITGA4',
#   'FN1',
#   'PARVB',
#   'LAMB1',
#   'PARVA',
#   'RNASE1',
#   'EFNA1',
#   'FERMT2',
#   'FER',
#   'PIK3R1',
#   'PXDN',
#   'RADIL',
#   'PEAK1',
#   'PARVG',
#   'TEK',
#   'ITGA8',
#   'TYRO3',
#   'EPHA1',
#   'FERMT3',
#   'VAMP3',
#   'POPDC1',
#   'ILK',
#   'LAMA5',
#   'ITGB3',
#   'LAMC1',
#   'KIF14',
#   'NTN4',
#   'MICALL2',
#   'LPXN',
#   'ITGAV',
#   'ITGB7',
#   'EPHB3',
#   'SRGAP2'],
#  'Superoxide Anion Generation (GO:0042554)': ['NCF2',
#   'NCF4',
#   'NOXO1',
#   'CYBB',
#   'ALOX12',
#   'CYBA',
#   'RNASE1',
#   'DUOX1',
#   'DUOX2',
#   'SH3PXD2B',
#   'SH3PXD2A',
#   'TAFA4',
#   'NOXA1',
#   'NOX4',
#   'NOX5',
#   'NCF1',
#   'RAC2',
#   'NOX1',
#   'NOX3'],
#  'Superoxide Metabolic Process (GO:0006801)': ['NANOS2',
#   'NQO1',
#   'NANOS3',
#   'CYBB',
#   'MT3',
#   'APOA4',
#   'CYBA',
#   'SOD3',
#   'RNASE1',
#   'SOD1',
#   'SOD2',
#   'CCS',
#   'TAFA4',
#   'NOXA1',
#   'NOX4',
#   'NOX5',
#   'NCF1',
#   'NOX1',
#   'NOX3',
#   'NRROS',
#   'NCF2',
#   'NCF4',
#   'NOXO1',
#   'PARK7',
#   'ALOX12',
#   'CYGB',
#   'DUOX1',
#   'DUOX2',
#   'CYB5R4',
#   'MB',
#   'SH3PXD2B',
#   'SH3PXD2A',
#   'PRDX2',
#   'PREX1',
#   'PRDX1',
#   'RAC2',
#   'ATP7A'],
#  'Supramolecular Fiber Organization (GO:0097435)': ['CARMIL1',
#   'KRT1',
#   'LUM',
#   'KRT5',
#   'KRT4',
#   'KRT3',
#   'ACTN1',
#   'KRT2',
#   'KRT9',
#   'KRT7',
#   'MYO7A',
#   'OPTC',
#   'WDR73',
#   'MYO7B',
#   'P3H4',
#   'COL1A2',
#   'DES',
#   'COL1A1',
#   'MARCKS',
#   'KATNAL2',
#   'HIP1R',
#   'KATNAL1',
#   'VIM',
#   'BAX',
#   'CORO6',
#   'MYL9',
#   'APP',
#   'MAP10',
#   'KHDC3L',
#   'COL12A1',
#   'SCX',
#   'AVIL',
#   'SLAIN2',
#   'SLAIN1',
#   'AQP2',
#   'CD2AP',
#   'CHORDC1',
#   'FSD1',
#   'CYP1B1',
#   'POF1B',
#   'B2M',
#   'SAMD14',
#   'SNCA',
#   'SIAH1',
#   'PLK3',
#   'SERPINF2',
#   'SIAH2',
#   'MYO5A',
#   'MYO5B',
#   'BACE1',
#   'CCDC88C',
#   'COL2A1',
#   'CCDC88B',
#   'CCDC88A',
#   'BIN3',
#   'MYO5C',
#   'FAT1',
#   'TAGLN2',
#   'TAGLN3',
#   'STMN3',
#   'STMN4',
#   'STMN1',
#   'STMN2',
#   'ZBED3',
#   'SERPINH1',
#   'AGFG1',
#   'AGFG2',
#   'NCOA3',
#   'RHOA',
#   'CDSN',
#   'USP9X',
#   'RIPK3',
#   'KRT14',
#   'RHOH',
#   'EMP2',
#   'KRT13',
#   'KRT12',
#   'RHOF',
#   'CRIPT',
#   'RHOG',
#   'KRT10',
#   'RHOB',
#   'OOEP',
#   'RHOC',
#   'TPPP2',
#   'RHOQ',
#   'COL3A1',
#   'KRT19',
#   'P4HA1',
#   'TPPP3',
#   'MAPT',
#   'PXDN',
#   'KRT17',
#   'P4HA3',
#   'KRT16',
#   'RHOJ',
#   'KRT15',
#   'ARHGEF2',
#   'PRPH2',
#   'RHOV',
#   'RHOU',
#   'DDR2',
#   'FLII',
#   'TMPRSS4',
#   'KRT25',
#   'KIF14',
#   'KRT24',
#   'KRT23',
#   'KRT20',
#   'SPTA1',
#   'MAP4',
#   'KRT28',
#   'KRT27',
#   'MYO6',
#   'KRT26',
#   'EMD',
#   'RIPK1',
#   'CD36',
#   'CGNL1',
#   'TMOD2',
#   'CAP1',
#   'TMOD1',
#   'CDKN2A',
#   'TMOD4',
#   'TMOD3',
#   'DSPP',
#   'RNASE1',
#   'CLIP4',
#   'CLIP3',
#   'FKBP1A',
#   'CLIP2',
#   'CLIP1',
#   'HCLS1',
#   'EPPK1',
#   'DYNC1H1',
#   'DBN1',
#   'HIP1',
#   'COL11A2',
#   'CST3',
#   'PCM1',
#   'NEFL',
#   'COL11A1',
#   'ZNF207',
#   'RAC2',
#   'BID',
#   'MYOZ1',
#   'GSN',
#   'TGFB2',
#   'CRTAP',
#   'TPM4',
#   'TPM3',
#   'TPM2',
#   'TRPV3',
#   'TRPV4',
#   'KLHL24',
#   'BFSP1',
#   'ERMN',
#   'ARHGAP25',
#   'TLE6',
#   'BFSP2',
#   'COL5A2',
#   'PLOD1',
#   'COL5A1',
#   'IAPP',
#   'COL5A3',
#   'ELMO1',
#   'ELMO2',
#   'TUBGCP6',
#   'ELMO3',
#   'TUBGCP4',
#   'TUBGCP5',
#   'HDGFL3',
#   'TARDBP',
#   'MAD2L2',
#   'CEP126',
#   'PRKN',
#   'TNXB',
#   'KATNB1',
#   'LOXL4',
#   'PLOD3',
#   'CIB1',
#   'INPPL1',
#   'PLOD2',
#   'LOC112694756',
#   'LOXL1',
#   'LOXL2',
#   'FBLN5',
#   'LOXL3',
#   'KRT6A',
#   'SLK',
#   'BASP1',
#   'SH3BP1',
#   'NLRP5',
#   'CAPN3',
#   'TPM1',
#   'MYH11',
#   'KRT6C',
#   'KRT6B',
#   'LOC100653049',
#   'SERF1A',
#   'CCDC13',
#   'KRT36',
#   'KRT35',
#   'NUP153',
#   'KIF24',
#   'KRT34',
#   'TBCB',
#   'GFAP',
#   'KRT32',
#   'KRT31',
#   'CKAP5',
#   'ARHGAP12',
#   'DLG1',
#   'KIF18A',
#   'KIF18B',
#   'NAT8',
#   'KIF2B',
#   'KIF2A',
#   'KRT39',
#   'LOX',
#   'KRT38',
#   'KRT37',
#   'MAP7D3',
#   'CLRN1',
#   'CDC42EP2',
#   'KIF2C',
#   'FGF13',
#   'MDM2',
#   'CPAP',
#   'TUBGCP2',
#   'TUBGCP3',
#   'DPT',
#   'SH3KBP1',
#   'LTBP3',
#   'LTBP4',
#   'ARHGAP6',
#   'CORO1A',
#   'PPP1R9B',
#   'CORO1B',
#   'PPP1R9A',
#   'RHOBTB1',
#   'CAMSAP2',
#   'CORO1C',
#   'RHOBTB2',
#   'KRT40',
#   'CNN3',
#   'CNN2',
#   'CNN1',
#   'EFEMP2',
#   'PDZD2',
#   'CHAMP1',
#   'TRDN',
#   'FUS',
#   'SHROOM3',
#   'SHROOM4',
#   'ARAP1',
#   'SHROOM2',
#   'TGFBR1',
#   'BMP1',
#   'HOOK3',
#   'HOOK2',
#   'HOOK1',
#   'MFAP4',
#   'NF1',
#   'DSG3',
#   'MYH6',
#   'BCAR1',
#   'COL14A1',
#   'WHAMM',
#   'TNFAIP6',
#   'LMOD2',
#   'LMOD1',
#   'MTM1',
#   'LMOD3',
#   'KRT33B',
#   'FYCO1',
#   'ADAMTS14',
#   'DNAJB6',
#   'ADAMTS19',
#   'KASH5',
#   'KRT33A',
#   'XIRP2',
#   'EMILIN1',
#   'XIRP1',
#   'TPPP',
#   'KRT72',
#   'KRT71',
#   'MARCKSL1',
#   'NCKAP5L',
#   'KATNA1',
#   'KRT79',
#   'KRT78',
#   'KRT77',
#   'KRT76',
#   'MYO19',
#   'KLHL41',
#   'KRT75',
#   'KRT74',
#   'CDC42',
#   'KRT73',
#   'MYO1E',
#   'MYO1F',
#   'GREM1',
#   'MYO1D',
#   'KATNBL1',
#   'MYO1A',
#   'MYO1B',
#   'SH3D21',
#   'MYO15A',
#   'INA',
#   'TLL2',
#   'EVL',
#   'TLL1',
#   'B4GALT7',
#   'MYO1G',
#   'MYO1H',
#   'KRT83',
#   'KRT82',
#   'KRT81',
#   'NCKAP5',
#   'KRT80',
#   'HSP90AB1',
#   'PLA2G1B',
#   'FURIN',
#   'TCHH',
#   'RND3',
#   'KRT86',
#   'KRT85',
#   'RND1',
#   'KRT84',
#   'RND2',
#   'THSD4',
#   'ADAMTS3',
#   'ADAMTS2',
#   'VHL',
#   'PGM5',
#   'COLGALT1',
#   'ATP7A',
#   'COLGALT2'],
#  'Telomere Maintenance (GO:0000723)': ['ZNF365',
#   'CTC1',
#   'ACTR8',
#   'MCRS1',
#   'PTGES3',
#   'ACTR5',
#   'HUS1',
#   'PPP1CA',
#   'RAD51D',
#   'ARTN',
#   'TEP1',
#   'CDK2',
#   'ATM',
#   'ZSCAN4',
#   'DNA2',
#   'SLX1A',
#   'MRE11',
#   'POT1',
#   'TERF2IP',
#   'MAD2L2',
#   'DCLRE1C',
#   'DCLRE1B',
#   'SERPINA2',
#   'SP100',
#   'HUS1B',
#   'RTEL1',
#   'RUVBL1',
#   'YY1',
#   'TFPT',
#   'TERT',
#   'ZNF827',
#   'RUVBL2',
#   'NHEJ1',
#   'XRCC5',
#   'PARP3',
#   'STN1',
#   'XRCC6',
#   'ACTL6A',
#   'TINF2',
#   'XRCC3',
#   'PARP1',
#   'INO80',
#   'NSMCE2',
#   'RPA3',
#   'LTO1',
#   'TERF1',
#   'TERF2',
#   'RAD50',
#   'UCHL5',
#   'SHLD1',
#   'RAD51',
#   'ERCC4',
#   'POLR1A',
#   'TEN1',
#   'POLR1B',
#   'SHLD3',
#   'APEX1',
#   'SHLD2',
#   'LRIF1',
#   'INO80B',
#   'INO80D',
#   'INO80C',
#   'BLM',
#   'INO80E',
#   'ZBTB48',
#   'PRKDC',
#   'SMC6',
#   'SMC5',
#   'RECQL4',
#   'WRN',
#   'FBXO4',
#   'NFRKB'],
#  'Telomere Maintenance via Recombination (GO:0000722)': ['RAD51',
#   'RAD51D',
#   'ERCC4',
#   'TERT',
#   'TEP1',
#   'XRCC3',
#   'NSMCE2',
#   'SMC6',
#   'RAD50',
#   'SMC5'],
#  'Telomere Maintenance via Telomerase (GO:0007004)': ['HSP90AA1',
#   'HSP90AB1',
#   'PINX1',
#   'XRCC5',
#   'PTGES3',
#   'PIF1',
#   'TERF1',
#   'RAD50',
#   'WRAP53',
#   'HMBOX1',
#   'DKC1',
#   'POLR1A',
#   'TERT',
#   'GAR1',
#   'MRE11',
#   'NOP10',
#   'SLC19A1',
#   'POT1',
#   'TERF2IP',
#   'TNKS1BP1',
#   'NHP2'],
#  'Telomere Maintenance via Telomere Lengthening (GO:0010833)': ['CTC1',
#   'HSP90AA1',
#   'XRCC5',
#   'PTGES3',
#   'STN1',
#   'TERF1',
#   'RAD50',
#   'WRAP53',
#   'RAD51',
#   'DKC1',
#   'POLR1A',
#   'ZSCAN4',
#   'SLX1A',
#   'MRE11',
#   'NOP10',
#   'POT1',
#   'TERF2IP',
#   'NHP2',
#   'DCLRE1B',
#   'HSP90AB1',
#   'PINX1',
#   'ZBTB48',
#   'PIF1',
#   'HMBOX1',
#   'TERT',
#   'GAR1',
#   'SLC19A1',
#   'TNKS1BP1'],
#  'Telomere Organization (GO:0032200)': ['ZNF365',
#   'CTC1',
#   'ACTR8',
#   'MCRS1',
#   'PTGES3',
#   'ACTR5',
#   'HUS1',
#   'RAD51D',
#   'ARTN',
#   'ATM',
#   'DNA2',
#   'MRE11',
#   'POT1',
#   'TERF2IP',
#   'DCLRE1C',
#   'DOT1L',
#   'DCLRE1B',
#   'SERPINA2',
#   'SP100',
#   'HUS1B',
#   'RTEL1',
#   'RUVBL1',
#   'YY1',
#   'TFPT',
#   'HMBOX1',
#   'TERT',
#   'ZNF827',
#   'RUVBL2',
#   'NHEJ1',
#   'H3-3B',
#   'H3C7',
#   'XRCC5',
#   'PARP3',
#   'STN1',
#   'XRCC6',
#   'ACTL6A',
#   'TINF2',
#   'PARP1',
#   'INO80',
#   'RPA3',
#   'LTO1',
#   'TERF1',
#   'TERF2',
#   'RAD50',
#   'UCHL5',
#   'ERCC4',
#   'POLR1A',
#   'H4C15',
#   'POLR1B',
#   'APEX1',
#   'LRIF1',
#   'INO80B',
#   'INO80D',
#   'INO80C',
#   'BLM',
#   'INO80E',
#   'PRKDC',
#   'RECQL4',
#   'WRN',
#   'FBXO4',
#   'NFRKB'],
#  'Transepithelial Transport (GO:0070633)': ['CXADR',
#   'GPLD1',
#   'ABCC2',
#   'SLC1A1',
#   'SLC12A2',
#   'SLC1A2',
#   'SLC1A3',
#   'CLCNKB',
#   'BEST1',
#   'CLCN7',
#   'SLC9A4',
#   'OSTM1',
#   'CLDN18',
#   'RHBG',
#   'ABCC1',
#   'ABCG2',
#   'RHCG',
#   'SLC26A6'],
#  'Transport Across Blood-Brain Barrier (GO:0150104)': ['ABCC4',
#   'ABCC5',
#   'ABCC2',
#   'SLC16A1',
#   'ABCC3',
#   'KCNJ8',
#   'SLC16A2',
#   'ABCC9',
#   'SLC12A2',
#   'ATP1B2',
#   'SLC7A5',
#   'SLC7A8',
#   'SLCO1C1',
#   'ABCC1',
#   'SLC22A8',
#   'SLC28A2',
#   'ABCG2',
#   'ABCB1',
#   'SLC27A1',
#   'LRP2',
#   'SLC1A1',
#   'SLC1A2',
#   'SLC44A1',
#   'SLC1A3',
#   'ATP1A4',
#   'SLC1A4',
#   'SLC1A5',
#   'SLC5A1',
#   'ATP1A2',
#   'LRP3',
#   'SLC5A3',
#   'SLC7A1',
#   'SLC7A2',
#   'SLC5A5',
#   'SLC7A3',
#   'SLC5A6',
#   'FLVCR2',
#   'SLC16A7',
#   'CD36',
#   'NHERF1',
#   'INSR',
#   'SLC13A3',
#   'SLC15A2',
#   'SLC38A2',
#   'SLC38A1',
#   'SLC6A17',
#   'SLC2A13',
#   'ATP2B4',
#   'SLC16A12',
#   'SLC6A13',
#   'AVPR1A',
#   'SLC2A10',
#   'AVPR1B',
#   'SLC4A8',
#   'SLC6A6',
#   'FABP5',
#   'SLC6A9',
#   'C1D',
#   'SLCO3A1',
#   'SLC27A4',
#   'SLC29A2',
#   'LEPROT',
#   'SLC29A1',
#   'SLC29A4',
#   'SLC22A5',
#   'SLC24A3',
#   'SLC22A1',
#   'ATP8A1',
#   'TFRC',
#   'SLC22A3',
#   'SLC22A2',
#   'SLC2A1',
#   'ATP2A3',
#   'SLC2A3',
#   'SLC2A4',
#   'SLC4A3',
#   'SLC6A1',
#   'AGER',
#   'SLC4A4',
#   'SLC6A20',
#   'SLC8A2',
#   'SLCO2B1',
#   'SLC19A1',
#   'SLC38A3',
#   'MFSD2A',
#   'SLC38A5'],
#  'Unsaturated Fatty Acid Biosynthetic Process (GO:0006636)': ['CBR1',
#   'PTGIS',
#   'PTGES2',
#   'PTGES3',
#   'SCD5',
#   'ALOX15',
#   'ALOX12',
#   'ALOX15B',
#   'SCD',
#   'DOK7',
#   'TBXAS1',
#   'MUSK',
#   'DEGS1',
#   'DECR2',
#   'PTGDS'],
#  'Unsaturated Fatty Acid Metabolic Process (GO:0033559)': ['GPX1',
#   'ACOT8',
#   'GSTM2',
#   'GPX4',
#   'CYP4A11',
#   'SCD',
#   'DOK7',
#   'FAAH2',
#   'GSTA1',
#   'DEGS1',
#   'MGLL',
#   'DAGLA',
#   'DAGLB',
#   'ALOX15',
#   'ABHD6',
#   'ALOX12',
#   'ALOX12B',
#   'CYP2D7',
#   'ALOX5',
#   'CYP1B1',
#   'AWAT1',
#   'MUSK',
#   'ALOXE3',
#   'ELOVL1',
#   'ELOVL2',
#   'ELOVL5',
#   'EPHX1',
#   'PNPLA8',
#   'CYP4F2',
#   'CYP4F3',
#   'ELOVL3',
#   'PLA2G4C',
#   'SCD5',
#   'PLA2G4A',
#   'PLA2G4B',
#   'CYP4F11',
#   'CYP4F8',
#   'CYP4F12',
#   'ALOX15B',
#   'PTGR1',
#   'FA2H',
#   'LOC107987479',
#   'PLA2G10',
#   'SYCP2',
#   'CYP4A22',
#   'GSTP1',
#   'MGST3',
#   'CYP4Z1',
#   'ABHD12',
#   'ACAA1',
#   'FADS2',
#   'CYP2J2',
#   'DECR2'],
#  'Vascular Endothelial Growth Factor Receptor Signaling Pathway (GO:0048010)': ['XBP1',
#   'VEGFC',
#   'VEGFD',
#   'SLC31A1',
#   'SULF1',
#   'VAV1',
#   'VAV2',
#   'VEGFA',
#   'DAB2IP',
#   'MAPK14',
#   'PGF',
#   'PTK2',
#   'VEGFB',
#   'MAPKAPK2',
#   'MAPKAPK3',
#   'PRKD1',
#   'PKN2',
#   'PRKD2',
#   'BCAR1',
#   'NRP1',
#   'FLT1',
#   'SRC',
#   'FLT4',
#   'PDCD6',
#   'CLEC14A',
#   'HSPB1',
#   'PTK2B',
#   'KDR',
#   'FYN'],
#  'Vascular Transport (GO:0010232)': ['ABCC4',
#   'ABCC5',
#   'ABCC2',
#   'SLC16A1',
#   'ABCC3',
#   'KCNJ8',
#   'SLC16A2',
#   'ABCC9',
#   'SLC12A2',
#   'ATP1B2',
#   'SLC7A5',
#   'SLC7A8',
#   'SLCO1C1',
#   'ABCC1',
#   'SLC22A8',
#   'SLC28A2',
#   'ABCG2',
#   'ABCB1',
#   'SLC27A1',
#   'LRP2',
#   'SLC1A1',
#   'SLC1A2',
#   'SLC44A1',
#   'SLC1A3',
#   'ATP1A4',
#   'SLC1A4',
#   'SLC1A5',
#   'SLC5A1',
#   'ATP1A2',
#   'LRP3',
#   'SLC5A3',
#   'SLC7A1',
#   'SLC7A2',
#   'SLC5A5',
#   'SLC7A3',
#   'SLC5A6',
#   'FLVCR2',
#   'SLC16A7',
#   'NHERF1',
#   'INSR',
#   'SLC13A3',
#   'SLC15A2',
#   'SLC38A2',
#   'SLC38A1',
#   'SLC6A17',
#   'SLC2A13',
#   'ATP2B4',
#   'SLC16A12',
#   'SLC6A13',
#   'AVPR1A',
#   'SLC2A10',
#   'AVPR1B',
#   'SLC4A8',
#   'SLC6A6',
#   'SLC6A9',
#   'C1D',
#   'SLCO3A1',
#   'SLC27A4',
#   'SLC29A2',
#   'LEPROT',
#   'SLC29A1',
#   'SLC29A4',
#   'SLC22A5',
#   'SLC24A3',
#   'SLC22A1',
#   'ATP8A1',
#   'TFRC',
#   'SLC22A3',
#   'SLC22A2',
#   'SLC2A1',
#   'ATP2A3',
#   'SLC2A3',
#   'SLC2A4',
#   'SLC4A3',
#   'SLC6A1',
#   'AGER',
#   'SLC4A4',
#   'SLC6A20',
#   'SLC8A2',
#   'SLCO2B1',
#   'SLC19A1',
#   'SLC38A3',
#   'MFSD2A',
#   'SLC38A5'],
#  'Vitamin Transport (GO:0051180)': ['CD320',
#   'AMN',
#   'CUBN',
#   'SLC2A11',
#   'CBLIF',
#   'SLC2A14',
#   'SLC52A3',
#   'SLC52A1',
#   'SLC52A2',
#   'SLC2A10',
#   'TCN2',
#   'APOA1',
#   'TCN1',
#   'FOLR3',
#   'FOLR2',
#   'ABCG2',
#   'ABCD4',
#   'SLC27A1',
#   'LRP2',
#   'SLC22A1',
#   'SLC35F3',
#   'SLC46A1',
#   'AFM',
#   'SLC23A1',
#   'SLC2A1',
#   'SLC2A2',
#   'SLC2A3',
#   'SLC2A4',
#   'SLC2A5',
#   'SLC2A6',
#   'SLC2A7',
#   'SLC2A8',
#   'SLC2A9',
#   'SLC5A6',
#   'NPC1L1',
#   'PDPN',
#   'TTPA',
#   'GC',
#   'SLC19A1',
#   'SLC19A2',
#   'SLC19A3'],
#  'Wound Healing (GO:0042060)': ['LACRT',
#   'PDGFRA',
#   'TGFB2',
#   'MYOF',
#   'WNT5A',
#   'CFLAR',
#   'NRG1',
#   'TGFBR1',
#   'DCBLD2',
#   'EREG',
#   'SYTL4',
#   'MMP12',
#   'COL3A1',
#   'JAML',
#   'MYH9',
#   'CHMP4C',
#   'NF1',
#   'CHMP4B',
#   'PLEC',
#   'ARL8B',
#   'SPRR3',
#   'VPS4A',
#   'VPS4B',
#   'PRCP',
#   'EVPL',
#   'CLDN1',
#   'KRT6A',
#   'PPP3CA',
#   'ERBB2',
#   'ERBB3',
#   'TPM1',
#   'SMAD3',
#   'NOG',
#   'ODAM',
#   'DST',
#   'SLC11A1',
#   'FZD7',
#   'WNT7A',
#   'ARHGEF19',
#   'IGF1',
#   'ANO5',
#   'LRG1',
#   'RNASE3',
#   'DSPP',
#   'SYT7',
#   'RNF103-CHMP3',
#   'NACA',
#   'SYT12',
#   'C6ORF89',
#   'CHMP2B',
#   'FGF10',
#   'HPSE',
#   'PKN1',
#   'CHMP2A',
#   'EPPK1',
#   'CHMP7',
#   'ENG',
#   'FGF13',
#   'CHMP5',
#   'CHMP6',
#   'TRIM72',
#   'FUT10',
#   'MACF1',
#   'RAB3A',
#   'ITGB3',
#   'SRF',
#   'MIA3',
#   'PDGFA',
#   'PPL',
#   'FGF1',
#   'GATA4',
#   'INS',
#   'CORO1B',
#   'TSKU',
#   'EPB41L4B',
#   'CHMP1B',
#   'SMPD1',
#   'CHMP1A',
#   'HMOX1',
#   'SCARB1',
#   'MYOZ1'],
#  'Xenobiotic Transport (GO:0042908)': ['ABCC5',
#   'SLC22A4',
#   'ABCB1',
#   'ABCC2',
#   'SLC15A2',
#   'SLC47A1',
#   'ABCC3',
#   'NR1I2',
#   'SLC22A1',
#   'SLC67A1',
#   'SLC22A3',
#   'SLC22A2',
#   'ABCA8',
#   'SLC31A1',
#   'ABCC11',
#   'SLC7A5',
#   'GJA1',
#   'ABCC1',
#   'ABCG2',
#   'SLC29A4'],
#  'Xenobiotic Transport Across Blood-Brain Barrier (GO:1990962)': ['ABCC2',
#   'SLC22A1',
#   'SLC22A2',
#   'ABCC1',
#   'ABCG2']}

# %%
first_key = next(iter(drug_data.keys()))
print(first_key)
# Out:
# Mitotic Spindle

# %%
up = next(iter(drug_data.values()))
print(up)
# Out:
# ['ACTN4', 'PCGF5', 'APC', 'MARCKS', 'NIN', 'KIF20B', 'EPB41', 'STAU1', 'CD2AP', 'UXT', 'PPP4R2', 'CSNK1D', 'RACGAP1', 'CDC27', 'PREX1', 'STK38L', 'ARFIP2', 'PLK1', 'BCR', 'LATS1', 'CCDC88A', 'TPX2', 'BIN1', 'NET1', 'SASS6', 'EZR', 'TRIO', 'ITSN1', 'NUMA1', 'SMC4', 'SMC3', 'ABR', 'EPB41L2', 'CDK5RAP2', 'CEP72', 'KIFAP3', 'CEP192', 'SYNPO', 'RHOF', 'LRPPRC', 'ANLN', 'CENPE', 'CENPF', 'INCENP', 'CENPJ', 'PAFAH1B1', 'ARHGEF2', 'ARHGEF3', 'RAPGEF6', 'KPTN', 'ARHGEF7', 'RAPGEF5', 'RABGAP1', 'KIF11', 'PIF1', 'TOP2A', 'KIF15', 'NEDD9', 'RASAL2', 'BRCA2', 'CNTRL', 'KIF1B', 'SPTBN1', 'CEP57', 'DLGAP5', 'MAP1S', 'SORBS2', 'DYNLL2', 'MYO9B', 'FARP1', 'RANBP9', 'SEPTIN9', 'CLIP2', 'CLIP1', 'CTTN', 'TAOK2', 'LLGL1', 'ARF6', 'DYNC1H1', 'MAPRE1', 'RAB3GAP1', 'ALMS1', 'TUBD1', 'WASL', 'AKAP13', 'PCM1', 'OPHN1', 'NUSAP1', 'RICTOR', 'SPTAN1', 'GSN', 'RALBP1', 'ARHGAP29', 'TSC1', 'ARHGAP27', 'MID1', 'TUBA4A', 'ABI1', 'KIF4A', 'TUBGCP6', 'ARL8A', 'TUBGCP5', 'CNTROB', 'ROCK1', 'GEMIN4', 'AURKA', 'KATNB1', 'FGD4', 'BCL2L11', 'FGD6', 'KIF5B', 'CEP250', 'FLNA', 'CLASP1', 'FLNB', 'KNTC1', 'MYH10', 'PCNT', 'ARHGEF12', 'ARHGEF11', 'KIF22', 'TBCD', 'KIF23', 'CKAP5', 'NDC80', 'SSH2', 'DLG1', 'ARHGAP10', 'CDC42EP4', 'BIRC5', 'CDC42EP2', 'FSCN1', 'MAP3K11', 'CDC42EP1', 'KIF2C', 'VCL', 'DOCK4', 'NOTCH2', 'PXN', 'TUBGCP2', 'TUBGCP3', 'ARHGAP4', 'ARHGAP5', 'CCNB2', 'KIF3C', 'KIF3B', 'NEK2', 'ABL1', 'MARK4', 'SAC3D1', 'SUN2', 'ARFGEF1', 'RFC1', 'ARAP3', 'SHROOM1', 'SHROOM2', 'CDC42BPA', 'SMC1A', 'RASA1', 'HOOK3', 'ESPL1', 'RASA2', 'MYH9', 'CDK1', 'NF1', 'ATG4B', 'DOCK2', 'BCAR1', 'SOS1', 'YWHAE', 'LMNB1', 'KLC1', 'RHOT2', 'CAPZB', 'ECT2', 'WASF1', 'WASF2', 'PDLIM5', 'PLEKHG2', 'DST', 'CEP131', 'MID1IP1', 'KATNA1', 'PRC1', 'TIAM1', 'CDC42', 'MYO1E', 'PALLD', 'ALS2', 'HDAC6', 'TTK', 'PKD2', 'ARHGDIA', 'FBXO5', 'TLK1', 'BUB1', 'CYTH2', 'NCK1', 'NCK2']

# %%
up_present = [gene for gene in up if gene in uk65.index]

# Print counts and summary
print(f"Total up genes in signature: {len(up)}")
print(f"Up genes found in expression data: {len(up_present)}")

# Optionally, print the missing ones
missing_up = set(up) - set(uk65.index)

print(f"Missing up genes: {len(missing_up)}")
# Out:
# Total up genes in signature: 199
# Up genes found in expression data: 199
# Missing up genes: 0

# %%
scored_data = score(up_gene=up, down_gene=False, sample=uk65,
                    norm_method='theoretical', full_data=True)
#getting the scored data for a pathway
total_score = scored_data["total_score"].to_list()[0]
total_score
# Out:
# 0.23076831651160246

# %%
permd = permutate(uk65, n_up=len(up_present), n_down=False)
pvals = empiricalpval(permutations=permd, score=scored_data)
empirical_p_value = pvals["empirical p value"].to_list()[0]
empirical_p_value
# Out:
# 9.999000099990002e-05

# %%
result = {
    f"{first_key}":{
        "gene_set_info": {
            "geneset_size": len(up),
            "geneset_covered_in_sample": len(up_present)
        },
        "scores": {
            "total_singscore": total_score
        },
        "statistics": {
            "p_value": empirical_p_value,
            "method": "permutation (empirical)",
            "permutations": 10000
        }
    }
}
result
# Out:
# {'Mitotic Spindle': {'gene_set_info': {'geneset_size': 199,
#    'geneset_covered_in_sample': 199},
#   'scores': {'total_singscore': 0.23076831651160246},
#   'statistics': {'p_value': 9.999000099990002e-05,
#    'method': 'permutation (empirical)',
#    'permutations': 10000}}}

# %%
import os
from singscore.singscore import *
import pandas as pd
import json
from tqdm import tqdm

## loading the patient uk65 data 
uk65 = pd.read_csv("singscore_new_code/UK65_clean_gene_log_tpm.txt", header='infer', sep='\t')
uk65 = uk65.set_index(keys='GeneName')

#loading drug_data
drug_data = json.load(open("singscore_new_code/Doxorubicin/Doxorubicin_relevant_pathways.json"))
count = len(drug_data)
print("Number of items:", count)

final_result = {}

for key, value in tqdm(drug_data.items(), desc="Calculating pathways"):
    print(f"{key}: {value}")
    up = drug_data[key]
    up_present = [gene for gene in up if gene in uk65.index]

    # Print counts and summary
    print(f"Total up genes in signature: {len(up)}")
    print(f"Up genes found in expression data: {len(up_present)}")

    # Optionally, print the missing ones
    missing_up = set(up) - set(uk65.index)

    print(f"Missing up genes: {len(missing_up)}")
    scored_data = score(up_gene=up, down_gene=False, sample=uk65,
                    norm_method='theoretical', full_data=True)
    #getting the scored data for a pathway
    total_score = scored_data["total_score"].to_list()[0]
    permd = permutate(uk65, n_up=len(up_present), n_down=False)
    pvals = empiricalpval(permutations=permd, score=scored_data)
    empirical_p_value = pvals["empirical p value"].to_list()[0]
    result = {
    f"{key}":{
        "gene_set_info": {
            "geneset_size": len(up),
            "geneset_covered_in_sample": len(up_present)
        },
        "scores": {
            "total_singscore": total_score
        },
        "statistics": {
            "p_value": empirical_p_value,
            "method": "permutation (empirical)",
            "permutations": 10000
        }}}
    final_result.update(result)

# Save final combined JSON
with open("singscore_new_code/Doxorubicin/Doxorubicin_singscore_results.json", "w", encoding="utf-8") as f:
    json.dump(final_result, f, indent=2, ensure_ascii=False)
# Out:
# Calculating pathways:   0%|          | 0/796 [00:00<?, ?it/s]
# Mitotic Spindle: ['ACTN4', 'PCGF5', 'APC', 'MARCKS', 'NIN', 'KIF20B', 'EPB41', 'STAU1', 'CD2AP', 'UXT', 'PPP4R2', 'CSNK1D', 'RACGAP1', 'CDC27', 'PREX1', 'STK38L', 'ARFIP2', 'PLK1', 'BCR', 'LATS1', 'CCDC88A', 'TPX2', 'BIN1', 'NET1', 'SASS6', 'EZR', 'TRIO', 'ITSN1', 'NUMA1', 'SMC4', 'SMC3', 'ABR', 'EPB41L2', 'CDK5RAP2', 'CEP72', 'KIFAP3', 'CEP192', 'SYNPO', 'RHOF', 'LRPPRC', 'ANLN', 'CENPE', 'CENPF', 'INCENP', 'CENPJ', 'PAFAH1B1', 'ARHGEF2', 'ARHGEF3', 'RAPGEF6', 'KPTN', 'ARHGEF7', 'RAPGEF5', 'RABGAP1', 'KIF11', 'PIF1', 'TOP2A', 'KIF15', 'NEDD9', 'RASAL2', 'BRCA2', 'CNTRL', 'KIF1B', 'SPTBN1', 'CEP57', 'DLGAP5', 'MAP1S', 'SORBS2', 'DYNLL2', 'MYO9B', 'FARP1', 'RANBP9', 'SEPTIN9', 'CLIP2', 'CLIP1', 'CTTN', 'TAOK2', 'LLGL1', 'ARF6', 'DYNC1H1', 'MAPRE1', 'RAB3GAP1', 'ALMS1', 'TUBD1', 'WASL', 'AKAP13', 'PCM1', 'OPHN1', 'NUSAP1', 'RICTOR', 'SPTAN1', 'GSN', 'RALBP1', 'ARHGAP29', 'TSC1', 'ARHGAP27', 'MID1', 'TUBA4A', 'ABI1', 'KIF4A', 'TUBGCP6', 'ARL8A', 'TUBGCP5', 'CNTROB', 'ROCK1', 'GEMIN4', 'AURKA', 'KATNB1', 'FGD4', 'BCL2L11', 'FGD6', 'KIF5B', 'CEP250', 'FLNA', 'CLASP1', 'FLNB', 'KNTC1', 'MYH10', 'PCNT', 'ARHGEF12', 'ARHGEF11', 'KIF22', 'TBCD', 'KIF23', 'CKAP5', 'NDC80', 'SSH2', 'DLG1', 'ARHGAP10', 'CDC42EP4', 'BIRC5', 'CDC42EP2', 'FSCN1', 'MAP3K11', 'CDC42EP1', 'KIF2C', 'VCL', 'DOCK4', 'NOTCH2', 'PXN', 'TUBGCP2', 'TUBGCP3', 'ARHGAP4', 'ARHGAP5', 'CCNB2', 'KIF3C', 'KIF3B', 'NEK2', 'ABL1', 'MARK4', 'SAC3D1', 'SUN2', 'ARFGEF1', 'RFC1', 'ARAP3', 'SHROOM1', 'SHROOM2', 'CDC42BPA', 'SMC1A', 'RASA1', 'HOOK3', 'ESPL1', 'RASA2', 'MYH9', 'CDK1', 'NF1', 'ATG4B', 'DOCK2', 'BCAR1', 'SOS1', 'YWHAE', 'LMNB1', 'KLC1', 'RHOT2', 'CAPZB', 'ECT2', 'WASF1', 'WASF2', 'PDLIM5', 'PLEKHG2', 'DST', 'CEP131', 'MID1IP1', 'KATNA1', 'PRC1', 'TIAM1', 'CDC42', 'MYO1E', 'PALLD', 'ALS2', 'HDAC6', 'TTK', 'PKD2', 'ARHGDIA', 'FBXO5', 'TLK1', 'BUB1', 'CYTH2', 'NCK1', 'NCK2']
# Total up genes in signature: 199
# Up genes found in expression data: 199
# Missing up genes: 0
# Calculating pathways:   0%|          | 0/796 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 20
#      18 #getting the scored data for a pathway
#      19 total_score = scored_data["total_score"].to_list()[0]
# ---> 20 permd = permutate(uk65, n_up=len(up_present), n_down=False)
#      21 pvals = empiricalpval(permutations=permd, score=scored_data)
#      22 empirical_p_value = pvals["empirical p value"].to_list()[0]
#
# File d:\GS\PySingscore_replicate\singscore\singscore.py:730, in permutate(sample, n_up, n_down, reps, norm_method, rs_down, centering)
#     727 # permutate
#     728 for r in range(reps):
#     729     # select n_up genes at random
# --> 730     up_gene = numpy.random.choice(sample.index, n_up,
#     731                                   replace=False)
#     732     ru = [] # empty list to append up score to
#     733     # find the rank of the genes
#
# KeyboardInterrupt:
