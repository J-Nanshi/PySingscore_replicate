# %%
# !pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.5-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from statsmodels) (2.2.5)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from statsmodels) (1.15.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from statsmodels) (2.2.3)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\jeet\.conda\envs\gs-dcgpd\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Downloading statsmodels-0.14.5-cp313-cp313-win_amd64.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    -------------------- ------------------- 5.0/9.6 MB 25.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 22.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 22.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 22.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 10.2 MB/s eta 0:00:00
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Installing collected packages: patsy, statsmodels
#
#    ---------------------------------------- 0/2 [patsy]
#    ---------------------------------------- 0/2 [patsy]
#    ---------------------------------------- 0/2 [patsy]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    ---------------------------------------- 2/2 [statsmodels]
#
# Successfully installed patsy-1.0.2 statsmodels-0.14.5

# %% [markdown]
# ## Setting the path to input files

# %%
import os
from singscore.singscore import *

BASE_DIR = os.getcwd()   # current working directory
print(BASE_DIR)

entrez_sample_path = os.path.normpath('{}/{}'.format(BASE_DIR,
                                'singscore/test/test_data/entrez_sample.txt'))

sig_path = os.path.normpath('{}/{}'.format(BASE_DIR,
                                'singscore/test/test_sigs/tgfb_upDown.txt'))
# Out:
# d:\GS\PySingscore_replicate

# %% [markdown]
# ## Reading the data

# %%
data = pandas.read_csv(open(entrez_sample_path, 'r'), header=
'infer', sep='\t')
data = data.set_index(keys='EntrezID')
data
# Out:
#           D_Ctrl_R1  D_TGFb_R1  D_Ctrl_R2  D_TGFb_R2  Hes_Ctrl_R1  \
# EntrezID
# 2          4.449761   4.536331   4.600037   4.515623     4.550698
# 9          7.209661   7.643405   7.115128   7.343871     7.002150
# 10         4.759523   4.692182   4.651241   4.700832     4.798863
# 12         6.605422   5.630332   7.130885   6.432135     5.774363
# 13         5.484495   5.591267   5.450615   5.510995     5.481345
# ...             ...        ...        ...        ...          ...
# 727897     5.662754   5.445969   5.433057   5.159152     5.695544
# 728215     4.562833   5.060502   4.665515   5.077294     5.199263
# 728621     3.887105   3.967852   3.999327   3.986190     3.904852
# 729164     5.550880   5.295511   5.173193   5.182718     5.391617
# 752014     5.517907   5.215606   5.121201   5.107979     5.191096
#
#           Hes_TGFb_R1  Hes_Ctrl_R2  Hes_TGFb_R2  Hil_Ctrl_R1  Hil_Ctrl_R2
# EntrezID
# 2            4.681318     4.434600     4.462480     4.440943     4.516277
# 9            7.508886     7.432266     7.390676     7.026492     7.516390
# 10           4.722866     4.676497     4.600500     4.671553     4.797493
# 12           6.668610     5.973094     7.382852     6.328466     6.328010
# 13           5.372441     5.372441     5.794506     5.571761     5.361441
# ...               ...          ...          ...          ...          ...
# 727897       5.665951     4.747162     5.525359     5.510900     5.345197
# 728215       4.770554     4.759490     4.603406     4.438098     4.724390
# 728621       4.057919     3.886360     4.000872     3.980695     3.822199
# 729164       5.096315     5.466387     5.251477     5.319442     5.078190
# 752014       5.337286     5.099750     5.263531     5.219676     5.158507
#
# [11900 rows x 10 columns]

# %% [markdown]
# # prepare signatures

# %% [markdown]
# ### seperating the aanotated up and downregulated genes

# %%
sigs = pandas.read_csv(open(sig_path, 'r'), header=
'infer', sep='\t')
sigs
# Out:
#      EntrezID    Symbol upDown_integrative_signature  \
# 0          19     ABCA1                            0
# 1          87     ACTN1                            0
# 2         136   ADORA2B                            0
# 3         182      JAG1                           up
# 4         220   ALDH1A3                         down
# ..        ...       ...                          ...
# 296    161291   TMEM30B                         down
# 297    221749  C6orf145                            0
# 298    347902    AMIGO2                            0
# 299    389136     VGLL3                           up
# 300    402055      SRRD                            0
#
#     upDown_comparative_signature upDown
# 0                             up     up
# 1                             up     up
# 2                           down   down
# 3                             up     up
# 4                              0   down
# ..                           ...    ...
# 296                            0   down
# 297                           up     up
# 298                           up     up
# 299                            0     up
# 300                           up     up
#
# [301 rows x 5 columns]

# %%
# subset the data for up and down
up = sigs[sigs['upDown'] == 'up']
down = sigs[sigs['upDown'] == 'down']
up
# Out:
#      EntrezID    Symbol upDown_integrative_signature  \
# 0          19     ABCA1                            0
# 1          87     ACTN1                            0
# 3         182      JAG1                           up
# 6         241   ALOX5AP                           up
# 8         323     APBB2                            0
# ..        ...       ...                          ...
# 295    150094      SIK1                            0
# 297    221749  C6orf145                            0
# 298    347902    AMIGO2                            0
# 299    389136     VGLL3                           up
# 300    402055      SRRD                            0
#
#     upDown_comparative_signature upDown
# 0                             up     up
# 1                             up     up
# 3                             up     up
# 6                             up     up
# 8                             up     up
# ..                           ...    ...
# 295                           up     up
# 297                           up     up
# 298                           up     up
# 299                            0     up
# 300                           up     up
#
# [193 rows x 5 columns]

# %%
# get a list of ids
up = list(up['EntrezID'])
down = list(down['EntrezID'])
up
# Out:
# [19,
#  87,
#  182,
#  241,
#  323,
#  406,
#  649,
#  650,
#  659,
#  669,
#  800,
#  860,
#  966,
#  1000,
#  1009,
#  1277,
#  1281,
#  1282,
#  1284,
#  1289,
#  1290,
#  1293,
#  1294,
#  1462,
#  1490,
#  1836,
#  2004,
#  2009,
#  2048,
#  2114,
#  2200,
#  2297,
#  2335,
#  2791,
#  2887,
#  3162,
#  3269,
#  3488,
#  3490,
#  3589,
#  3624,
#  3678,
#  3690,
#  3720,
#  3725,
#  3726,
#  3772,
#  3778,
#  3918,
#  4015,
#  4060,
#  4092,
#  4094,
#  4148,
#  4237,
#  4312,
#  4313,
#  4318,
#  4319,
#  4330,
#  4616,
#  4651,
#  4688,
#  4739,
#  4824,
#  4907,
#  5054,
#  5154,
#  5218,
#  5270,
#  5293,
#  5329,
#  5420,
#  5654,
#  5708,
#  5744,
#  5796,
#  5898,
#  5999,
#  6447,
#  6498,
#  6578,
#  6583,
#  6588,
#  6591,
#  6678,
#  6695,
#  6781,
#  6876,
#  6925,
#  6926,
#  7040,
#  7041,
#  7045,
#  7052,
#  7057,
#  7077,
#  7130,
#  7145,
#  7168,
#  7171,
#  7277,
#  7286,
#  7424,
#  7431,
#  7474,
#  7846,
#  7857,
#  7980,
#  8038,
#  8091,
#  8406,
#  8407,
#  8459,
#  8460,
#  8553,
#  8609,
#  8682,
#  8728,
#  8821,
#  8877,
#  8905,
#  9244,
#  9260,
#  9267,
#  9315,
#  9540,
#  9645,
#  9732,
#  9891,
#  9902,
#  9945,
#  9953,
#  9955,
#  10000,
#  10202,
#  10272,
#  10395,
#  10398,
#  10512,
#  10631,
#  10916,
#  10979,
#  11010,
#  11015,
#  11077,
#  11099,
#  11174,
#  11221,
#  22891,
#  23002,
#  23022,
#  23023,
#  23141,
#  23180,
#  26278,
#  26499,
#  26585,
#  29931,
#  29940,
#  29995,
#  50515,
#  51083,
#  51129,
#  51313,
#  51339,
#  54908,
#  55022,
#  55323,
#  55568,
#  55584,
#  55701,
#  55738,
#  56034,
#  56675,
#  56937,
#  57007,
#  64131,
#  64750,
#  79669,
#  79899,
#  80206,
#  81029,
#  81606,
#  81631,
#  85458,
#  92689,
#  129642,
#  150094,
#  221749,
#  347902,
#  389136,
#  402055]

# %% [markdown]
# # Scoring the genes

# %%
scored_data = score(up_gene=up, down_gene=down, sample=data,
                    norm_method='theoretical', full_data=True)
print(scored_data)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\GS\PySingscore_replicate\singscore\singscore.py", line 287, in score
#     # data = data.append(temp_df)
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\site-packages\pandas\core\generic.py", line 6299, in __getattr__
#     return object.__getattribute__(self, name)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# AttributeError: 'DataFrame' object has no attribute 'append'. Did you mean: '_append'?
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\logging\__init__.py", line 472, in format
#     return self._format(record)
#            ~~~~~~~~~~~~^^^^^^^^
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\logging\__init__.py", line 468, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'messages'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\logging\__init__.py", line 715, in format
#     s = self.formatMessage(record)
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\logging\__init__.py", line 684, in formatMessage
#     return self._style.format(record)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\logging\__init__.py", line 474, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'messages'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\site-packages\IPython\core\interactiveshell.py", line 3153, in _run_cell
#     result = runner(coro)
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\site-packages\IPython\core\interactiveshell.py", line 3362, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\site-packages\IPython\core\interactiveshell.py", line 3607, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\site-packages\IPython\core\interactiveshell.py", line 3667, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Jeet\AppData\Local\Temp\ipykernel_5044\1656833619.py", line 1, in <module>
#     scored_data = score(up_gene=up, down_gene=down, sample=data,
#   File "d:\GS\PySingscore_replicate\singscore\singscore.py", line 291, in score
#     except:
# Message: 'The gene identifiers are not of the same type.'
# Arguments: ()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\GS\PySingscore_replicate\singscore\singscore.py in ?(up_gene, sample, down_gene, norm_method, norm_down, full_data, centering)
#     290
#     291     except:
# --> 292         logger.exception('The gene identifiers are not of the same type.')
#     293         raise  InvalidIDType
#
# c:\Users\Jeet\.conda\envs\gs-dcgpd\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'
#
# During handling of the above exception, another exception occurred:
#
# InvalidIDType                             Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 scored_data = score(up_gene=up, down_gene=down, sample=data,
#       2                     norm_method='theoretical', full_data=True)
#       3 print(scored_data)
#
# File d:\GS\PySingscore_replicate\singscore\singscore.py:292, in score(up_gene, sample, down_gene, norm_method, norm_down, full_data, centering)
#     290 except:
#     291     logger.exception('The gene identifiers are not of the same type.')
# --> 292     raise  InvalidIDType
#
# InvalidIDType:
